# %%
import pandas as pd

# %%
CLINVAR_FILEPATH = "../other/gene_condition_source_id.txt"

# %%
df = pd.read_table(CLINVAR_FILEPATH)
df
# Out:
#       #GeneID AssociatedGenes RelatedGenes ConceptID  \
# 0           2             A2M          NaN  C0002395
# 1      144568           A2ML1          NaN  C1833692
# 2       53947          A4GALT          NaN  C3549485
# 3        8086            AAAS          NaN  C0271742
# 4       79719           AAGAB          NaN  C1835662
# ...       ...             ...          ...       ...
# 9547   346171             NaN        ZFP57  C0158981
# 9548     7546             NaN         ZIC2  C0079541
# 9549    51364             NaN      ZMYND10  C0008780
# 9550    63925             NaN       ZNF335  C3711387
# 9551   130557             NaN       ZNF513  C0035334
#
#                                    DiseaseName                SourceName  \
# 0                            Alzheimer disease  Human Phenotype Ontology
# 1              Otitis media, susceptibility to             NCBI curation
# 2                                  p phenotype             NCBI curation
# ...

# %%
df.isnull().sum()
# Out:
# #GeneID               0
# AssociatedGenes    2621
# RelatedGenes       6931
# ConceptID             6
# DiseaseName           0
# SourceName          919
# SourceID           6451
# DiseaseMIM         2787
# LastUpdated           0
# dtype: int64

# %%
df["gene"] = df.apply(lambda row: row.AssociatedGenes if (not pd.isna(row.AssociatedGenes)) else row.RelatedGenes, axis=1)
df
# Out:
#       #GeneID AssociatedGenes RelatedGenes ConceptID  \
# 0           2             A2M          NaN  C0002395
# 1      144568           A2ML1          NaN  C1833692
# 2       53947          A4GALT          NaN  C3549485
# 3        8086            AAAS          NaN  C0271742
# 4       79719           AAGAB          NaN  C1835662
# ...       ...             ...          ...       ...
# 9547   346171             NaN        ZFP57  C0158981
# 9548     7546             NaN         ZIC2  C0079541
# 9549    51364             NaN      ZMYND10  C0008780
# 9550    63925             NaN       ZNF335  C3711387
# 9551   130557             NaN       ZNF513  C0035334
#
#                                    DiseaseName                SourceName  \
# 0                            Alzheimer disease  Human Phenotype Ontology
# 1              Otitis media, susceptibility to             NCBI curation
# 2                                  p phenotype             NCBI curation
# ...

# %%
df.isnull().sum()
# Out:
# #GeneID               0
# AssociatedGenes    2621
# RelatedGenes       6931
# ConceptID             6
# DiseaseName           0
# SourceName          919
# SourceID           6451
# DiseaseMIM         2787
# LastUpdated           0
# gene                  0
# dtype: int64

# %%
df = df[["gene","DiseaseName"]]
df.columns = ["gene", "disease"]
df.to_csv("../genes_and_diseases.tsv", sep="\t", index=False)
df.head(10)
# Out:
#      gene                                            disease
# 0     A2M                                  Alzheimer disease
# 1   A2ML1                    Otitis media, susceptibility to
# 2  A4GALT                                        p phenotype
# 3    AAAS           Glucocorticoid deficiency with achalasia
# 4   AAGAB                  Keratosis palmoplantaris papulosa
# 5   AARS1      Epileptic encephalopathy, early infantile, 29
# 6   AARS1               Charcot-Marie-Tooth disease, type 2N
# 7   AARS2    Combined oxidative phosphorylation deficiency 8
# 8   AARS2  Leukoencephalopathy, progressive, with ovarian...
# 9    AASS                                     Hyperlysinemia
