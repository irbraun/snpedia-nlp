# %% [markdown]
# ## Parsing Survey Results
# This notebook produces the intended datasets by looking at the original files of text and relationships scraped from SNPedia and the results of the survey in order to construct the relationships between genes, SNPs, and different types of text snippets or context sentences. This notebook also deals with looking at how much of the dataset was covered by a given set of results from the survey.

# %%
import pandas as pd
import numpy as np
import json
import math
import random
import datetime
import re
from collections import Counter
from utils import flatten
from nltk.tokenize import sent_tokenize

# %% [markdown]
# ### Defining paths to input files
# These first two files should always stay the same, the first one defines the project-wide mapping between unique strings and IDs. The second one is the starting dataset of the text that was scraped and cleaned from SNPedia, so changing that would impact everything else downstream in the creation of the dataset. The paths to the Qualtrics results files can be changed though, and all the output files will be with respect to just those results. Running with different result sets should produce individual files that could be stacked after the fact.

# %%
# This is the original data with duplicate text strings because IDs refer to particular SNPs from particular genes.
ORIGINAL_DATA_PATH = "../data/3_snps_and_cleaned_text_with_ids.csv"

# What the survey was built from, the IDs in this refer to unique text strings so that duplicates weren't part of it.
SURVEY_SOURCE_DATA_PATH = "../data/6_part_1_binned_and_blocked_texts.csv"

# JSON file from parsing the results of the qualtrics survey designed for extracting phenotypes from text.
QUALTRICS_RAW_CSV_EXPORT_PATH = "../qualtrics/results_raw_qualtrics_exports_v1/SNPedia_Survey_September_24_2020_22_24_Completed_and_In_Progress.csv"
QUALTRICS_RESULTS_JSON_PATH = "../qualtrics/results_processed_json_files_v1/snpedia_survey_september_24_2020_h22_m24_completed_and_in_progress.json"

# %% [markdown]
# ### Defining paths to output files
# These should be left alone, they'll be named automatically according to when they were run and will be grouped.

# %%
# Where to send the resulting output dataframes and some other information about coverage.
random_six_digit_number = random.randrange(100000,999999)
datetime_str = datetime.datetime.now().strftime('%m_%d_%Y_h%Hm%Ms%S')
FILENAMES_OUTPUT_PATH = "../data/S{}_input_file_paths_{}.txt".format(random_six_digit_number, datetime_str)
RESPONSES_OUTPUT_PATH = "../data/S{}_processed_survey_responses_{}.csv".format(random_six_digit_number, datetime_str)
SURVEY_TAKERS_OUTPUT_PATH = "../data/S{}_processed_survey_takers_{}.csv".format(random_six_digit_number, datetime_str)
SNPS_AND_SNIPPETS_OUTPUT_PATH = "../data/S{}_snps_and_snippets_{}.csv".format(random_six_digit_number, datetime_str)
SNPS_AND_CONTEXTS_OUTPUT_PATH = "../data/S{}_snps_and_contexts_{}.csv".format(random_six_digit_number, datetime_str)
NUM_ANNOTATIONS_PATH = "../data/S{}_number_of_annotations_per_id_{}.csv".format(random_six_digit_number, datetime_str)

# %%
# Create an output file that makes a not of which input files were used for these results.
with open(FILENAMES_OUTPUT_PATH, "w") as f:
    filenames = [
        ORIGINAL_DATA_PATH,
        SURVEY_SOURCE_DATA_PATH,
        QUALTRICS_RAW_CSV_EXPORT_PATH,
        QUALTRICS_RESULTS_JSON_PATH]
    filenames = "\n".join(filenames)
    f.write(filenames)

# %%
# Make sure the mapping between the unique texts used to create the survey and the original SNP data exists.
original_df = pd.read_csv(ORIGINAL_DATA_PATH)
#survey_df = pd.read_csv(SURVEY_SOURCE_DATA_PATH)
#text_to_unique_text_id = dict(zip(survey_df.text, survey_df.id))
#unique_text_id_to_text = dict(zip(survey_df.id, survey_df.text))
#original_df["id"] = original_df["text"].map(text_to_unique_text_id)

id_to_unique_text = dict(zip(original_df["id"].values, original_df["text"].values))


original_df.head(20)
# Out:
#       gene         snp                                               text  id
# 0    AANAT  Rs28936679  rs28936679, also known as Ala129Thr or A129T (...   1
# 1    AANAT   Rs3760138  Genetic differences in human circadian clock g...   2
# 2    AANAT   Rs4238989  Genetic differences in human circadian clock g...   3
# 3    ABCA1   Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...   4
# 4    ABCA1   Rs1883025  Apolipoprotein E levels in cerebrospinal fluid...   5
# 5    ABCA1   Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 6    ABCA1   Rs2066714  Apolipoprotein E levels in cerebrospinal fluid...   7
# 7    ABCA1   Rs2066715  Apolipoprotein E levels in cerebrospinal fluid...   8
# 8    ABCA1   Rs2230806  rs2230806, also known as Arg219Lys or R219K, i...   9
# 9    ABCA1   Rs2230808  rs2297404, rs2230808, and rs2020927 haplotype ...  10
# 10   ABCA1   Rs2297404  rs2297404, rs2230808, and rs2020927 haplotype ...  11
# 11   ABCA1    Rs363717  Examining the effect of linkage disequilibrium...  12
# 12   ABCA1   Rs4149268  G allele is associated with 0.82mg/dl increase...  13
# 13   ABCA1   Rs4149274  C allele is associated with 1.51mg/dl increase...  14
# 14  ABCA12  Rs28940268  This is a recessive SNP for congenital Lamella...  15
# 15  ABCA12  Rs28940269  This is a recessive SNP for congenital Lamella...  15
# 16  ABCA12  Rs28940270  This is a recessive SNP for congenital Lamella...  15
# 17  ABCA12  Rs28940271  This is a recessive SNP for congenital Lamella...  15
# 18  ABCA12  Rs28940568  This is a recessive SNP for congenital Lamella...  15
# 19  ABCA12    Rs726070  aka c.7093G>A (p.Asp2365Asn)The variant allele...  16

# %%
original_df.isnull().sum(axis = 0)
# Out:
# gene    0
# snp     0
# text    0
# id      0
# dtype: int64

# %%
original_df.shape
# Out:
# (6535, 4)

# %%
# Create a dictionary using the JSON data output from a qualtrics survey.
with open(QUALTRICS_RESULTS_JSON_PATH) as f:
    responses = json.load(f)
responses
# Out:
# [{'response_id': 'R_eOSosrnczqYqE9P',
#   'recorded_datetime': '9/22/20 10:37',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 1252,
#   'hilights': [{'qid': 4769, 'selection': 'Disease ', 'selection_index': 13},
#    {'qid': 5162,
#     'selection': 'Focal segmental glomerulosclerosis',
#     'selection_index': 0},
#    {'qid': 2451, 'selection': ' Alpha Thalassemia', 'selection_index': 23},
#    {'qid': 3964,
#     'selection': 'Congenital Disorder of Glycosylation',
#     'selection_index': 0},
#    {'qid': 5448, 'selection': 'schizophrenia.', 'selection_index': 54},
#    {'qid': 3027, 'selection': 'glaucoma', 'selection_index': 29},
#    {'qid': 2287,
#     'selection': 'Nonsyndromic Sensorineural',
#     'selection_index': 33},
#    {'qid': 2287, 'selection': 'Connexin', 'selection_index': 13},
#    {'qid': 1783, 'selection': 'schizophrenia', 'selection_index': 10},
#    {'qid': 628, 'selection': 'cholesterol', 'selection_index': 4},
#    {'qid': 628, 'selection': 'cholesterol', 'selection_index': 26},
#    {'qid': 628, 'selection': 'LDL ', 'selection_index': 0},
#    {'qid': 2515, 'selection': 'hemochromatosis', 'selection_index': 0},
#    {'qid': 3684, 'selection': 'Rheumatoid Arthritis', 'selection_index': 38},
#    {'qid': 4613, 'selection': 'rheumatoid arthritis', 'selection_index': 39},
#    {'qid': 2261, 'selection': 'cyclohydrolase', 'selection_index': 4},
#    {'qid': 2261, 'selection': 'tetrahydrobiopterin', 'selection_index': 23},
#    {'qid': 2215, 'selection': "Gaucher's disease", 'selection_index': 73},
#    {'qid': 2255, 'selection': 'Vasoocclusive Pain', 'selection_index': 51},
#    {'qid': 2255,
#     'selection': 'Impaired Vascular Function in Sickle Cell Anemia',
#     'selection_index': 74},
#    {'qid': 3271, 'selection': 'allopurinol.', 'selection_index': 87},
#    {'qid': 3271, 'selection': 'allele', 'selection_index': 11},
#    {'qid': 1380, 'selection': 'allele', 'selection_index': 83},
#    {'qid': 1840, 'selection': 'Hemophilia', 'selection_index': 78},
#    {'qid': 4559,
#     'selection': 'Lymphoproliferative syndrome',
#     'selection_index': 59},
#    {'qid': 2620, 'selection': 'chromosome 1', 'selection_index': 109},
#    {'qid': 838, 'selection': 'bronchial asthma', 'selection_index': 84},
#    {'qid': 2187, 'selection': 'Krabbe disease', 'selection_index': 73},
#    {'qid': 762, 'selection': 'breast cancer', 'selection_index': 128},
#    {'qid': 3780, 'selection': 'spitoonObesity', 'selection_index': 123},
#    {'qid': 730, 'selection': 'breast cancer', 'selection_index': 126},
#    {'qid': 4644, 'selection': 'Pendred Syndrome', 'selection_index': 142},
#    {'qid': 22, 'selection': "Alzheimer's disease", 'selection_index': 0},
#    {'qid': 5194, 'selection': 'Asthenozoospermia', 'selection_index': 157},
#    {'qid': 5015, 'selection': 'Polymorphisms', 'selection_index': 0},
#    {'qid': 5015, 'selection': ' breast cancer', 'selection_index': 69},
#    {'qid': 5015, 'selection': 'polymorphism', 'selection_index': 124},
#    {'qid': 5015,
#     'selection': 'thoracic adolescent idiopathic scoliosis.',
#     'selection_index': 216},
#    {'qid': 2023, 'selection': "Friedreich's ataxia", 'selection_index': 143},
#    {'qid': 2260, 'selection': 'capsaicin pain', 'selection_index': 219},
#    {'qid': 2260, 'selection': 'Polymorphisms', 'selection_index': 136},
#    {'qid': 2039, 'selection': "Friedreich's ataxia", 'selection_index': 154},
#    {'qid': 569, 'selection': 'rheumatic diseases', 'selection_index': 138},
#    {'qid': 1355, 'selection': 'breast cancer', 'selection_index': 18},
#    {'qid': 2793, 'selection': 'diabetes', 'selection_index': 148},
#    {'qid': 2568,
#     'selection': 'intermittent porphyria.',
#     'selection_index': 221},
#    {'qid': 3797, 'selection': ' type-2 diabetes', 'selection_index': 66},
#    {'qid': 3965, 'selection': 'Congenital disorder', 'selection_index': 186},
#    {'qid': 2512, 'selection': 'Tay Sachs', 'selection_index': 62},
#    {'qid': 5107, 'selection': 'torsion dystonia', 'selection_index': 191},
#    {'qid': 2919, 'selection': 'priapism', 'selection_index': 160},
#    {'qid': 3533, 'selection': 'Crohn disease', 'selection_index': 50},
#    {'qid': 3367, 'selection': 'abetalipoproteinemia', 'selection_index': 182},
#    {'qid': 3979, 'selection': 'endometrial cancer', 'selection_index': 369},
#    {'qid': 3979, 'selection': 'colorectal cancer', 'selection_index': 249},
#    {'qid': 858, 'selection': 'hypertension', 'selection_index': 169},
#    {'qid': 289, 'selection': 'breast cancer', 'selection_index': 184},
#    {'qid': 3836, 'selection': 'endometrial cancer', 'selection_index': 49},
#    {'qid': 3836, 'selection': 'breast cancer risk', 'selection_index': 623},
#    {'qid': 5430,
#     'selection': 'epithelial ovarian cancer',
#     'selection_index': 356},
#    {'qid': 2853, 'selection': 'cardiac arrhythmias', 'selection_index': 257},
#    {'qid': 2375, 'selection': 'stuttering', 'selection_index': 197},
#    {'qid': 4594, 'selection': 'Andermann syndrome', 'selection_index': 192},
#    {'qid': 3078, 'selection': " Raynaud's phenomenon", 'selection_index': 390},
#    {'qid': 1276,
#     'selection': 'Schizophrenia Susceptibility Genetic',
#     'selection_index': 555},
#    {'qid': 3985,
#     'selection': 'cumulative risk of developing CRC',
#     'selection_index': 415},
#    {'qid': 4718,
#     'selection': 'Association of serotonin transporter gene variation with smoking, chronic obstructive pulmonary disease, and its depressive symptoms',
#     'selection_index': 782},
#    {'qid': 3551, 'selection': 'lung cancer.', 'selection_index': 1379},
#    {'qid': 3551,
#     'selection': 'rinary bladder cancer pathogenesis',
#     'selection_index': 1741},
#    {'qid': 3551,
#     'selection': 'diabetes-associated combination of SNPs',
#     'selection_index': 1047},
#    {'qid': 3551,
#     'selection': 'synthase gene polymorphisms and prostate cancer risk.',
#     'selection_index': 866},
#    {'qid': 3551, 'selection': "Parkinson's disease", 'selection_index': 607},
#    {'qid': 5031, 'selection': 'leukemia', 'selection_index': 1476},
#    {'qid': 5031, 'selection': 'prostate cancer', 'selection_index': 576},
#    {'qid': 83, 'selection': 'heterozygotes', 'selection_index': 834},
#    {'qid': 83, 'selection': 'Atherosclerosis Risk', 'selection_index': 500},
#    {'qid': 4475,
#     'selection': 'chronic liver disease',
#     'selection_index': 1082},
#    {'qid': 4475,
#     'selection': 'Granulomatosis with Polyangiitis',
#     'selection_index': 615},
#    {'qid': 4475,
#     'selection': 'emphysema and liver disease.',
#     'selection_index': 333},
#    {'qid': 2840, 'selection': 'Bipolar Disorder', 'selection_index': 2613},
#    {'qid': 2840,
#     'selection': 'Autism-spectrum disorders',
#     'selection_index': 1769},
#    {'qid': 2840, 'selection': 'depressive disorder.', 'selection_index': 3235},
#    {'qid': 2840,
#     'selection': 'major depressive disorder',
#     'selection_index': 3423},
#    {'qid': 2840, 'selection': 'psychiatric illness,', 'selection_index': 1012},
#    {'qid': 2759, 'selection': "Crohn's disease", 'selection_index': 221},
#    {'qid': 2759, 'selection': "Crohn's Disease", 'selection_index': 540},
#    {'qid': 1158, 'selection': 'lung cancer', 'selection_index': 903},
#    {'qid': 1158, 'selection': 'Artery Disease', 'selection_index': 1927},
#    {'qid': 2475,
#     'selection': 'argely unexplained difference is the level of circulating virus in the plasma during the non-symptomatic phase preceding progression to AIDS.',
#     'selection_index': 1073},
#    {'qid': 2475,
#     'selection': 'This SNP is thought to be involved in determining the HIV viral load set point during the asymptomatic period of infection.',
#     'selection_index': 715},
#    {'qid': 2475,
#     'selection': 'This HLA allele, in turn, has been associated with several conditions',
#     'selection_index': 251},
#    {'qid': 28,
#     'selection': 'Polymorphisms in genes that regulate cyclosporine metabolism affect cyclosporine blood levels and clinical outcomes in patients who receive allogeneic hematopoietic stem cell transplantation.',
#     'selection_index': 6612},
#    {'qid': 28, 'selection': 'esophageal cancer.', 'selection_index': 5791},
#    {'qid': 28,
#     'selection': ' Pharmacogenetics of antidepressant response. Correlation between genetic polymorphisms',
#     'selection_index': 5465},
#    {'qid': 28,
#     'selection': 'rs1045642, also known as C3435T, is a SNP located in the ABCB1 gene. It is often studied in conjunction with rs2032582. C3435T has been mentioned by: A "Silent" Polymorphism in the MDR1 Gene Changes Substrate Specificity (for example, to verapamil) (R)-lansoprazole (Prevacid) concentrations are significantly increased in CYP2C19 extensive metabolizers with ABCB1 C3435T C allele. In a Korean population, plasma concentrations of fexofenadine (Allegra) were 17% lower in 2677AA/3435CC subjects and 47% higher in the 2677TT/3435TT subjects compared to 2677GG/3435CC subjects. In contrast, in this study no association was observed between the C3435T polymorphism and fexofenadine plasma or urine concentrations in a German Caucasian population. A meta-analysis including 9 case-control studies (totaling ~2,500 patients) found no association between rs1045642 and epilepsy riskA study of 98 methadone-maintaining patients concluded that the higher (>150 mg/day) and lower (< or =150 mg/day) methadone dose groups differed significantly in their rs1128503 status (experiment-wise p = 0.0325). Furthermore, individuals with the 3-locus genotype pattern (T;T)-(T;T)-(T;T) for SNPs rs1045642, rs2032582 and rs1128503, respectively, had an approximately 5-fold chance of requiring the \'higher\' methadone dose, while individuals heterozygous for these three SNPs have an approximately 3-fold chance of stabilizing at the \'lower\' methadone dose (point-wise p-value = 0.026). Identifying candidate causal variants responsible for altered activity of the ABCB1 multidrug resistance gene. Genetic predictors of the maximum doses patients receive during clinical use of the anti-epileptic drugs carbamazepine and phenytoin. ABCB1 genotypes and haplotypes in patients with dementia and age-matched non-demented control patients. Association of MDR1 genotypes with susceptibility to colorectal cancer in older non-smokers. Genetic studies of a cluster of acute lymphoblastic leukemia cases in Churchill County, Nevada. MDR1 gene variants, indoor insecticide exposure, and the risk of childhood acute lymphoblastic leukemia. No association between MDR1 (ABCB1) 2677G>T and 3435C>T polymorphism and sporadic colorectal cancer among Bulgarian patients. ABCB1 (MDR1) gene polymorphisms are associated with the clinical response to paroxetine in patients with major depressive disorder. Pharmacogenetics of minimal residual disease response in children with B-precursor acute lymphoblastic leukemia: a report from the Children\'s Oncology Group. Multiplexed genotyping of ABC transporter polymorphisms with the Bioplex suspension array. A PAI-1 (SERPINE1) polymorphism predicts osteonecrosis in children with acute lymphoblastic leukemia: a report from the Children\'s Oncology Group. Association of ABCB1 genetic variants with renal function in Africans and in Caucasians. Genotyping panel for assessing response to cancer chemotherapy. Polymorphisms affecting gene transcription and mRNA processing in pharmacogenetic candidate genes: detection through allelic expression imbalance in human target tissues. Bidirectional translational research: Progress in understanding addictive diseases. The pharmacokinetics and pharmacogenomics of efavirenz and lopinavir/ritonavir in HIV-infected persons requiring hemodialysis. No association of ABCB1 polymorphisms with drug-refractory epilepsy in a north Indian population. Germline genetic variations in drug action pathways predict clinical outcomes in advanced lung cancer treated with platinum-based chemotherapy. Prevalence in the United States of selected candidate gene variants: Third National Health and Nutrition Examination Survey, 1991-1994. Opiate and cocaine addiction: from bench to clinic and back to the bench. Investigation of candidate polymorphisms and disease activity in rheumatoid arthritis patients on methotrexate. Steroid biosynthesis and renal excretion in human essential hypertension: association with blood pressure and en ...
#     'selection_index': 0},
#    {'qid': 28, 'selection': 'arthritis', 'selection_index': 3838}]},
#  {'response_id': 'R_2XjJU6SMJAlU4I2',
#   'recorded_datetime': '9/22/20 10:40',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 1074,
#   'hilights': [{'qid': 4622, 'selection': 'Skin color', 'selection_index': 0},
#    {'qid': 5199, 'selection': 'cardiac amyloidosis', 'selection_index': 12},
#    {'qid': 162,
#     'selection': "Alzheimer's disease assocation",
#     'selection_index': 10},
#    {'qid': 5160,
#     'selection': 'Focal segmental glomerulosclerosis',
#     'selection_index': 0},
#    {'qid': 5083, 'selection': 'dilated cardiomyopathy', 'selection_index': 11},
#    {'qid': 2151, 'selection': "Alzheimer's risk", 'selection_index': 20},
#    {'qid': 4923, 'selection': 'Leigh syndrome', 'selection_index': 0},
#    {'qid': 5133,
#     'selection': 'dilated cardiomyopathy.',
#     'selection_index': 81},
#    {'qid': 1766, 'selection': 'arterial calcification', 'selection_index': 56},
#    {'qid': 1766,
#     'selection': 'hypophosphatemic rickets',
#     'selection_index': 114},
#    {'qid': 75, 'selection': 'adrenoleukodystrophy', 'selection_index': 69},
#    {'qid': 3536,
#     'selection': 'inflammatory bowel disease',
#     'selection_index': 67},
#    {'qid': 4558,
#     'selection': 'Lymphoproliferative syndrome',
#     'selection_index': 60},
#    {'qid': 15,
#     'selection': 'congenital Lamellar ichthyosis',
#     'selection_index': 28},
#    {'qid': 15, 'selection': 'skin condition', 'selection_index': 109},
#    {'qid': 4534, 'selection': 'schizophrenia', 'selection_index': 61},
#    {'qid': 4534,
#     'selection': 'developmental disorders',
#     'selection_index': 79},
#    {'qid': 2685, 'selection': 'obesity', 'selection_index': 42},
#    {'qid': 2685, 'selection': 'insulin sensitivity', 'selection_index': 17},
#    {'qid': 3011,
#     'selection': 'Elevated HDL-Cholesterol',
#     'selection_index': 37},
#    {'qid': 983,
#     'selection': 'pathogenic rare mutation',
#     'selection_index': 73},
#    {'qid': 983,
#     'selection': 'hereditary diffuse gastric cancer',
#     'selection_index': 102},
#    {'qid': 2346, 'selection': 'fabry disease', 'selection_index': 14},
#    {'qid': 2346,
#     'selection': 'hypertrophic cardiomyopathy',
#     'selection_index': 71},
#    {'qid': 2346, 'selection': 'mental retardation', 'selection_index': 178},
#    {'qid': 1965,
#     'selection': 'glomerulopathy with fibronectin deposits',
#     'selection_index': 92},
#    {'qid': 5223, 'selection': 'gastric cancer.', 'selection_index': 183},
#    {'qid': 5223, 'selection': 'Polymorphisms', 'selection_index': 108},
#    {'qid': 385, 'selection': 'longevity', 'selection_index': 27},
#    {'qid': 1283, 'selection': 'hearing loss', 'selection_index': 136},
#    {'qid': 1283, 'selection': 'Cisplatin', 'selection_index': 185},
#    {'qid': 1762,
#     'selection': 'intracranial aneurysms',
#     'selection_index': 115},
#    {'qid': 3360,
#     'selection': 'single nucleotide polymorphisms',
#     'selection_index': 18},
#    {'qid': 3360, 'selection': 'prostate cancer risk', 'selection_index': 86},
#    {'qid': 3360,
#     'selection': 'pseudoexfoliation syndrome',
#     'selection_index': 183},
#    {'qid': 3360, 'selection': 'glaucoma', 'selection_index': 214},
#    {'qid': 1505, 'selection': 'myocardial infarction', 'selection_index': 114},
#    {'qid': 5174,
#     'selection': 'progressive familial heart block',
#     'selection_index': 172},
#    {'qid': 2753,
#     'selection': 'ankylosing spondylitis',
#     'selection_index': 143},
#    {'qid': 3874,
#     'selection': 'utosomal dominant polycystic kidney disease',
#     'selection_index': 146},
#    {'qid': 3868, 'selection': 'talipes equinovarus', 'selection_index': 170},
#    {'qid': 2568,
#     'selection': 'acute intermittent porphyria',
#     'selection_index': 215},
#    {'qid': 1917, 'selection': 'achondroplasia', 'selection_index': 184},
#    {'qid': 2048, 'selection': "Friedreich's ataxia", 'selection_index': 142},
#    {'qid': 1735,
#     'selection': 'pulmonary hypertension',
#     'selection_index': 163},
#    {'qid': 1735,
#     'selection': 'pulmonary capillary hemangiomatosis',
#     'selection_index': 201},
#    {'qid': 1735,
#     'selection': 'pulmonary venoocclusive disease',
#     'selection_index': 247},
#    {'qid': 2920, 'selection': 'priapism', 'selection_index': 160},
#    {'qid': 5107,
#     'selection': 'developing torsion dystonia',
#     'selection_index': 180},
#    {'qid': 4655, 'selection': 'type-2 diabetes', 'selection_index': 40},
#    {'qid': 3002,
#     'selection': 'familial male precocious puberty',
#     'selection_index': 127},
#    {'qid': 3838, 'selection': 'colorectal cancer', 'selection_index': 179},
#    {'qid': 1828,
#     'selection': 'deficiency-causing mutations',
#     'selection_index': 183},
#    {'qid': 2718, 'selection': "Graves' disease", 'selection_index': 63},
#    {'qid': 2718,
#     'selection': 'nasopharyngeal carcinoma',
#     'selection_index': 131},
#    {'qid': 2718,
#     'selection': 'adiation-induced toxicity',
#     'selection_index': 225},
#    {'qid': 2718,
#     'selection': 'risk of coronary artery disease',
#     'selection_index': 356},
#    {'qid': 2718, 'selection': 'gene polymorphism', 'selection_index': 406},
#    {'qid': 5449, 'selection': 'Pancreatic cancer', 'selection_index': 372},
#    {'qid': 4573,
#     'selection': 'potential breast cancer variant',
#     'selection_index': 12},
#    {'qid': 4573, 'selection': 'Ovarian cancer risk', 'selection_index': 44},
#    {'qid': 4852,
#     'selection': 'autosomal recessive spherocytosis',
#     'selection_index': 163},
#    {'qid': 819,
#     'selection': 'familial breast cancer risk',
#     'selection_index': 25},
#    {'qid': 819, 'selection': 'prostate cancer', 'selection_index': 236},
#    {'qid': 4294,
#     'selection': 'congenital myasthenic syndrome',
#     'selection_index': 354},
#    {'qid': 1732,
#     'selection': 'non-small cell lung cancer',
#     'selection_index': 208},
#    {'qid': 622,
#     'selection': "patient's attention levels.",
#     'selection_index': 474},
#    {'qid': 2773,
#     'selection': 'Visceral leishmaniasis',
#     'selection_index': 238},
#    {'qid': 2773, 'selection': 'Leishmania chagasi', 'selection_index': 276},
#    {'qid': 4857, 'selection': "Parkinson's disease", 'selection_index': 532},
#    {'qid': 3003,
#     'selection': 'mutations of the LH receptor gene',
#     'selection_index': 644},
#    {'qid': 565,
#     'selection': "increased risk for late-onset Alzheimer's disease",
#     'selection_index': 134},
#    {'qid': 3041,
#     'selection': 'altered risk for celiac disease',
#     'selection_index': 383},
#    {'qid': 3161,
#     'selection': 'undergo menopause early',
#     'selection_index': 484},
#    {'qid': 196,
#     'selection': 'increased risk of insulin resistance',
#     'selection_index': 195},
#    {'qid': 2845, 'selection': 'rheumatoid arthritis', 'selection_index': 486},
#    {'qid': 2158, 'selection': 'Alcoholism', 'selection_index': 47},
#    {'qid': 4166, 'selection': "Alzheimer's disease", 'selection_index': 289},
#    {'qid': 5424,
#     'selection': 'squamous cell cancer risk',
#     'selection_index': 301},
#    {'qid': 5424, 'selection': 'oral cancer risk', 'selection_index': 500},
#    {'qid': 5424, 'selection': 'gastric cancer', 'selection_index': 1071},
#    {'qid': 1403,
#     'selection': 'congenital adrenal hyperplasia',
#     'selection_index': 897},
#    {'qid': 4209, 'selection': "Alzheimer's disease", 'selection_index': 206},
#    {'qid': 4209,
#     'selection': 'dilated cardiomyopathy',
#     'selection_index': 240},
#    {'qid': 4209, 'selection': 'incomplete penetrance', 'selection_index': 432},
#    {'qid': 3010, 'selection': 'higher HDL levels', 'selection_index': 236},
#    {'qid': 3010,
#     'selection': 'coronary artery disease',
#     'selection_index': 401},
#    {'qid': 3010,
#     'selection': 'risk for carotid artery disease',
#     'selection_index': 2969},
#    {'qid': 3010,
#     'selection': 'coronary heart disease',
#     'selection_index': 3294},
#    {'qid': 3010, 'selection': 'colorectal cancer', 'selection_index': 3447},
#    {'qid': 5324, 'selection': 'increased risk', 'selection_index': 261},
#    {'qid': 5324, 'selection': 'macular degeneration', 'selection_index': 97},
#    {'qid': 5324, 'selection': 'bladder cancer risk', 'selection_index': 1024},
#    {'qid': 5324,
#     'selection': 'non-small-cell lung cancer',
#     'selection_index': 1375},
#    {'qid': 5324, 'selection': 'gastric cancer', 'selection_index': 2617},
#    {'qid': 5324,
#     'selection': 'peptic ulcer diseases',
#     'selection_index': 2636},
#    {'qid': 5324,
#     'selection': 'neovascular age-related macular degeneration',
#     'selection_index': 3412},
#    {'qid': 5324, 'selection': 'multiple myeloma', 'selection_index': 4505},
#    {'qid': 5324, 'selection': 'heumatoid arthritis', 'selection_index': 4827},
#    {'qid': 3205, 'selection': 'schizophrenia', 'selection_index': 296},
#    {'qid': 3205,
#     'selection': 'ability to recognize facial emotion',
#     'selection_index': 311},
#    {'qid': 3205,
#     'selection': 'chronic rhinosinusitis',
#     'selection_index': 352},
#    {'qid': 3205, 'selection': 'neurocognition', 'selection_index': 1902},
#    {'qid': 4882, 'selection': 'rheumatoid arthritis', 'selection_index': 814},
#    {'qid': 4882, 'selection': 'type 1 diabetes', 'selection_index': 1196},
#    {'qid': 4882,
#     'selection': 'systemic lupus erythematosus',
#     'selection_index': 1333},
#    {'qid': 4882,
#     'selection': 'Inflammatory Bowel Diseases',
#     'selection_index': 2079},
#    {'qid': 1711, 'selection': 'schizophrenia', 'selection_index': 186},
#    {'qid': 1711,
#     'selection': 'decreased attentional capacity,',
#     'selection_index': 242},
#    {'qid': 1711,
#     'selection': 'worse performance on memory tasks',
#     'selection_index': 274},
#    {'qid': 1711,
#     'selection': 'alterations in schizotypal beliefs and experiences',
#     'selection_index': 313},
#    {'qid': 1711,
#     'selection': 'major depressive disorder',
#     'selection_index': 2020},
#    {'qid': 1711, 'selection': 'neuroticism', 'selection_index': 2308},
#    {'qid': 1711, 'selection': 'anxiety', 'selection_index': 2321},
#    {'qid': 1711, 'selection': 'depression', 'selection_index': 2334},
#    {'qid': 1278,
#     'selection': 'higher dopamine levels;',
#     'selection_index': 706},
#    {'qid': 1278,
#     'selection': 'lower COMT enzymatic activity',
#     'selection_index': 665},
#    {'qid': 1278, 'selection': 'lower pain threshold', 'selection_index': 730},
#    {'qid': 1278,
#     'selection': 'enhanced vulnerability to stress',
#     'selection_index': 752},
#    {'qid': 1278, 'selection': 'schizophrenia', 'selection_index': 2988}]},
#  {'response_id': 'R_25R9SJyLb4p6iv7',
#   'recorded_datetime': '9/22/20 10:42',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 361,
#   'hilights': []},
#  {'response_id': 'R_1CpRIVeWQ8AGNqi',
#   'recorded_datetime': '9/22/20 10:45',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 2002,
#   'hilights': [{'qid': 1115,
#     'selection': 'Cystic Fibrosisrs',
#     'selection_index': 0},
#    {'qid': 1100, 'selection': 'Cystic Fibrosisrs', 'selection_index': 0},
#    {'qid': 3042, 'selection': 'Celiac Disease', 'selection_index': 0},
#    {'qid': 278,
#     'selection': 'Hereditary fructose intolerancers',
#     'selection_index': 0},
#    {'qid': 1117, 'selection': 'Cystic Fibrosisrs', 'selection_index': 0},
#    {'qid': 4658,
#     'selection': 'Glycogen Storage Disease Type 1brs',
#     'selection_index': 0},
#    {'qid': 113,
#     'selection': 'Dehydrogenase Deficiency',
#     'selection_index': 22},
#    {'qid': 1597, 'selection': 'Bipolar disorder', 'selection_index': 0},
#    {'qid': 852,
#     'selection': 'Clinical spectrum of episodic ataxia type 2.',
#     'selection_index': 0},
#    {'qid': 4805,
#     'selection': 'A polymorphism on the SOD1 gene known as A4V.',
#     'selection_index': 0},
#    {'qid': 2901, 'selection': 'developmental dyslexia', 'selection_index': 66},
#    {'qid': 1140, 'selection': 'silent polymorphism', 'selection_index': 22},
#    {'qid': 3824,
#     'selection': 'Rhizomelic chondrodysplasia punctata type 1',
#     'selection_index': 23},
#    {'qid': 3020, 'selection': 'cardiomyopathy', 'selection_index': 125},
#    {'qid': 3646,
#     'selection': 'carriers of the G allele',
#     'selection_index': 82},
#    {'qid': 5211,
#     'selection': 'Human Oocyte Meiotic Arrest',
#     'selection_index': 63},
#    {'qid': 5211,
#     'selection': 'R2K Mutations in TUBB8 ',
#     'selection_index': 36},
#    {'qid': 712, 'selection': 'breast cancer', 'selection_index': 89},
#    {'qid': 2218, 'selection': "Gaucher's disease", 'selection_index': 73},
#    {'qid': 2218, 'selection': 'Gaucher Disease', 'selection_index': 91},
#    {'qid': 4314, 'selection': "Hirschsprung's disease", 'selection_index': 79},
#    {'qid': 857, 'selection': 'arrhythmia disorder', 'selection_index': 7},
#    {'qid': 857, 'selection': 'arrhythmia disorder', 'selection_index': 86},
#    {'qid': 857,
#     'selection': 'cardiac L-type calcium channel mutations',
#     'selection_index': 116},
#    {'qid': 990, 'selection': 'gastric cancer', 'selection_index': 107},
#    {'qid': 2972,
#     'selection': 'decreased total cholesterol levels',
#     'selection_index': 99},
#    {'qid': 766, 'selection': 'breast cancer', 'selection_index': 127},
#    {'qid': 697, 'selection': 'breast cancer', 'selection_index': 119},
#    {'qid': 2956,
#     'selection': 'cerebral cavernous malformation',
#     'selection_index': 125},
#    {'qid': 263, 'selection': 'abnormality of albumin', 'selection_index': 119},
#    {'qid': 3015,
#     'selection': 'hyperalphalipoproteinemia',
#     'selection_index': 59},
#    {'qid': 4785, 'selection': 'Parkinson disease', 'selection_index': 154},
#    {'qid': 351,
#     'selection': 'limb-girdle muscular dystrophy',
#     'selection_index': 197},
#    {'qid': 1762,
#     'selection': 'intracranial aneurysms',
#     'selection_index': 115},
#    {'qid': 1762, 'selection': 'intracranial aneurysm', 'selection_index': 222},
#    {'qid': 2556,
#     'selection': 'azoospermia (lack of sperm)',
#     'selection_index': 103},
#    {'qid': 3770, 'selection': 'Parkinson disease ', 'selection_index': 170},
#    {'qid': 326, 'selection': 'hypophosphatasia', 'selection_index': 201},
#    {'qid': 3219, 'selection': 'AIDS', 'selection_index': 119},
#    {'qid': 303, 'selection': 'hypophosphatasia', 'selection_index': 204},
#    {'qid': 1674, 'selection': 'autism', 'selection_index': 88},
#    {'qid': 606, 'selection': 'depression', 'selection_index': 95},
#    {'qid': 3785, 'selection': 'coronary events.', 'selection_index': 237},
#    {'qid': 2232, 'selection': 'Asthma', 'selection_index': 0},
#    {'qid': 2232, 'selection': 'prostate cancer', 'selection_index': 310},
#    {'qid': 3877,
#     'selection': 'end-stage renal disease (ESRD) ',
#     'selection_index': 84},
#    {'qid': 3877,
#     'selection': ' autosomal dominant polycystic kidney disease',
#     'selection_index': 118},
#    {'qid': 3877, 'selection': 'ADPKD', 'selection_index': 210},
#    {'qid': 3877, 'selection': 'few cysts', 'selection_index': 289},
#    {'qid': 5023, 'selection': ' diabetes ', 'selection_index': 242},
#    {'qid': 5023, 'selection': 'allergic asthma', 'selection_index': 256},
#    {'qid': 2703, 'selection': 'allergy', 'selection_index': 75},
#    {'qid': 2703, 'selection': 'asthma', 'selection_index': 87},
#    {'qid': 4763,
#     'selection': 'type 2 or 3 spinal muscular atrophy',
#     'selection_index': 192},
#    {'qid': 3188,
#     'selection': 'familial Mediterranean fever',
#     'selection_index': 88},
#    {'qid': 414, 'selection': 'lung cancer ', 'selection_index': 51},
#    {'qid': 414, 'selection': 'lung cancer', 'selection_index': 262},
#    {'qid': 3407,
#     'selection': 'familial hypertrophic cardiomyopathy (HCM',
#     'selection_index': 103},
#    {'qid': 3407,
#     'selection': 'Hypertrophic cardiomyopathy',
#     'selection_index': 246},
#    {'qid': 1748, 'selection': "Parkinson's disease", 'selection_index': 183},
#    {'qid': 3236, 'selection': 'lung cancer', 'selection_index': 4},
#    {'qid': 3236, 'selection': ' lung cancer', 'selection_index': 149},
#    {'qid': 225, 'selection': 'pre-eclampsia', 'selection_index': 285},
#    {'qid': 225, 'selection': 'pre-eclampsia,', 'selection_index': 131},
#    {'qid': 2591, 'selection': 'ADHD', 'selection_index': 164},
#    {'qid': 2755,
#     'selection': 'ankylosing spondylitis',
#     'selection_index': 142},
#    {'qid': 2755, 'selection': 'rheumatoid arthriti', 'selection_index': 336},
#    {'qid': 2755, 'selection': "Crohn's Disease", 'selection_index': 457},
#    {'qid': 5200,
#     'selection': 'TTR-related familial amyloid polyneuropathy',
#     'selection_index': 189},
#    {'qid': 5200,
#     'selection': 'heart-related symptoms',
#     'selection_index': 255},
#    {'qid': 4294,
#     'selection': 'congenital myasthenic syndrome',
#     'selection_index': 354},
#    {'qid': 3837, 'selection': 'preterm birth', 'selection_index': 226},
#    {'qid': 3837, 'selection': 'preterm birth', 'selection_index': 543},
#    {'qid': 4073,
#     'selection': 'ubcortical silent brain infarction',
#     'selection_index': 144},
#    {'qid': 4073, 'selection': 'stroke', 'selection_index': 197},
#    {'qid': 4462, 'selection': 'cancers', 'selection_index': 323},
#    {'qid': 4462, 'selection': 'paragangliomas', 'selection_index': 381},
#    {'qid': 4462, 'selection': 'pheochromocytomas', 'selection_index': 400},
#    {'qid': 4887, 'selection': 'rheumatoid arthritis ', 'selection_index': 26},
#    {'qid': 4887,
#     'selection': 'systemic lupus erythematosu',
#     'selection_index': 155},
#    {'qid': 4887, 'selection': 'lupus erythematosus', 'selection_index': 224},
#    {'qid': 4887,
#     'selection': 'ystemic lupus erythematosus ',
#     'selection_index': 595},
#    {'qid': 655, 'selection': 'ovarian cancer', 'selection_index': 212},
#    {'qid': 655, 'selection': 'breast cancer', 'selection_index': 194},
#    {'qid': 4625, 'selection': 'Asperger syndrome', 'selection_index': 152},
#    {'qid': 4625, 'selection': 'Asperger syndrome', 'selection_index': 39},
#    {'qid': 164, 'selection': "Alzheimer's disease", 'selection_index': 272},
#    {'qid': 4453,
#     'selection': 'lower post-operative pain following surgery',
#     'selection_index': 463},
#    {'qid': 4453, 'selection': 'pain', 'selection_index': 445},
#    {'qid': 4453, 'selection': 'mall fiber neuropathy', 'selection_index': 592},
#    {'qid': 4453, 'selection': 'increased pain', 'selection_index': 618},
#    {'qid': 1248,
#     'selection': 'decreased bone mineral density',
#     'selection_index': 333},
#    {'qid': 1248,
#     'selection': 'ntervertebral disc disease.',
#     'selection_index': 418},
#    {'qid': 1248,
#     'selection': 'anterior cruciate ligament ruptures',
#     'selection_index': 572},
#    {'qid': 798, 'selection': 'breast cancer', 'selection_index': 338},
#    {'qid': 4113, 'selection': 'schizophrenia', 'selection_index': 87},
#    {'qid': 4113, 'selection': 'anxiety', 'selection_index': 250},
#    {'qid': 4113, 'selection': 'schizophrenia', 'selection_index': 441},
#    {'qid': 1693, 'selection': 'borderline ', 'selection_index': 608},
#    {'qid': 1693, 'selection': 'schizophrenia', 'selection_index': 1021},
#    {'qid': 521, 'selection': 'breast cancer', 'selection_index': 167},
#    {'qid': 521, 'selection': 'breast cancer', 'selection_index': 296},
#    {'qid': 521, 'selection': 'breast tumour ', 'selection_index': 781},
#    {'qid': 111, 'selection': 'Caucasian', 'selection_index': 695},
#    {'qid': 111,
#     'selection': 'hypersensitivity to ibuprofen',
#     'selection_index': 953},
#    {'qid': 2422,
#     'selection': 'ubiquitin-positive frontotemporal lobar degeneration',
#     'selection_index': 229},
#    {'qid': 2422,
#     'selection': 'amyotrophic lateral sclerosis',
#     'selection_index': 1176},
#    {'qid': 2422, 'selection': 'aphasia', 'selection_index': 1128},
#    {'qid': 2422,
#     'selection': 'extrapyramidal features',
#     'selection_index': 1137},
#    {'qid': 365, 'selection': 'obesity', 'selection_index': 68},
#    {'qid': 365, 'selection': 'heart disease', 'selection_index': 80},
#    {'qid': 365, 'selection': 'obesity', 'selection_index': 289},
#    {'qid': 365, 'selection': 'Body Mass Index ', 'selection_index': 297},
#    {'qid': 365, 'selection': 'heart disease ', 'selection_index': 856},
#    {'qid': 365, 'selection': 'fat ', 'selection_index': 1176},
#    {'qid': 365, 'selection': 'ages 4, 7 and 10', 'selection_index': 1271},
#    {'qid': 952,
#     'selection': ' rheumatoid arthritis (RA)',
#     'selection_index': 34},
#    {'qid': 952, 'selection': 'autoimmune disease', 'selection_index': 72},
#    {'qid': 952, 'selection': 'European ancestry', 'selection_index': 946},
#    {'qid': 952, 'selection': 'Korean ancestry', 'selection_index': 2234},
#    {'qid': 952, 'selection': 'orean ancestry', 'selection_index': 2327},
#    {'qid': 952, 'selection': 'RA ', 'selection_index': 2406},
#    {'qid': 952, 'selection': 'Europeans', 'selection_index': 2412},
#    {'qid': 952, 'selection': 'Korean', 'selection_index': 2431},
#    {'qid': 4729, 'selection': 'myopathy', 'selection_index': 1224},
#    {'qid': 4729, 'selection': 'myopathy', 'selection_index': 1469},
#    {'qid': 5035,
#     'selection': 'infectious and non-infectious diseases',
#     'selection_index': 308},
#    {'qid': 5035, 'selection': 'Diabetic neuropathy ', 'selection_index': 508},
#    {'qid': 5035, 'selection': 'Heart disease ', 'selection_index': 561},
#    {'qid': 5035, 'selection': 'Men ', 'selection_index': 577},
#    {'qid': 5035, 'selection': 'myocardial infarction', 'selection_index': 643},
#    {'qid': 5035, 'selection': 'premature birth', 'selection_index': 1152},
#    {'qid': 5035, 'selection': 'Bacterial vaginosis', 'selection_index': 1171},
#    {'qid': 5035, 'selection': ' Pregnant ', 'selection_index': 1191},
#    {'qid': 5035,
#     'selection': 'pH and a 10 fold higher level ',
#     'selection_index': 1257},
#    {'qid': 5035, 'selection': ' Bacterial infection', 'selection_index': 1307},
#    {'qid': 5035,
#     'selection': 'gram-negative bacterial infections',
#     'selection_index': 1397},
#    {'qid': 5035,
#     'selection': ' Respiratory syncytial virus infection ',
#     'selection_index': 1533},
#    {'qid': 5035,
#     'selection': 'septic shock Respiratory syncytial virus infection ',
#     'selection_index': 1520},
#    {'qid': 5035, 'selection': 'viral infection.', 'selection_index': 1659},
#    {'qid': 5035, 'selection': ' Asthma', 'selection_index': 1676},
#    {'qid': 5035, 'selection': 'lung transplantation', 'selection_index': 1977},
#    {'qid': 1227, 'selection': 'ADHD', 'selection_index': 516},
#    {'qid': 1227, 'selection': 'schizophrenia', 'selection_index': 796},
#    {'qid': 1227, 'selection': 'obesity', 'selection_index': 872},
#    {'qid': 1227, 'selection': 'European', 'selection_index': 912},
#    {'qid': 1227, 'selection': 'nicotine dependence', 'selection_index': 979},
#    {'qid': 1227, 'selection': 'obesity', 'selection_index': 1496},
#    {'qid': 1227,
#     'selection': 'metabolic syndrome in postmenopausal Polish women',
#     'selection_index': 1508},
#    {'qid': 1227, 'selection': 'cocaine addiction', 'selection_index': 1791},
#    {'qid': 249, 'selection': ', schizophrenia', 'selection_index': 270},
#    {'qid': 249,
#     'selection': 'drug-related psychoses,',
#     'selection_index': 291},
#    {'qid': 249,
#     'selection': 'cannabis-related psychosis',
#     'selection_index': 330},
#    {'qid': 249,
#     'selection': 'once-a-month cannabis users',
#     'selection_index': 383},
#    {'qid': 249, 'selection': 'mind-altering symptoms', 'selection_index': 710},
#    {'qid': 249, 'selection': 'psychotic disorde', 'selection_index': 1144},
#    {'qid': 3678, 'selection': 'empathetic', 'selection_index': 142},
#    {'qid': 3678, 'selection': 'feel less lonely', 'selection_index': 154},
#    {'qid': 3678, 'selection': 'Korean ', 'selection_index': 432},
#    {'qid': 3678, 'selection': 'Americans', 'selection_index': 315},
#    {'qid': 3678, 'selection': 'stress', 'selection_index': 1044},
#    {'qid': 3678, 'selection': 'marital discord', 'selection_index': 1946},
#    {'qid': 3678, 'selection': 'depression', 'selection_index': 1963},
#    {'qid': 3678, 'selection': 'Forty-five female', 'selection_index': 2278},
#    {'qid': 3678,
#     'selection': 'Two hundred three healthy German male university students',
#     'selection_index': 2795},
#    {'qid': 3678, 'selection': 'female', 'selection_index': 3066},
#    {'qid': 3678,
#     'selection': 'lower cortisol responses to stress',
#     'selection_index': 3246},
#    {'qid': 3678,
#     'selection': 'grey matter volume in the hypothalamus',
#     'selection_index': 4060},
#    {'qid': 3678,
#     'selection': 'prosocial temperament',
#     'selection_index': 5092},
#    {'qid': 3678, 'selection': 'Caucasian ', 'selection_index': 5212},
#    {'qid': 3678, 'selection': 'autism', 'selection_index': 5202}]},
#  {'response_id': 'R_2wQNxJNyQdjSeq9',
#   'recorded_datetime': '9/22/20 11:20',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 1438,
#   'hilights': [{'qid': 1092,
#     'selection': 'Cystic Fibrosisrs',
#     'selection_index': 0},
#    {'qid': 3416,
#     'selection': 'familial hypertrophic cardiomyopathy',
#     'selection_index': 11},
#    {'qid': 5235, 'selection': 'eye color', 'selection_index': 0},
#    {'qid': 4747,
#     'selection': 'spinal muscular atrophy',
#     'selection_index': 10},
#    {'qid': 4767,
#     'selection': 'Niemann-Pick Disease Type',
#     'selection_index': 0},
#    {'qid': 5368, 'selection': 'Von Willebrand disease', 'selection_index': 10},
#    {'qid': 3849, 'selection': "Parkinson's disease", 'selection_index': 10},
#    {'qid': 2322,
#     'selection': 'associated with deafness',
#     'selection_index': 39},
#    {'qid': 3764, 'selection': "Parkinson's disease", 'selection_index': 11},
#    {'qid': 3764, 'selection': 'recessive/early-onset', 'selection_index': 32},
#    {'qid': 3764, 'selection': 'digenic', 'selection_index': 55},
#    {'qid': 3055, 'selection': 'Leigh syndrome', 'selection_index': 0},
#    {'qid': 259, 'selection': 'analbuminemia', 'selection_index': 31},
#    {'qid': 259, 'selection': 'Novel nonsense mutation', 'selection_index': 0},
#    {'qid': 3873,
#     'selection': 'polycystic kidney disease',
#     'selection_index': 83},
#    {'qid': 5119,
#     'selection': 'bipolar affective disorder',
#     'selection_index': 75},
#    {'qid': 5119, 'selection': 'suicide attempts.', 'selection_index': 107},
#    {'qid': 5119,
#     'selection': 'tryptophan hydroxylase II',
#     'selection_index': 48},
#    {'qid': 544,
#     'selection': 'prone to epigenetic alterations',
#     'selection_index': 82},
#    {'qid': 544,
#     'selection': 'X-inactivation in female human embryonic stem cells',
#     'selection_index': 0},
#    {'qid': 4169, 'selection': 'ALZHEIMER DISEASE', 'selection_index': 38},
#    {'qid': 4169, 'selection': 'Dementia', 'selection_index': 83},
#    {'qid': 4169, 'selection': 'SPASTIC PARAPARESIS', 'selection_index': 93},
#    {'qid': 4169, 'selection': 'APRAXIA', 'selection_index': 114},
#    {'qid': 993,
#     'selection': 'hereditary diffuse gastric cancer',
#     'selection_index': 88},
#    {'qid': 2185, 'selection': 'Krabbe disease', 'selection_index': 72},
#    {'qid': 740, 'selection': 'breast cancer', 'selection_index': 142},
#    {'qid': 982,
#     'selection': 'hereditary diffuse gastric cancer',
#     'selection_index': 109},
#    {'qid': 700, 'selection': 'breast cancer', 'selection_index': 119},
#    {'qid': 5328, 'selection': 'rheumatoid arthritis', 'selection_index': 52},
#    {'qid': 44,
#     'selection': 'atrial fibrillation/flutter',
#     'selection_index': 169},
#    {'qid': 4333,
#     'selection': 'late-onset Alzheimer disease',
#     'selection_index': 81},
#    {'qid': 4333, 'selection': 'chromosome 10', 'selection_index': 10},
#    {'qid': 4333, 'selection': 'Renalase gene', 'selection_index': 111},
#    {'qid': 4333, 'selection': 'hypertension', 'selection_index': 170},
#    {'qid': 4791, 'selection': 'Parkinson disease', 'selection_index': 156},
#    {'qid': 4257, 'selection': 'deafnes', 'selection_index': 107},
#    {'qid': 1964, 'selection': 'trimethylaminuria', 'selection_index': 130},
#    {'qid': 5176,
#     'selection': 'familial heart block type 1B',
#     'selection_index': 178},
#    {'qid': 1210, 'selection': 'obesity', 'selection_index': 170},
#    {'qid': 1210, 'selection': 'overweight', 'selection_index': 15},
#    {'qid': 313, 'selection': 'hypophosphatasia', 'selection_index': 205},
#    {'qid': 313, 'selection': 'rare/minor allele', 'selection_index': 136},
#    {'qid': 3881,
#     'selection': 'Polycystic Kidney disease',
#     'selection_index': 0},
#    {'qid': 4070,
#     'selection': 'post-traumatic stress disorder',
#     'selection_index': 133},
#    {'qid': 4070, 'selection': 'memory capacity', 'selection_index': 81},
#    {'qid': 2026, 'selection': "Friedreich's ataxia", 'selection_index': 140},
#    {'qid': 1739,
#     'selection': 'pulmonary hypertension',
#     'selection_index': 160},
#    {'qid': 1739,
#     'selection': 'pulmonary capillary hemangiomatosis',
#     'selection_index': 198},
#    {'qid': 1739,
#     'selection': 'pulmonary venoocclusive disease',
#     'selection_index': 244},
#    {'qid': 2252, 'selection': "Parkinson's disease", 'selection_index': 65},
#    {'qid': 3651,
#     'selection': 'higher likelihood of smoking initiation and nicotine dependence.',
#     'selection_index': 185},
#    {'qid': 1004,
#     'selection': 'Usher syndrome and nonsyndromic deafness.',
#     'selection_index': 83},
#    {'qid': 1004, 'selection': 'hearing loss', 'selection_index': 212},
#    {'qid': 4464, 'selection': 'thrombotic disorders', 'selection_index': 87},
#    {'qid': 4464,
#     'selection': 'recurrent venous thromboembolism',
#     'selection_index': 192},
#    {'qid': 2034, 'selection': "Friedreich's ataxia", 'selection_index': 171},
#    {'qid': 2423,
#     'selection': 'frontotemporal dementia',
#     'selection_index': 19},
#    {'qid': 2423,
#     'selection': 'primary progressive aphasia',
#     'selection_index': 106},
#    {'qid': 2423,
#     'selection': 'progranulin haploinsufficiency',
#     'selection_index': 251},
#    {'qid': 287,
#     'selection': 'myocardial infarction or ischemic stroke',
#     'selection_index': 140},
#    {'qid': 287,
#     'selection': 'bifurcation intima-media thickness',
#     'selection_index': 275},
#    {'qid': 287, 'selection': 'alcohol consumption', 'selection_index': 314},
#    {'qid': 1921, 'selection': 'prostate cancer', 'selection_index': 25},
#    {'qid': 1921,
#     'selection': 'benign prostate hyperplasia',
#     'selection_index': 164},
#    {'qid': 1988, 'selection': 'Physical activity', 'selection_index': 170},
#    {'qid': 1988, 'selection': 'obesity', 'selection_index': 261},
#    {'qid': 1988, 'selection': 'diabetes', 'selection_index': 318},
#    {'qid': 341, 'selection': 'coron', 'selection_index': 352},
#    {'qid': 341, 'selection': ' artery disease', 'selection_index': 360},
#    {'qid': 1218, 'selection': 'colorblindness', 'selection_index': 187},
#    {'qid': 1218, 'selection': 'photophobia', 'selection_index': 203},
#    {'qid': 1218, 'selection': 'nystagmus', 'selection_index': 216},
#    {'qid': 1218, 'selection': '20/200 visual acuity', 'selection_index': 227},
#    {'qid': 2726, 'selection': 'schizophrenia', 'selection_index': 18},
#    {'qid': 2726, 'selection': 'herpes', 'selection_index': 36},
#    {'qid': 1055, 'selection': 'ischemic stroke', 'selection_index': 297},
#    {'qid': 183, 'selection': 'dyskinesia disorder', 'selection_index': 229},
#    {'qid': 183, 'selection': 'facial myokymia', 'selection_index': 431},
#    {'qid': 2778, 'selection': 'type I diabetes', 'selection_index': 180},
#    {'qid': 4428,
#     'selection': 'gain significant weight',
#     'selection_index': 222},
#    {'qid': 2401, 'selection': 'alcoholism', 'selection_index': 58},
#    {'qid': 3267, 'selection': 'Endometrial cancer', 'selection_index': 0},
#    {'qid': 3267,
#     'selection': 'sporadic renal cell carcinoma',
#     'selection_index': 545},
#    {'qid': 5411, 'selection': 'Frasier syndrome', 'selection_index': 155},
#    {'qid': 5411, 'selection': 'Denys-Drash syndrome', 'selection_index': 199},
#    {'qid': 1144, 'selection': 'schizophrenia ', 'selection_index': 0},
#    {'qid': 1144, 'selection': 'atopy', 'selection_index': 474},
#    {'qid': 4014, 'selection': 'type 2', 'selection_index': 161},
#    {'qid': 4014, 'selection': ' diabetes', 'selection_index': 167},
#    {'qid': 1516, 'selection': 'prostate cancer', 'selection_index': 156},
#    {'qid': 1516, 'selection': 'ovarian cancer', 'selection_index': 383},
#    {'qid': 861, 'selection': 'hyperthermia', 'selection_index': 160},
#    {'qid': 49, 'selection': 'intrahepatic cholestasis', 'selection_index': 86},
#    {'qid': 49,
#     'selection': 'nonalcoholic fatty liver disease',
#     'selection_index': 193},
#    {'qid': 1555, 'selection': 'cerebral infarction', 'selection_index': 147},
#    {'qid': 361, 'selection': 'colorectal cancer', 'selection_index': 37},
#    {'qid': 5226,
#     'selection': 'systemic lupus erythematosus',
#     'selection_index': 136},
#    {'qid': 1936, 'selection': 'ichthyosis vulgaris', 'selection_index': 93},
#    {'qid': 1936, 'selection': 'dermatitis', 'selection_index': 124},
#    {'qid': 1562, 'selection': 'schizophrenia ', 'selection_index': 106},
#    {'qid': 1562, 'selection': 'autism ', 'selection_index': 350},
#    {'qid': 1562,
#     'selection': 'bipolar affective disorder',
#     'selection_index': 463},
#    {'qid': 4295,
#     'selection': 'congenital myasthenic syndrome',
#     'selection_index': 311},
#    {'qid': 1009, 'selection': 'type-2 diabetes', 'selection_index': 231},
#    {'qid': 1403,
#     'selection': 'congenital adrenal hyperplasia',
#     'selection_index': 897},
#    {'qid': 3251, 'selection': "Alzheimer's disease", 'selection_index': 105},
#    {'qid': 3251, 'selection': 'lung cancer', 'selection_index': 260},
#    {'qid': 3251,
#     'selection': 'cutaneous malignant melanoma',
#     'selection_index': 192},
#    {'qid': 3251, 'selection': 'non-atopic asthma', 'selection_index': 845},
#    {'qid': 3251, 'selection': 'breast cancer', 'selection_index': 1136},
#    {'qid': 1693, 'selection': 'personality', 'selection_index': 475},
#    {'qid': 1693, 'selection': 'schizophrenia', 'selection_index': 1021},
#    {'qid': 1693, 'selection': 'Anorexia Nervosa', 'selection_index': 911},
#    {'qid': 3205, 'selection': 'tumor metastasis', 'selection_index': 136},
#    {'qid': 3205, 'selection': 'autism ', 'selection_index': 257},
#    {'qid': 3205, 'selection': 'schizophrenia', 'selection_index': 296},
#    {'qid': 3205, 'selection': 'rhinosinusitis', 'selection_index': 360},
#    {'qid': 3205, 'selection': 'nasal polyps', 'selection_index': 3334},
#    {'qid': 5427, 'selection': 'breast cancer', 'selection_index': 118},
#    {'qid': 5427, 'selection': 'prostate cancer', 'selection_index': 264},
#    {'qid': 5427, 'selection': 'lung cancer', 'selection_index': 1178},
#    {'qid': 3250, 'selection': 'cigarette smoking', 'selection_index': 216},
#    {'qid': 3250,
#     'selection': 'chronic obstructive pulmonary disease',
#     'selection_index': 286},
#    {'qid': 3250, 'selection': 'lung cancer', 'selection_index': 528},
#    {'qid': 3250, 'selection': 'myocardial infarction', 'selection_index': 706},
#    {'qid': 3250, 'selection': 'heart disease', 'selection_index': 947},
#    {'qid': 3250, 'selection': "Alzheimer's disease", 'selection_index': 1497},
#    {'qid': 3250, 'selection': 'malignant melanoma', 'selection_index': 1747},
#    {'qid': 3250,
#     'selection': 'hepatitis B virus infection',
#     'selection_index': 1958},
#    {'qid': 3250, 'selection': 'lymphoma', 'selection_index': 2375},
#    {'qid': 3250, 'selection': 'glaucoma', 'selection_index': 2475},
#    {'qid': 3250, 'selection': 'type 2 diabetes', 'selection_index': 2669},
#    {'qid': 3250, 'selection': 'leukemia', 'selection_index': 3232},
#    {'qid': 3833, 'selection': 'ovarian cancer', 'selection_index': 220},
#    {'qid': 3833, 'selection': 'endometrial cancer', 'selection_index': 1355},
#    {'qid': 5344, 'selection': 'ischemic stroke', 'selection_index': 750},
#    {'qid': 5344,
#     'selection': 'myocardial infarction',
#     'selection_index': 1508},
# ...
#     'selection_index': 0},
#    {'qid': 3542,
#     'selection': 'fluvoxamine response in major depressive disorder in the Japanese population.',
#     'selection_index': 128},
#    {'qid': 793,
#     'selection': 'rs80358158, also known as c.135-1G>T and c.135-1G>C, represents a variant in the BRCA1 gene',
#     'selection_index': 0},
#    {'qid': 2426,
#     'selection': ' rs794729671(T) allele is reported',
#     'selection_index': 125},
#    {'qid': 2426,
#     'selection': 'as a dominant mutation pathogenic for frontotemporal dementia.',
#     'selection_index': 171},
#    {'qid': 3418,
#     'selection': 'familial hypertrophic cardiomyopathy (HCM)',
#     'selection_index': 89},
#    {'qid': 3418, 'selection': 'HCM', 'selection_index': 207},
#    {'qid': 3887,
#     'selection': 'Polycystic Kidney disease',
#     'selection_index': 0},
#    {'qid': 1950, 'selection': 'increased height', 'selection_index': 136},
#    {'qid': 1950,
#     'selection': 'rs1867138(T;T) or rs1867137(G;G) were approximately one inch taller than rs1867138(C;C) rs9834312(G;G) or rs939882(G;G)',
#     'selection_index': 16},
#    {'qid': 507, 'selection': 'ASPA gene variant', 'selection_index': 0},
#    {'qid': 507,
#     'selection': 'the minor allele is a pathogenic mutation (for Canavan disease)',
#     'selection_index': 85},
#    {'qid': 4762,
#     'selection': 'he rare rs75660264(T) allele is a mutation associated with the recessively inherited type 3 spinal muscular atrophy',
#     'selection_index': 107},
#    {'qid': 3393,
#     'selection': ' c.545G>A (p.Arg182His or R182H)',
#     'selection_index': 3},
#    {'qid': 3393,
#     'selection': 'is considered pathogenic in ClinVar for a hereditary cancer-predisposing syndrome (polyposis)',
#     'selection_index': 90},
#    {'qid': 2033,
#     'selection': "The minor allele of this SNP is associated with Friedreich's ataxia when inherited in two copies or as a compound heterozygote.",
#     'selection_index': 95},
#    {'qid': 2037,
#     'selection': "The minor allele of this SNP is associated with Friedreich's ataxia when inherited in two copies or as a compound heterozygote.",
#     'selection_index': 95},
#    {'qid': 359,
#     'selection': 'The minor (A) allele of rs760021635 was reported as a mutation in the AP4E1 gene associated with stuttering in a 2015 study.',
#     'selection_index': 108},
#    {'qid': 1735,
#     'selection': 'c.1392delT (p.Arg465Valfs), this rare mutation in the EIF2AK4 gene ',
#     'selection_index': 14},
#    {'qid': 1735,
#     'selection': 'rare forms of pulmonary hypertension, specifically, pulmonary capillary hemangiomatosis (PCH) and pulmonary venoocclusive disease (PVOD).',
#     'selection_index': 149},
#    {'qid': 1735,
#     'selection': 'when inherited recessively',
#     'selection_index': 120},
#    {'qid': 4071,
#     'selection': ' the rare rs121908517(G) allele is reported to lead in a dominant manner to spinocerebellar ataxia, type 14. ',
#     'selection_index': 129},
#    {'qid': 262,
#     'selection': 'Exome sequencing identifies GRIN2A as frequently mutated in melanoma.',
#     'selection_index': 274},
#    {'qid': 262,
#     'selection': 'Amino acid substitution in two identical inherited human serum albumin variants: albumin Oliphant and albumin Ann Arbor',
#     'selection_index': 76},
#    {'qid': 375,
#     'selection': 'biliary tract conditions, including cancer and gallstones,',
#     'selection_index': 161},
#    {'qid': 375,
#     'selection': 'men carrying a rs520354(A) allele had a 2x risk of bile duct cancer',
#     'selection_index': 220},
#    {'qid': 6,
#     'selection': "rs2297404, rs2230808, and rs2020927 haplotype (CAC) was more prevalent in the Alzheimer's disease group",
#     'selection_index': 0},
#    {'qid': 6,
#     'selection': 'while haplotype1 (TGG) was over-represented in the healthy controls',
#     'selection_index': 140},
#    {'qid': 6,
#     'selection': 'atherogenic dyslipidaemia',
#     'selection_index': 270},
#    {'qid': 6, 'selection': 'Type 2 diabetes', 'selection_index': 313},
#    {'qid': 2647,
#     'selection': 'attention-deficit/hyperactivity',
#     'selection_index': 77},
#    {'qid': 2647,
#     'selection': 'association for 5HT2A, DDC and MAOB. ',
#     'selection_index': 129},
#    {'qid': 2647,
#     'selection': 'C allele associated with ADHD in adults.',
#     'selection_index': 166},
#    {'qid': 2647, 'selection': 'ADHD', 'selection_index': 276},
#    {'qid': 2647,
#     'selection': " points to the 'T' allele as being the cause.",
#     'selection_index': 299},
#    {'qid': 3518,
#     'selection': ' multiple sclerosis and malignant melanoma,',
#     'selection_index': 186},
#    {'qid': 3518,
#     'selection': 'when inherited recessively, the rs115799546(T) allele (in dbSNP orientation) may cause both conditions.',
#     'selection_index': 264},
#    {'qid': 971,
#     'selection': 'Also known as c.59G>A, p.Trp20Ter or W20X, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer',
#     'selection_index': 0},
#    {'qid': 1055,
#     'selection': ' meta-analysis of candidate gene polymorphisms and ischemic stroke in 6 study populations: association of lymphotoxin-alpha in nonhypertensive patients. ',
#     'selection_index': 246},
#    {'qid': 19,
#     'selection': "rs113809142, also known as c.4416+2T>G, is one of several loss-of-function ABCA7 mutations associated with Alzheimer's disease",
#     'selection_index': 0},
#    {'qid': 19,
#     'selection': "Carriers of one rare rs113809142(G) allele are at roughly more than twice the risk for developing late-onset Alzheimer's disease compared to people having the most common genotype (T;T); ",
#     'selection_index': 193},
#    {'qid': 4211,
#     'selection': 'rs63750666, also known as c.1289C>T, T430M or Thr430Met, is a SNP in the presenilin 2 PSEN2 gene.',
#     'selection_index': 0},
#    {'qid': 4211,
#     'selection': "Acting as an autosomal dominant, the rare rs63750666(T) allele has been suggested to lead to early-onset Alzheimer's disease. ",
#     'selection_index': 97},
#    {'qid': 4211, 'selection': "Alzheimer's patient ", 'selection_index': 275},
#    {'qid': 141,
#     'selection': 'Confronting complexity in late-onset Alzheimer disease: application of two-stage analysis approach addressing heterogeneity and epistasis.',
#     'selection_index': 80},
#    {'qid': 141,
#     'selection': 'An association analysis of Alzheimer disease candidate genes detects an ancestral risk haplotype clade in ACE and putative multilocus association between ACE, A2M, and LRRTM3.',
#     'selection_index': 340},
#    {'qid': 2715,
#     'selection': 'rs20541 is a C/T polymorphism on the interleukin 13 gene IL13 associated with IgE levels. ',
#     'selection_index': 0},
#    {'qid': 2715,
#     'selection': 'genotypes associated with lower IgE/ 23andMe blog psoriasis Europeans rs20541(G)',
#     'selection_index': 320},
#    {'qid': 1306,
#     'selection': 'rs397514693, also known as His46Arg or H46R, is a SNP in the casein kinase 1, delta CSNK1D gene.Heterozygotes for rs397514693 have been reported to have a sleep disorder, Familial Advanced Sleep Phase syndrome 2 (FASPS2), and it is therefore considered to be inherited as an autosomal dominant trait. ',
#     'selection_index': 0},
#    {'qid': 2481,
#     'selection': 'rs1667394 increases susceptibility to Blond rather than brown hair 4.94 ',
#     'selection_index': 0},
#    {'qid': 2481,
#     'selection': 'he A allele rs1667394 increases susceptibility to Blue rather than brown eyes 29.43 times for carriers of the A allele rs1667394 increases susceptibility to Blue rather than green eyes 6.74 times for carriers of the A allele',
#     'selection_index': 95},
#    {'qid': 2481,
#     'selection': 'For green versus blue eye color rs12913832 in OCA2/HERC2 has a score of 51.5 and an estimated allelic OR of 8.43 . ',
#     'selection_index': 320},
#    {'qid': 1935,
#     'selection': 'This variant is predicted to cause loss of normal protein function through protein truncation.',
#     'selection_index': 145},
#    {'qid': 2589,
#     'selection': 'The increased risk associated with rs7501939 and the closely linked rs4430796 is approximately doubled in individuals hereditarily predisposed to develop early-onset prostate cancer,',
#     'selection_index': 47},
#    {'qid': 2589,
#     'selection': 'rs7501939 identified as one of three HNF1B gene SNPs associated with decreased risk for prostate cancer in two large prospective studies ',
#     'selection_index': 262},
#    {'qid': 1928,
#     'selection': 'rs4713902, a SNP in the FKBP5 gene, is associated with increased risk for bipolar disorder in a study of 500+ Caucasian patients.',
#     'selection_index': 0},
#    {'qid': 1928,
#     'selection': 'most common allele, rs4713902(T), was associated with highest risk. ',
#     'selection_index': 134},
#    {'qid': 3196,
#     'selection': "The symptoms of familial Mediterranean fever are caused by the person's own inflammatory response; it is not an infectious disease.",
#     'selection_index': 183},
#    {'qid': 3196,
#     'selection': 'The condition is more common among Turks, Sephardic Jews, and people of Arab and Armenian ancestry.',
#     'selection_index': 315},
#    {'qid': 962, 'selection': 'rs587777149', 'selection_index': 0},
#    {'qid': 962,
#     'selection': 'The deletion mutation was originally observed in a 7 month old baby with inherited CD59 deficiency, who went on to develop hemolytic anemia with progressive neurologic deterioration. ',
#     'selection_index': 165},
#    {'qid': 962,
#     'selection': 'This change was found in a multiplex family with strokes, chronic immune-mediated peripheral neuropathy, and hemolysis, all with onset in infancy.',
#     'selection_index': 574},
#    {'qid': 962,
#     'selection': 'Heterozygotes were unaffected.',
#     'selection_index': 721},
#    {'qid': 86,
#     'selection': 'rs11887534, a SNP in the hepatic cholesterol transporter ABCG8 gene, has been implicated in gallstone disease, a process known formally as cholelithiasis.',
#     'selection_index': 0},
#    {'qid': 86,
#     'selection': 'Up to 10% of the population attributable risk for gallstones may be accounted for by this SNP.',
#     'selection_index': 436},
#    {'qid': 4215,
#     'selection': 'Functional considerations suggest that the pathogenic effects of ET-specific FUS mutations are different from the effects observed when FUS is mutated in amyotrophic lateral sclerosis cases;',
#     'selection_index': 77},
#    {'qid': 292,
#     'selection': 'rs9551963, also known as SG13S32, is an ALOX5AP gene SNP that has been defined as part of a haplotype potentially associated with risk for myocardial infarction or ischemic stroke.',
#     'selection_index': 0},
#    {'qid': 292,
#     'selection': 'Genetic effects in the leukotriene biosynthesis pathway and association with atherosclerosis.',
#     'selection_index': 260},
#    {'qid': 292,
#     'selection': 'role of LTA4H and ALOX5AP genes in the risk for asthma in Latinos.',
#     'selection_index': 551},
#    {'qid': 292,
#     'selection': 'ALOX5AP and LTA4H polymorphisms modify augmentation of bronchodilator responsiveness by leukotriene modifiers in Latinos.',
#     'selection_index': 618},
#    {'qid': 292,
#     'selection': '5-Lipoxygenase activating protein (ALOX5AP) gene variants associate with the presence of xanthomas in familial hypercholesterolemia.',
#     'selection_index': 354},
#    {'qid': 1255,
#     'selection': 'odds ratio of 5 (CI: 1.4-17.1) between rs1800255(A;A) homozygotes and risk for pelvic organ prolapse.',
#     'selection_index': 184},
#    {'qid': 1255,
#     'selection': 'No significance was found for the heterozygous genotype.',
#     'selection_index': 286},
#    {'qid': 1255,
#     'selection': 'A meta-analysis published in 2014 reported that the rs1800255(A;A) genotype was associated with pelvic organ prolapse ',
#     'selection_index': 342},
#    {'qid': 1255,
#     'selection': 'compared with the reference genotype (G;G) in populations of Asian and Dutch women.',
#     'selection_index': 496},
#    {'qid': 4113,
#     'selection': 'rs450046 was most strongly positively associated with schizophrenia in families.',
#     'selection_index': 33},
#    {'qid': 4113,
#     'selection': 'rs372055(C), rs450046(G), rs385440(A) haplotype carriers ',
#     'selection_index': 114},
#    {'qid': 4113,
#     'selection': 'exhibited attenuated PPI + verbal memory ',
#     'selection_index': 180},
#    {'qid': 4113,
#     'selection': ' as well as higher anxiety ',
#     'selection_index': 231},
#    {'qid': 4113, 'selection': 'and schizotypy ', 'selection_index': 269},
#    {'qid': 4113, 'selection': 'schizophrenia', 'selection_index': 441},
#    {'qid': 4113,
#     'selection': 'Functional polymorphisms in PRODH are associated with risk and protection for schizophrenia and fronto-striatal structure and function.',
#     'selection_index': 506},
#    {'qid': 4113, 'selection': 'schizophrenia', 'selection_index': 706},
#    {'qid': 1154,
#     'selection': 'No significant association was found between this CHRM2 gene SNP and diverse measures of cognitive ability ',
#     'selection_index': 0},
#    {'qid': 1154, 'selection': 'bipolar disorder.', 'selection_index': 388},
#    {'qid': 1154, 'selection': ' cognitive ability ', 'selection_index': 439},
#    {'qid': 1154, 'selection': 'cognitive ageing ', 'selection_index': 462},
#    {'qid': 1154, 'selection': 'cognition', 'selection_index': 547},
#    {'qid': 1154, 'selection': 'cognition', 'selection_index': 615},
#    {'qid': 1154,
#     'selection': 'alcoholism spectrum disorders:',
#     'selection_index': 754},
#    {'qid': 1154,
#     'selection': 'Synergistic effects of genetic variation in nicotinic and muscarinic receptors on visual attention but not working memory.',
#     'selection_index': 851},
#    {'qid': 5032,
#     'selection': 'chorionic plate inflammation',
#     'selection_index': 127},
#    {'qid': 5032,
#     'selection': 'rs1554973 was associated with increased risk when present in the fetal genome.',
#     'selection_index': 171},
#    {'qid': 5032,
#     'selection': 'No evidence of major effects in several Toll-like receptor gene polymorphisms in rheumatoid arthritis.',
#     'selection_index': 364},
#    {'qid': 5032, 'selection': 'asthma', 'selection_index': 526},
#    {'qid': 5032, 'selection': 'prostate cancer', 'selection_index': 596},
#    {'qid': 5032, 'selection': 'neonatal sepsis. ', 'selection_index': 750},
#    {'qid': 5241,
#     'selection': 'Two causative, dominantly inherited mutations have been mapped to this location on the X chromosome: c.1490C>A, p.Pro497His, P497H: Amyotrophic lateral sclerosis 15, with or without frontotemporal dementia',
#     'selection_index': 0},
#    {'qid': 5241,
#     'selection': 'Two causative, dominantly inherited mutations have been mapped to this location on the X chromosome: c.1490C>A, p.Pro497His, P497H: Amyotrophic lateral sclerosis 15, with or without frontotemporal dementia',
#     'selection_index': 0},
#    {'qid': 5241,
#     'selection': 'Amyotrophic lateral sclerosis',
#     'selection_index': 133},
#    {'qid': 5241,
#     'selection': 'frontotemporal dementia',
#     'selection_index': 183},
#    {'qid': 4789,
#     'selection': "rs356165 is a SNP in the 3' UTR of the alpha-synuclein SNCA gene.",
#     'selection_index': 0},
#    {'qid': 4789,
#     'selection': 'It has been associated ',
#     'selection_index': 66},
#    {'qid': 4789,
#     'selection': "with Parkinson's disease.",
#     'selection_index': 122},
#    {'qid': 4789,
#     'selection': "A study of 330 Chinese with Parkinson's found no association with rs356165 and risk for Parkinson's.",
#     'selection_index': 148},
#    {'qid': 4789, 'selection': "Parkinson's disease", 'selection_index': 427},
#    {'qid': 4789, 'selection': " Parkinson's disease.", 'selection_index': 527},
#    {'qid': 4789, 'selection': "Alzheimer's", 'selection_index': 812},
#    {'qid': 4789, 'selection': 'Lewy body', 'selection_index': 828}]},
#  {'response_id': 'R_in_progress_35',
#   'recorded_datetime': '9/24/20 16:26',
#   'status': 'IP Address',
#   'progress': 1,
#   'is_finished': 'FALSE',
#   'duration': 1,
#   'hilights': []}]

# %%
# Load the original source CSV that was used in creating the survey. This will used to check against the results.
# We want to make sure there is no discrepency in which IDs are referring to which texts.
source_df = pd.read_csv(SURVEY_SOURCE_DATA_PATH)
#source_df.reset_index(drop=False, inplace=True)

# Question IDs in the actual survey will use the 
#source_df["qid"] = source_df["index"]
#source_df.drop(labels=["index"], axis=1, inplace=True)
#qid_to_source_text = {i:text for i,text in zip(source_df["qid"].values, source_df["text"].values)}
#qid_to_unique_text_id = {qid:i for qid,i in zip(source_df["qid"].values, source_df["id"].values)}
source_df.head(10)
# Out:
#      id                       text  bin_id  bin_size  block_id  block_size  \
# 0  1169                    smoking       1       988         1         247
# 1  3702  Phenylketonuriars62514952       1       988         1         247
# 2  3701   Phenylketonuriars5030860       1       988         1         247
# 3  3700   Phenylketonuriars5030859       1       988         1         247
# 4  3699   Phenylketonuriars5030856       1       988         1         247
# 5  3698   Phenylketonuriars5030851       1       988         1         247
# 6  3697   Phenylketonuriars5030850       1       988         1         247
# 7  3696   Phenylketonuriars5030847       1       988         1         247
# 8  3695   Phenylketonuriars5030846       1       988         1         247
# 9  3694   Phenylketonuriars5030843       1       988         1         247
#
#    block_sample
# 0             5
# 1             5
# 2             5
# 3             5
# 4             5
# 5             5
# 6             5
# 7             5
# 8             5
# 9             5

# %%
print(source_df.shape)
print(len(pd.unique(source_df["id"])))
# Out:
# (5081, 7)
# 5081

# %%
# Put the responses into a dataframe.
row_tuples = []
for response in responses:
    
    # Metadata associated with this response.
    response_id = response["response_id"]
    recorded_datetime = response["recorded_datetime"]
    status = response["status"]
    progress = response["progress"]
    is_finished = response["is_finished"]
    duration = response["duration"]


    # The actual highlighted text strings from this response.
    for hilight in response["hilights"]:

        # The information about this one particular highlight.
        qid = hilight["qid"]
        hilighted_text = hilight["selection"]
        index_of_first_selected_char = hilight["selection_index"]
        source_text = id_to_unique_text[qid]        

        # First check that the question IDs are correct so we know what the source text was for this question.
        # Then additionally make sure the location of the highlight makes sense as well.
        #assert hilighted_text in source_text
        #assert source_text[index_of_first_selected_char:index_of_first_selected_char+len(hilighted_text)] == hilighted_text
       
        # Those asserts don't pass 100% of the time due to special cases with the text.
        # Save them to variables instead and check how often they don't pass, should be very infrequently.
        # Look at the special cases by hand.
        text_match = (hilighted_text in source_text)
        indices_match = (source_text[index_of_first_selected_char:index_of_first_selected_char+len(hilighted_text)] == hilighted_text)
        
        # Add this as a row.
        row_tuples.append((response_id, recorded_datetime, status, progress, is_finished, duration, qid, hilighted_text, text_match, indices_match))

        
        
# Create the dataframe that holds all this information.
columns = ["response_id", "recorded_datetime", "status", "progress", "is_finished", "duration", "id", "snippet", "text_match", "idx_match"]
df = pd.DataFrame(row_tuples, columns=columns)


# Add another column indicating how many times a particular ID was annotated by a survey taker.
snippets_per_id = dict(df.groupby("id").size())
df["num_ann"] = df["id"].map(lambda x: snippets_per_id[x])


# Save the dataframe to a file.
df.to_csv(RESPONSES_OUTPUT_PATH, index=False)
df.head(10)
# Out:
#          response_id recorded_datetime      status  progress is_finished  \
# 0  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
# 1  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
# 2  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
# 3  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
# 4  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
# 5  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
# 6  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
# 7  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
# 8  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
# 9  R_eOSosrnczqYqE9P     9/22/20 10:37  IP Address       100        TRUE
#
#    duration    id                               snippet  text_match  \
# 0      1252  4769                              Disease         True
# 1      1252  5162    Focal segmental glomerulosclerosis        True
# 2      1252  2451                     Alpha Thalassemia        True
# 3      1252  3964  Congenital Disorder of Glycosylation        True
# 4      1252  5448                        schizophrenia.        True
# 5      1252  3027                              glaucoma        True
# 6      1252  2287            Nonsyndromic Sensorineural        True
# 7      1252  2287                              Connexin        True
# 8      1252  1783                         schizophrenia        True
# 9      1252   628                           cholesterol        True
#
#    idx_match  num_ann
# 0       True        2
# 1       True        2
# 2       True        6
# 3       True        2
# 4       True        1
# 5       True        5
# 6       True        2
# 7       True        2
# 8       True        2
# 9       True        4

# %%
# How many times did the asserts not evaluate to true?
print(Counter(df["text_match"].values))
print(Counter(df["idx_match"].values))
# Out:
# Counter({True: 18027, False: 109})
# Counter({True: 17101, False: 1035})

# %%
# Preparing a dataset of context sentences that include the highlighted text snippets.
def get_contexts(i, snippet, text):
    sentences = sent_tokenize(text)
    sentences_with_snippet = [s for s in sentences if snippet in s]
    
    # Some additional processing to clean up the context sentences. Can insert more steps here if needed.
    
    # One way to do substitutions with regex. re.sub(old, new, string). The old pattern matches a SNP name.
    # That pattern includes () to define a group. In the new pattern, you can reference whatever is in that 
    # group with \1, as long as it's a raw string. A second group would be referenced with \2, etc.
    sentences_with_snippet = [re.sub(r"(rs[0-9]+)", r" \1 ", s) for s in sentences_with_snippet]
    
    
    
    
    
    
    # Make sure that bracketed text has spaces around it, this might add extra whitespace, will be removed later.
    sentences_with_snippet = [s.replace("("," (") for s in sentences_with_snippet]
    sentences_with_snippet = [s.replace(")",") ") for s in sentences_with_snippet]
    
    # Replace all instances of whitespace with a single space.
    whitespace_pattern = re.compile(r"\s+")
    sentences_with_snippet = [whitespace_pattern.sub(r" ", s) for s in sentences_with_snippet]
    
    # Remove whitespaces that occur before periods or commas.
    whitespace_before_period_pattern = re.compile(r"\s+[\.\;]")
    whitespace_before_comma_pattern = re.compile(r"\s+[\,\;]")
    sentences_with_snippet = [whitespace_before_period_pattern.sub(r".", s) for s in sentences_with_snippet]
    sentences_with_snippet = [whitespace_before_comma_pattern.sub(r",", s) for s in sentences_with_snippet]
    
    # Strip of leading and trailing whitespaces.
    sentences_with_snippet = [s.strip() for s in sentences_with_snippet]
    
    # Capitalize each sentence.
    sentences_with_snippet = ["{}{}".format(s[0].upper(),s[1:]) for s in sentences_with_snippet]
    
    # End each sentence with a single period.
    add_end_character = lambda x: "{}.".format(x[:len(x)-1]) if (x[len(x)-1]==".") or (x[len(x)-1]==";") else "{}.".format(x)
    sentences_with_snippet = [add_end_character(s) for s in sentences_with_snippet]
    
    # Remove all quotes from the sentences.
    sentences_with_snippet = [s.replace('"', '') for s in sentences_with_snippet]
    sentences_with_snippet = [s.replace("'", "") for s in sentences_with_snippet]
    
    
    # Notes to save about how to do this.
    # Another regex substitution trick. The repl (new) argument can be a function, which has to always take a single
    # parameter, which is the regex match. You can then capture groups inside that function, do any transformations,
    # and return, which would have been less straight forward or not possible to do in the repl raw string.
    def make_lowercase(match):
        group = match.group(1)
        group = group.lower()
        return(group)
    
    # Fix a problem where SNP names were being capitalized if they were the first token in the sentence.
    sentences_with_snippet = [re.sub(r"(Rs[0-9]+)", make_lowercase, s) for s in sentences_with_snippet]
    
    # Done.
    return((i,sentences_with_snippet))


# Create a mapping between text IDs and lists of the context sentences that relevant snippets were found in.
obj = df.apply(lambda row: get_contexts(row.id, row.snippet, id_to_unique_text[row.id]), axis=1)
id_to_context_sentences = dict(obj.values)
id_to_context_sentences
# Out:
# {4769: ['Niemann-Pick Disease Type A rs120074117.'],
#  5162: ['Focal segmental glomerulosclerosis 2 rs121434393.'],
#  2451: ['rs281864889 see HBA2 and Alpha Thalassemia.'],
#  3964: ['Congenital Disorder of Glycosylation Type 1a rs28936415.'],
#  5448: ['Evidence of sex-modulated association of ZNF804A with schizophrenia.'],
#  3027: ['Association with exfoliation glaucoma; possible genoset partner with rs2165241.'],
#  2287: ['Hearing loss?Connexin 26-Related Nonsyndromic Sensorineural Hearing Losssee rs80338939.'],
#  1783: ['Linked to schizophrenia with rs7598440, rs839523, and rs707284.'],
#  628: ['LDL cholesterol and total cholesterol levels being the quantitative trait associated with in.'],
#  2515: ['Hemochromatosis related; better known in dbSNP nomenclature as rs1800730 / discussion at 23andMe.'],
#  3684: ['rs1621005 increases susceptibility to Rheumatoid Arthritis 1.89 times for carriers of the G allele.'],
#  4613: ['rs2073838 and rs3792876 replicated for rheumatoid arthritis in Japanese, but not Caucasian populations.'],
#  2261: ['G allele associated with higher tolerance to pain.'],
#  2215: ['I4000386, also known as R496H (risk genotype AA) Possibly associated with Gauchers disease.Gaucher Disease rs80356773.'],
#  2255: ['A GCH1 Haplotype Associated with Susceptibility to Vasoocclusive Pain and Impaired Vascular Function in Sickle Cell Anemia.'],
#  3271: ['HLA-B 5801 allele as a genetic marker for severe cutaneous adverse reactions caused by allopurinol.'],
#  1380: ['rs35694136, also known as -2467delT, is a SNP in the CYP1A2 gene.The rs35694136 (-) allele defines the CYP1A2 1D variant.'],
#  1840: ['rs398122990 The (G) allele represents a very rare - possibly extinct - form of Hemophilia B.'],
#  4559: ['Aka c.95G>C (p.Arg32Thr) considered pathogenic for X-linked Lymphoproliferative syndrome, type 1 in ClinVar23andMe name: i5003046.'],
#  2620: ['rs770815049, also known as c.555_556insC and p.Thr187Hisfs, represents a rare mutation in the HSD3B2 gene on chromosome 1.'],
#  838: ['A SNP in the C3 gene, rs11569562, has been associated with increased risk for adult bronchial asthma in a study of Japanese patients.'],
#  2187: ['Aka c.1591C>T, p.Arg531CysIdentified in ClinVar as likely pathogenic for Krabbe disease (when inherited in two copies or as a compound heterozygote).'],
#  762: ['rs80357829, also known as 3109insAA, c.2990_2991insAA and p.Asn997?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  3780: ['rs6232 G allele (in dbSNP orientation) linked to 1.34x increased risk of obesity rs6234 / rs6235 (or rs10515237 ) see also: / spitoonObesity: Preliminary Research.'],
#  730: ['rs80357597, also known as 1459insG, c.1340_1341insG and p.Val447?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  4644: ['rs111033244, also known as c.1151A>G, p.Glu384Gly and E384G, is a SNP in the SLC26A4 gene associated with the hearing loss condition known as Pendred Syndrome.'],
#  22: ['Alzheimers disease associated, based on large 2011 study The minor allele of rs3764650 in ABCA7 was associated with a later age at onset and shorter disease course according to /.'],
#  5194: ['Note: cDNA is on reverse strand: Mutations in TTC29, Encoding an Evolutionarily Conserved Axonemal Protein, Result in Asthenozoospermia and Male Infertility.'],
#  5015: ['A promoter polymorphism of tissue inhibitor of metalloproteinase-2 gene is associated with severity of thoracic adolescent idiopathic scoliosis.'],
#  2023: ['rs140472905, also known as c.443_A>G or p.Q148R, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  2260: ['T allele associated with higher tolerance to pain.Polymorphisms in the GTP cyclohydrolase gene (GCH1) are associated with ratings of capsaicin pain.'],
#  2039: ['rs147211454, also known as c.340_352 del13 or p.A114TfsX15, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  569: ['BAK1 gene SNPs rs513349 OR=0.57 (0.46-0.72), p=8.57x10 (-7) and rs5745582 OR=1.61 (1.26-2.04), p=1.08x10 (-4) were associated with autoimmune rheumatic diseases (AIRDs) in a study of 719 Colombian women.'],
#  1355: ['Increased risk of breast cancer with concurrent proliferative fibrocystic conditions rs1004982 (C) 2.19 (1.24-3.85) rs28566535 (C) 2.20 (1.27-3.82) rs936306 (T) 1.94 (1.13-3.30) rs4775936 (C) 1.95 (1.07-3.58).'],
#  2793: ['Inflammation and stress-related candidate genes, plasma interleukin-6 levels, and longevity in older adults.'],
#  2568: ['Aka c.532G>A, p.Asp178Asn, D178NHMBS enzyme from the variant allele of this SNP is reported to have 81% of the activity of the normal, wild-type; it is reported as likely to be pathogenic in ClinVar, presumably for acute intermittent porphyria.'],
#  3797: ['rs4655595 has been reported in a large study to be associated with type-2 diabetes.The risk allele (oriented to the dbSNP entry) is (G). the odds ratio associated with heterozygotes is 1.37 (CI 1.17-1.59), and for homozygotes, 2.33 (CI 1.23-4.42).'],
#  3965: ['rs28936415, also known as c.422G>A, p.Arg141His and R141H, represents a rare variant in the PMM2 gene on chromosome 16.ClinVar and other sources designate this variant as pathogenic for Congenital disorder of glycosylation, type 1a, which is a recessive disorder.'],
#  2512: ['Aka c.672+30T>GAlthough reported in ClinVar as pathogenic for Tay Sachs, the consensus seems to be that this variant is likely to be benign, because its seen at a higher frequency in general and because minor homozygotes have been observed in large-scale sequencing projects.'],
#  5107: ['Specifically, the 216H allele (c.646C) appears to reduce the odds of developing torsion dystonia in rs80358233 (-;GAG) carriers, while the 216D allele appears to increase the odds.,,.'],
#  2919: ['The odds ratio is 1.7 (CI: 1.2-2.6) for carriers of a rs211239 (C) allele, as in dbSNP orientation.'],
#  3533: ['Association of NOD1 and NOD2 genes polymorphisms with Helicobacter pylori related gastric cancer in a Chinese population.'],
#  3367: ['Aka c.2593G>T, p.Gly865Ter and G865XWith a carrier frequency of 1 in 131 among Ashkenazi Jews, the recessively inherited rs146064714 (T) variant is the basis of an incidence rate for abetalipoproteinemia of about 1 in 70,000 in this population.'],
#  3979: ['rs397514632, also known as c.1433G>A, p.Ser478Asn or S478N, represents a very rare variant in the POLD1 gene on chromosome 19.The rs397514632 (A) allele is considered to be a high penetrance, dominant mutation significantly increasing ones risk for colorectal cancer, manifesting primarily as tumors occuring predominantly or exclusively in the large bowel, as well as endometrial cancer.'],
#  858: ['rs312481 is a SNP in the calcium channel, voltage-dependent, L type, alpha 1D subunit CACNA1D gene.A study of 161 Japanese patients (85 men, 76 women) being treated for hypertension with L-type dCCBs (calcium channel blockers) concluded that individuals with rs312481 (C;C) genotypes responded better, as measured by lowered systolic and diastolic blood pressure readings.'],
#  289: ['Based on a mixed-ethnicity study, women consuming a diet high in linoleic acid (top quartile of intake, >17.4 g/d) and carrying the rs4076128 (A;A) genotype were associated with higher breast cancer risk (age- and race-adjusted odds ratio, 1.8, CI: 1.2-2.9) compared with (A;G) and (G;G) genotypes.',
#   'Among women consuming </=17.4 g/d of linoleic acid, there was no association with breast cancer risk.'],
#  3836: ['Association of progesterone receptor gene polymorphism with male infertility and clinical outcome of ICSI Progesterone receptor polymorphisms and clinical response to 17-alpha-hydroxyprogesterone caproate Clarifying the PROGINS allele association in ovarian and breast cancer risk: a haplotype-based analysis.'],
#  5430: ['The odds ratio for the His-encoding rs3218536 (A) allele carriers is homozygote is 0.79, CI: 0.62-1.00, p=0.05. rs3218536 (A) carriers also appear to be at lower risk for epithelial ovarian cancer.'],
#  2853: ['This SNP, also known as P532L, affecting an amino acid in exon 1 of the KCNA5 potassium channel gene, may mediate the response to drugs such as quinidine.The risk allele is rs45477792 (T), and carriers receiving quinidine or propafenone for the treatment of cardiac arrhythmias may be resistant to the drug (and thus treatment).'],
#  2375: ['rs137853824, also known as c.961A>G, Ser321Gly or S321G, is a variant in the GNPTAB gene on chromosome 12.The minor (G) allele of rs137853824 was a rare mutation in the GNPTAB gene associated with stuttering in a 2010 study.'],
#  4594: ['Aka c.963C>A (p.Tyr321Ter or Y321X) and also c.963C>T (p.Tyr321=). the latter is annotated in ClinVar as likely to be benign, while the former has been reported as likely to be pathogenic for Andermann syndrome, a recessively inherited disorder.Note that the ref and alt alleles that are tested by both Ancestry and 23andMe are G and A, respectively, which means they represent the benign c.963C>T variant, since the alleles are reported by these companies based on the forward/plus strand, whereas the cDNA for the SLC12A6 gene is reported on the reverse/minus strand.'],
#  3078: ['rs1800630 is a SNP upstream of the tumor necrosis alpha (TNF) gene; this SNP is also typically called the -863 variant.In a study of 154 Thai patients with systemic lupus erythematosus (SLE), rs1800630 (A) allele frequency was significantly increased, with an odds ratio of 1.85 (CI: 1.21-2.83, p (corr) = 0.009).',
#   'This allele was also found to be significantly increased in the SLE group with Raynauds phenomenon compared to SLE without Raynauds phenomenon ( odds ratio of 2.23, CI: 1.21-4.10, p (corr) = 0.048).Separately, a meta-analysis of 10 case-control studies, including over 2,200 Graves disease cases, concluded that rs1800630 (A) carriers were associated with the disease.'],
#  1276: ['Pubmed 1180576 Schizophrenia Susceptibility Genetic basis for individual variations in pain perception and the development of a chronic pain condition.'],
#  3985: ['In a 2017 publication, carriers of a rs483352909 (G) mutation had an estimated cumulative risk of developing CRC by age 70 years of 97% (CI: 85%–99%) for males and 92% (CI: 75%–99%) for females.Note: as a C/G mutation oriented on the minus strand in dbSNP, be wary of ambiguous flips when interpreting data from this SNP.'],
#  4718: ['Variants of the serotonin transporter gene and NEO-PI-R Neuroticism: No association in the BLSA and SardiNIA samples.'],
#  3551: ['Ser608Leu polymorphisms in the nitric oxide synthase-2 gene may influence urinary bladder cancer pathogenesis.'],
#  5031: ['Sequence variants of Toll-like receptor 4 (TLR4) and the risk of prostate cancer in Korean men.'],
#  83: ['Among non-small cell lung cancer patients treated with gefitinib, theres a 4-5x higher risk of diarrhea for rs2231142 heterozygotes (and presumably minor allele homozygotes), based on a study of 124 patients treated with 250mg oral gefitinib once daily. rs2231142 also appears to influence the effectiveness of rosuvastatin.'],
#  4475: ['Genetic polymorphisms and susceptibility to lung disease.'],
#  2840: ['A GWAS carried out by Smoller et al identified three SNPs predictive of autism spectrum disorder, attention deficit-hyperactivity disorder, bipolar disorder, major depressive disorder, and schizophrenia &#8211; rs2535629, rs11191454, and rs2799573 &#8211; and one predictive of bipolar disorder and schizophrenia only &#8211; rs1024582.',
#   'All subjects were of European ancestry.====Major Depressive and Bipolar Disorder====Another study identified rs2251219, a SNP 248kb away from rs2535629, but within the 1Mb haplotype, as significantly associated with bipolar disorder and combined major depressive disorder.',
#   'The study analyzed individuals of European origin, of whom 8765 cases of bipolar disorder and major depressive disorder as defined by DSM-IV and 9122 controls.'],
#  2759: ['An investigation of genome-wide studies reported susceptibility loci for ulcerative colitis shows limited replication in north Indians.'],
#  1158: ['rs1051730 (T;T) individuals respond slower to alcohol, which generally is considered to actually increase their long-term risk of alcohol abuse./ 23andMe blog (T;T) makes it harder to quit smokingPeripheral Artery Disease.'],
#  2475: ['This SNP is estimated to explain 9.6% of the total variation in the viral set point.Humans show remarkable variation in vulnerability to infection by HIV-1 and especially in the clinical outcome following infection.',
#   'HCP5 is a good candidate to interact with HIV-1, possibly through an antisense mechanism.',
#   'HIV-1 nonprogressors (odds ratio, 3.47) Marker HLA-B 5701 hypersensitivity to the HIV drug abacavir; FDA warning hereHIV ProgressionAbacavir HypersensitivityFloxacillin Toxicity.'],
#  28: ['MDR1 C3435T polymorphism and cancer risk: a meta-analysis based on 39 case-control studies.'],
#  4622: ['Skin color.'],
#  5199: ['TTR-related cardiac amyloidosis rs76992529.'],
#  162: ['rs61751103 Alzheimers disease assocation.'],
#  5160: ['Focal segmental glomerulosclerosis 2 rs121434391.'],
#  5083: ['rs267607130 dilated cardiomyopathy, type 1FF.'],
#  2151: ['GAB2 alleles modify Alzheimers risk in APOE epsilon4 carriers.'],
#  4923: ['Leigh syndrome is more common in some French-Canadian populations.'],
#  5133: ['Mutations that alter the surface charge of alpha-tropomyosin are associated with dilated cardiomyopathy.'],
#  1766: ['Loss-of-function ENPP1 mutations cause both generalized arterial calcification of infancy and autosomal-recessive hypophosphatemic rickets.'],
#  75: ['Aka c.31_46del16 (p.Arg11Serfs) Reported in ClinVar as pathogenic for adrenoleukodystrophy (ALD).'],
#  3536: ['NOD2 SNP, aka R703COne of 11 SNPs used in a genetic risk score for inflammatory bowel disease.'],
#  4558: ['Aka c.163C>T (p.Arg55Ter) considered pathogenic for X-linked Lymphoproliferative syndrome, type 1 in ClinVar.'],
#  15: ['This is a recessive SNP for congenital Lamellar ichthyosis, type 2, also called ichthyosis-4A, a significant skin condition.'],
#  4534: ['Rare loss-of-function variants in SETD1A are associated with schizophrenia and developmental disorders.referred to in the cited paper as 16:30977140_C/G and also as p.Y646X.'],
#  2685: ['Type-2 diabetes, insulin sensitivity, and obesity with body fat decreasing ~1.5-2% per copy of the A allele.'],
#  3011: ['rs261332 increases susceptibility to Elevated HDL-Cholesterol for carriers of the A allele A allele is associated with 1.41mg/dl increase in HDL cholesterol (good cholesterol).'],
#  983: ['Also known as c.2287G>T or p.Glu763Ter, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer in ClinVar.'],
#  2346: ['A systematic, large-scale resequencing screen of X-chromosome coding exons in mental retardation.'],
#  1965: ['Aka c.2918A>G, p.Tyr973Cys and Y973C; autosomal dominant mutation associated with a form of glomerulopathy with fibronectin deposits (type 2). see also OMIM.'],
#  5223: ['Polymorphisms in estrogen- and androgen-metabolizing genes and the risk of gastric cancer.'],
#  385: ['One study found that Ashkenazi who lived to age 95 or older are more likely to have two copies of the C allele.'],
#  1283: ['/ 23andMe blog hearing loss linked to a chemotherapy drug named Cisplatin.'],
#  1762: ['Sequencing of TGF-beta pathway genes in familial cases of intracranial aneurysm.'],
#  3360: ['Lack of association of polymorphisms in homocysteine metabolism genes with pseudoexfoliation syndrome and glaucoma.'],
#  1505: ['A study of 858 cases concluded that SNPs in the intron of the CYP2J2 gene were associated with increased risk for myocardial infarction.'],
#  5174: ['rs200038418, also known as c.2531G>A, p.Gly844Asp and G844D, represents a rare mutation in the TRPM4 gene.The minor allele is considered causative in a dominant manner for progressive familial heart block type 1B in ClinVar.'],
#  2753: ['rs11465804 is one of several SNPs in the IL23R gene that has been shown in a large (over 1,000 Caucasian patients) study to be associated with ankylosing spondylitis.'],
#  3874: ['C.12310_12311delGT (p.Val4104Tyrfs) The variant allele of this SNP is considered either definitely pathogenic or highly likely pathogenic for autosomal dominant polycystic kidney disease in the PKD Foundation database as well as in ClinVar.'],
#  3868: ['Aka c.388G>A (p.Glu130Lys) rs121909109 represents a variant in the PITX1 gene on chromosome 5; the rare rs121909109 (A) allele is considered a dominant mutation leading to talipes equinovarus, based on an analysis of a 5-generation family segregating asymmetric right-sided predominant clubfoot.'],
#  1917: ['rs121913114, also known as Ser279Cys or S279C, is a mutation in the FGFR3 gene on chromosome 4.Acting in an autosomal dominant manner, the rs121913114 (T) allele is considered to cause achondroplasia; see also OMIM 134934.0030Note that 23andMe refers to this SNP as i5001264.'],
#  2048: ['rs56214919, also known as c.517 T>G or p.W173G, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  1735: ['Also known as c.1392delT (p.Arg465Valfs), this rare mutation in the EIF2AK4 gene is reported in ClinVar as leading to - when inherited recessively - rare forms of pulmonary hypertension, specifically, pulmonary capillary hemangiomatosis (PCH) and pulmonary venoocclusive disease (PVOD).'],
#  2920: ['The odds ratio is 2.6 (CI: 1.4-5.5) for carriers of a rs2249358 (G) allele, as in dbSNP orientation.'],
#  4655: ['rs3802177 replicated as significant for type-2 diabetes risk in 1,900 Japanese patients, with odds ratio of 1.16 (CI: 1.05-1.27, p = 4.5 x 10e-3) Note: this SNP is fairly tightly linked (r<sup>2</sup> = 0.83) to another SNP in the SLC30A8 gene also linked to type-2 diabetes, rs13266634.'],
#  3002: ['Aka c.1733A>G (p.Asp578Gly or D578G) The rs121912518 (G) mutation is considered to be a dominantly inherited mutation leading to familial male precocious puberty, and in the US (but not in Europe), it is the most common such mutation.A 2019 article about a male inheriting such a mutation is here.'],
#  3838: ['p-values account for ethnic heterogenity of study population.In, no evidence for linkage to colorectal cancer in women was found in a study with 158 European subjects and 563 controls.',
#   'Genetic variation in sex-steroid receptors and synthesizing enzymes and colorectal cancer risk in women.'],
#  1828: ['rs373297713, better known as c.1716+1G>A or IVS14DS, G-A, +1, is a SNP in the coagulation factor XI F11 gene.This SNP is reported by 23andMe as one of the three most common factor XI deficiency-causing mutations found in Ashkenazi Jews; it is termed i4000397 by 23andMe.See OMIM 264900.0001.'],
#  2718: ['IL-16 rs11556218 gene polymorphism is associated with coronary artery disease in the Chinese Han population.'],
#  5449: ['A 2014 study Genome-wide association study identifies multiple susceptibility loci for pancreatic cancer of 7,683 European cases and 14,397 controls found the minor allele rs16986825 (T) in ZNRF3 (zinc and ring finger 3) conferring risk of statistically genome-wide significance (per-allele odds ratio (OR) = 1.18, 95% confidence interval (CI) 1.12-1.25, P = 1.2E-8) for Pancreatic cancer.'],
#  4573: ['rs6257 is a potential breast cancer variant Ovarian cancer risk and common variation in the sex hormone-binding globulin gene: a population-based case-control study.',
#   'Genetic polymorphisms are associated with serum levels of sex hormone binding globulin in postmenopausal women.',
#   'Coffee and caffeine consumption in relation to sex hormone-binding globulin and risk of type 2 diabetes in postmenopausal women.'],
#  4852: ['rs35948326, also known as c.2909C>A, p.Ala970Asp, A970D and alpha-IIa, represents a variant in the SPTA1 gene on chromosome 1.Although reported as associated with autosomal recessive spherocytosis, the rs35948326 (A) allele (as reported in dbSNP orientation) may actually be more of a proxy for a truly defective variant that is co-inherited as a result of linkage.'],
#  819: ['Thyroid nodules, polymorphic variants in DNA repair and RET-related genes, and interaction with ionizing radiation exposure from nuclear tests in Kazakhstan.'],
#  4294: ['The N88K mutation is the most common one leading, when inherited recessively, to congenital myasthenic syndrome.'],
#  1732: ['Aka c.2573T>A, p.Leu858Gln or L858Q, and also c.2573T>G, p.Leu858Arg or L858RThe L858Q variant (in the EGFR gene) is reported in ClinVar as a germline variant considered likely pathogenic in association with non-small cell lung cancer.The L858R variant is reported in ClinVar primarily as a somatic (not germline) variant, observed in tumors and reported to be predictive of response to various chemotherapeutics used to treat non-small cell lung cancer.'],
#  622: ['The activity of this gene product can be affected by stress, by cortisol levels and may play a role in ADD/ADHD by affecting norepinephrine levels.Yasko believes that BHMT-02 and BHMT-04 play a role in the gut environment.'],
#  2773: ['rs2070874 is a SNP in the promoter region of the interleukin 4 IL4 gene.This SNP is one of five SNPs reported to be useful in a SNP set defining the risk of dying from prostate cancer among patients with the disease; see gs242 and gs243.'],
#  4857: ['Plos Polymorphisms in the gene encoding sterol regulatory element-binding factor-1c are associated with type 2 diabetes.'],
#  3003: ['Mutation analysis of the LH receptor gene in Leydig cell adenoma and hyperplasia and functional and biochemical studies of activating mutations of the LH receptor gene.'],
#  565: ['rs638405, a SNP also known as Val262, is located in exon 5 of the BACE1 gene, and is associated in some studies (but not others) with increased risk for late-onset Alzheimers disease.',
#   'The only statistically robust associations with increased risk for Alzheimers disease appear to be seen in individuals who are also ApoE4 carriers.',
#   'For example, a meta-analysis pooling 4 Chinese and 1 Korean study found a significant association between the (G;G) - in orientation to dbSNP, not as published - genotype and Alzheimers disease in ApoE4+ groups with an odds ratio of 1.99 (CI: 1.319-3.018, p=0.0044).'],
#  3041: ['The LPP protein is involved in cell motility and cell&#8211;cell adhesion, which is crucial to maintaining the barrier integrity of epithelial monolayers such as those in the small intestine.A study of several populations eventually settled on rs4686484 as the SNP most likely to be the functional variant at the heart of the haplotypes associated with altered risk for celiac disease.'],
#  3161: ['This also meant that each rs16991615 (G) allele yielded an odds ratio of 1.85 (CI: 1.51&#8211;2.2, p = 1.45 x 10e-9) of early menopause, defined as occurring before the age of 46.Overall, women homozygous for the early alleles at all 4 SNPs found in this study were ~4 times more likely to undergo menopause early compared to women who had a total of 3 or less risk alleles.'],
#  196: ['rs17300539, also known as -11391 G/A, is a SNP in the promoter of the adiponectin ADIPOQ gene.A small study of 180 Spanish patients with obesity concluded that rs17300539 (G;G) individuals are at increased risk of insulin resistance and MetS complications compared to carriers of an (A) allele.'],
#  2845: ['Individuals with risk genotypes of both rs3748079 and rs3095870, in the ITPR3 and NKX2.5 genes, respectively, have even high risk for SLE (odds ratio 5.77).This particular SNP also revealed associations with rheumatoid arthritis (RA) (p=0.0084 with odds ratio of 1.23, CI:1.05-1.43) and with Graves disease (GD) (p=0.00036 with odds ratio of 1.57, CI:1.22-2.02).Note that the orientation of this SNP as published is reversed compared to the dbSNP entry.'],
#  2158: ['This SNP in the GABRA2 gene has been linked to Alcoholism.'],
#  4166: ['They are trying to discover why at least a third of people with Alzheimers disease do not have the an APO E4 allele, and why some people who are homozygotes for APO E4 do not get the disease.'],
#  5424: ['Pseudo-haplotype with AG-CC genotypes in 2.45x risk rs2040639 - rs861539 5.03x risk rs2040639 - rs861539 - rs2075685 10.10x risk rs2040639 - rs861539 - rs2075685 - rs1799782 A meta-analysis concludes that this SNP is not associated with risk of gastric cancer.'],
#  1403: ['The allele with impaired function, rs6467 (C), is the CYP21A2 9 allele.See further details at congenital adrenal hyperplasia.'],
#  4209: ['rs63750197, also known as S130L or Ser130Leu, is a SNP in the presenilin 2 PSEN2 gene.Although based on small numbers of patients, the rare rs63750197 (T) allele has been reported to be associated with both Alzheimers disease and a form of dilated cardiomyopathy., However, the Alzheimer pathogenicity is considered unclear, and while the evidence for involvement with dilated cardiomyopathy evidence is strong, the condition has incomplete penetrance.'],
#  3010: ['Genetic polymorphisms in fatty acid metabolism genes and colorectal cancer.'],
#  5324: ['Vascular endothelial growth factor gene polymorphisms and rheumatoid arthritis.',
#   'Interaction between smoking and polymorphism in the promoter region of the VEGFA gene is associated with ischemic heart disease and myocardial infarction in rheumatoid arthritis.',
#   'Polymorphism in the vascular endothelial growth factor A (VEGFA) gene is associated with serum VEGF-A level and disease activity in rheumatoid arthritis: differential effect of cigarette smoking.'],
#  3205: ['According to the authors, this is the first study to suggest that genetic factors can affect performance of facial emotion perception.==Association with chronic rhinosinusitis==The MET gene has been implicated in nasal polyp development, and Castano et al showed that the minor allele at rs2237717 is associated with chronic rhinosinusitis in patients with nasal polyps (genotypic P nominal = 0.09, empirical P = 0.04, OR = 1.4, CI = 1.0-1.9).',
#   'Study findings apply to patients with nasal polyps and severe CRS unresponsive to surgery.'],
#  4882: ['Genetic risk factors in lupus nephritis and IgA nephropathy--no support of an overlap.'],
#  1711: ['Association study of candidate variants from brain-derived neurotrophic factor and dystrobrevin-binding protein 1 with neuroticism, anxiety, and depression.',
#   'Dysbindin gene (DTNBP1) in major depression: association with clinical response to selective serotonin reuptake inhibitors.'],
#  1278: ['Reports that ease of entering hypnosis correlates with number of rs4680 (G) alleles.see gs226 for a report related to impulsiveness and / blog discussion of data about rs4680 thinking about nothing in an fmri.Breast Cancer Risk Modifiers.'],
#  1115: ['Cystic Fibrosis rs397508393.'],
#  1100: ['Cystic Fibrosis rs121908744.'],
#  3042: ['Celiac Disease.'],
#  278: ['Hereditary fructose intolerance rs387906225.'],
#  1117: ['Cystic Fibrosis rs121909013.'],
#  4658: ['Glycogen Storage Disease Type 1b rs80356489.'],
#  113: ['Medium-Chain Acyl-CoA Dehydrogenase Deficiency rs121434282.'],
#  1597: ['Bipolar disorder failed to replicate in.'],
#  852: ['Clinical spectrum of episodic ataxia type 2.'],
#  4805: ['A polymorphism on the SOD1 gene known as A4V.'],
#  2901: ['Further evidence that the KIAA0319 gene confers susceptibility to developmental dyslexia.'],
#  1140: ['This SNP represents a silent polymorphism in the cancer-associated cell cycle regulator CHEK2 gene.'],
#  3824: ['PEX7 Arg232Ter or R232XRhizomelic chondrodysplasia punctata type 1This SNP is called i5006212 by 23andMe.'],
#  3020: ['Aka c.1296_1299dupGCAC and also c.1296_1299delGCACGCAC; both are annotated in ClinVar as pathogenic or likely pathogenic for cardiomyopathy.'],
#  3646: ['rs1042114 increases susceptibility to Substance dependence, Opioid 3.56 times for carriers of the G allele.'],
#  5211: ['Also known as c.5G>A, p.Arg2Lys and R2K Mutations in TUBB8 and Human Oocyte Meiotic Arrest.'],
#  712: ['C.211A>G (p.Arg71Gly) ClinVar designates this variant as pathogenic/likely pathogenic for breast cancer23andMe name: i5005573.'],
#  2218: ['I4000419, also known as V394L (risk genotype AA) Possibly associated with Gauchers disease.Gaucher Disease rs80356769.'],
#  4314: ['Haplotype analysis reveals a possible founder effect of RET mutation R114H for Hirschsprungs disease in the Chinese population.'],
#  857: ['Severe arrhythmia disorder caused by cardiac L-type calcium channel mutations.',
#   'Severe arrhythmia disorder caused by cardiac L-type calcium channel mutations.'],
#  990: ['Also known as c.1999delC, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer in ClinVar.'],
#  2972: ['Gwas among adults residing on Korcula Island in Croatia, cholesterol, the C allele associated with decreased total cholesterol levels<br><br>.'],
#  766: ['rs80357848, also known as 3883insA, c.3764_3765insA and p.Asn1255?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  697: ['rs80357071, also known as S1383X, c.4148C>G and p.Ser1383Ter, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  2956: ['KRIT1 gene, c.987C>A, p.Cys329Ter, C329X mutation rs267607204 (A) is considered a dominantly inherited pathogenic mutation for cerebral cavernous malformation.'],
#  263: ['Point substitutions in Japanese alloalbumins.'],
#  3015: ['Association of an intronic haplotype of the LIPC gene with hyperalphalipoproteinemia in two independent populations.'],
#  4785: ['C.136G>A (p.Glu46Lys or E46K) Considered probably pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal dominant Parkinson disease.See also OMIM 163890.000423andMe calls this i5002552.'],
#  351: ['A founder mutation in Anoctamin 5 is a major cause of limb-girdle muscular dystrophy.'],
#  2556: ['It has been associated with slightly (~30%) higher risk for azoospermia (lack of sperm) and thus male infertility in both Chinese and Japanese men.'],
#  3770: ['C.192G>C (p.Glu64Asp or E64D) Considered definitely pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal recessive, early-onset Parkinson disease (type 7) See also OMIM 602533.000523andMe names this i5047044.'],
#  326: ['I6006953, also known as c.1363G>A or p.G455S, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the adult form of hypophosphatasia.'],
#  3219: ['Shows that the following four SNPs in the MHC region play a particular important role in the protection of developing AIDS: rs9264942, rs4418214, rs2395029, rs3131018 also including the two variants in CCR5 rs333 (delta32) and C927T.'],
#  303: ['I5002773, also known as c.881A>C or p.D294A, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the infantile form of hypophosphatasia.'],
#  1674: ['Implicated as part of a haplotype of the dopamine D1 receptor DRD1 gene associated with autism spectrum disorders in families having only affected males.'],
#  606: [],
#  3785: ['rs28362263, also known as A443T, is a SNP in the PCSK9 gene.It has been reported in several studies (including and ) to be a loss-of-function mutation leading to modestly (~3%) lowered LDL-C levels and thereby somewhat reduced risk for coronary events.'],
#  2232: ['Genetic and environmental determinants of 25-hydroxyvitamin D and 1,25-dihydroxyvitamin D levels in Hispanic and African Americans.'],
#  3877: ['Aka c.9829C>T, p.Arg3277Cys and R3277CConsidered a hypomorphic mutation in terms of end-stage renal disease (ESRD) and autosomal dominant polycystic kidney disease; when homozygous, associated with adult onset ADPKD and when heterozygous more likely to result in the development of just a few cysts.'],
#  5023: ['rs3804100, also known as 1350T/C, is a SNP in the toll-like receptor 2 TLR2 gene.A study of 700 T1D children, 357 nuclear families with T1D children and 796 children from the Environment and Childhood Asthma study concluded that both type-1 diabetes and allergic asthma were significantly associated with the rs3804100 (T) allele.'],
#  2703: ['Dust mite exposure modifies the effect of functional IL10 polymorphisms on allergy and asthma exacerbations.Dust mite exposure significantly modified the relation between 3 SNPs in IL10 ( rs1800896, rs3024492, and rs3024496 ).'],
#  4763: ['rs76871093, also known as c.821C>T, p.Thr274Ile and T274I, is a mutation in the SMN1 gene on chromosome 5.The rare rs76871093 (T) allele is a mutation associated with the recessively inherited type 2 or 3 spinal muscular atrophy.This SNP is referred to as i5005727 by 23andMe.'],
#  3188: ['rs104895093, also known as c.2076_2078delAAT, is a SNP in the MEFV gene.The symptoms of familial Mediterranean fever are caused by the persons own inflammatory response; it is not an infectious disease.'],
#  414: ['Lung cancer rs3117582 P = 4.97 x 10 (-10) Update in lung cancer 2008.',
#   'Role of 5p15.33 (TERT-CLPTM1L), 6p21.33 and 15q25.1 (CHRNA5-CHRNA3) variation and lung cancer risk in never-smokers.'],
#  3407: ['The rare minor allele of this variant, c.1624+2T>C, is reported to be pathogenic/likely pathogenic for familial hypertrophic cardiomyopathy (HCM), according to.'],
#  1748: ['A study of several cases of familial Parkinsons disease concluded that rs113169049 (C), a very rare allele, may be a dominant mutation leading to late-onset disease.'],
#  3236: ['635 lung cancer cases with onset of disease below 51 years of age and 1,300 controls.',
#   'Major alleles associated with increased in risk of early-onset lung cancer modified by smoking.'],
#  225: ['rs3889728 is a SNP in the AGT gene that, at least when part of a haplotype, has been associated with increased risk for developing pre-eclampsia, but it was not reported to have the most influence of the 3 SNPs in the haplotype.'],
#  2591: ['According to the lack of a C allele for this gene indicates an increase in ADHD behavior for children age 3 and 8/9 when they have been exposed to certain food additives: sunset yellow, carmoisine, tartrazine, ponceau 4R, quinoline yellow, allura red AC and sodium benzoate.'],
#  2755: ['A;A homozygous individuals showed a strongly reduced risk of Crohns Disease compared those who were G;G homozygous.'],
#  5200: ['News article indicating up to 1% of Irelands Donegal County may carry the T60A mutation.23andMe name: i5004213.'],
#  3837: ['rs578029 who had a least one copy of the major allele, treatment significantly reduced in preterm birthnon-black women a least one copy of the minor allele of rs503362 had a significant reduction with treatment with at least one copy of the minor allele of rs666553 had a significant reduction in very preterm birth.'],
#  4073: ['Association of PRKCH gene with lacunar infarction in a local Chinese Han population.'],
#  4462: ['The cancers most often mentioned in association with G12S are paragangliomas and pheochromocytomas.'],
#  4887: ['Specificity of the STAT4 genetic association for severe disease manifestations of systemic lupus erythematosus.',
#   'A risk haplotype of STAT4 for systemic lupus erythematosus is over-expressed, correlates with anti-dsDNA and shows additive effects with two risk alleles of IRF5.',
#   'Role of STAT4 polymorphisms in systemic lupus erythematosus in a Japanese population: a case-control association study of the STAT1-STAT4 region.',
#   'Population differences in SLE susceptibility genes: STAT4 and BLK, but not PXK, are associated with systemic lupus erythematosus in Hong Kong Chinese.'],
#  655: ['Note that this SNP is known to have reduced penetrance (~40 - 50%).The normal/common (unmutated) form of the 185delAG SNP is called i4000377 (I;I) by 23andMe; the genotypes containing the mutation are i4000377 (D;I) or even less commonly i4000377 (D;D).'],
#  4625: ['In a study size of 117 Caucasians with Asperger syndrome and 426 controls Single nucleotide polymorphism rs6716901 in SLC25A12 gene is associated with Asperger syndrome found association of this SNPs minor allele (A) in SLC25A12 gene with Asperger syndrome.'],
#  164: ['The rs61751103 (G) allele was found in 11 of 16 individuals affected by Alzheimers disease (average onset age 69.5 years) from seven late-onset AD families.'],
#  4453: ['There are at least two publications in which the complex allele carrying both variants is reported to be associated with congenital insensitivity to pain (CIP) and/or lower post-operative pain following surgery.However, there is also a report of a patient carrying this complex allele who had a small fiber neuropathy and increased pain.'],
#  1248: ['rs1800012 (T;T) was significantly (p=0.031, OR=0.08, 95%CI <0.01 to 1.46) under-represented in South African participants with anterior cruciate ligament ruptures, based on a study of ~100 patients vs ~100 controls.Summary relevant to intervertebral disc disease for rs1800012 (T), from : odds ratio (OR) 3.6 for TT genotype compared with GT or GG, in study of 966 elderly Dutch T allele associated with more severe IVDD in study of 75 Southern European male patients vs 25 controls.'],
#  798: ['The genotypes containing the causal/pathogenic variants are (D;I) and the even rarer (D;D).For information about causal/pathogenic BRCA2 mutations and what they imply about the odds of developing breast cancer, please see the BRCA2 page and links from that page.i4000379 is the identifier used by 23andMe for the 6174delT mutation that is rs80359550 as identified in public SNP databases.Additional BRCA information may be found in numerous places online, and within 23andMe, / here.In addition to i4000379, the other names used by 23andMe for the most common causal mutations are i4000377 and i4000378.'],
#  4113: ['Also referred to as 1766A/G plos rs450046 was most strongly positively associated with schizophrenia in families.',
#   'Structural cerebral variations as useful endophenotypes in schizophrenia: do they help construct extended endophenotypes?.',
#   'Functional polymorphisms in PRODH are associated with risk and protection for schizophrenia and fronto-striatal structure and function.',
#   'Executive function, neural circuitry, and genetic mechanisms in schizophrenia.'],
#  1693: ['Association and synergistic interaction between promoter variants of the DRD4 gene in Japanese schizophrenics.'],
#  521: ['Variants in the ATM gene associated with a reduced risk of contralateral breast cancer.'],
#  111: ['However, the same study describing the decreased gene activity reported that this variant was not associated with histamine intolerance (HIT), suggesting that the variant may be necessary but not sufficient (on its own) to lead to actual HIT.No association between the promoter SNP rs2052129 and the risk of developing NSAID hypersensitivity was seen in a 2012 study of 442 Caucasian patients.A different 2012 study of ~300 patients with selective NSAID hypersensitivity found no association for rs2052129. however, they reported that logistic regression analyses suggested that rs2052129 (C;C) homozygotes were related to selective hypersensitivity to ibuprofen.'],
#  2422: ['OMIM reports the rs63751243 (A) allele as representing a dominantly inherited mutation associated with ubiquitin-positive frontotemporal lobar degeneration.'],
#  365: ['rs5082 is a SNP in the apolipoprotein APOA2 gene, and may influence obesity and heart disease risk.Individuals homozygous for the -265T>C polymorphism in rs5082, i.e.',
#   'Individuals with the rs5082 (C;C) genotype of the Apolipoprotein A-II gene (APOA2) promoter, are associated with increased obesity|Body Mass Index and food intake in the Genetics of Lipid Lowering Drugs and Diet Network (GOLDN) Study of ~1000 individuals.',
#   'The odds ratio for obesity in (C;C) individuals compared to rs5082 (T) allele carriers was 1.70 (CI: 1.02-2.80, p=0.039).'],
#  952: ['Again, the odds ratio suggests a modest protective affect for the minor allele T.An additional study looked at this SNP and its association with RA in individuals of Korean ancestry.',
#   'This study found no association between rs4810485 and RA in patients with Korean ancestry.',
#   'The targeted validation study looked at 5 SNPs associated with RA in Europeans in 1,113 Korean cases and 988 controls, and found a p-value of 0.39 and an odds ratio of 1.06, suggesting no association between the SNP and RA in Koreans.'],
#  4729: ['The Gene Sherpa points out a 16x odds ratio for myopathy when taking statins and suggests fenofibrates might be a good alterative.From Coriell (re SLCO1B1 haplotypes) : rs72559745 (SLCO1B1 1) AAAA rs56061388 (SLCO1B1 3) TTTT rs4149056 (SLCO1B1 5) TTTT rs55901008 (SLCO1B1 6) TTTT A study of ~500 individuals taking statins concluded that rs4149056 (C), i.e.'],
#  5035: ['Allograft rejection Carriers of the risk alleles of either rs4986790 or rs4986791 have a lower rate of acute allograft rejection following lung transplantation.'],
#  1227: ['Further evidence for association of polymorphisms in the CNR1 gene with cocaine addiction: confirmation in an independent sample and meta-analysis.'],
#  249: ['A case-control study of 489 first-episode psychosis patients concluded that while rs2494732 was not associated with an increased risk of a psychotic disorder, with lifetime cannabis use, or with frequency of use, there was a significant association between psychosis and cannabis use.',
#   'rs2494732 (C;C) individuals with a history of cannabis use had an increased likelihood of a psychotic disorder (odds ratio 2.18, CI: 1.1 - 4.3) when compared with users who were (T;T) carriers.'],
#  3678: ['Studies have demonstrated that individuals with the G allele are more empathetic, feel less lonely, employ more sensitive parenting techniques, and have lower rates of autism (discussed in ) The blog / Not Exactly Rocket Science discusses that Americans with (G;G) tend to be more sensitive parents, more empathetic and less lonely than those with an &#8216;A&#8217;.',
#   'This study found that there is no association between rs53576 variants and the risk of autism in Caucasian children and adolescents.Followup:.'],
#  1092: ['Cystic Fibrosis rs74597325.'],
#  3416: ['rs121913626 familial hypertrophic cardiomyopathy.'],
#  5235: ['Eye color.'],
#  4747: ['rs75660264 spinal muscular atrophy.'],
#  4767: ['Niemann-Pick Disease Type A rs120074124.'],
#  5368: ['rs61749397 Von Willebrand disease.'],
#  3849: ['rs74315360 Parkinsons disease, type 6.'],
#  2322: ['rs371024165 recessive GJB2 gene variant associated with deafness.'],
#  3764: ['rs137853051 Parkinsons disease, recessive/early-onset, digenic.'],
#  3055: ['Leigh syndrome, French Canadian Type (LSFC) rs119466000.'],
#  259: ['Novel nonsense mutation causes analbuminemia in a Moroccan family.'],
#  3873: ['C.6424delC (p.Gln2142Argfs) Listed in ClinVar as pathogenic for autosomal dominant polycystic kidney disease.'],
#  5119: ['Nested association between genetic variation in tryptophan hydroxylase II, bipolar affective disorder, and suicide attempts.'],
#  544: ['X-inactivation in female human embryonic stem cells is in a nonrandom pattern and prone to epigenetic alterations.'],
#  4169: ['Dementia, SPASTIC PARAPARESIS, APRAXIA,.'],
#  993: ['Also known as c.1064delT, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer in ClinVar.'],
#  2185: ['Aka c.862T>C, p.Trp288ArgIdentified in ClinVar as likely pathogenic for Krabbe disease (when inherited recessively or as a compound heterozygote).'],
#  740: ['rs80357635, also known as 3347delAG, c.3228_3229delAG and p.Arg1076_Gly1077ArgAlafs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  982: ['Also known as c.1003C>T, p.Arg335Ter or R335X, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer in ClinVar.'],
#  700: ['rs80357161, also known as E1038X, c.3112G>T and p.Glu1038Ter, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  5328: ['Identification of genes and haplotypes that predict rheumatoid arthritis using random forests.'],
#  44: ['Aka c.523A>G (p.Thr175Ala) Based on a 2015 study of <100 patients, individuals carrying a rs58238559 (C) allele have a 3.75-fold increase in the probability of developing atrial fibrillation/flutter.'],
#  4333: ['Renalase gene is a novel susceptibility gene for essential hypertension: a two-stage association study in northern Han Chinese population.'],
#  4791: ['C.152G>A (p.Gly51Asp or G51D) Considered definitely pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal dominant Parkinson diseaseSee also OMIM 163890.0006.'],
#  4257: ['The rare (deletion) allele for this PTPRQ gene variant is reported to be causative for a recessive form of deafness; see PTPRQ for details and sources.'],
#  1964: ['In the homozygous minor genotype, it has been reported to lead to trimethylaminuria.'],
#  5176: ['rs267607142, also known as c.19G>A, p.Glu7Lys and E7K, represents a rare mutation in the TRPM4 gene.The minor allele is considered causative in a dominant manner for progressive familial heart block type 1B in ClinVar.'],
#  1210: ['A study of 391 overweight patients concluded that the haplotype of rs1554483 (G) and rs4864548 (A) was associated with a 1.8-fold higher risk (CI: 1.31-2.54, p < 0.001) of obesity.'],
#  313: ['I6006897, also known as c.1184T>C or p.I395T, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the perinatal form of hypophosphatasia.'],
#  3881: ['Polycystic Kidney disease; see OMIM 601313.0004NM_001009944.2:c.12682C>TThe variant allele of this SNP is considered either definitely pathogenic or highly likely pathogenic for autosomal dominant polycystic kidney disease in the PKD Foundation database.'],
#  4070: ['It has been linked to memory capacity in healthy subjects and to risk for post-traumatic stress disorder Risk allele is A..'],
#  2026: ['rs141526971, also known as c.482_+_2 T>G or, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  1739: ['Also known as c.1754G>A (p.Arg585Gln), this rare mutation in the EIF2AK4 gene is reported in ClinVar as leading to - when inherited recessively - rare forms of pulmonary hypertension, specifically, pulmonary capillary hemangiomatosis (PCH) and pulmonary venoocclusive disease (PVOD).'],
#  2252: ['rs11158026 (T) allele carriers show a slight increase in risk for Parkinsons disease, based on a study of ~200 patients; odds ratio 1.23, p = 0.048 (i.e.'],
#  3651: ['rs10485057 is a SNP in the opioid receptor, mu 1 OPRM1 gene.A study of 688 Caucasian smokers (and non-smoking controls) indicated that the rare rs10485057 (G) allele was associated with higher likelihood of smoking initiation and nicotine dependence.'],
#  1004: ['Variable clinical features in patients with CDH23 mutations (USH1D-DFNB12).'],
#  4464: ['The rs5361 Ser128Arg variation in this gene, known as E-selectin, is linked to several thrombotic disorders. rs5361 (C;C) homozygous carriers of the Ser128Arg allele are at a 4X higher risk for recurrent venous thromboembolism (VTE). heterozygous carriers are not at increased risk.'],
#  2034: ['2), is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  2423: ['Characteristics of frontotemporal dementia patients with a Progranulin mutation.',
#   'Distinct genetic forms of frontotemporal dementia.'],
# ...
#  3545: ['rs10494366 minor homozygotes had a 9.3 msec longer QT interval compared to major homozygotes (p=5.7x10 (-5) ). rs10918594 minor homozygotes had a 12.5 msec longer QT interval compared to major homozygotes (p=1.5x10 (-6) ).'],
#  3790: ['Mutations and polymorphisms in the proprotein convertase subtilisin kexin 9 (PCSK9) gene in cholesterol metabolism and disease.'],
#  2702: ['This combination of risk alleles led to lower IL-10 expression and higher TNF gene expression, resulting in a pro-inflammatory response.',
#   'The authors explain that in Ghana, pro-inflammatory alleles rescue their carriers of excess mortality in adverse environmental conditions such as drinking from boreholes, and thus minor alleles occur more frequently in African populations, but in an affluent environment, the same pro-inflammatory response leads to increased mortality, and minor alleles occur much less frequently (i.e.'],
#  1989: ['Appetite regulation genes are associated with body mass index in black South African adolescents: a genetic association study.'],
#  5244: ['In colorectal cancer patients being treated with irinotecan, adverse side effects (neutropenia and/or severe diarrhea) are reported to be strongly associated with the number of UGT1A1 28 alleles.'],
#  3052: ['LRP5 mutations in osteoporosis-pseudoglioma syndrome and high-bone-mass disorders.'],
#  2095: ['G6PD deficiency frequency is highest in malarial regions where G6PD deficient individuals are typically less affected by malarial infection ().The minor allele of this SNP should be reclassified as benign according to Study of malaria in Gambian children uses the rs1050829 allele to help detect G6PD deficient individuals.',
#   'The study found that in comparison to controls (n=69), Massalit individuals (n=60) who possess the rs105829 G allele were less susceptible to malarial infection (p=0.02).'],
#  1192: ['Kidney Stones.'],
#  2354: ['rs121964979 Non-ketotic hyperglycinemia.'],
#  963: ['rs121964874 CDH1, gastric cancer.'],
#  967: ['rs121964878 CDH1, gastric cancer.'],
#  3819: ['Rhizomelic Chondrodysplasia Punctata Type 1 rs1805137.'],
#  3404: ['See discussion at rs397515963 familial hypertrophic cardiomyopathy.'],
#  261: ['Analbuminemia produced by a novel splicing mutation.'],
#  2588: ['Chromosome 17q12 variants contribute to risk of early-onset prostate cancer.'],
#  4989: ['Juvenile hemochromatosis associated with pathogenic mutations of adult hemochromatosis genes.'],
#  5209: ['Also known as c.686T>C Mutations in TUBB8 and Human Oocyte Meiotic Arrest.'],
#  148: ['Genome-wide significant association between a sequence variant at 15q15.2 and lung cancer risk.'],
#  491: ['C.476C>T, p.Thr159Ile or T159Ipathogenic for argininosuccinate lyase deficiency, according to.'],
#  2886: ['A novel KCNQ4 pore-region mutation (p.G296S) causes deafness by impairing cell-surface channel expression.'],
#  2333: ['This variant has been reported for both recessive and dominant forms of both deafness and keratitis-ichthyosis-deafness syndrome.'],
#  1869: ['Individual and cumulative effects of GWAS susceptibility loci in lung cancer: associations after sub-phenotyping for COPD.'],
#  2183: ['Aka c.121G>A, p.Gly41SerIdentified in ClinVar as pathogenic for Krabbe disease (when inherited in two copies or as a compound heterozygote).'],
#  1219: ['Cone cGMP-gated channel mutations and clinical findings in patients with achromatopsia, macular degeneration, and other hereditary cone diseases.'],
#  5255: ['rs11892031A on chromosome 2q37 in an intronic region of the UGT1A locus is associated with urinary bladder cancer risk.'],
#  2265: ['Polymorphic Variation of the Guanosine Triphosphate Cyclohydrolase 1 Gene Predicts Outcome in Patients Undergoing Surgical Treatment for Lumbar Degenerative Disc Disease.'],
#  4640: ['rs111033199, also known as V138F, is a SNP in the SLC26A4 gene associated with the hearing loss condition known as Pendred Syndrome.'],
#  3978: ['Heterozygotes are predicted to have a significantly higher risk of colorectal cancer, based on both patient and theoretical studies.'],
#  843: ['rs10985112 increases susceptibility to Rheumatoid Arthritis 1.57 times for carriers of the A allele Genome-wide association study of rheumatoid arthritis by a score test based on wavelet transformation.'],
#  761: ['rs80357823, also known as 5438insC, c.5319_5320insC and p.Thr1773_Asn1774?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  1379: ['rs28399424, also known as 5090C>T or R431W, is a SNP in the CYP1A2 gene.The rs28399424 (T) allele defines the CYP1A2 6 decreased activity variant.'],
#  1460: ['rs72558187, also known as 269T>C, 3276T>C or L90P, is a SNP in the CYP2C9 gene.The rs72558187 (C) allele defines the CYP2C9 13 variant, which has decreased activity.'],
#  3542: ['Genetic association analysis of functional polymorphisms in neuronal nitric oxide synthase 1 gene (NOS1) and mood disorders and fluvoxamine response in major depressive disorder in the Japanese population.'],
#  854: ['Mutations in the cardiac L-type calcium channel associated with inherited J-wave syndromes and sudden cardiac death.'],
#  1994: ['The risk allele is C.'],
#  2017: ['rs138034837, also known as c.493 C>T or p.R165C, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  35: ['Polymorphisms in multidrug resistance 1 (MDR1) gene are associated with refractory Crohn disease and ulcerative colitis.'],
#  4421: ['rs140559739, also known as R514X, is a variant in the sarcosine dehydrogenase SARDH gene that has been reported to cause sarcosinemia, a condition brought about through autosomal recessive inheritance.In dbSNP orientation for this SNP, the variant (rare) allele is rs140559739 (A).'],
#  4938: ['TDP-43 mutations in familial and sporadic amyotrophic lateral sclerosis.',
#   'TDP-43 is not a common cause of sporadic amyotrophic lateral sclerosis.'],
#  4452: ['rs121908917, also known as c.984C>A, p.Tyr328Ter and Y328X, is a rare mutation in the SCN9A gene on chromosome 2.Inherited in a recessive manner, the homozygous minor genotype for this SNP is reported to result in insensitivity to pain.'],
#  1188: ['Decrement of compound muscle action potential is related to mutation type in myotonia congenita.'],
#  3093: ['Financial and psychological risk attitudes associated with two single nucleotide polymorphisms in the nicotine receptor (CHRNA4) gene.'],
#  1230: ['Randomized pharmacodynamic and pharmacogenetic trial of dronabinol effects on colon transit in irritable bowel syndrome-diarrhea.'],
#  3584: ['A Ser (T) at this location denotes the NQO1 2 allele.influences the risk of breast cancer according to the / 23andMe blog rs1800566 (C;T) heterozygotes have 0.48x reduced risk for Lung cancer.'],
#  3554: ['Lead exposure, polymorphisms in genes related to oxidative stress, and risk of adult brain tumors.'],
#  4775: ['The G allele of SNAP25 gene SNP rs362584 was associated with increased personality_traits|neurotic traits (combined p value = 0.0000522) in a group of 3972 Sardinians, and two smaller replicative samples from the USA and Netherlands (the replicative samples were not significant by themselves, with the Netherlands sample showing considerably less of a trend).'],
#  3076: ['827 males and 709 females, 606 subjects without cancer and 930 subjects with various cancers rs1041981 (A;C) (C804A, T60N) associated with lung cancer (CA + AA: CC, adjusted OR = 0.60, 95% CI = 0.37 - 0.97), in males but not in females.'],
#  1020: ['rs3731239 shows a slight protective association against breast cancer in a British study involving ~2300 patients.'],
#  4680: ['It is reported in ClinVar as likely to be benign, although some publications do cite some variation in anion transport in erythrocytes due to this (Memphis) variant.'],
#  5179: ['rs10166942 is a SNP on ch 2q37.1 in the TRPM8 gene.A large GWAS study of over 5,000 patients with migraines and a meta-analysis concluded that this SNP was one of three influencing the condition, albeit with only slight risk changes on its own.'],
#  5224: ['Polymorphisms in the tyrosine kinase 2 and interferon regulatory factor 5 genes are associated with systemic lupus erythematosus.',
#   'Evidence for genetic association and interaction between the TYK2 and IRF5 genes in systemic lupus erythematosus.'],
#  1733: ['The EGLN1 gene encodes prolyl hydroxylase 2 (PHD2) protein.Along with another SNP seen frequently primarily in Tibetans, rs186996510, this SNP is reported to have arisen ~8,000 years ago as an adaptation protecting Tibetans from hypoxia at the high altitudes they inhabit.'],
#  1014: ['Detection of fetomaternal genotype associations in early-onset disorders: evaluation of different methods and their application to childhood leukemia.'],
#  1306: [],
#  1270: ['rs61734651, most commonly known as the Trp3 allele yet technically also known as c.307C>T, p.Arg103Trp and R103W, represents a variant in the COL9A3 gene on chromosome 20.Several studies, albeit older ones and relatively small ones, have linked the rs61734651 (T) allele to somewhat higher risk (odds ratio of ~3) to lumbar disc disease.'],
#  1713: ['Large replication study and meta-analyses of DVWA as an osteoarthritis susceptibility locus in European and Asian populations.'],
#  4306: ['A total of 2,274 cases of schizophrenia were studied, resulting in an association between rs7341475, exclusively in women.',
#   'Based on all populations the estimated relative risk for women carrying the common (G;G) genotype is 1.58 (p = 8.8 x 10 (<sup>-7</sup>).This finding was replicated in a large independent Ashkenazi Jewish collection (721 cases, 259 female; 1455 controls, 834 female), with confirmation that it applies to both schizophrenia and schizoaffective disorder.'],
#  1943: ['This variant is predicted to cause loss of normal protein function through protein truncation.'],
#  5045: ['rs113449357, also known as c.934C>T, p.Arg312Trp and R312W, is a variant in the TMEM43 gene on chromosome 3.There are conflicting interpretations in ClinVar of whether the minor allele of this variant is pathogenic for an unspecified form of cardiomyopathy.'],
#  4172: ['rs63749824, also known as c.236C>T, A79V or Ala79Val, is a SNP in the presenilin 1 PSEN1 gene.Inherited as an autosomal dominant, the rare rs63749824 (T) allele is considered pathogenic for late-onset Alzheimers disease.Reported in to be a definitely pathogenic mutation.'],
#  4179: ['There is an alternate allele, c.1292C>T, however the medical consequence if any is not currently reported.As described initially in 2006 in families from the Jalisco region of Mexiso, the rs63750083 (A) variant is considered a founder mutation for early-onset Alzheimers disease.'],
#  4430: ['In a total of 852 individuals with high HDL-C compared to 1,156 with low HDL-C, the rs74830677 (T) allele was significantly over-represented and, surprisingly, it was also associated with increased risk for coronary heart disease (odds ratio 1.79, p<0.0001).'],
#  4888: ['Abnormal Genetic and Epigenetic Changes in Signal Transducer and Activator of Transcription 4 in the Pathogenesis of Inflammatory Bowel Diseases.'],
#  2230: ['rs2282679, located in the group-specific component (vitamin D binding protein) GC gene on chromosome 4p12, has been linked by several studies to vitamin D serum concentrations.In both studies, the allele associated with lower vitamin D, and thus the potential for vitamin D insufficiency, is rs2282679 (C).'],
#  5256: ['Pazopanib-induced hyperbilirubinemia is associated with Gilberts syndrome UGT1A1 polymorphism.'],
#  226: ['A systematic meta-analysis of genetic association studies for diabetic retinopathy.'],
#  89: ['DeCode reports that the G allele is associated with a lower risk of gallstone disease (cholelithiasis).'],
#  4713: ['Association study of serotonin transporter gene (SLC6A4) in systemic sclerosis in European Caucasian populations.'],
#  5059: ['Psoriasis is a common and chronic autoimmune disease characterized by skin lesions, which are raised, often red and scaly.'],
#  1474: ['Replication Study to Confirm the Role of CYP2D6 Polymorphism rs1080985 on Donepezil Efficacy in Alzheimers Disease Patients.'],
#  1076: ['Compound heterozygosity of two novel truncation mutations in RP1 causing autosomal recessive retinitis pigmentosa.'],
#  2351: ['There was only a non-significant trend toward less response in rs37973 (G;G) patients.In a study of 400 Japanese patients with bronchial asthma receiving inhaled corticosteroids, the pulmonary function was not significantly different in rs37973 (G;G) compared with rs37973 (A;A) genotypes.'],
#  1724: ['rs1801253 with increased susceptibility to edema (P=0.034) rs5370 (T;T) genotypes were the factor most significantly associated with reduced risk of diabetic retinopathy (odds ratio = 0.19, CI: 0.07-0.53; p=0.002) and with later onset of type-2 diabetes ( (T;T) : 59 years; (G;G) and (G;T) : 53 years; p=0.02), in a Chinese population of diabetics.High Blood Pressure (Hypertension).'],
#  3029: ['Confirmed as risk for pseudoexfoliation (PEX) and pseudoexfoliation glaucoma (PEXG) in populations of German and Italian descent. rs2165241 increases susceptibility to Exfoliation glaucoma 3.62 times for carriers of the T allele rs2165241 increases susceptibility to Glaucoma 1.96 times for carriers of the T allele rs2165241 increases susceptibility to Primary open-angle glaucoma 1.04 times for carriers of the T allele.'],
#  3159: ['Lactase persistence genotypes and malaria susceptibility in Fulani of Mali.'],
#  450: ['Polymorphisms in the LOC387715/ARMS2 putative gene and the risk for Alzheimers disease.'],
#  5382: ['rs267607353 Von Willebrand disease.'],
#  1915: ['Achondroplasia rs28931614.'],
#  3526: ['CARD15 mutations in Blau syndrome.'],
#  2979: ['Epidermolysis bullosa, junctional, Herlitz type rs80356680.'],
#  3825: ['PEX7 Tyr115Ter or Y115XRhizomelic chondrodysplasia punctata type 1.'],
#  4275: ['Neurotransmission and bipolar disorder: a systematic family-based association study.'],
#  1209: ['/ blog Association of Circadian Genes with Mood Disorders rs2287161 rs10462028 rs11123857 rs17083008 rs885861.'],
#  5422: ['In vitro functional effects of XPC gene rare variants from bladder cancer patients.'],
#  1627: ['Population-specific variation in haplotype composition and heterozygosity at the POLB locus.'],
#  3611: ['rs12467557 increases susceptibility to Substance dependence, Nicotine 1.81 times for carriers of the C allele.'],
#  3735: ['Breast-Cancer Risk in Families with Mutations in PALB2see also ClinVar (where clinical significance = pathogenic) and.'],
#  4391: ['rs121918596, aka p.Glu2347del, is a deletion SNP in the RYR1 gene associated with malignant hyperthermia.'],
#  3826: ['PEX7 IVS9, G-C, +1Rhizomelic chondrodysplasia punctata type 1This SNP is called i5006214 and i6055954 by 23andMe.'],
#  4132: ['rs1046089 is a SNP in the HLA-B associated transcript 2 BAT2 gene.A study of 2,162 case-controls found an association between rs1046089 and severe malaria.'],
#  2590: ['In a study conducted on 6,580 Nondiabetic Finnish Men, rs757210 in HNF1B gene showed nominal or significant associations with several lipoprotein traits.'],
#  3338: ['rs1076991 C > T exerts a significant effect on promoter activity in vitro and along with rs2236225 G > A influences embryonic development.'],
#  ...}

# %%
# We need the unprocessed CSV file exported from Qualtrics for some of the following information.
# Specifically, let's use this to get the mapping betweeen response IDs (from Qualtrics) and user IDs (from Prolific).
exported_df = pd.read_csv(QUALTRICS_RAW_CSV_EXPORT_PATH)
exported_df.drop(df.index[[0,1]], inplace=True)
prolific_pid_column = "Q564"
response_id_column = "ResponseId"
response_id_to_prolific_pid = dict(zip(exported_df[response_id_column], exported_df[prolific_pid_column]))
response_id_to_prolific_pid
# Out:
# {'R_eOSosrnczqYqE9P': '5f56f670e492b316bbd2a47c',
#  'R_2XjJU6SMJAlU4I2': '5e703f3dd6d4336135b8818d',
#  'R_25R9SJyLb4p6iv7': '5f68eb472f60ad099401f587',
#  'R_1CpRIVeWQ8AGNqi': '5f206e18fb9d281e91500fcd',
#  'R_2wQNxJNyQdjSeq9': '5d3cc9010e510a00013df6f6',
#  'R_qPe5vObZ349P3I5': '5ec5925cb3d6035afea34d20',
#  'R_2Bs2kBIw93NmaCj': '5e7e6df49867d653e250ade8',
#  'R_2wodESRdFsJZ5pq': '5f3e31e2769ffb267b9d1a24',
#  'R_PUpvfu7l6QKh6mJ': '5f4da07b144b1ca7f76c51ed',
#  'R_3p2QR3KSEVmy0d6': nan,
#  'R_1mOvl29nViC00Om': nan,
#  'R_3oHIVnFYPhAiXmm': '5e6ce6ff1b327528ec9bf6ec',
#  'R_27OU6CzuLPmcd3m': '5e5695b653966101689727e6',
#  'R_3RqnqavYAULCLRa': '5ccd9d0c95e4a30016d4652b',
#  'R_2YVCzat5Edfkexn': '5c587fb58fba0a000189f4d8',
#  'R_W2vxxai4v7q8uUF': '5cfa65c24b639a0019a45c8e',
#  'R_un8BFK0QoCkgDIJ': '5c8becf18f5b6400158e1214',
#  'R_RQRoTbUD7VIhjAl': '5eab7c4c10a7c01634f3b4ef',
#  'R_sp56F93gtkQUdoJ': '5d98bb1424a6e302b056c77e',
#  'R_3HMHg1x9JldKGTZ': '5e9b725d85157c0816f1f0dd',
#  'R_1NkwPymSEyk4XxD': '5c726ae51384ee0001115f7a',
#  'R_25vaA6Y5hES3mK1': '5defde6e8489380361975e4d',
#  'R_10oN9ythcAiiYDw': '5f53df1ad4ac6472fb4a0e50',
#  'R_2EmnKcS5x32ALWY': '5ea6572b086c724ee6eb019a',
#  'R_1DnTweJl3pGzMw3': '5dc0aa580133ef05c901e161',
#  'R_3G1W92LqOtRUYQG': '5e8f7fd24b34ff279115a2b4',
#  'R_22AfbP3zzvf2P8e': '5eac66ab9334300f4c37121b',
#  'R_2CCJfuuDFtNp298': '5edc753bcee6c1953c31dacd',
#  'R_PHYh8K85S7UfWdX': '5b09360c2971540001e3e248',
#  'R_yvwbGDRWRYQ756x': '5b02fe323bc9af0001909bc5',
#  'R_qCJbVB4JI2yQ1rz': '576c141ecef15b000137895a',
#  'R_3Miq1vPz4ry2c0t': '5f02fbee212873485f6ce5b8',
#  'R_3qrMJOeN0LPyHJz': '5eb44a4d4e9bd8289b01ccb5',
#  'R_1IbIXHu7uanaL2Y': '5dd6e561bd95ad000d495788',
#  'R_3kqcIc6gI78SxIM': '5ee3a20ec682de03c0234f67',
#  'R_22FdhiHG7WuRMCQ': '5cfba9da04fd2c001941a7e3',
#  'R_3qfBaSVHtzNpMaS': '5ee111bcc53e0f4bbf967e40',
#  'R_2tmciRl13xTlpOK': '59c1a5c0e3a73b00011a89ca',
#  'R_2QyrBITmGtNXaJt': '5d9ad74c0bc1550016bf4daf',
#  'R_1gBBeWaS2oVWQE8': '5f08f3e3ff3278174e40069b',
#  'R_10D9ysIiSEHlmBY': '5f63b9d3a83a7d0ecdda4eb2',
#  'R_W28XHcuJqnpaYlb': '5e2a5541e179570b9a3dcbc8',
#  'R_3PMFHWEQu81T0Q5': '5f4bccaefca4707a4ca6ba7d',
#  'R_1loCw6wUB91vE14': '5e5c3d75348de24188d2c698',
#  'R_2f843yEHXAk7i3m': '5d17b6f2c9ee35001a76a33b',
#  'R_0PzB7lxnRvN82YN': '5e120c2c8dffa088ab11ce9e',
#  'R_2TttEoD2JLX1Hy1': '5f3e31e2769ffb267b9d1a24',
#  'R_RFtMei9xCfgQJlD': '5f6265b707ccb62ae21f22a2',
#  'R_1oFlyogshZ4NaQQ': '5c665e1948985d0001f09675',
#  'R_in_progress_1': '5c70a9cee514010001b40087',
#  'R_in_progress_2': '5d0fe43ab5b7bb0019ce156b',
#  'R_in_progress_3': '5f022da3d2fab63b60a9427a',
#  'R_in_progress_4': '5e5c993cd0394c474f7cc502',
#  'R_in_progress_5': '5ee2a071402f7d7bcd0b26c1',
#  'R_in_progress_6': '5f4fc31bd7f57c0ca5143b2d',
#  'R_in_progress_7': '5f6957c4724d5915d01e8af7',
#  'R_in_progress_8': '5f6957c4724d5915d01e8af7',
#  'R_in_progress_9': '5de122adf5d667174cda4228',
#  'R_in_progress_10': '5aa429f7b5e2110001c726db',
#  'R_in_progress_11': '5f16c30d59ac784a401cb353',
#  'R_in_progress_12': '5e6ff43e18d1a809cd0b836a',
#  'R_in_progress_13': '5e18d751a90da51a32381ead',
#  'R_in_progress_14': '5e8a1a956d76506b6c899082',
#  'R_in_progress_15': '5f6911ceb989470d55fb3d9e',
#  'R_in_progress_16': '5e8dce370e5d280598092b2a',
#  'R_in_progress_17': '5e9a24815a17f10a10f1d44d',
#  'R_in_progress_18': '5eb4f5a68aa23236a7dee5a3',
#  'R_in_progress_19': '5e63af9d7f7cf811d90164ed',
#  'R_in_progress_20': '5e67342a9d4deb4b8599a812',
#  'R_in_progress_21': '5f5d2ceddc72d811bac30d7d',
#  'R_in_progress_22': '5e638770b45c641082fd309f',
#  'R_in_progress_23': '5ef367a7d74fe20961629c2d',
#  'R_in_progress_24': '5e15bde8f6191fba54ce8d15',
#  'R_in_progress_25': '5e18bdb1e80b8e18dc8209ac',
#  'R_in_progress_26': '5f319efc2977330948eebbcd',
#  'R_in_progress_27': '5d12020e90265e00199ba8a9',
#  'R_in_progress_28': '5ec18f4e3938ab5a37947140',
#  'R_in_progress_29': '5d34ab54c374970001e8b76b',
#  'R_in_progress_30': '5d6906bf2aedf5001509d5f4',
#  'R_in_progress_31': '5ed9fe560adb8b5a860d8d80',
#  'R_in_progress_32': '5c3dcf4fc1c7e30001e4e735',
#  'R_in_progress_33': '5ec554706960444f4a1768de',
#  'R_in_progress_34': '5f3fa50ad4ad3d025f3bca8e',
#  'R_in_progress_35': '5c3dcf4fc1c7e30001e4e735'}

# %%
exported_df
# Out:
#         StartDate        EndDate      Status        IPAddress Progress  \
# 2   9/22/20 10:16  9/22/20 10:37  IP Address   174.16.161.244      100
# 3   9/22/20 10:22  9/22/20 10:40  IP Address    96.63.207.134      100
# 4   9/22/20 10:36  9/22/20 10:42  IP Address    107.77.235.23      100
# 5   9/22/20 10:12  9/22/20 10:45  IP Address   185.241.197.34      100
# 6   9/22/20 10:55  9/22/20 11:19  IP Address    73.103.85.226      100
# ..            ...            ...         ...              ...      ...
# 81  9/24/20 17:36  9/24/20 18:26  IP Address  177.237.183.200        1
# 82  9/24/20 17:40  9/24/20 18:33  IP Address    81.111.140.54        1
# 83  9/24/20 17:52  9/24/20 18:41  IP Address   193.137.168.32        1
# 84  9/24/20 18:22  9/24/20 20:03  IP Address     90.94.55.188        1
# 85  9/24/20 18:32  9/24/20 18:32  IP Address   148.252.129.67        1
#
#    Duration (in seconds) Finished   RecordedDate         ResponseId  \
# 2                   1252     TRUE  9/22/20 10:37  R_eOSosrnczqYqE9P
# 3                   1074     TRUE  9/22/20 10:40  R_2XjJU6SMJAlU4I2
# 4                    361     TRUE  9/22/20 10:42  R_25R9SJyLb4p6iv7
# 5                   2002     TRUE  9/22/20 10:45  R_1CpRIVeWQ8AGNqi
# 6                   1438     TRUE  9/22/20 11:20  R_2wQNxJNyQdjSeq9
# ..                   ...      ...            ...                ...
# 81                     1    FALSE  9/24/20 16:23   R_in_progress_31
# 82                     1    FALSE  9/24/20 16:24   R_in_progress_32
# 83                     1    FALSE  9/24/20 16:24   R_in_progress_33
# 84                     1    FALSE  9/24/20 16:25   R_in_progress_34
# 85                     1    FALSE  9/24/20 16:26   R_in_progress_35
#
#    RecipientLastName  ... ExternalReference LocationLatitude  \
# 2                NaN  ...               NaN      39.73010254
# 3                NaN  ...               NaN      40.11199951
# 4                NaN  ...               NaN      33.74850464
# 5                NaN  ...               NaN      54.19020081
# 6                NaN  ...               NaN      40.44439697
# ..               ...  ...               ...              ...
# 81               NaN  ...               NaN      44.31359863
# 82               NaN  ...               NaN      47.49839783
# 83               NaN  ...               NaN      52.11579895
# 84               NaN  ...               NaN      20.67599487
# 85               NaN  ...               NaN      38.71670532
#
#    LocationLongitude DistributionChannel UserLanguage  \
# 2       -104.9077988           anonymous           EN
# 3        -88.2365036           anonymous           EN
# 4       -84.38710022           anonymous           EN
# 5        18.68330383           anonymous           EN
# 6       -86.92559814           anonymous           EN
# ..               ...                 ...          ...
# 81      -78.23999786           anonymous           EN
# 82       19.04040527           anonymous           EN
# 83         21.271698           anonymous           EN
# 84      -103.3358002           anonymous           EN
# 85      -9.133300781           anonymous           EN
#
#                         Q564  \
# 2   5f56f670e492b316bbd2a47c
# 3   5e703f3dd6d4336135b8818d
# 4   5f68eb472f60ad099401f587
# 5   5f206e18fb9d281e91500fcd
# 6   5d3cc9010e510a00013df6f6
# ..                       ...
# 81  5ed9fe560adb8b5a860d8d80
# 82  5c3dcf4fc1c7e30001e4e735
# 83  5ec554706960444f4a1768de
# 84  5f3fa50ad4ad3d025f3bca8e
# 85  5c3dcf4fc1c7e30001e4e735
#
#                                              hilights  \
# 2   [["4769","Disease ",13],["5162","Focal segment...
# 3   [["4622","Skin color",0],["5199","cardiac amyl...
# 4                                                  []
# 5   [["1115","Cystic Fibrosisrs",0],["1100","Cysti...
# 6   [["1092","Cystic Fibrosisrs",0],["3416","famil...
# ..                                                ...
# 81  [["1883","Marfan syndrome",0],["1101","Cystic ...
# 82  [["666","breast cancer",15],["454","A deficien...
# 83  [["1089","Cystic Fibrosisrs",0],["3311","allel...
# 84  [["3705","Phenylketonuria",0],["276","heredita...
# 85                                                 []
#
#                 PROLIFIC_PID                  STUDY_ID  \
# 2   5f56f670e492b316bbd2a47c  5f64e6570956ab016016af94
# 3   5e703f3dd6d4336135b8818d  5f64e6570956ab016016af94
# 4   5f68eb472f60ad099401f587  5f64e6570956ab016016af94
# 5   5f206e18fb9d281e91500fcd  5f64e6570956ab016016af94
# 6   5d3cc9010e510a00013df6f6  5f64e6570956ab016016af94
# ..                       ...                       ...
# 81  5ed9fe560adb8b5a860d8d80  5f6ced9888653511ed8d2192
# 82  5c3dcf4fc1c7e30001e4e735  5f6ced9888653511ed8d2192
# 83  5ec554706960444f4a1768de  5f6ced9888653511ed8d2192
# 84  5f3fa50ad4ad3d025f3bca8e  5f6ced9888653511ed8d2192
# 85  5c3dcf4fc1c7e30001e4e735  5f6ced9888653511ed8d2192
#
#                   SESSION_ID
# 2   5f6a23566fb13d080b7c3f69
# 3   5f6a24bc329c8d08bec90645
# 4   5f6a2802f5f82209600309eb
# 5   5f6a2229ebc2b407cd210f87
# 6   5f6a2b5951380a0a0049815a
# ..                       ...
# 81  5f6d1f8534ac6f1923dd9414
# 82  5f6d200e3a85c5187676c901
# 83  5f6d233ac179911989a6d742
# 84  5f6d24f9850e4918e5f2653f
# 85  5f6d200e3a85c5187676c901
#
# [84 rows x 22 columns]

# %%
# Breaking it down by specific users who took the survey.
users_df = df.copy(deep=True)[["response_id","recorded_datetime","status","progress","is_finished","duration"]]
users_df.drop_duplicates(inplace=True)
users_df.reset_index(inplace=True, drop=True)

# Some extra information to know, the duration, and the number of total highlights in each response, and Prolific IDs.
users_df["duration_min"] = users_df["duration"].map(lambda x: math.ceil(x/60))
response_id_to_num_snippets = dict(df.groupby("response_id").size())
users_df["num_snippets"] = users_df["response_id"].map(response_id_to_num_snippets)
users_df["prolific_id"] = users_df["response_id"].map(response_id_to_prolific_pid)
users_df.to_csv(SURVEY_TAKERS_OUTPUT_PATH, index=False)
users_df.tail(50)
# Out:
#           response_id recorded_datetime      status  progress is_finished  \
# 30  R_3qrMJOeN0LPyHJz     9/24/20 16:24  IP Address       100        TRUE
# 31  R_1IbIXHu7uanaL2Y     9/24/20 16:25  IP Address       100        TRUE
# 32  R_3kqcIc6gI78SxIM     9/24/20 16:26  IP Address       100        TRUE
# 33  R_22FdhiHG7WuRMCQ     9/24/20 16:29  IP Address       100        TRUE
# 34  R_3qfBaSVHtzNpMaS     9/24/20 16:33  IP Address       100        TRUE
# 35  R_2tmciRl13xTlpOK     9/24/20 16:48  IP Address       100        TRUE
# 36  R_2QyrBITmGtNXaJt     9/24/20 16:50  IP Address       100        TRUE
# 37  R_1gBBeWaS2oVWQE8     9/24/20 16:54  IP Address       100        TRUE
# 38  R_10D9ysIiSEHlmBY     9/24/20 16:54  IP Address       100        TRUE
# 39  R_W28XHcuJqnpaYlb     9/24/20 16:55  IP Address       100        TRUE
# 40  R_3PMFHWEQu81T0Q5     9/24/20 17:05  IP Address       100        TRUE
# 41  R_1loCw6wUB91vE14     9/24/20 17:30  IP Address       100        TRUE
# 42  R_2f843yEHXAk7i3m     9/24/20 18:00  IP Address       100        TRUE
# 43  R_0PzB7lxnRvN82YN     9/24/20 18:08  IP Address       100        TRUE
# 44  R_2TttEoD2JLX1Hy1     9/24/20 18:21  IP Address       100        TRUE
# 45  R_RFtMei9xCfgQJlD     9/24/20 18:55  IP Address       100        TRUE
# 46  R_1oFlyogshZ4NaQQ     9/24/20 21:27  IP Address       100        TRUE
# 47    R_in_progress_1     9/22/20 10:37  IP Address         1       FALSE
# 48    R_in_progress_2     9/22/20 10:40  IP Address         1       FALSE
# 49    R_in_progress_3     9/22/20 10:42  IP Address         1       FALSE
# 50    R_in_progress_4     9/22/20 10:45  IP Address         1       FALSE
# 51    R_in_progress_5     9/22/20 11:20  IP Address         1       FALSE
# 52    R_in_progress_6     9/22/20 11:32  IP Address         1       FALSE
# 53    R_in_progress_7     9/22/20 12:03  IP Address         1       FALSE
# 54    R_in_progress_9     9/22/20 12:35  IP Address         1       FALSE
# 55   R_in_progress_10      9/23/20 9:20  IP Address         1       FALSE
# 56   R_in_progress_11     9/23/20 10:02  IP Address         1       FALSE
# 57   R_in_progress_12     9/24/20 15:21  IP Address         1       FALSE
# 58   R_in_progress_13     9/24/20 15:44  IP Address         1       FALSE
# 59   R_in_progress_14     9/24/20 15:54  IP Address         1       FALSE
# 60   R_in_progress_15     9/24/20 15:57  IP Address         1       FALSE
# 61   R_in_progress_16     9/24/20 15:58  IP Address         1       FALSE
# 62   R_in_progress_17     9/24/20 16:02  IP Address         1       FALSE
# 63   R_in_progress_18     9/24/20 16:02  IP Address         1       FALSE
# 64   R_in_progress_19     9/24/20 16:05  IP Address         1       FALSE
# 65   R_in_progress_20     9/24/20 16:08  IP Address         1       FALSE
# 66   R_in_progress_21     9/24/20 16:08  IP Address         1       FALSE
# 67   R_in_progress_22     9/24/20 16:13  IP Address         1       FALSE
# 68   R_in_progress_23     9/24/20 16:13  IP Address         1       FALSE
# 69   R_in_progress_24     9/24/20 16:15  IP Address         1       FALSE
# 70   R_in_progress_25     9/24/20 16:15  IP Address         1       FALSE
# 71   R_in_progress_26     9/24/20 16:16  IP Address         1       FALSE
# 72   R_in_progress_27     9/24/20 16:16  IP Address         1       FALSE
# 73   R_in_progress_28     9/24/20 16:17  IP Address         1       FALSE
# 74   R_in_progress_29     9/24/20 16:19  IP Address         1       FALSE
# 75   R_in_progress_30     9/24/20 16:20  IP Address         1       FALSE
# 76   R_in_progress_31     9/24/20 16:23  IP Address         1       FALSE
# 77   R_in_progress_32     9/24/20 16:24  IP Address         1       FALSE
# 78   R_in_progress_33     9/24/20 16:24  IP Address         1       FALSE
# 79   R_in_progress_34     9/24/20 16:25  IP Address         1       FALSE
#
#     duration  duration_min  num_snippets               prolific_id
# 30      4069            68           284  5eb44a4d4e9bd8289b01ccb5
# 31      3699            62           162  5dd6e561bd95ad000d495788
# 32      3522            59           238  5ee3a20ec682de03c0234f67
# 33      4120            69           189  5cfba9da04fd2c001941a7e3
# 34      4198            70           208  5ee111bcc53e0f4bbf967e40
# 35      5340            89           328  59c1a5c0e3a73b00011a89ca
# 36      5316            89           330  5d9ad74c0bc1550016bf4daf
# 37      5087            85           363  5f08f3e3ff3278174e40069b
# 38      5189            87           240  5f63b9d3a83a7d0ecdda4eb2
# 39      5226            88           219  5e2a5541e179570b9a3dcbc8
# 40      2381            40           287  5f4bccaefca4707a4ca6ba7d
# 41      7432           124           275  5e5c3d75348de24188d2c698
# 42      3791            64           166  5d17b6f2c9ee35001a76a33b
# 43      3785            64           406  5e120c2c8dffa088ab11ce9e
# 44      1815            31           183  5f3e31e2769ffb267b9d1a24
# 45      5323            89           441  5f6265b707ccb62ae21f22a2
# 46      3827            64           225  5c665e1948985d0001f09675
# 47         1             1           111  5c70a9cee514010001b40087
# 48         1             1             1  5d0fe43ab5b7bb0019ce156b
# 49         1             1           289  5f022da3d2fab63b60a9427a
# 50         1             1           145  5e5c993cd0394c474f7cc502
# 51         1             1             5  5ee2a071402f7d7bcd0b26c1
# 52         1             1            19  5f4fc31bd7f57c0ca5143b2d
# 53         1             1           135  5f6957c4724d5915d01e8af7
# 54         1             1           298  5de122adf5d667174cda4228
# 55         1             1           244  5aa429f7b5e2110001c726db
# 56         1             1           281  5f16c30d59ac784a401cb353
# 57         1             1           481  5e6ff43e18d1a809cd0b836a
# 58         1             1           404  5e18d751a90da51a32381ead
# 59         1             1           230  5e8a1a956d76506b6c899082
# 60         1             1            18  5f6911ceb989470d55fb3d9e
# 61         1             1           201  5e8dce370e5d280598092b2a
# 62         1             1           166  5e9a24815a17f10a10f1d44d
# 63         1             1             8  5eb4f5a68aa23236a7dee5a3
# 64         1             1           204  5e63af9d7f7cf811d90164ed
# 65         1             1           255  5e67342a9d4deb4b8599a812
# 66         1             1           211  5f5d2ceddc72d811bac30d7d
# 67         1             1           251  5e638770b45c641082fd309f
# 68         1             1           466  5ef367a7d74fe20961629c2d
# 69         1             1            39  5e15bde8f6191fba54ce8d15
# 70         1             1           223  5e18bdb1e80b8e18dc8209ac
# 71         1             1           240  5f319efc2977330948eebbcd
# 72         1             1           163  5d12020e90265e00199ba8a9
# 73         1             1           237  5ec18f4e3938ab5a37947140
# 74         1             1           362  5d34ab54c374970001e8b76b
# 75         1             1           360  5d6906bf2aedf5001509d5f4
# 76         1             1           214  5ed9fe560adb8b5a860d8d80
# 77         1             1           248  5c3dcf4fc1c7e30001e4e735
# 78         1             1           366  5ec554706960444f4a1768de
# 79         1             1           146  5f3fa50ad4ad3d025f3bca8e

# %%
# Create a mapping from unique text IDs to all of the text snippets that were hilighted in these survey results.
unique_text_id_to_snippet_list = {}
for unique_text_id,row_indices in df.groupby("id", axis=0).groups.items():
    hilighted_texts_list = list(df.iloc[row_indices]["snippet"].values)
    unique_text_id_to_snippet_list[unique_text_id] = hilighted_texts_list
print(unique_text_id_to_snippet_list)
# Out:
# {2: ['autism', 'autism'], 4: ['polymorphism', 'therothrombotic cerebral infarction'], 5: ['risk for carotid artery disease', 'Mexican dyslipidemic'], 6: ["Alzheimer's disease", 'atherogenic dyslipidaemia', 'Type 2 diabetes', 'haplotype ', 'haplotype1 ', 'healthy controls', "Alzheimer's disease group", 'atherogenic dyslipidaemia', 'Type 2 diabetes treated with rosiglitazone.', "Alzheimer's disease", 'atherogenic dyslipidaemia', 'patients with Type 2 diabetes', 'rosiglitazone', "rs2297404, rs2230808, and rs2020927 haplotype (CAC) was more prevalent in the Alzheimer's disease group", 'while haplotype1 (TGG) was over-represented in the healthy controls', 'atherogenic dyslipidaemia', 'Type 2 diabetes'], 7: ['preterm delivery', 'chronic kidney disease', 'Japanese individuals'], 9: ['coronary artery disease', 'HDL-C', 'coronary artery disease ', "Alzheimer's disease", "Alzheimer's disease", "Alzheimer's disease", 'ischaemic stroke', 'dementia', 'postprandial lipoproteins', 'hyperlipidemic '], 10: ["Alzheimer's disease", "Alzheimer's disease", 'ABCA1 polymorphisms', "Alzheimer's disease", 'ischaemic stroke', 'dementia', 'schizophrenia ', 'brain changes', "Alzheimer's disease", 'CSF cholesterol levels', 'ABCA1 polymorphisms', 'cerebrospinal fluid', 'ischaemic stroke', 'HDL cholesterol levels', 'dementia', 'schizophrenia', 'brain changes', "Alzheimer's disease", 'cholesterol levels', " Alzheimer's disease", 'polymorphisms', "Alzheimer's disease", 'polymorphisms.', 'dementia', 'polymorphism', 'schizophrenia and related brain changes.', "Alzheimer's disease", "polymorphisms and Alzheimer's disease.", "Alzheimer's disease", "Alzheimer's disease", "Alzheimer's disease", 'cholesterol', "Alzheimer's disease", 'polymorphisms', 'schizophrenia', "Alzheimer's disease", 'schizophrenia'], 11: ["Alzheimer's disease", 'rs2297404', 'rs2230808', 'rs2020927 ', 'haplotype1 ', 'TGG', "Alzheimer's disease group", 'haplotype1', 'ver-represented in the healthy controls', 'rs2297404,', 'rs2230808', 'rs2020927'], 13: ['0.82mg/dl increase in HDL cholesterol', 'increase in HDL cholesterol', 'good cholesterol'], 15: ['congenital Lamellar ichthyosis', 'skin condition', 'Lamellar ichthyosis', 'recessive SNP', 'skin condition', 'congenital Lamellar ichthyosis, type 2, also called ichthyosis-4A, a significant skin condition.'], 19: ["rs113809142, also known as c.4416+2T>G, is one of several loss-of-function ABCA7 mutations associated with Alzheimer's disease", "Carriers of one rare rs113809142(G) allele are at roughly more than twice the risk for developing late-onset Alzheimer's disease compared to people having the most common genotype (T;T); "], 21: ["Alzheimer's disease", "late-onset Alzheimer's disease ", 'loss-of-function ABCA7 mutations', "Alzheimer's disease", "late-onset Alzheimer's disease", "is one of several loss-of-function ABCA7 mutations associated with Alzheimer's disease initially in Icelanders", "developing late-onset Alzheimer's disease compared to people having the most common genotype"], 22: ["Alzheimer's disease", 'disease ', "Alzheimer's "], 23: ["late onset Alzheimer's disease"], 24: ["Alzheimer's disease cases identified"], 25: ["Alzheimer's disease polygenic hazard score"], 26: ['ABCA7 gene', "Alzheimer's disease", 'rs78117248(G) allele'], 27: ['depression ', 'depression', 'depressio', 'colonic disease ', 'depression ', 'depression ', 'depression ', 'colonic disease'], 28: ['Polymorphisms in genes that regulate cyclosporine metabolism affect cyclosporine blood levels and clinical outcomes in patients who receive allogeneic hematopoietic stem cell transplantation.', 'esophageal cancer.', ' Pharmacogenetics of antidepressant response. Correlation between genetic polymorphisms', 'rs1045642, also known as C3435T, is a SNP located in the ABCB1 gene. It is often studied in conjunction with rs2032582. C3435T has been mentioned by: A "Silent" Polymorphism in the MDR1 Gene Changes Substrate Specificity (for example, to verapamil) (R)-lansoprazole (Pr ...

# %%
# Use that mapping to create a version of the original dataframe with just the hilighted text snippets.
subset_df = original_df.copy(deep=True)[original_df["id"].isin(unique_text_id_to_snippet_list.keys())]
subset_df["n"] = subset_df["id"].map(lambda x: len(unique_text_id_to_snippet_list[x]))
text_snippets = flatten([unique_text_id_to_snippet_list[i] for i in subset_df["id"].values])

# Extend the dataframe to duplicate each row n times where n is the number of text hilight results from the surveys.
modified_df = subset_df.reindex(np.repeat(subset_df.index.values, subset_df["n"]), method="ffill")

# Make sure that the extension occured as expected based on the number of text snippets, and add them as a new column.
assert len(modified_df) == len(text_snippets)
modified_df["snippet"] = text_snippets
modified_df.head(20)
# Out:
#     gene        snp                                               text  id  \
# 1  AANAT  Rs3760138  Genetic differences in human circadian clock g...   2
# 1  AANAT  Rs3760138  Genetic differences in human circadian clock g...   2
# 3  ABCA1  Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...   4
# 3  ABCA1  Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...   4
# 4  ABCA1  Rs1883025  Apolipoprotein E levels in cerebrospinal fluid...   5
# 4  ABCA1  Rs1883025  Apolipoprotein E levels in cerebrospinal fluid...   5
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 5  ABCA1  Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
#
#     n                                            snippet
# 1   2                                             autism
# 1   2                                             autism
# 3   2                                       polymorphism
# 3   2                therothrombotic cerebral infarction
# 4   2                    risk for carotid artery disease
# 4   2                               Mexican dyslipidemic
# 5  17                                Alzheimer's disease
# 5  17                          atherogenic dyslipidaemia
# 5  17                                    Type 2 diabetes
# 5  17                                         haplotype
# 5  17                                        haplotype1
# 5  17                                   healthy controls
# 5  17                          Alzheimer's disease group
# 5  17                          atherogenic dyslipidaemia
# 5  17        Type 2 diabetes treated with rosiglitazone.
# 5  17                                Alzheimer's disease
# 5  17                          atherogenic dyslipidaemia
# 5  17                      patients with Type 2 diabetes
# 5  17                                      rosiglitazone
# 5  17  rs2297404, rs2230808, and rs2020927 haplotype ...

# %%
# Check all IDs for unique texts and see how many times they were annotated here.
id_to_num_annotations = {}
for i in original_df["id"].values:
    # This ID was annotated atleast once, it was in the results dataframe for this survey.
    if i in snippets_per_id:
        id_to_num_annotations[i] = snippets_per_id[i]
    else:
        id_to_num_annotations[i] = 0

# Save that information to a file.
num_ann_df = pd.DataFrame({"id":list(id_to_num_annotations.keys()),"num_highlights":list(id_to_num_annotations.values())})
num_ann_df.to_csv(NUM_ANNOTATIONS_PATH, index=False)
num_ann_df.head(10)
# Out:
#    id  num_highlights
# 0   1               0
# 1   2               2
# 2   3               0
# 3   4               2
# 4   5               2
# 5   6              17
# 6   7               3
# 7   8               0
# 8   9              10
# 9  10              37

# %%
# Save that dataframe as a new CSV file with just the final cleaned text snippets for each gene and SNP.
modified_df = modified_df[["gene","snp","snippet"]]
modified_df.sort_values(by="gene", inplace=True)
modified_df.to_csv(SNPS_AND_SNIPPETS_OUTPUT_PATH, index=False)
modified_df.head(20)
# Out:
#     gene        snp                                   snippet
# 1  AANAT  Rs3760138                                    autism
# 1  AANAT  Rs3760138                                    autism
# 9  ABCA1  Rs2230808                       Alzheimer's disease
# 9  ABCA1  Rs2230808                       Alzheimer's disease
# 9  ABCA1  Rs2230808    polymorphisms and Alzheimer's disease.
# 9  ABCA1  Rs2230808                       Alzheimer's disease
# 9  ABCA1  Rs2230808  schizophrenia and related brain changes.
# 9  ABCA1  Rs2230808                              polymorphism
# 9  ABCA1  Rs2230808                                  dementia
# 9  ABCA1  Rs2230808                            polymorphisms.
# 9  ABCA1  Rs2230808                       Alzheimer's disease
# 9  ABCA1  Rs2230808                             polymorphisms
# 9  ABCA1  Rs2230808                       Alzheimer's disease
# 9  ABCA1  Rs2230808                        cholesterol levels
# 9  ABCA1  Rs2230808                       Alzheimer's disease
# 9  ABCA1  Rs2230808                             brain changes
# 9  ABCA1  Rs2230808                             schizophrenia
# 9  ABCA1  Rs2230808                    HDL cholesterol levels
# 9  ABCA1  Rs2230808                          ischaemic stroke
# 9  ABCA1  Rs2230808                       cerebrospinal fluid

# %%
# How many genes had atleast one snippet associated to it in these results?
len(modified_df["gene"].unique())
# Out:
# 1076

# %%
# Create a version of the dataset with mapping genes and SNPs to context sentences.
subset_df = original_df.copy(deep=True)[original_df["id"].isin(id_to_context_sentences.keys())]
subset_df["n"] = subset_df["id"].map(lambda x: len(id_to_context_sentences[x]))
sentences = flatten([id_to_context_sentences[i] for i in subset_df["id"].values])

# Extend the dataframe to duplicate each row n times where n is the number of text hilight results from the surveys.
modified_df = subset_df.reindex(np.repeat(subset_df.index.values, subset_df["n"]), method="ffill")

# Make sure that the extension occured as expected based on the number of text snippets, and add them as a new column.
assert len(modified_df) == len(sentences)
modified_df["context"] = sentences
modified_df.head(20)
# Out:
#       gene          snp                                               text  \
# 1    AANAT    Rs3760138  Genetic differences in human circadian clock g...
# 3    ABCA1    Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...
# 4    ABCA1    Rs1883025  Apolipoprotein E levels in cerebrospinal fluid...
# 5    ABCA1    Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...
# 6    ABCA1    Rs2066714  Apolipoprotein E levels in cerebrospinal fluid...
# 8    ABCA1    Rs2230806  rs2230806, also known as Arg219Lys or R219K, i...
# 9    ABCA1    Rs2230808  rs2297404, rs2230808, and rs2020927 haplotype ...
# 10   ABCA1    Rs2297404  rs2297404, rs2230808, and rs2020927 haplotype ...
# 12   ABCA1    Rs4149268  G allele is associated with 0.82mg/dl increase...
# 14  ABCA12   Rs28940268  This is a recessive SNP for congenital Lamella...
# 15  ABCA12   Rs28940269  This is a recessive SNP for congenital Lamella...
# 16  ABCA12   Rs28940270  This is a recessive SNP for congenital Lamella...
# 17  ABCA12   Rs28940271  This is a recessive SNP for congenital Lamella...
# 18  ABCA12   Rs28940568  This is a recessive SNP for congenital Lamella...
# 22   ABCA7  Rs113809142  rs113809142, also known as c.4416+2T>G, is one...
# 24   ABCA7  Rs200538373  rs200538373, also known as c.5570+5G>C, is one...
# 25   ABCA7    Rs3764650  Alzheimer's disease associated, based on large...
# 26   ABCA7    Rs4147929  rs4147929 is a SNP in the ATP-binding cassette...
# 27   ABCA7   Rs72973581  A sequencing study of 332 sporadic Alzheimer's...
# 28   ABCA7    Rs7408475         Alzheimer's disease polygenic hazard score
#
#     id  n                                            context
# 1    2  1  Examination of association of genes in the ser...
# 3    4  1  The -14C->T polymorphism rs1800977 of the ABCA...
# 4    5  1  Investigation of variants identified in caucas...
# 5    6  1  rs2297404, rs2230808, and rs2020927 haplotype ...
# 6    7  1  Association of genetic variants with chronic k...
# 8    9  1  Increase in HDL-C concentration by a dietary p...
# 9   10  1  A polymorphism of the ABCA1 gene confers susce...
# 10  11  1  rs2297404, rs2230808, and rs2020927 haplotype ...
# 12  13  1  G allele is associated with 0.82mg/dl increase...
# 14  15  1  This is a recessive SNP for congenital Lamella...
# 15  15  1  This is a recessive SNP for congenital Lamella...
# 16  15  1  This is a recessive SNP for congenital Lamella...
# 17  15  1  This is a recessive SNP for congenital Lamella...
# 18  15  1  This is a recessive SNP for congenital Lamella...
# 22  19  1  rs113809142, also known as c.4416+2T>G, is one...
# 24  21  1  rs200538373, also known as c.5570+5G>C, is one...
# 25  22  1  Alzheimers disease associated, based on large ...
# 26  23  1  rs4147929 is a SNP in the ATP-binding cassette...
# 27  24  1  A sequencing study of 332 sporadic Alzheimers ...
# 28  25  1         Alzheimers disease polygenic hazard score.

# %%
# Save that dataframe as a new CSV file with just the contexts for each gene and SNP.
modified_df = modified_df[["gene","snp","context"]]
modified_df.sort_values(by="gene", inplace=True)
modified_df.to_csv(SNPS_AND_CONTEXTS_OUTPUT_PATH, index=False)
modified_df.head(20)
# Out:
#       gene          snp                                            context
# 1    AANAT    Rs3760138  Examination of association of genes in the ser...
# 10   ABCA1    Rs2297404  rs2297404, rs2230808, and rs2020927 haplotype ...
# 9    ABCA1    Rs2230808  A polymorphism of the ABCA1 gene confers susce...
# 8    ABCA1    Rs2230806  Increase in HDL-C concentration by a dietary p...
# 12   ABCA1    Rs4149268  G allele is associated with 0.82mg/dl increase...
# 5    ABCA1    Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...
# 4    ABCA1    Rs1883025  Investigation of variants identified in caucas...
# 3    ABCA1    Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...
# 6    ABCA1    Rs2066714  Association of genetic variants with chronic k...
# 14  ABCA12   Rs28940268  This is a recessive SNP for congenital Lamella...
# 15  ABCA12   Rs28940269  This is a recessive SNP for congenital Lamella...
# 16  ABCA12   Rs28940270  This is a recessive SNP for congenital Lamella...
# 17  ABCA12   Rs28940271  This is a recessive SNP for congenital Lamella...
# 18  ABCA12   Rs28940568  This is a recessive SNP for congenital Lamella...
# 28   ABCA7    Rs7408475         Alzheimers disease polygenic hazard score.
# 29   ABCA7   Rs78117248  Sequencing of the ABCA7 gene in a Belgian coho...
# 27   ABCA7   Rs72973581  A sequencing study of 332 sporadic Alzheimers ...
# 22   ABCA7  Rs113809142  rs113809142, also known as c.4416+2T>G, is one...
# 25   ABCA7    Rs3764650  Alzheimers disease associated, based on large ...
# 24   ABCA7  Rs200538373  rs200538373, also known as c.5570+5G>C, is one...
