# %% [markdown]
# ## Parsing Survey Results
# This notebook produces the intended datasets by looking at the original files of text and relationships scraped from SNPedia and the results of the survey in order to construct the relationships between genes, SNPs, and different types of text snippets or context sentences. This notebook also deals with looking at how much of the dataset was covered by a given set of results from the survey.

# %%
import pandas as pd
import numpy as np
import json
import math
import random
import datetime
import re
from collections import Counter
from utils import flatten
from nltk.tokenize import sent_tokenize

# %% [markdown]
# ### Defining paths to input files
# These first two files should always stay the same, the first one defines the project-wide mapping between unique strings and IDs. The second one is the starting dataset of the text that was scraped and cleaned from SNPedia, so changing that would impact everything else downstream in the creation of the dataset. The paths to the Qualtrics results files can be changed though, and all the output files will be with respect to just those results. Running with different result sets should produce individual files that could be stacked after the fact.

# %%
# This is the original data with duplicate text strings because IDs refer to particular SNPs from particular genes.
ORIGINAL_DATA_PATH = "../data/3_snps_and_cleaned_text_with_ids.csv"

# What the survey was built from, the IDs in this refer to unique text strings so that duplicates weren't part of it.
SURVEY_SOURCE_DATA_PATH = "../data/6_part_2_binned_and_blocked_texts.csv"

# JSON file from parsing the results of the qualtrics survey designed for extracting phenotypes from text.
QUALTRICS_RAW_CSV_EXPORT_PATH = "../qualtrics/part_2_results_raw_qualtrics_exports/SNPedia_Survey__Version_2_October_1_2020_22_14_Completed_and_in_Progress.csv"
QUALTRICS_RESULTS_JSON_PATH = "../qualtrics/part_2_results_processed_json_files/snpedia_survey_version_2_october_1_2020_22_14_completed_and_in_progress.json"

# %% [markdown]
# ### Defining paths to output files
# These should be left alone, they'll be named automatically according to when they were run and will be grouped.

# %%
# Where to send the resulting output dataframes and some other information about coverage.
random_six_digit_number = random.randrange(100000,999999)
datetime_str = datetime.datetime.now().strftime('%m_%d_%Y_h%Hm%Ms%S')
FILENAMES_OUTPUT_PATH = "../data/S{}_input_file_paths_{}.txt".format(random_six_digit_number, datetime_str)
RESPONSES_OUTPUT_PATH = "../data/S{}_processed_survey_responses_{}.csv".format(random_six_digit_number, datetime_str)
SURVEY_TAKERS_OUTPUT_PATH = "../data/S{}_processed_survey_takers_{}.csv".format(random_six_digit_number, datetime_str)
SNPS_AND_SNIPPETS_OUTPUT_PATH = "../data/S{}_snps_and_snippets_{}.csv".format(random_six_digit_number, datetime_str)
SNPS_AND_CONTEXTS_OUTPUT_PATH = "../data/S{}_snps_and_contexts_{}.csv".format(random_six_digit_number, datetime_str)
NUM_ANNOTATIONS_PATH = "../data/S{}_number_of_annotations_per_id_{}.csv".format(random_six_digit_number, datetime_str)

# %%
# Create an output file that makes a not of which input files were used for these results.
with open(FILENAMES_OUTPUT_PATH, "w") as f:
    filenames = [
        ORIGINAL_DATA_PATH,
        SURVEY_SOURCE_DATA_PATH,
        QUALTRICS_RAW_CSV_EXPORT_PATH,
        QUALTRICS_RESULTS_JSON_PATH]
    filenames = "\n".join(filenames)
    f.write(filenames)

# %%
# Make sure the mapping between the unique texts used to create the survey and the original SNP data exists.
original_df = pd.read_csv(ORIGINAL_DATA_PATH)
#survey_df = pd.read_csv(SURVEY_SOURCE_DATA_PATH)
#text_to_unique_text_id = dict(zip(survey_df.text, survey_df.id))
#unique_text_id_to_text = dict(zip(survey_df.id, survey_df.text))
#original_df["id"] = original_df["text"].map(text_to_unique_text_id)

id_to_unique_text = dict(zip(original_df["id"].values, original_df["text"].values))


original_df.head(20)
# Out:
#       gene         snp                                               text  id
# 0    AANAT  Rs28936679  rs28936679, also known as Ala129Thr or A129T (...   1
# 1    AANAT   Rs3760138  Genetic differences in human circadian clock g...   2
# 2    AANAT   Rs4238989  Genetic differences in human circadian clock g...   3
# 3    ABCA1   Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...   4
# 4    ABCA1   Rs1883025  Apolipoprotein E levels in cerebrospinal fluid...   5
# 5    ABCA1   Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...   6
# 6    ABCA1   Rs2066714  Apolipoprotein E levels in cerebrospinal fluid...   7
# 7    ABCA1   Rs2066715  Apolipoprotein E levels in cerebrospinal fluid...   8
# 8    ABCA1   Rs2230806  rs2230806, also known as Arg219Lys or R219K, i...   9
# 9    ABCA1   Rs2230808  rs2297404, rs2230808, and rs2020927 haplotype ...  10
# 10   ABCA1   Rs2297404  rs2297404, rs2230808, and rs2020927 haplotype ...  11
# 11   ABCA1    Rs363717  Examining the effect of linkage disequilibrium...  12
# 12   ABCA1   Rs4149268  G allele is associated with 0.82mg/dl increase...  13
# 13   ABCA1   Rs4149274  C allele is associated with 1.51mg/dl increase...  14
# 14  ABCA12  Rs28940268  This is a recessive SNP for congenital Lamella...  15
# 15  ABCA12  Rs28940269  This is a recessive SNP for congenital Lamella...  15
# 16  ABCA12  Rs28940270  This is a recessive SNP for congenital Lamella...  15
# 17  ABCA12  Rs28940271  This is a recessive SNP for congenital Lamella...  15
# 18  ABCA12  Rs28940568  This is a recessive SNP for congenital Lamella...  15
# 19  ABCA12    Rs726070  aka c.7093G>A (p.Asp2365Asn)The variant allele...  16

# %%
original_df.isnull().sum(axis = 0)
# Out:
# gene    0
# snp     0
# text    0
# id      0
# dtype: int64

# %%
original_df.shape
# Out:
# (6535, 4)

# %%
# Create a dictionary using the JSON data output from a qualtrics survey.
with open(QUALTRICS_RESULTS_JSON_PATH) as f:
    responses = json.load(f)
responses
# Out:
# [{'response_id': 'R_2eUMgNrFozgjPf3',
#   'recorded_datetime': '10/1/20 13:40',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 973,
#   'hilights': [{'qid': 3279,
#     'selection': 'prone to miscalls',
#     'selection_index': 0},
#    {'qid': 957,
#     'selection': 'vaccine-induced immunity to HBV',
#     'selection_index': 25},
#    {'qid': 5071,
#     'selection': "increased risk for Crohn's disease",
#     'selection_index': 16},
#    {'qid': 1807, 'selection': 'risk of breast cancer', 'selection_index': 55},
#    {'qid': 1103,
#     'selection': 'predictive of Cystic Fibrosis',
#     'selection_index': 22},
#    {'qid': 4536, 'selection': 'schizophrenia', 'selection_index': 104},
#    {'qid': 4536,
#     'selection': 'developmental disorders',
#     'selection_index': 122},
#    {'qid': 3015,
#     'selection': 'hyperalphalipoproteinemia',
#     'selection_index': 59},
#    {'qid': 2178, 'selection': 'Krabbe disease', 'selection_index': 66},
#    {'qid': 2393, 'selection': 'oxidative stress', 'selection_index': 88},
#    {'qid': 2393,
#     'selection': 'risk of adult brain tumors',
#     'selection_index': 110},
#    {'qid': 760, 'selection': 'breast cancer', 'selection_index': 141},
#    {'qid': 4574,
#     'selection': 'risk of gastric cancer',
#     'selection_index': 130},
#    {'qid': 324, 'selection': 'hypophosphatasia', 'selection_index': 200},
#    {'qid': 4203, 'selection': "Alzheimer's disease", 'selection_index': 296},
#    {'qid': 1018, 'selection': 'malignant melanoma', 'selection_index': 195},
#    {'qid': 5064, 'selection': 'lupus erythematosus', 'selection_index': 383},
#    {'qid': 4280, 'selection': 'breast cancer', 'selection_index': 320},
#    {'qid': 4848, 'selection': "Parkinson's disease", 'selection_index': 56},
#    {'qid': 2478, 'selection': 'Tourette syndrome', 'selection_index': 228},
#    {'qid': 2845, 'selection': 'lupus erythematosus', 'selection_index': 147},
#    {'qid': 2845, 'selection': 'SLE', 'selection_index': 412},
#    {'qid': 1567,
#     'selection': 'lower DBH expression in plasma',
#     'selection_index': 117},
#    {'qid': 1567, 'selection': 'ADHD', 'selection_index': 353},
#    {'qid': 1567, 'selection': 'neuroticism', 'selection_index': 681},
#    {'qid': 1567, 'selection': 'impulsiveness', 'selection_index': 951},
#    {'qid': 1567, 'selection': 'aggressive hostility', 'selection_index': 969},
#    {'qid': 1567, 'selection': 'impulsiveness', 'selection_index': 1388},
#    {'qid': 1567, 'selection': 'aggression', 'selection_index': 1403},
#    {'qid': 998, 'selection': 'ADHD', 'selection_index': 531},
#    {'qid': 998, 'selection': 'autism', 'selection_index': 538},
#    {'qid': 998, 'selection': 'schizophrenia', 'selection_index': 546},
#    {'qid': 998, 'selection': 'substance abuse', 'selection_index': 561},
#    {'qid': 998, 'selection': 'bipolar disorder', 'selection_index': 580},
#    {'qid': 143, 'selection': 'obesity', 'selection_index': 991},
#    {'qid': 143,
#     'selection': 'the highest carbohydrate intake',
#     'selection_index': 1004},
#    {'qid': 1296, 'selection': 'longevity', 'selection_index': 278},
#    {'qid': 1296,
#     'selection': 'cause-specific mortality',
#     'selection_index': 292},
#    {'qid': 1296,
#     'selection': 'coronary heart disease',
#     'selection_index': 445},
#    {'qid': 1296, 'selection': 'prostate cancer', 'selection_index': 746},
#    {'qid': 1296, 'selection': 'COPD', 'selection_index': 842},
#    {'qid': 1296, 'selection': 'systemic inflammation', 'selection_index': 856},
#    {'qid': 1296,
#     'selection': 'complex human diseases',
#     'selection_index': 1122},
#    {'qid': 1296,
#     'selection': 'cortisol awakening response',
#     'selection_index': 1203},
#    {'qid': 1296, 'selection': 'obesity', 'selection_index': 1288},
#    {'qid': 1296,
#     'selection': 'low high-density lipoprotein cholesterol',
#     'selection_index': 1297},
#    {'qid': 1296,
#     'selection': 'C-reactive protein polymorphisms',
#     'selection_index': 1342},
#    {'qid': 1296, 'selection': 'lung cancer', 'selection_index': 1519},
#    {'qid': 2419,
#     'selection': 'frontotemporal dementia',
#     'selection_index': 158},
#    {'qid': 2419,
#     'selection': 'progressive neurodegenerative disease',
#     'selection_index': 219},
#    {'qid': 2419,
#     'selection': 'frontotemporal dementia',
#     'selection_index': 541},
#    {'qid': 2419, 'selection': "Alzheimer's disease", 'selection_index': 697},
#    {'qid': 2419, 'selection': "Alzheimer's disease", 'selection_index': 1307},
#    {'qid': 2419,
#     'selection': 'frontotemporal dementia',
#     'selection_index': 1258},
#    {'qid': 2419,
#     'selection': 'behavioral and/or language dysfunction',
#     'selection_index': 1408},
#    {'qid': 2419, 'selection': 'amnesic syndrome', 'selection_index': 1472},
#    {'qid': 2419, 'selection': "Alzheimer's disease", 'selection_index': 1501},
#    {'qid': 2419,
#     'selection': 'Reduced serum progranulin level',
#     'selection_index': 1549},
#    {'qid': 2419, 'selection': "Parkinson's disease", 'selection_index': 1606},
#    {'qid': 2419, 'selection': "Parkinson's disease", 'selection_index': 1649},
#    {'qid': 2419,
#     'selection': 'reduces progranulin levels',
#     'selection_index': 1689},
#    {'qid': 2419, 'selection': "Alzheimer's disease", 'selection_index': 1780},
#    {'qid': 2419, 'selection': "Parkinson's disease", 'selection_index': 1850},
#    {'qid': 2419, 'selection': "Parkinson's disease", 'selection_index': 1932},
#    {'qid': 2419,
#     'selection': 'neurodegenerative disorders',
#     'selection_index': 2101},
#    {'qid': 2419,
#     'selection': "reduces plasma and brain levels of granulin in Alzheimer's disease patients",
#     'selection_index': 2381},
#    {'qid': 2419, 'selection': "Alzheimer's disease", 'selection_index': 2565},
#    {'qid': 2419, 'selection': 'inflammation', 'selection_index': 3035},
#    {'qid': 2419,
#     'selection': 'frontotemporal dementia',
#     'selection_index': 3476}]},
#  {'response_id': 'R_utbyJnQ1UKOs1mp',
#   'recorded_datetime': '10/1/20 13:43',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 653,
#   'hilights': [{'qid': 4315,
#     'selection': 'Hirschsprung disease',
#     'selection_index': 32},
#    {'qid': 2617, 'selection': 'HSD3B2 mutation', 'selection_index': 37},
#    {'qid': 2617,
#     'selection': 'congenital adrenal hyperplasia',
#     'selection_index': 54},
#    {'qid': 2617, 'selection': 'deficiency ', 'selection_index': 17},
#    {'qid': 2617, 'selection': 'recessively inherited', 'selection_index': 86},
#    {'qid': 2415, 'selection': 'schizophrenia ', 'selection_index': 37},
#    {'qid': 2415, 'selection': 'GRM3 splicing', 'selection_index': 65},
#    {'qid': 1126,
#     'selection': 'autosomal dominant mental retardation',
#     'selection_index': 74},
#    {'qid': 584,
#     'selection': 'Pseudocholinesterase Deficiency',
#     'selection_index': 68},
#    {'qid': 3773, 'selection': 'pathogenic variant', 'selection_index': 53},
#    {'qid': 3474, 'selection': 'SNPs ', 'selection_index': 19},
#    {'qid': 3474, 'selection': 'human aging', 'selection_index': 91},
#    {'qid': 131, 'selection': 'pathogenic variant', 'selection_index': 55},
#    {'qid': 282, 'selection': 'ALDOB gene mutation', 'selection_index': 120},
#    {'qid': 1592, 'selection': 'Haplogroup I (Y-DNA)', 'selection_index': 55},
#    {'qid': 3431, 'selection': 'Polymorphisms ', 'selection_index': 0},
#    {'qid': 3431, 'selection': 'asthma', 'selection_index': 122},
#    {'qid': 5291, 'selection': 'Y haplogroup D', 'selection_index': 116},
#    {'qid': 5291, 'selection': 'mutation ', 'selection_index': 136},
#    {'qid': 5291, 'selection': 'Asian haplogroup D', 'selection_index': 185},
#    {'qid': 3861, 'selection': 'definitely pathogenic', 'selection_index': 51},
#    {'qid': 3861, 'selection': 'autosomal recessive', 'selection_index': 147},
#    {'qid': 3861,
#     'selection': 'early-onset Parkinson disease',
#     'selection_index': 168},
#    {'qid': 604,
#     'selection': 'increased risk for depression',
#     'selection_index': 76},
#    {'qid': 4164,
#     'selection': 'spastic spastic paraparesis (paraplegia)',
#     'selection_index': 201},
#    {'qid': 4164,
#     'selection': "arly-onset Alzheimer's disease",
#     'selection_index': 101},
#    {'qid': 1131, 'selection': 'pathogenic in ClinVar', 'selection_index': 45},
#    {'qid': 1131,
#     'selection': 'autosomal dominant mental retardation',
#     'selection_index': 172},
#    {'qid': 909,
#     'selection': 'increased risk for developing type 1 diabetes',
#     'selection_index': 114},
#    {'qid': 1427,
#     'selection': 'reduction in the metabolism of S-mephenytoin and tolbutamide in vitro.Clopidogrel Efficacy',
#     'selection_index': 220},
#    {'qid': 3094,
#     'selection': 'major depressive disorder',
#     'selection_index': 238},
#    {'qid': 3094,
#     'selection': 'lower magnitude of placebo response.',
#     'selection_index': 340},
#    {'qid': 437,
#     'selection': "pathogenic for an aggressive, early-onset form of Alzheimer's disease",
#     'selection_index': 160},
#    {'qid': 1185,
#     'selection': 'autosomal dominant or recessive manner',
#     'selection_index': 120},
#    {'qid': 1185, 'selection': 'myotonia congenita', 'selection_index': 209},
#    {'qid': 3056, 'selection': 'inherited recessively', 'selection_index': 154},
#    {'qid': 3056, 'selection': 'pathogenic ', 'selection_index': 191},
#    {'qid': 3056,
#     'selection': 'Leigh syndrome known as the French-Canadian type',
#     'selection_index': 216},
#    {'qid': 4221,
#     'selection': 'coronary angiographies (CAGs)',
#     'selection_index': 169},
#    {'qid': 4221, 'selection': 'experienced bleeding', 'selection_index': 275},
#    {'qid': 4221,
#     'selection': 'higher risk for bleeding in otherwise low risk patients who (i) did undergo percutaneous coronary intervention and (ii) did not take clopidogrel',
#     'selection_index': 522},
#    {'qid': 1663,
#     'selection': 'disease susceptibility',
#     'selection_index': 504},
#    {'qid': 1663,
#     'selection': 'coronary heart disease',
#     'selection_index': 679},
#    {'qid': 1239,
#     'selection': 'delayed onset of speech',
#     'selection_index': 103},
#    {'qid': 3266, 'selection': 'pathogenic ', 'selection_index': 186},
#    {'qid': 3266,
#     'selection': 'ClinVar for Lynch syndrome',
#     'selection_index': 220},
#    {'qid': 3266,
#     'selection': 'Muir-Torre syndrome among Lynch syndrome families.',
#     'selection_index': 1242},
#    {'qid': 30, 'selection': 'adverse side effects', 'selection_index': 278},
#    {'qid': 30, 'selection': 'depression ', 'selection_index': 699},
#    {'qid': 30, 'selection': 'depression ', 'selection_index': 997},
#    {'qid': 30, 'selection': 'depression ', 'selection_index': 1427},
#    {'qid': 88, 'selection': 'dyslipidemia ', 'selection_index': 728},
#    {'qid': 88, 'selection': 'carotid artery disease', 'selection_index': 794},
#    {'qid': 1228,
#     'selection': 'comorbid drug dependence (DD) and alcohol dependence (AD)',
#     'selection_index': 201},
#    {'qid': 1228, 'selection': 'Alcoholic patients', 'selection_index': 733},
#    {'qid': 1609, 'selection': 'Polymorphism ', 'selection_index': 1135},
#    {'qid': 1609, 'selection': 'polymorphism ', 'selection_index': 1336},
#    {'qid': 1609, 'selection': 'Polymorphisms ', 'selection_index': 929},
#    {'qid': 1609,
#     'selection': 'hypothyroid patients',
#     'selection_index': 1441}]},
#  {'response_id': 'R_3nAyzwespvUg02B',
#   'recorded_datetime': '10/1/20 13:44',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 454,
#   'hilights': [{'qid': 499, 'selection': ' 2T>', 'selection_index': 11},
#    {'qid': 614, 'selection': 'Brain-derived', 'selection_index': 0},
#    {'qid': 2458, 'selection': 'Modeling effects', 'selection_index': 0},
#    {'qid': 2458, 'selection': 'human single', 'selection_index': 20},
#    {'qid': 2458, 'selection': 'polymorphisms', 'selection_index': 44},
#    {'qid': 1885, 'selection': 'polymorphisms', 'selection_index': 40},
#    {'qid': 1885, 'selection': 'dermatitis', 'selection_index': 100},
#    {'qid': 5255, 'selection': 'intronic region', 'selection_index': 37},
#    {'qid': 5255, 'selection': 'bladder cancer risk', 'selection_index': 99},
#    {'qid': 3689, 'selection': 'Rheumatoid Arthritis', 'selection_index': 38},
#    {'qid': 3353, 'selection': 'matrix-assisted', 'selection_index': 98},
#    {'qid': 3353, 'selection': 'strategy based', 'selection_index': 34},
#    {'qid': 2994, 'selection': 'associated', 'selection_index': 10},
#    {'qid': 2994, 'selection': 'pressure', 'selection_index': 32},
#    {'qid': 2994, 'selection': 'hypertension', 'selection_index': 45},
#    {'qid': 675, 'selection': 'considered', 'selection_index': 129},
#    {'qid': 675, 'selection': 'breast cancer', 'selection_index': 155},
#    {'qid': 3046, 'selection': 'polymorphism', 'selection_index': 46},
#    {'qid': 3046,
#     'selection': 'increases susceptibility',
#     'selection_index': 64},
#    {'qid': 3046, 'selection': 'Osteoporotic fractures', 'selection_index': 92},
#    {'qid': 984,
#     'selection': 'pathogenic rare mutation',
#     'selection_index': 65},
#    {'qid': 984, 'selection': 'gastric cancer', 'selection_index': 113},
#    {'qid': 984, 'selection': 'hereditary diffuse', 'selection_index': 94},
#    {'qid': 5240, 'selection': 'pathogenic', 'selection_index': 82},
#    {'qid': 5240,
#     'selection': 'autosomal recessive spinocerebellar',
#     'selection_index': 97},
#    {'qid': 3589, 'selection': 'supranuclear', 'selection_index': 108},
#    {'qid': 3788, 'selection': 'autosomal dominantly', 'selection_index': 127},
#    {'qid': 3788, 'selection': 'inherited familial', 'selection_index': 148},
#    {'qid': 4377,
#     'selection': 'increased susceptibility',
#     'selection_index': 130},
#    {'qid': 4377,
#     'selection': 'malignant hyperthermia',
#     'selection_index': 158},
#    {'qid': 2028, 'selection': 'compound heterozygote', 'selection_index': 196},
#    {'qid': 2028, 'selection': "Friedreich's ataxia", 'selection_index': 139},
#    {'qid': 4427, 'selection': 'in-depth review', 'selection_index': 95},
#    {'qid': 4427,
#     'selection': 'Scavenger receptor class B',
#     'selection_index': 112},
#    {'qid': 4427, 'selection': 'independent predictor', 'selection_index': 160},
#    {'qid': 4427,
#     'selection': 'high-density lipoprotein',
#     'selection_index': 185},
#    {'qid': 4427,
#     'selection': 'hyperalphalipoproteinemia.',
#     'selection_index': 246},
#    {'qid': 1252,
#     'selection': 'familial intracranial aneurysms',
#     'selection_index': 70},
#    {'qid': 441,
#     'selection': 'Familial Bipolar Disorder',
#     'selection_index': 20},
#    {'qid': 441, 'selection': 'variants speculated', 'selection_index': 94},
#    {'qid': 441, 'selection': 'bipolar disorder', 'selection_index': 209},
#    {'qid': 5172,
#     'selection': 'progressive familial heart block',
#     'selection_index': 175},
#    {'qid': 5172, 'selection': 'An additional mention', 'selection_index': 277},
#    {'qid': 4177, 'selection': 'autosomal dominant', 'selection_index': 112},
#    {'qid': 4177, 'selection': 'considered pathogenic', 'selection_index': 165},
#    {'qid': 4177,
#     'selection': 'potentially early-onset',
#     'selection_index': 212},
#    {'qid': 1665, 'selection': 'homozygotes', 'selection_index': 383},
#    {'qid': 1665,
#     'selection': 'Bonferroni significance',
#     'selection_index': 652},
#    {'qid': 2008,
#     'selection': 'n strong linkage disequilibrium',
#     'selection_index': 352},
#    {'qid': 2008,
#     'selection': 'nonsecretor variant encoding',
#     'selection_index': 398},
#    {'qid': 833, 'selection': 'Brazilian patients', 'selection_index': 624},
#    {'qid': 833, 'selection': 'human monocytes', 'selection_index': 749},
#    {'qid': 833,
#     'selection': 'X-linked agammaglobulinemia',
#     'selection_index': 648},
#    {'qid': 833,
#     'selection': "Bruton's tyrosine kinase",
#     'selection_index': 677},
#    {'qid': 833, 'selection': 'agammaglobulinemia', 'selection_index': 184}]},
#  {'response_id': 'R_32XGNR4nwZcoLZI',
#   'recorded_datetime': '10/1/20 13:47',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 615,
#   'hilights': [{'qid': 838,
#     'selection': 'adult bronchial asthma',
#     'selection_index': 78},
#    {'qid': 3384,
#     'selection': 'uncertain significance according to ClinVar.',
#     'selection_index': 107},
#    {'qid': 2563, 'selection': 'heumatoid arthritis', 'selection_index': 82},
#    {'qid': 2267,
#     'selection': 'late-onset noninsulin-dependent diabetes',
#     'selection_index': 97},
#    {'qid': 2046, 'selection': "Friedreich's ataxia", 'selection_index': 140},
#    {'qid': 5142, 'selection': 'Thyroid cancer', 'selection_index': 162},
#    {'qid': 5142,
#     'selection': 'lower risk of hypothyroidism ',
#     'selection_index': 80},
#    {'qid': 317, 'selection': 'hypophosphatasia.', 'selection_index': 204},
#    {'qid': 1232, 'selection': 'cannabis dependence', 'selection_index': 96},
#    {'qid': 1232,
#     'selection': 'gaze duration for happy faces.',
#     'selection_index': 476},
#    {'qid': 420, 'selection': "Alzheimer's disease ", 'selection_index': 151},
#    {'qid': 4840, 'selection': 'Lamb-shaffer syndrome', 'selection_index': 210},
#    {'qid': 4840,
#     'selection': 'autosomal dominant mutation',
#     'selection_index': 143},
#    {'qid': 567, 'selection': 'Bonferroni correction', 'selection_index': 272},
#    {'qid': 567, 'selection': 'ADHD.', 'selection_index': 376},
#    {'qid': 3669, 'selection': "Alzheimer's disease", 'selection_index': 177},
#    {'qid': 3669,
#     'selection': 'independent of age and ApoE status.',
#     'selection_index': 467},
#    {'qid': 4774,
#     'selection': 'higher intelligence in children',
#     'selection_index': 532},
#    {'qid': 2429, 'selection': 'ipolar disorder', 'selection_index': 60},
#    {'qid': 2429,
#     'selection': 'ithium treatment respons',
#     'selection_index': 415},
#    {'qid': 2120,
#     'selection': 'biochemical characterization',
#     'selection_index': 134},
#    {'qid': 232, 'selection': 'SNP', 'selection_index': 10},
#    {'qid': 4227, 'selection': ' breast canc', 'selection_index': 190},
#    {'qid': 4227, 'selection': "Parkinson's disease", 'selection_index': 403},
#    {'qid': 4227, 'selection': 'cervical cancer', 'selection_index': 726},
#    {'qid': 4227, 'selection': 'prostate cancer', 'selection_index': 798},
#    {'qid': 4227,
#     'selection': 'ridine diphosphate glucuronosyltransferase',
#     'selection_index': 1442},
#    {'qid': 2916, 'selection': 'tumors.', 'selection_index': 892},
#    {'qid': 4816, 'selection': 'neuronal apoptosis', 'selection_index': 1032},
#    {'qid': 4816,
#     'selection': 'neuronal dysfunction.',
#     'selection_index': 1161}]},
#  {'response_id': 'R_3oYnbK47VvX8jrt',
#   'recorded_datetime': '10/1/20 13:49',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 1524,
#   'hilights': []},
#  {'response_id': 'R_3rDF5fdF3oDgOuR',
#   'recorded_datetime': '10/1/20 13:49',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 677,
#   'hilights': [{'qid': 2109,
#     'selection': 'ndMe nazwa: i5008436',
#     'selection_index': 3},
#    {'qid': 2440, 'selection': 'GUCY2D c.389delC', 'selection_index': 0},
#    {'qid': 353, 'selection': 'ka c.762', 'selection_index': 1},
#    {'qid': 5297, 'selection': '23andMe nazwa: i4000146', 'selection_index': 0},
#    {'qid': 2319, 'selection': 'rs111033451', 'selection_index': 0},
#    {'qid': 2319, 'selection': ' GJB2 ', 'selection_index': 33},
#    {'qid': 2324, 'selection': 'rs786204597', 'selection_index': 0},
#    {'qid': 2324, 'selection': 'GJB2 ', 'selection_index': 34},
#    {'qid': 4081, 'selection': 'rs267606980,', 'selection_index': 0},
#    {'qid': 4081, 'selection': 'G127V', 'selection_index': 13},
#    {'qid': 4403, 'selection': 'aka c.7063C', 'selection_index': 0},
#    {'qid': 4403,
#     'selection': '(p.Arg2355Trp lub R2355W)',
#     'selection_index': 15},
#    {'qid': 2968, 'selection': 'aka c.715C', 'selection_index': 0},
#    {'qid': 2968, 'selection': 'T (p.Gln239Ter)', 'selection_index': 12},
#    {'qid': 991, 'selection': 'aka c.60G', 'selection_index': 0},
#    {'qid': 991, 'selection': 'A, p.Trp20Ter i W20X', 'selection_index': 11},
#    {'qid': 4514, 'selection': 'NM_000062', 'selection_index': 0},
#    {'qid': 4514, 'selection': '.2', 'selection_index': 9},
#    {'qid': 4514, 'selection': 'SERPING1):', 'selection_index': 13},
#    {'qid': 4514, 'selection': '936delC (', 'selection_index': 26},
#    {'qid': 3388, 'selection': 'lias c.280G> A,', 'selection_index': 1},
#    {'qid': 3388, 'selection': 'Gly94Arg', 'selection_index': 19},
#    {'qid': 3388, 'selection': 'G94R;', 'selection_index': 32},
#    {'qid': 654, 'selection': 'aka c.736G', 'selection_index': 0},
#    {'qid': 654, 'selection': 'p.Ala246Pro)', 'selection_index': 15},
#    {'qid': 654, 'selection': '23andMe', 'selection_index': 28},
#    {'qid': 3760, 'selection': 'rs74315354', 'selection_index': 0},
#    {'qid': 3896, 'selection': 'aka c.1213C', 'selection_index': 0},
#    {'qid': 3896, 'selection': 'T (p.Gln405Ter)', 'selection_index': 13},
#    {'qid': 4285, 'selection': 'aka c.781C', 'selection_index': 0},
#    {'qid': 4285, 'selection': 'T (p.Pro261Ser) 23', 'selection_index': 12},
#    {'qid': 4285, 'selection': 'i5008105', 'selection_index': 44},
#    {'qid': 997, 'selection': 'rs11149566 ', 'selection_index': 83},
#    {'qid': 997, 'selection': 'rs4458717', 'selection_index': 94},
#    {'qid': 997, 'selection': 'rs4660646', 'selection_index': 104},
#    {'qid': 4230, 'selection': 'COX-2 (PTGS2) ', 'selection_index': 43},
#    {'qid': 4519,
#     'selection': 'M_000062.2 (SERPING1): c.1394C> T (p.Ala465Val) 23 andMe name: i5000466',
#     'selection_index': 1},
#    {'qid': 4341, 'selection': '20q13', 'selection_index': 41},
#    {'qid': 4341, 'selection': '21q22', 'selection_index': 49},
#    {'qid': 4301, 'selection': '15', 'selection_index': 14},
#    {'qid': 5274, 'selection': 'aka c.1389 + 1G', 'selection_index': 0},
#    {'qid': 5274, 'selection': 'HLH', 'selection_index': 88},
#    {'qid': 205, 'selection': 'g.-7309A', 'selection_index': 0},
#    {'qid': 205, 'selection': 'rs75172865)', 'selection_index': 13},
#    {'qid': 205, 'selection': ' g.33447T (rs1044471)', 'selection_index': 98},
#    {'qid': 1531, 'selection': 'rs55901263', 'selection_index': 0},
#    {'qid': 1531, 'selection': '653C> ', 'selection_index': 31},
#    {'qid': 1531, 'selection': '15702C', 'selection_index': 40},
#    {'qid': 1531, 'selection': ' rs55901263 ', 'selection_index': 91},
#    {'qid': 3381, 'selection': 'aka c.655A>', 'selection_index': 0},
#    {'qid': 3381, 'selection': 'i5000071', 'selection_index': 103},
#    {'qid': 3381, 'selection': 'N219Y', 'selection_index': 31},
#    {'qid': 3597, 'selection': '492K SNP', 'selection_index': 43},
#    {'qid': 5062, 'selection': 'TNF', 'selection_index': 59},
#    {'qid': 5062, 'selection': '55 kDa', 'selection_index': 71},
#    {'qid': 3618,
#     'selection': '35AA 58,12 ± 0,27Aa 57,15 ± 0,31aa 55,26 ± 0,65',
#     'selection_index': 121},
#    {'qid': 2039, 'selection': 'rs147211454', 'selection_index': 0},
#    {'qid': 2039, 'selection': 'c.340_352', 'selection_index': 32},
#    {'qid': 5349, 'selection': 'aka c.1858G', 'selection_index': 0},
#    {'qid': 5349, 'selection': 'p.Asp620Asn,', 'selection_index': 16},
#    {'qid': 5349, 'selection': 'D620N ', 'selection_index': 29},
#    {'qid': 311, 'selection': 'i6006890', 'selection_index': 0},
#    {'qid': 311, 'selection': 'c.1112C>', 'selection_index': 29},
#    {'qid': 311, 'selection': 'p.T371I,', 'selection_index': 44},
#    {'qid': 4448, 'selection': 'rs121908908', 'selection_index': 0},
#    {'qid': 4448, 'selection': 'c.1376C>', 'selection_index': 32},
#    {'qid': 4448, 'selection': ' p.Ser459Ter', 'selection_index': 43},
#    {'qid': 4448, 'selection': 'S459X', 'selection_index': 58},
#    {'qid': 4224, 'selection': 'rs2745557 ', 'selection_index': 71},
#    {'qid': 4224, 'selection': 'PTGS2,', 'selection_index': 90},
#    {'qid': 1951, 'selection': 'rs9834312', 'selection_index': 146},
#    {'qid': 1951, 'selection': 'rs939882', 'selection_index': 388},
#    {'qid': 5088, 'selection': 'rs104894725,', 'selection_index': 0},
#    {'qid': 5088, 'selection': 'c.616A> C, p.Lys206Gln', 'selection_index': 32},
#    {'qid': 5088, 'selection': 'i5007728', 'selection_index': 335},
#    {'qid': 16, 'selection': 'aka c.7093G>', 'selection_index': 0},
#    {'qid': 16, 'selection': 'p.Asp2365Asn', 'selection_index': 16},
#    {'qid': 2691, 'selection': 'rs137853022', 'selection_index': 0},
#    {'qid': 2691, 'selection': 'R696P', 'selection_index': 32},
#    {'qid': 2691, 'selection': 'Arg696Pro,', 'selection_index': 42},
#    {'qid': 2691, 'selection': 'i4000400', 'selection_index': 32},
#    {'qid': 61, 'selection': 'rs11046205', 'selection_index': 0},
#    {'qid': 4852, 'selection': 'rs35948326,', 'selection_index': 0},
#    {'qid': 4852, 'selection': ' c.2909C>', 'selection_index': 30},
#    {'qid': 140, 'selection': 'G12269A', 'selection_index': 54},
#    {'qid': 2736, 'selection': 'rs419598', 'selection_index': 126},
#    {'qid': 2736, 'selection': 'rs419598', 'selection_index': 208},
#    {'qid': 2736, 'selection': 'rs419598', 'selection_index': 26},
#    {'qid': 3668, 'selection': 'rs8069176', 'selection_index': 0},
#    {'qid': 3668, 'selection': '(17q21)', 'selection_index': 228},
#    {'qid': 4778, 'selection': 'SNAP25 ', 'selection_index': 12},
#    {'qid': 5025,
#     'selection': 'rs4696480 (T-16934A i Arg753Gln)',
#     'selection_index': 34},
#    {'qid': 1288, 'selection': 'rs4675690 ', 'selection_index': 0},
#    {'qid': 1288, 'selection': 'CREB1,', 'selection_index': 33},
#    {'qid': 2672, 'selection': 'TNIP1,', 'selection_index': 46},
#    {'qid': 2672, 'selection': 'PRDM1,', 'selection_index': 53},
#    {'qid': 2672, 'selection': 'JAZF1,', 'selection_index': 60},
#    {'qid': 2672, 'selection': 'UHRF1BP1', 'selection_index': 67},
#    {'qid': 2672, 'selection': 'IL10', 'selection_index': 78}]},
#  {'response_id': 'R_YWGiyoyuJx2FDIR',
#   'recorded_datetime': '10/1/20 13:52',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 1359,
#   'hilights': [{'qid': 3711,
#     'selection': 'Phenylketonuria',
#     'selection_index': 0},
#    {'qid': 5079,
#     'selection': 'familial hypertrophic cardiomyopathy',
#     'selection_index': 11},
#    {'qid': 2943, 'selection': 'endometriosis', 'selection_index': 27},
#    {'qid': 4838, 'selection': 'systemic sclerosis', 'selection_index': 30},
#    {'qid': 2334, 'selection': 'deafness', 'selection_index': 65},
#    {'qid': 2867, 'selection': 'Relapsing diabetes', 'selection_index': 0},
#    {'qid': 4988, 'selection': 'hemochromatosis', 'selection_index': 50},
#    {'qid': 4988, 'selection': 'young Italian patients', 'selection_index': 22},
#    {'qid': 1758, 'selection': 'elastic microfibrils', 'selection_index': 44},
#    {'qid': 1758, 'selection': 'striae distensae', 'selection_index': 100},
#    {'qid': 1146, 'selection': 'schizophrenia', 'selection_index': 0},
#    {'qid': 1662, 'selection': 'ovarian endometriosis', 'selection_index': 128},
#    {'qid': 197, 'selection': 'diabetes', 'selection_index': 103},
#    {'qid': 788, 'selection': 'breast cancer', 'selection_index': 142},
#    {'qid': 2441, 'selection': 'MN blood group', 'selection_index': 84},
#    {'qid': 5425, 'selection': 'African-Americans', 'selection_index': 228},
#    {'qid': 5425, 'selection': 'lung cancer', 'selection_index': 175},
#    {'qid': 5425, 'selection': 'Latinos', 'selection_index': 216},
#    {'qid': 300, 'selection': 'hypophosphatasia', 'selection_index': 202},
#    {'qid': 3231, 'selection': "Alzheimer's disease", 'selection_index': 184},
#    {'qid': 2975, 'selection': 'leprosy', 'selection_index': 75},
#    {'qid': 2975, 'selection': "Crohn's disease", 'selection_index': 212},
#    {'qid': 2975, 'selection': 'Leprosy', 'selection_index': 296},
#    {'qid': 2975, 'selection': 'leprosy', 'selection_index': 232},
#    {'qid': 2257,
#     'selection': 'Dopa-Responsive Dystonia',
#     'selection_index': 76},
#    {'qid': 2257, 'selection': 'Dystonia', 'selection_index': 101},
#    {'qid': 2257, 'selection': 'British patients', 'selection_index': 222},
#    {'qid': 2257,
#     'selection': 'Dopa-responsive dystonia',
#     'selection_index': 194},
#    {'qid': 2257,
#     'selection': 'dopa-responsive myoclonus-dystonia syndrome',
#     'selection_index': 379},
#    {'qid': 3996,
#     'selection': 'hypomyelinating leukodystrophy',
#     'selection_index': 386},
#    {'qid': 3087, 'selection': 'autism', 'selection_index': 128},
#    {'qid': 3087, 'selection': 'autism', 'selection_index': 247},
#    {'qid': 5390,
#     'selection': 'Von Willebrand disease',
#     'selection_index': 323},
#    {'qid': 5390, 'selection': 'blood group O', 'selection_index': 245},
#    {'qid': 912, 'selection': 'Ehlers-Danlos syndrome', 'selection_index': 769},
#    {'qid': 912,
#     'selection': 'overproduction of ammonia',
#     'selection_index': 575},
#    {'qid': 912,
#     'selection': 'decrease in glutathione',
#     'selection_index': 610},
#    {'qid': 393, 'selection': 'Caucasians', 'selection_index': 87},
#    {'qid': 393, 'selection': "Alzheimer's disease", 'selection_index': 159},
#    {'qid': 393, 'selection': 'post-menopausal women', 'selection_index': 728},
#    {'qid': 393,
#     'selection': 'low bone mineral density',
#     'selection_index': 789},
#    {'qid': 393, 'selection': 'gastric cancer risk', 'selection_index': 970},
#    {'qid': 5184, 'selection': 'Graves disease ', 'selection_index': 131},
#    {'qid': 5184, 'selection': 'Italian Origin', 'selection_index': 380},
#    {'qid': 5184, 'selection': "Graves' disease", 'selection_index': 469},
#    {'qid': 504, 'selection': 'Canavan disease', 'selection_index': 212},
#    {'qid': 3603,
#     'selection': 'Glucocorticoid receptor gene polymorphisms',
#     'selection_index': 432},
#    {'qid': 3603, 'selection': 'rheumatoid arthritis', 'selection_index': 497},
#    {'qid': 3603,
#     'selection': 'Glucocorticoid receptor gene polymorphisms',
#     'selection_index': 642},
#    {'qid': 3603, 'selection': 'major depression', 'selection_index': 1322},
#    {'qid': 3603, 'selection': 'bipolar disorder', 'selection_index': 1387},
#    {'qid': 3603, 'selection': 'depression', 'selection_index': 1359},
#    {'qid': 3603,
#     'selection': 'anovulatory polycystic ovary syndrome',
#     'selection_index': 1497},
#    {'qid': 3603,
#     'selection': 'Glucocorticoid receptor polymorphism',
#     'selection_index': 1536},
#    {'qid': 3603, 'selection': 'bipolar patients', 'selection_index': 1612},
#    {'qid': 4956, 'selection': 'type-2 diabetes,', 'selection_index': 180},
#    {'qid': 4956, 'selection': 'breast cancer ', 'selection_index': 197},
#    {'qid': 4956,
#     'selection': 'aggressive prostate cancer',
#     'selection_index': 215},
#    {'qid': 4956, 'selection': 'type-2 diabetes', 'selection_index': 709},
#    {'qid': 4956, 'selection': 'Breast cancer.', 'selection_index': 1785}]},
#  {'response_id': 'R_1CkzzlePivYgMZr',
#   'recorded_datetime': '10/1/20 13:53',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 1322,
#   'hilights': [{'qid': 669,
#     'selection': 'breast cancer',
#     'selection_index': 10},
#    {'qid': 5354, 'selection': 'Willebrand disease', 'selection_index': 13},
#    {'qid': 2849,
#     'selection': 'ominant mutation in plakoglobin',
#     'selection_index': 9},
#    {'qid': 2849,
#     'selection': 'arrhythmogenic right ventricular cardiomyopathy',
#     'selection_index': 48},
#    {'qid': 5278,
#     'selection': 'hemophagocytic lymphohistiocytosis (HLH)',
#     'selection_index': 51},
#    {'qid': 3778,
#     'selection': 'cisplatin-induced cytotoxicity',
#     'selection_index': 51},
#    {'qid': 1256,
#     'selection': 'Mutations in the type IV collagen alpha 3 (COL4A3) gene',
#     'selection_index': 0},
#    {'qid': 1256,
#     'selection': 'autosomal recessive Alport syndrome',
#     'selection_index': 59},
#    {'qid': 2264,
#     'selection': 'autosomal dominant dopa-responsive dystonia',
#     'selection_index': 142},
#    {'qid': 796, 'selection': 'breast cancer', 'selection_index': 133},
#    {'qid': 795, 'selection': 'breast cancer', 'selection_index': 132},
#    {'qid': 1743,
#     'selection': 'leukoencephalopathy with vanishing white matter',
#     'selection_index': 66},
#    {'qid': 1743,
#     'selection': 'Leukoencephalopathy with vanishing white matter',
#     'selection_index': 115},
#    {'qid': 904, 'selection': 'A CAV3 microdeletion', 'selection_index': 0},
#    {'qid': 904, 'selection': 'A CAV3 microdeletion', 'selection_index': 76},
#    {'qid': 904, 'selection': 'A CAV3 microdeletion', 'selection_index': 152},
#    {'qid': 2984, 'selection': 'type 2 diabetes', 'selection_index': 136},
#    {'qid': 4802,
#     'selection': 'cardiovascular mortality',
#     'selection_index': 83},
#    {'qid': 3073,
#     'selection': 'utosomal dominant Parkinson disease (type 8)',
#     'selection_index': 143},
#    {'qid': 2417,
#     'selection': 'a very rare mutation in the GRN gene',
#     'selection_index': 65},
#    {'qid': 2417,
#     'selection': 'frontotemporal dementia',
#     'selection_index': 208},
#    {'qid': 959, 'selection': 'multiple sclerosis', 'selection_index': 68},
#    {'qid': 4002,
#     'selection': '(glycine replacing alanine)',
#     'selection_index': 53},
#    {'qid': 4002,
#     'selection': 'xacerbates glycemia in non-insulin dependent diabetes mellitus',
#     'selection_index': 138},
#    {'qid': 4726, 'selection': 'sclerosis disease', 'selection_index': 54},
#    {'qid': 4726, 'selection': 'multiple sclerosis', 'selection_index': 168},
#    {'qid': 2409,
#     'selection': 'subunit 2B are not associated with alcohol dependence and alcohol withdrawal-induced seizures and delirium tremens',
#     'selection_index': 26},
#    {'qid': 2409, 'selection': "Alzheimer's disease", 'selection_index': 229},
#    {'qid': 2409,
#     'selection': "Association between NMDA receptor subunit 2b gene polymorphism and Alzheimer's disease",
#     'selection_index': 250},
#    {'qid': 160, 'selection': 'type-1 diabetes', 'selection_index': 68},
#    {'qid': 4297, 'selection': 'ype-2 diabetes', 'selection_index': 49},
#    {'qid': 4297,
#     'selection': 'wer visceral adipose tissue mass',
#     'selection_index': 229},
#    {'qid': 4297,
#     'selection': 'lower waist-to-hip ratio',
#     'selection_index': 306},
#    {'qid': 3831, 'selection': 'African-American', 'selection_index': 8},
#    {'qid': 3831,
#     'selection': 'intense muscle pain and cramps upon exercising',
#     'selection_index': 109},
#    {'qid': 3831,
#     'selection': 'polymorphisms in human genes',
#     'selection_index': 282},
#    {'qid': 526, 'selection': 'breast cancer', 'selection_index': 166},
#    {'qid': 526, 'selection': 'breast cancer', 'selection_index': 295},
#    {'qid': 526, 'selection': 'breast cancer', 'selection_index': 331},
#    {'qid': 526, 'selection': 'breast cancer', 'selection_index': 473},
#    {'qid': 526,
#     'selection': 'Breast Cancer Association Consortium',
#     'selection_index': 543},
#    {'qid': 5228,
#     'selection': 'he risk of developing tuberculosis',
#     'selection_index': 143},
#    {'qid': 38,
#     'selection': "A Danish case-control study comprising 373 Crohn's disease",
#     'selection_index': 0},
#    {'qid': 5152, 'selection': 'chronic inflammation', 'selection_index': 59},
#    {'qid': 5152,
#     'selection': 'anti CCP-positive rheumatoid arthritis',
#     'selection_index': 133},
#    {'qid': 5152,
#     'selection': 'deaths due to malignancies and sepsis but not cardiovascular disease (CVD)',
#     'selection_index': 485},
#    {'qid': 3357,
#     'selection': 'an increased risk of type-2 diabetes',
#     'selection_index': 31},
#    {'qid': 3357,
#     'selection': 'increased fasting plasma glucose',
#     'selection_index': 201},
#    {'qid': 3357,
#     'selection': 'higher fasting plasma glucose concentrations',
#     'selection_index': 397},
#    {'qid': 3357,
#     'selection': 'lower fasting plasma glucose levels and increased OGTT-induced insulin release ',
#     'selection_index': 544},
#    {'qid': 3357,
#     'selection': 'the risk for type-2 diabetes',
#     'selection_index': 733},
#    {'qid': 3357,
#     'selection': 'of isolated impaired fasting glycemia',
#     'selection_index': 811},
#    {'qid': 3357,
#     'selection': 'but not isolated impaired glucose tolerance',
#     'selection_index': 874},
#    {'qid': 3357,
#     'selection': 'patients with gestational diabetes',
#     'selection_index': 924},
#    {'qid': 4031,
#     'selection': 'risk for hypertension and systolic blood pressure (SBP)',
#     'selection_index': 118},
#    {'qid': 4031,
#     'selection': 'individuals over 50yrs',
#     'selection_index': 571},
#    {'qid': 4031,
#     'selection': 'hypertrophic cardiomyopathy',
#     'selection_index': 1092},
#    {'qid': 4031,
#     'selection': 'not with hypertension hypertrophy',
#     'selection_index': 1124},
#    {'qid': 4031,
#     'selection': 'PPARGC1A variation associated with DNA damage, diabetes, and cardiovascular diseases',
#     'selection_index': 1159},
#    {'qid': 4031,
#     'selection': 'polymorphisms and type 2 diabetes',
#     'selection_index': 1339},
#    {'qid': 4031,
#     'selection': 'gene ABCC8 is associated with antidiabetic efficacy of gliclazide in Chinese type 2 diabetic patients',
#     'selection_index': 1418},
#    {'qid': 4031,
#     'selection': 'female reproductive disorders',
#     'selection_index': 1558},
#    {'qid': 4031,
#     'selection': 'Part I: Polycystic ovary syndrome and ovarian response',
#     'selection_index': 1589},
#    {'qid': 4031,
#     'selection': 'patients with sarcoidosis',
#     'selection_index': 1815},
#    {'qid': 4031,
#     'selection': "PGC-1alpha modifies age at onset in Huntington's Disease",
#     'selection_index': 1862},
#    {'qid': 4031,
#     'selection': 'GC-1alpha as modifier of onset age in Huntington disease',
#     'selection_index': 1921},
#    {'qid': 4031,
#     'selection': 'due to Intensive Diabetes Therapy',
#     'selection_index': 2092},
#    {'qid': 4031,
#     'selection': 'nfluence their modifying effect in Huntington disease',
#     'selection_index': 2374},
#    {'qid': 4031,
#     'selection': 'between five candidate genes and type 2 diabetes in Chinese Han population',
#     'selection_index': 2466},
#    {'qid': 2371,
#     'selection': 'a number of metabolic conditions including obesity, coronary artery disease, insulin resistance and therefore diabetes, left ventricular hypertrophy, and hypertension',
#     'selection_index': 126},
#    {'qid': 2371,
#     'selection': 'obese in Caucasian, Chinese, and African American populations',
#     'selection_index': 610},
#    {'qid': 2371,
#     'selection': 'carriers are clearly at higher risk for hypertension, but this review indicates that whether they are also at increased risk for stroke and left ventricular hypertrophy remains controversial',
#     'selection_index': 684},
#    {'qid': 2371,
#     'selection': 'for the treatment of schizophrenia',
#     'selection_index': 1401},
#    {'qid': 2371, 'selection': 'more weight', 'selection_index': 1455},
#    {'qid': 2371,
#     'selection': 'treatment of migraines or cluster headaches',
#     'selection_index': 1609},
#    {'qid': 2371, 'selection': 'Caucasian patients', 'selection_index': 1793},
#    {'qid': 2371,
#     'selection': 'genotypes are more prevalent in gastroesophageal reflux disease',
#     'selection_index': 1826},
#    {'qid': 2371,
#     'selection': '131 obese Taiwanese patients',
#     'selection_index': 2098},
#    {'qid': 681,
#     'selection': 'SNP is listed at pathogenic for breast cancer',
#     'selection_index': 329},
#    {'qid': 681,
#     'selection': 'it does predispose carriers to breast cancer',
#     'selection_index': 514},
#    {'qid': 681,
#     'selection': 'There are breast cancer patients harboring the BRCA1 V1736G mutation',
#     'selection_index': 707},
#    {'qid': 5051,
#     'selection': 'This SNP in the tumor necrosis factor-alpha gene',
#     'selection_index': 0},
#    {'qid': 5051,
#     'selection': 'Allograft rejection Among 72 Polish patients receiving a kidney transplant, the risk of acute kidney allograft rejection',
#     'selection_index': 344},
#    {'qid': 5051,
#     'selection': 'Asthma A meta-analysis of ~2,500 patients',
#     'selection_index': 568},
#    {'qid': 5051,
#     'selection': 'increased risk for asthma',
#     'selection_index': 688},
#    {'qid': 5051,
#     'selection': 'Mexican families and their asthmatic children',
#     'selection_index': 737},
#    {'qid': 5051,
#     'selection': 'carriers had an increased risk of asthma',
#     'selection_index': 797},
#    {'qid': 5051,
#     'selection': 'especially among children of non-smoking parents',
#     'selection_index': 877},
#    {'qid': 5051,
#     'selection': 'In a study of Norwegian children, nonallergic asthma was associated with rs1800629(A)',
#     'selection_index': 988},
#    {'qid': 5051,
#     'selection': 'Chronic obstructive pulmonary disease A meta-analysis of 36 publications totaling ~5,000 patients',
#     'selection_index': 1116},
#    {'qid': 5051,
#     'selection': 'he risk of COPD was statistically significant for Asians',
#     'selection_index': 1284},
#    {'qid': 5051,
#     'selection': ' but not for Caucasians',
#     'selection_index': 1387},
#    {'qid': 5051,
#     'selection': "Crohn's disease In a study of 235 Portuguese patients",
#     'selection_index': 1413},
#    {'qid': 5051,
#     'selection': "genotype was associated with higher susceptibility to Crohn's disease",
#     'selection_index': 1489},
#    {'qid': 5051,
#     'selection': 'Exfoliation glaucoma (XFG) A study of 204 patients with exfoliation glaucoma (XFG) concluded that rs1800629 is unlikely to be a major risk factor for XFG in Caucasians',
#     'selection_index': 1669},
#    {'qid': 5051,
#     'selection': "Graves' disease A meta-analysis of 10 case-control studies",
#     'selection_index': 1842},
#    {'qid': 5051,
#     'selection': "Graves' disease cases, concluded that rs1800629(A) carriers were associated with this type of hyperthyroidism",
#     'selection_index': 1925},
#    {'qid': 5051,
#     'selection': 'Heart disease A study of 600 Italian patients concluded that rs1800629(A) carriers are at increased risk for acute heart attack and have other markers of heart disease',
#     'selection_index': 2038},
#    {'qid': 5051,
#     'selection': 'A study of 50 Egyptian children with rheumatic heart disease',
#     'selection_index': 2261},
#    {'qid': 5051,
#     'selection': 'association between rs1800629 and risk for myocardial infarction',
#     'selection_index': 2608},
#    {'qid': 5051,
#     'selection': 'Ischemic stroke A meta-analysis of 18 studies with 8075 patients found no significant association between ischemic stroke and the TNFα-308G/A, except potentially in a subgroup of East Asians',
#     'selection_index': 2675},
#    {'qid': 5051,
#     'selection': 'Leprosy A study of 37 Thai patients with leprosy found that the rs1800629(A) allele was more common',
#     'selection_index': 2870},
#    {'qid': 5051,
#     'selection': 'Liver disease A study of 108 Chinese patients',
#     'selection_index': 3017},
#    {'qid': 5051,
#     'selection': 'increased risk for liver cancer and are also at higher risk for hepatic fibrosis and more severe liver damage',
#     'selection_index': 3131},
#    {'qid': 5051,
#     'selection': 'Lymphoma A study of 194 Tunisian patients indicated an increased risk for non-Hodgkin lymphoma among rs1800629(A;A) genotypes',
#     'selection_index': 3245},
#    {'qid': 5051,
#     'selection': 'incident non-Hodgkin lymphoma (NHL)',
#     'selection_index': 3427},
#    {'qid': 5051,
#     'selection': 'follicular lymphoma and diffuse large B-cell lymphoma',
#     'selection_index': 3686},
#    {'qid': 5051,
#     'selection': 'lymphoma patients and 982 controls looked at 57 SNPs in 36 immune function genes',
#     'selection_index': 3765},
#    {'qid': 5051,
#     'selection': 'tumor necrosis factor-alpha and lymphotoxin-alpha, were associated with a 1.31x increase in non-Hodgkin lymphoma',
#     'selection_index': 3880},
#    {'qid': 5051,
#     'selection': 'diffuse large B cell lymphoma',
#     'selection_index': 4083},
#    {'qid': 5051,
#     'selection': 'Susceptibility to Mediterranean spotted fever',
#     'selection_index': 4313},
#    {'qid': 5051,
#     'selection': 'in a Sicilian population the rs1800629 polymorphism did not affect susceptibility to Mediterranean spotted fever',
#     'selection_index': 4422},
#    {'qid': 5051,
#     'selection': 'igraine Polymorphisms in the tumor necrosis factor (TNF) gene may be associated with migraine and cardiovascular disease',
#     'selection_index': 4539},
#    {'qid': 5051,
#     'selection': 'Multiple sclerosis (MS) A study of 300 Croatian and Slovenian patients indicated that rs1800629(A) carriers might be at lower risk for multiple sclerosis',
#     'selection_index': 4715},
#    {'qid': 5051,
#     'selection': 'Nasal polyps The rs1800629(A;G) genotype was associated with increased risk for nasal polyps in a study of 82 Turkish patients',
#     'selection_index': 4874},
#    {'qid': 5051,
#     'selection': 'Psoriasis A study of 160 Polish patients indicated that the rs1800629(A) allele frequency was significantly decreased among patients with early-onset psoriasis',
#     'selection_index': 5129},
#    {'qid': 5051,
#     'selection': 'Irish patients with psoriasis were studied',
#     'selection_index': 5338},
#    {'qid': 5051,
#     'selection': 'as well as earlier onset of psoriasis',
#     'selection_index': 5475},
#    {'qid': 5051,
#     'selection': 'Rheumatoid arthritis - response to TNF-alpha inhibitors 2009 meta-analysis of 9 studies concludes rs1800629(A) allele carriers respond less well to TNF-alpha inhibitors when being treated for rheumatoid arthritis',
#     'selection_index': 5516},
#    {'qid': 5051,
#     'selection': 'Sarcoidosis In a pooled analysis of seven case-control studies, the odds ratio for sarcoidosis for carrier',
#     'selection_index': 5734},
#    {'qid': 5051,
#     'selection': 'Sarcoidosis In a pooled analysis of seven case-control studies, the odds ratio for sarcoidosis for carriers',
#     'selection_index': 5734},
#    {'qid': 5051,
#     'selection': 'Susceptibility to sepsis A study of 159 patients with severe trauma indicated that the rs1800629(A) allele was associated with higher risk of developing sepsis and of dying',
#     'selection_index': 5977},
#    {'qid': 5051,
#     'selection': 'anti-inflammatory interventions should be developed for use in carriers of this SNP should they suffer severe injuries',
#     'selection_index': 6250},
#    {'qid': 5051,
#     'selection': 'risk for sepsis, especially among Asians',
#     'selection_index': 6474},
#    {'qid': 5051,
#     'selection': 'mortality from sepsis',
#     'selection_index': 6543},
#    {'qid': 5051,
#     'selection': 'fatal outcomes among Asians',
#     'selection_index': 6610},
#    {'qid': 5051,
#     'selection': 'ystemic lupus erythematosus (SLE) A study of 120 Columbian patients with SLE found an increased risk for rs1800629(A) carriers',
#     'selection_index': 6680},
#    {'qid': 5051,
#     'selection': 'in European populations, the rs1800629(A) allele is associated with increased risk for systemic lupus erythematosus',
#     'selection_index': 6901},
#    {'qid': 5051,
#     'selection': 'In Europeans, the oodds ratio for the (A;A) genotype was 4.0, CI: 2.5-6.4, p<0.001. No association was detected in Asian-derived populations',
#     'selection_index': 7024}]},
#  {'response_id': 'R_3EFFKjKVN3PQ0In',
#   'recorded_datetime': '10/1/20 13:54',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'TRUE',
#   'duration': 1204,
#   'hilights': [{'qid': 538, 'selection': 'Phe851Cysfs', 'selection_index': 20},
#    {'qid': 1861, 'selection': 'Tyrosinemia', 'selection_index': 0},
#    {'qid': 5376, 'selection': 'Willebrand disease', 'selection_index': 14},
#    {'qid': 2318, 'selection': 'rs111033293recessive', 'selection_index': 0},
#    {'qid': 2318, 'selection': 'deafness', 'selection_index': 55},
#    {'qid': 4863, 'selection': 'Gln188Argfs', 'selection_index': 13},
#    {'qid': 1208, 'selection': 'p.Tyr392Terfs)', 'selection_index': 22},
#    {'qid': 2962, 'selection': 'p.His603Metfs', 'selection_index': 16},
#    {'qid': 995, 'selection': 'CDH1 gene', 'selection_index': 0},
#    {'qid': 4666, 'selection': 'p.Gly526Arg', 'selection_index': 15},
#    {'qid': 2280, 'selection': 'p.Arg235Ter', 'selection_index': 14},
#    {'qid': 2280, 'selection': 'R235X', 'selection_index': 29},
#    {'qid': 4849, 'selection': 'p.Gly102Cys', 'selection_index': 14},
#    {'qid': 1900, 'selection': 'p.Ser129Phe', 'selection_index': 14},
#    {'qid': 1900, 'selection': 'S129F', 'selection_index': 29},
# ...
#     'selection_index': 2742},
#    {'qid': 5051,
#     'selection': 'A study of 37 Thai patients with leprosy found that the rs1800629(A) allele was more common',
#     'selection_index': 2880},
#    {'qid': 5051,
#     'selection': 'A study of 108 Chinese patients concludes that rs1800629(A) carriers are at 3.23x (CI: 1.10-9.44) increased risk for liver cancer and are also at higher risk for hepatic fibrosis and more severe liver damage.',
#     'selection_index': 3033},
#    {'qid': 5051,
#     'selection': 'A study of 194 Tunisian patients indicated an increased risk for non-Hodgkin lymphoma among rs1800629(A;A) genotypes,',
#     'selection_index': 3256},
#    {'qid': 5051,
#     'selection': 'non-Hodgkin lymphoma (NHL) cases indicated that, compared with the wild-type rs1800629(G;G), the (A;A) genotype was associated with increased risk (odds ratio 2.14, CI: 0.94-4.85), whereas the (A;G) genotype was not. This association was similar for follicular lymphoma and diffuse large B-cell lymphoma.',
#     'selection_index': 3436},
#    {'qid': 5051,
#     'selection': 'Five SNPs in two cytokine genes, tumor necrosis factor-alpha and lymphotoxin-alpha, were associated with a 1.31x increase in non-Hodgkin lymphoma',
#     'selection_index': 3847},
#    {'qid': 5051,
#     'selection': 'with a 1.64x increase in the subtype known as diffuse large B cell lymphoma',
#     'selection_index': 4037},
#    {'qid': 5051,
#     'selection': 'The cytokine genes affect inflammatory and innate immune responses',
#     'selection_index': 4194},
#    {'qid': 5051,
#     'selection': 'in a Sicilian population the rs1800629 polymorphism did not affect susceptibility to Mediterranean spotted fever.',
#     'selection_index': 4422},
#    {'qid': 5051,
#     'selection': 'Migraine Polymorphisms in the tumor necrosis factor (TNF) gene may be associated with migraine and cardiovascular disease.',
#     'selection_index': 4538},
#    {'qid': 5051,
#     'selection': 'indicated that rs1800629(A) carriers might be at lower risk for multiple sclerosis',
#     'selection_index': 4788},
#    {'qid': 5051,
#     'selection': 'The rs1800629(A;G) genotype was associated with increased risk for nasal polyps in a study of 82 Turkish patients. Another study found a nearly doubled risk for rs1800629(A)',
#     'selection_index': 4889},
#    {'qid': 5051,
#     'selection': 'A study of 160 Polish patients indicated that the rs1800629(A) allele frequency was significantly decreased among patients with early-onset psoriasis',
#     'selection_index': 5141},
#    {'qid': 5051,
#     'selection': '147 Irish patients with psoriasis were studied and the results indicated that the rs1800629(A;A) genotype was associated with increased risk as well as earlier onset of psoriasis.',
#     'selection_index': 5334},
#    {'qid': 5051,
#     'selection': 's1800629(A) allele carriers respond less well to TNF-alpha inhibitors when being treated for rheumatoid arthritis.',
#     'selection_index': 5617},
#    {'qid': 5051,
#     'selection': 'In a pooled analysis of seven case-control studies, the odds ratio for sarcoidosis for carriers of the rs1800629(A) allele was either 1.47 (CI 1.03-2.08 under a dominant model) or 1.39 (CI: 0.67-2.90; under a recessive model).',
#     'selection_index': 5748},
#    {'qid': 5051,
#     'selection': 'A study of 159 patients with severe trauma indicated that the rs1800629(A) allele was associated with higher risk of developing sepsis and of dying',
#     'selection_index': 6004},
#    {'qid': 5051,
#     'selection': 'while rs1800629 status is significantly associated with risk for sepsis, especially among Asians, it was not associated with mortality from sepsis.',
#     'selection_index': 6418},
#    {'qid': 5051,
#     'selection': 'may be an increased risk for fatal outcomes among Asians',
#     'selection_index': 6581},
#    {'qid': 5051,
#     'selection': ' A study of 120 Columbian patients with SLE found an increased risk for rs1800629(A) carriers',
#     'selection_index': 6713},
#    {'qid': 5051,
#     'selection': 'in European populations, the rs1800629(A) allele is associated with increased risk for systemic lupus erythematosus (SLE). In Europeans, the oodds ratio for the (A;A) genotype was 4.0, CI: 2.5-6.4, p<0.001. No association was detected in Asian-derived populations.',
#     'selection_index': 6901}]},
#  {'response_id': 'FS_21dq7qRt9wOKYwr',
#   'recorded_datetime': '',
#   'status': 'IP Address',
#   'progress': 1,
#   'is_finished': 'FALSE',
#   'duration': 1,
#   'hilights': []},
#  {'response_id': 'FS_Pvvf27klRGTjmIp',
#   'recorded_datetime': '',
#   'status': 'IP Address',
#   'progress': 1,
#   'is_finished': 'FALSE',
#   'duration': 1,
#   'hilights': [{'qid': 4812, 'selection': 'A=', 'selection_index': 2}]},
#  {'response_id': 'FS_Xk4jjhD7d54HjJT',
#   'recorded_datetime': '',
#   'status': 'IP Address',
#   'progress': 1,
#   'is_finished': 'FALSE',
#   'duration': 1,
#   'hilights': [{'qid': 3433,
#     'selection': 'aka c.3126T>G',
#     'selection_index': 0},
#    {'qid': 1636, 'selection': 'Can', 'selection_index': 11},
#    {'qid': 1636, 'selection': 'ce', 'selection_index': 14},
#    {'qid': 1636, 'selection': 'Test', 'selection_index': 0},
#    {'qid': 5218, 'selection': 'and', 'selection_index': 2},
#    {'qid': 5218, 'selection': 'Me', 'selection_index': 5},
#    {'qid': 5218, 'selection': 'name', 'selection_index': 8},
#    {'qid': 3024, 'selection': 'and', 'selection_index': 2},
#    {'qid': 3024, 'selection': 'Me', 'selection_index': 5},
#    {'qid': 3024, 'selection': 'name', 'selection_index': 8},
#    {'qid': 3929, 'selection': 'see', 'selection_index': 11},
#    {'qid': 3929, 'selection': 'HD', 'selection_index': 17},
#    {'qid': 4850, 'selection': '596', 'selection_index': 6},
#    {'qid': 281,
#     'selection': 'aka c.360_363delCAAA (p.Asn120Lysfs)',
#     'selection_index': 0},
#    {'qid': 4058, 'selection': 'c.1304C>T (p.Thr435Met)', 'selection_index': 0},
#    {'qid': 4058, 'selection': 'c.1304C>T (p.Thr435Met)', 'selection_index': 0},
#    {'qid': 2103, 'selection': 'and', 'selection_index': 2},
#    {'qid': 2103, 'selection': 'Me', 'selection_index': 5},
#    {'qid': 2103, 'selection': 'name', 'selection_index': 8}]},
#  {'response_id': 'FS_1dBlMB6Zi7jyiCJ',
#   'recorded_datetime': '',
#   'status': 'IP Address',
#   'progress': 1,
#   'is_finished': 'FALSE',
#   'duration': 1,
#   'hilights': [{'qid': 3712,
#     'selection': 'Phenylketonuria',
#     'selection_index': 0},
#    {'qid': 2415,
#     'selection': 'contribute to risk for schizophrenia',
#     'selection_index': 14},
#    {'qid': 5011, 'selection': 'suicidal behavior', 'selection_index': 61},
#    {'qid': 3045,
#     'selection': 'usceptibility to Osteoporotic fractures',
#     'selection_index': 21},
#    {'qid': 5403, 'selection': 'systolic blood pressure', 'selection_index': 9},
#    {'qid': 4445,
#     'selection': 'suicidal behavior in psychiatric disorders',
#     'selection_index': 60},
#    {'qid': 4445, 'selection': 'Genetic polymorphisms', 'selection_index': 0},
#    {'qid': 4445, 'selection': 'Chinese', 'selection_index': 110},
#    {'qid': 4184, 'selection': "Alzheimer's", 'selection_index': 47},
#    {'qid': 1406, 'selection': 'non-classic 21-OH', 'selection_index': 48},
#    {'qid': 3733, 'selection': 'Breast-Cancer Risk', 'selection_index': 0},
#    {'qid': 5446, 'selection': 'Tardive dyskinesia', 'selection_index': 103},
#    {'qid': 1044,
#     'selection': 'Coronary artery disease ',
#     'selection_index': 38},
#    {'qid': 2701,
#     'selection': "pediatric onset Crohn's disease.",
#     'selection_index': 99},
#    {'qid': 50, 'selection': 'multidrug resistance', 'selection_index': 10},
#    {'qid': 50, 'selection': 'myocardial infarction', 'selection_index': 186},
#    {'qid': 5142,
#     'selection': 'hypothyroidism among Italians',
#     'selection_index': 94},
#    {'qid': 5142, 'selection': 'among Spanish', 'selection_index': 147},
#    {'qid': 5142, 'selection': 'Thyroid cancer', 'selection_index': 162},
#    {'qid': 5142, 'selection': 'Italians', 'selection_index': 193},
#    {'qid': 5142, 'selection': 'Spanish', 'selection_index': 213},
#    {'qid': 3115, 'selection': 'restless legs syndrome', 'selection_index': 96},
#    {'qid': 3115, 'selection': 'sleep disorder', 'selection_index': 129},
#    {'qid': 5399,
#     'selection': 'Japanese Werner Syndrome cases',
#     'selection_index': 70},
#    {'qid': 4164, 'selection': "Alzheimer's disease", 'selection_index': 112},
#    {'qid': 4164,
#     'selection': 'spastic spastic paraparesis',
#     'selection_index': 201},
#    {'qid': 1917,
#     'selection': 'autosomal dominant manner',
#     'selection_index': 108},
#    {'qid': 1917, 'selection': 'achondroplasia', 'selection_index': 184},
#    {'qid': 4568, 'selection': 'autism', 'selection_index': 181},
#    {'qid': 4568,
#     'selection': 'African-American woman with developmental delay',
#     'selection_index': 250},
#    {'qid': 4568,
#     'selection': 'seizures, mild facial dysmorphism, and an autism-like disorder',
#     'selection_index': 299},
#    {'qid': 4568,
#     'selection': 'Phelan-McDermid syndrome',
#     'selection_index': 378},
#    {'qid': 3462,
#     'selection': 'slow NAT2 metabolization',
#     'selection_index': 315},
#    {'qid': 2721,
#     'selection': 'epithelial ovarian cancer in non-Hispanic white women',
#     'selection_index': 34},
#    {'qid': 2721,
#     'selection': 'inflammation after cardiac surgery',
#     'selection_index': 150},
#    {'qid': 2721,
#     'selection': 'invasive epithelial ovarian cancer.',
#     'selection_index': 341},
#    {'qid': 3455,
#     'selection': 'average have lower vitamin D levels ',
#     'selection_index': 386},
#    {'qid': 3455,
#     'selection': 'have lower vitamin D than carriers',
#     'selection_index': 321},
#    {'qid': 3455, 'selection': 'lower vitamin D', 'selection_index': 205},
#    {'qid': 3758,
#     'selection': 'Parkinson disease (autosomal recessive, juvenile)',
#     'selection_index': 33},
#    {'qid': 3758,
#     'selection': ' males from Southern Germany',
#     'selection_index': 166},
#    {'qid': 3758,
#     'selection': 'metabolite range or with a ratio of metabolites',
#     'selection_index': 263},
#    {'qid': 3758,
#     'selection': 'ncreased lysine values',
#     'selection_index': 362},
#    {'qid': 2050,
#     'selection': 'increased risk for prostate cancer',
#     'selection_index': 102},
#    {'qid': 376,
#     'selection': 'familial hypercholesterolemia type B',
#     'selection_index': 270},
#    {'qid': 376, 'selection': 'Caucasians', 'selection_index': 476},
#    {'qid': 376,
#     'selection': 'Familial Hypercholesterolemia Type B',
#     'selection_index': 570},
#    {'qid': 5315, 'selection': 'asthma', 'selection_index': 44},
#    {'qid': 5315, 'selection': 'Asthma', 'selection_index': 52},
#    {'qid': 5315,
#     'selection': 'Hispanic and African Americans',
#     'selection_index': 270},
#    {'qid': 5315,
#     'selection': 'Chinese Han population',
#     'selection_index': 442},
#    {'qid': 5315,
#     'selection': 'prostate cancer prognosis',
#     'selection_index': 561},
#    {'qid': 5315, 'selection': 'adiposity phenotypes', 'selection_index': 646},
#    {'qid': 3786,
#     'selection': '2% frequency in Africans, 0.1% in Europeans',
#     'selection_index': 130},
#    {'qid': 3786,
#     'selection': 'plasma LDL-C levels being up to 40% lower than average',
#     'selection_index': 222},
#    {'qid': 3786, 'selection': 'owered LDL-C level', 'selection_index': 284},
#    {'qid': 3786,
#     'selection': 'lowered risk for coronary events',
#     'selection_index': 364},
#    {'qid': 3786, 'selection': 'decreased LDL levels', 'selection_index': 503},
#    {'qid': 3786,
#     'selection': 'low-density lipoprotein cholesterol levels: the Coronary Artery Risk Development in Young Adults',
#     'selection_index': 645},
#    {'qid': 45, 'selection': 'wet vs dry earwax', 'selection_index': 270},
#    {'qid': 45, 'selection': 'sweat production', 'selection_index': 299},
#    {'qid': 45, 'selection': 'lipid secretion', 'selection_index': 348},
#    {'qid': 45,
#     'selection': 'East Asians and (C;C) for Europeans and Africans',
#     'selection_index': 390},
#    {'qid': 45, 'selection': '(T;T) for ', 'selection_index': 380},
#    {'qid': 45,
#     'selection': 'genotypically nonodorous',
#     'selection_index': 618},
#    {'qid': 45, 'selection': 'risk of breast cancer', 'selection_index': 905},
#    {'qid': 45, 'selection': 'Caucasian women', 'selection_index': 973},
#    {'qid': 3253,
#     'selection': 'increased risk for myocardial infarction, but not coronary artery disease',
#     'selection_index': 62},
#    {'qid': 3253,
#     'selection': 'urther progression of breast cancer',
#     'selection_index': 689},
#    {'qid': 3253, 'selection': 'mixed ethnicities ', 'selection_index': 822},
#    {'qid': 3253, 'selection': 'Caucasians only', 'selection_index': 873},
#    {'qid': 505, 'selection': 'Canavan disease', 'selection_index': 134},
#    {'qid': 505,
#     'selection': 'Canavan disease is a degenerative disease of the nervous system',
#     'selection_index': 151},
#    {'qid': 505,
#     'selection': 'childhood onset disease',
#     'selection_index': 224},
#    {'qid': 505,
#     'selection': 'disordered muscular behavior',
#     'selection_index': 302},
#    {'qid': 505,
#     'selection': 'neurological symptoms, such as blindness, developmental and cognitive delays',
#     'selection_index': 369},
#    {'qid': 505,
#     'selection': 'demyelination and leukodystrophy',
#     'selection_index': 493},
#    {'qid': 505, 'selection': 'spongy degeneration', 'selection_index': 563},
#    {'qid': 505,
#     'selection': 'strocytic swelling of normal neurons and abnormality of astrocyte mitochondria',
#     'selection_index': 603},
#    {'qid': 505,
#     'selection': 'll and die on average at 18 months of age',
#     'selection_index': 724},
#    {'qid': 505,
#     'selection': 'common in Ashkenazi Jews',
#     'selection_index': 1250},
#    {'qid': 505,
#     'selection': 'Ashkenazi Jewish population',
#     'selection_index': 1429},
#    {'qid': 505, 'selection': 'European population', 'selection_index': 1690},
#    {'qid': 1393,
#     'selection': 'adult-onset primary open angle glaucoma',
#     'selection_index': 241},
#    {'qid': 1393, 'selection': 'recessively inherited', 'selection_index': 347},
#    {'qid': 1393,
#     'selection': 'Finnish European populations',
#     'selection_index': 925},
#    {'qid': 2672,
#     'selection': "type-1 diabetes, organ-specific autoimmune diseases, including Graves' disease",
#     'selection_index': 149},
#    {'qid': 2672, 'selection': 'autoimmune disorders', 'selection_index': 336},
#    {'qid': 2672, 'selection': 'Chinese patients', 'selection_index': 373},
#    {'qid': 2672, 'selection': "Graves' disease", 'selection_index': 395},
#    {'qid': 2672,
#     'selection': 'French Caucasian multiple sclerosis trio families ',
#     'selection_index': 473},
#    {'qid': 2672, 'selection': "Graves' disease", 'selection_index': 980},
#    {'qid': 2672, 'selection': 'type 1 diabetes', 'selection_index': 1133},
#    {'qid': 2672,
#     'selection': 'multiple sclerosis risk.',
#     'selection_index': 1186},
#    {'qid': 2672,
#     'selection': 'pre-diabetes to diabetes',
#     'selection_index': 1270},
#    {'qid': 2672,
#     'selection': 'type 1 diabetes and autoimmune thyroiditis:',
#     'selection_index': 1472},
#    {'qid': 2672, 'selection': 'type 1 diabetes ', 'selection_index': 1697},
#    {'qid': 2672,
#     'selection': 'type 1 diabetes and celiac disease',
#     'selection_index': 1896},
#    {'qid': 2672,
#     'selection': 'multiple sclerosis and type I diabetes',
#     'selection_index': 1816},
#    {'qid': 2672,
#     'selection': 'hereditary prostate cancer families',
#     'selection_index': 1974},
#    {'qid': 2672, 'selection': 'type 1 diabetes', 'selection_index': 2158}]},
#  {'response_id': 'FS_3QFNaOgC6T3oekz',
#   'recorded_datetime': '',
#   'status': 'IP Address',
#   'progress': 1,
#   'is_finished': 'FALSE',
#   'duration': 1,
#   'hilights': []},
#  {'response_id': 'FS_1CkGU9TH8KZkAxg',
#   'recorded_datetime': '',
#   'status': 'IP Address',
#   'progress': 1,
#   'is_finished': 'FALSE',
#   'duration': 1,
#   'hilights': []},
#  {'response_id': 'FS_6M5wWODpI0j9r6F',
#   'recorded_datetime': '',
#   'status': 'IP Address',
#   'progress': 1,
#   'is_finished': 'FALSE',
#   'duration': 1,
#   'hilights': []}]

# %%
# Load the original source CSV that was used in creating the survey. This will used to check against the results.
# We want to make sure there is no discrepency in which IDs are referring to which texts.
source_df = pd.read_csv(SURVEY_SOURCE_DATA_PATH)
#source_df.reset_index(drop=False, inplace=True)

# Question IDs in the actual survey will use the 
#source_df["qid"] = source_df["index"]
#source_df.drop(labels=["index"], axis=1, inplace=True)
#qid_to_source_text = {i:text for i,text in zip(source_df["qid"].values, source_df["text"].values)}
#qid_to_unique_text_id = {qid:i for qid,i in zip(source_df["qid"].values, source_df["id"].values)}
source_df.head(10)
# Out:
#      id                       text  bin_id  bin_size  block_id  block_size  \
# 0  1169                    smoking       1       630         1         210
# 1  1913  Achondroplasiars121913105       1       630         1         210
# 2   540             c.348-9_351del       1       630         1         210
# 3  3309                haplogroups       1       630         1         210
# 4  3712  Phenylketonuriars62508588       1       630         1         210
# 5  1446                   Warfarin       1       630         1         210
# 6  3711  Phenylketonuriars62516095       1       630         1         210
# 7  3698   Phenylketonuriars5030851       1       630         1         210
# 8  3697   Phenylketonuriars5030850       1       630         1         210
# 9  3696   Phenylketonuriars5030847       1       630         1         210
#
#    block_sample
# 0             5
# 1             5
# 2             5
# 3             5
# 4             5
# 5             5
# 6             5
# 7             5
# 8             5
# 9             5

# %%
print(source_df.shape)
print(len(pd.unique(source_df["id"])))
# Out:
# (2429, 7)
# 2429

# %%
# Put the responses into a dataframe.
row_tuples = []
for response in responses:
    
    # Metadata associated with this response.
    response_id = response["response_id"]
    recorded_datetime = response["recorded_datetime"]
    status = response["status"]
    progress = response["progress"]
    is_finished = response["is_finished"]
    duration = response["duration"]


    # The actual highlighted text strings from this response.
    for hilight in response["hilights"]:

        # The information about this one particular highlight.
        qid = hilight["qid"]
        hilighted_text = hilight["selection"]
        index_of_first_selected_char = hilight["selection_index"]
        source_text = id_to_unique_text[qid]        

        # First check that the question IDs are correct so we know what the source text was for this question.
        # Then additionally make sure the location of the highlight makes sense as well.
        #assert hilighted_text in source_text
        #assert source_text[index_of_first_selected_char:index_of_first_selected_char+len(hilighted_text)] == hilighted_text
       
        # Those asserts don't pass 100% of the time due to special cases with the text.
        # Save them to variables instead and check how often they don't pass, should be very infrequently.
        # Look at the special cases by hand.
        text_match = (hilighted_text in source_text)
        indices_match = (source_text[index_of_first_selected_char:index_of_first_selected_char+len(hilighted_text)] == hilighted_text)
        
        # Add this as a row.
        row_tuples.append((response_id, recorded_datetime, status, progress, is_finished, duration, qid, hilighted_text, text_match, indices_match))

        
        
# Create the dataframe that holds all this information.
columns = ["response_id", "recorded_datetime", "status", "progress", "is_finished", "duration", "id", "snippet", "text_match", "idx_match"]
df = pd.DataFrame(row_tuples, columns=columns)


# Add another column indicating how many times a particular ID was annotated by a survey taker.
snippets_per_id = dict(df.groupby("id").size())
df["num_ann"] = df["id"].map(lambda x: snippets_per_id[x])


# Save the dataframe to a file.
df.to_csv(RESPONSES_OUTPUT_PATH, index=False)
df.head(10)
# Out:
#          response_id recorded_datetime      status  progress is_finished  \
# 0  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
# 1  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
# 2  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
# 3  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
# 4  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
# 5  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
# 6  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
# 7  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
# 8  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
# 9  R_2eUMgNrFozgjPf3     10/1/20 13:40  IP Address       100        TRUE
#
#    duration    id                             snippet  text_match  idx_match  \
# 0       973  3279                   prone to miscalls        True       True
# 1       973   957     vaccine-induced immunity to HBV        True       True
# 2       973  5071  increased risk for Crohn's disease        True       True
# 3       973  1807               risk of breast cancer        True       True
# 4       973  1103       predictive of Cystic Fibrosis        True       True
# 5       973  4536                       schizophrenia        True       True
# 6       973  4536             developmental disorders        True       True
# 7       973  3015           hyperalphalipoproteinemia        True       True
# 8       973  2178                      Krabbe disease        True       True
# 9       973  2393                    oxidative stress        True       True
#
#    num_ann
# 0        1
# 1        2
# 2        1
# 3        1
# 4        1
# 5        3
# 6        3
# 7        1
# 8        2
# 9        2

# %%
# How many times did the asserts not evaluate to true?
print(Counter(df["text_match"].values))
print(Counter(df["idx_match"].values))
# Out:
# Counter({True: 6665, False: 70})
# Counter({True: 6232, False: 503})

# %%
# Preparing a dataset of context sentences that include the highlighted text snippets.
def get_contexts(i, snippet, text):
    sentences = sent_tokenize(text)
    sentences_with_snippet = [s for s in sentences if snippet in s]
    
    # Some additional processing to clean up the context sentences. Can insert more steps here if needed.
    
    # One way to do substitutions with regex. re.sub(old, new, string). The old pattern matches a SNP name.
    # That pattern includes () to define a group. In the new pattern, you can reference whatever is in that 
    # group with \1, as long as it's a raw string. A second group would be referenced with \2, etc.
    sentences_with_snippet = [re.sub(r"(rs[0-9]+)", r" \1 ", s) for s in sentences_with_snippet]
    
    
    
    
    
    
    # Make sure that bracketed text has spaces around it, this might add extra whitespace, will be removed later.
    sentences_with_snippet = [s.replace("("," (") for s in sentences_with_snippet]
    sentences_with_snippet = [s.replace(")",") ") for s in sentences_with_snippet]
    
    # Replace all instances of whitespace with a single space.
    whitespace_pattern = re.compile(r"\s+")
    sentences_with_snippet = [whitespace_pattern.sub(r" ", s) for s in sentences_with_snippet]
    
    # Remove whitespaces that occur before periods or commas.
    whitespace_before_period_pattern = re.compile(r"\s+[\.\;]")
    whitespace_before_comma_pattern = re.compile(r"\s+[\,\;]")
    sentences_with_snippet = [whitespace_before_period_pattern.sub(r".", s) for s in sentences_with_snippet]
    sentences_with_snippet = [whitespace_before_comma_pattern.sub(r",", s) for s in sentences_with_snippet]
    
    # Strip of leading and trailing whitespaces.
    sentences_with_snippet = [s.strip() for s in sentences_with_snippet]
    
    # Capitalize each sentence.
    sentences_with_snippet = ["{}{}".format(s[0].upper(),s[1:]) for s in sentences_with_snippet]
    
    # End each sentence with a single period.
    add_end_character = lambda x: "{}.".format(x[:len(x)-1]) if (x[len(x)-1]==".") or (x[len(x)-1]==";") else "{}.".format(x)
    sentences_with_snippet = [add_end_character(s) for s in sentences_with_snippet]
    
    # Remove all quotes from the sentences.
    sentences_with_snippet = [s.replace('"', '') for s in sentences_with_snippet]
    sentences_with_snippet = [s.replace("'", "") for s in sentences_with_snippet]
    
    
    # Notes to save about how to do this.
    # Another regex substitution trick. The repl (new) argument can be a function, which has to always take a single
    # parameter, which is the regex match. You can then capture groups inside that function, do any transformations,
    # and return, which would have been less straight forward or not possible to do in the repl raw string.
    def make_lowercase(match):
        group = match.group(1)
        group = group.lower()
        return(group)
    
    # Fix a problem where SNP names were being capitalized if they were the first token in the sentence.
    sentences_with_snippet = [re.sub(r"(Rs[0-9]+)", make_lowercase, s) for s in sentences_with_snippet]
    
    # Done.
    return((i,sentences_with_snippet))


# Create a mapping between text IDs and lists of the context sentences that relevant snippets were found in.
obj = df.apply(lambda row: get_contexts(row.id, row.snippet, id_to_unique_text[row.id]), axis=1)
id_to_context_sentences = dict(obj.values)
id_to_context_sentences
# Out:
# {3279: ['Prone to miscalls (false positives) ? rs267608099.'],
#  957: ['Host genetic factors and vaccine-induced immunity to HBV infection: haplotype analysis.'],
#  5071: ['Associated with increased risk for Crohns disease in a study of 380 Korean patients.'],
#  1807: ['Association of genetic polymorphisms of EXO1 gene with risk of breast cancer in Taiwan.'],
#  1103: ['Previously considered predictive of Cystic Fibrosis, 23andMe has removed it from their reports as unreliable.'],
#  4536: ['Also known as c.1272delC and p.Tyr425Thrfs Rare loss-of-function variants in SETD1A are associated with schizophrenia and developmental disorders.'],
#  3015: ['Association of an intronic haplotype of the LIPC gene with hyperalphalipoproteinemia in two independent populations.'],
#  2178: ['Aka c.1592G>A, p.Arg531HisIdentified in ClinVar as pathogenic for Krabbe disease (when inherited recessively or as a compound heterozygote).'],
#  2393: ['Mistakenly mentioned as rs18006688 in Lead exposure, polymorphisms in genes related to oxidative stress, and risk of adult brain tumors.'],
#  760: ['rs80357808, also known as c.3442delG, 3561delG, c.3442_3442delG and p.Glu1148Argfs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  4574: ['/ 23andMe blog See also rs12150660 Polymorphisms in estrogen- and androgen-metabolizing genes and the risk of gastric cancer.'],
#  324: ['I6006948, also known as c.529G>A or p.A177T, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the adult form of hypophosphatasia.'],
#  4203: ['Genetic screening of Alzheimers disease genes in Iberian and African samples yields novel mutations in presenilins and APP.',
#   'Rare variants in APP, PSEN1 and PSEN2 increase risk for AD in late-onset Alzheimers disease families.'],
#  1018: ['rs104894097, also known as c.71G>C, p.Arg24Pro and R24P, represents a rare mutation in the CDKN2A gene on chromosome 9.The rs104894097 (C) allele is considered pathogenic in a dominant manner for malignant melanoma, based on sources in ClinVar and elsewhere.'],
#  5064: ['Novel mutations in TNFRSF1A in patients with typical tumor necrosis factor receptor-associated periodic syndrome and with systemic lupus erythematosus in Japanese.'],
#  4280: ['Associations between single nucleotide polymorphisms in double-stranded DNA repair pathway genes and familial breast cancer.'],
#  4848: ['Sepiapterin reductase expression is increased in Parkinsons disease brain tissue.'],
#  2478: ['The HDC gene encodes L-histidine decarboxylase, the rate-limiting enzyme in histamine biosynthesis.Mutations leading to Tourette syndrome have been quite hard to find, and so far, there is only one mutation known: rs267606861 (A).'],
#  2845: ['rs3748079 is a SNP in the promoter region of the ITPR3 gene; it is also known as -1990C>T. rs3748079 has been linked to increased risk for systemic lupus erythematosus (SLE) in two independent Japanese case-control samples (p=0.0000000178 with odds ratio of 1.88, CI:1.51-2.35).',
#   'Individuals with risk genotypes of both rs3748079 and rs3095870, in the ITPR3 and NKX2.5 genes, respectively, have even high risk for SLE (odds ratio 5.77).This particular SNP also revealed associations with rheumatoid arthritis (RA) (p=0.0084 with odds ratio of 1.23, CI:1.05-1.43) and with Graves disease (GD) (p=0.00036 with odds ratio of 1.57, CI:1.22-2.02).Note that the orientation of this SNP as published is reversed compared to the dbSNP entry.'],
#  1567: ['This study concludes that rs1611115 (T;T) homozygotes appear to be at increased risk for personality traits related to impulsiveness, aggression, and adult ADHD.'],
#  998: ['The authors point out state that more than 20 studies have found associations between CDH13 - although not this specific SNP - and attention deficit/hyperactivity disorder (ADHD), autism, schizophrenia, substance abuse or bipolar disorder.'],
#  143: ['Could represent a gene modulator of carbohydrate intake in morbidly obese Czech population; the strong significant effect of DD genotype was observed in the phenotypes of extreme obesity with the highest carbohydrate intake.'],
#  1296: ['Individual and cumulative effects of GWAS susceptibility loci in lung cancer: associations after sub-phenotyping for COPD.'],
#  2419: ['rs5848 (T;T) found a 3.2-fold increased risk vs C-allele carriers (95% CI: 1.50-6.73, p=0.003) for ubiquitin- and TAR DNA-binding protein 43 (TDP-43) -positive frontotemporal dementia (FTLD-U also knows as FTLD-TDP43), a progressive neurodegenerative disease affecting approximately 10% of early-onset dementia patients.',
#   'Association between rs5848 (T;T) and frontotemporal dementia is now generally assumed in literature, despite some studies failing to reproduce it.First meta-analysis of rs5848 association with Alzheimers disease combining previous five studies for a total of 2502 Alzheimers disease cases and 2162 controls found association in homozygous model (TT vs. CC: OR, 1.36; 95% CI, 1.11-1.66; P=0.003) as well as recessive model.',
#   'According to First symptoms--frontotemporal dementia versus Alzheimers disease as well as other sources frontotemporal dementia is often misdiagnosed as Alzheimers disease so it is possible some studies have misdiagnosed cases.',
#   'Common variation in the miR-659 binding-site of GRN is a major risk factor for TDP43-positive frontotemporal dementia.'],
#  4315: ['Associated with protection from Hirschsprung diseaseSee OMIM 164761.0052.'],
#  2617: ['rs803582193 HSDB2 deficiency based on HSD3B2 mutation; congenital adrenal hyperplasia, recessively inherited.'],
#  2415: ['rs2228595 may contribute to risk for schizophrenia by modulating GRM3 splicing.'],
#  1126: ['Aka c.1192C>T (p.Arg398Ter) Considered pathogenic in ClinVar for a form of autosomal dominant mental retardation.'],
#  584: ['(T;T) abolishes catalytic activity in BCHE according to annerwrightPseudocholinesterase Deficiency.'],
#  3773: ['Aka NM_003990.4 (PAX2) :c.76dupG or (p.Val26Glyfs) OMIM pathogenic variant.'],
#  3474: ['Genetics and genomics of human aging.'],
#  131: ['Aka NM_000019.3 (ACAT1) :c.149delC or (p.Thr50Asnfs) OMIM pathogenic variant.'],
#  282: ['Aka c.524C>A (p.Ala175Asp or A175D; sometimes Ala174Asp in older literature). usually considered the second most common ALDOB gene mutation after the most common one, rs1800546.'],
#  1592: ['The rs9341301 (C;C) mutation is a reliable indicator of Haplogroup I (Y-DNA) and is also referred to as M258+.'],
#  3431: ['Polymorphisms in the myosin light chain kinase gene that confer risk of severe sepsis are associated with a lower risk of asthma.'],
#  5291: ['As such, it has been recognized as one of the most reliable indicators of Y haplogroup D. The mutation from T to C indicates membership of the Asian haplogroup D.'],
#  3861: ['C.1311G>A (p.Trp437Ter, W437X or W437 ) Considered definitely pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal recessive, early-onset Parkinson disease (type 6) 23andMe calls this i5003752.'],
#  604: ['rs2267012, a SNP in the BCR gene on chromosome 22, has been associated with increased risk for depression.'],
#  4164: ['Note that the clinical symptoms are reported to potentially include spastic spastic paraparesis (paraplegia).'],
#  1131: ['Aka c.542_543delCT (p.Ser181Cysfs) Considered pathogenic in ClinVar; condition not specified, but based on similar mutations also in the CHAMP1 gene, likely to be a form of autosomal dominant mental retardation.'],
#  909: ['One report based on a study of 480 Danish families indicated that the rs3772534 SNP in the CBLB gene indicated an increased risk for developing type 1 diabetes, and that there might be co-inheritance with the rs3087243 SNP found in the CTLA4 gene.'],
#  1427: ['This variant is associated with a dramatic (approximately 90% and 70%) reduction in the metabolism of S-mephenytoin and tolbutamide in vitro.Clopidogrel Efficacy.'],
#  3094: ['Subjects with major depressive disorder with the highest activity form of the enzyme (G or G/G) had a significantly lower magnitude of placebo response.'],
#  437: ['rs63750973, also known as c.2141C>T, p.Thr714Ile or T714I, represents a rare mutation in the APP gene.Inherited dominantly, the rare minor allele is considered pathogenic for an aggressive, early-onset form of Alzheimers disease; for more information, see ClinVar, AlzForum or OMIM.'],
#  1185: ['rs121912805, also known as c.871G>A or p.Glu291Lys, is a mutation in the CLCN1 gene on chromosome 7.Acting in either an autosomal dominant or recessive manner, the rs121912805 (A) allele is considered to cause myotonia congenita; see also OMIM 118425.0010Note that 23andMe refers to this SNP as i5003258.'],
#  3056: ['rs119466000, also known as c.1061C>T, p.Ala354Val and A354V, represents a rare variant in the LRPPRC gene on chromosome 2.The rs119466000 (T) allele, when inherited recessively, in considered pathogenic for a form of Leigh syndrome known as the French-Canadian type, due to this being a founder mutation in that population.23andMe name: i5012749.'],
#  4221: ['After controlling for various variables (especially gender), two co-inherited SNPs, rs10306114 and rs3842787, were found to be associated with higher risk for bleeding in otherwise low risk patients who (i) did undergo percutaneous coronary intervention and (ii) did not take clopidogrel.'],
#  1663: ['Genome-wide association study of coronary heart disease and its risk factors in 8,090 African Americans: the NHLBI CARe Project.'],
#  1239: ['rs2710102, a common SNP in the CNTNAP2 gene, was found to be significantly associated (p<0.028) with a delayed onset of speech, as measured by the age at which a child speaks their first words, in children with autism.',
#   'This effect is primarily seen in males, perhaps correlated with the 4-5x overrepresentation of males with autism compared with females.The confirmatory Stage 2 study was performed on 304 independent parent-child trios.'],
#  3266: ['rs193922376, also known as c.942+3A>T and c.943+3A>T, is a rare mutation in the MSH2 gene on chromosome 2.Acting in an autosomal dominant manner, the rs193922376 (T) allele is considered pathogenic by multiple sources in ClinVar for Lynch syndrome, a disorder characterized by increased risk for colon cancer and other cancers.Although still exceedingly rare, this mutation has been cited as perhaps the most common Lynch syndrome mutation.',
#   'The frequency of Muir-Torre syndrome among Lynch syndrome families.'],
#  30: ['According to a recent review, ten studies reported that ABCB1 SNPs have clinical effect in depression and eight that they do not.',
#   'The list of the 9 SNPs is shown below.When treated for depression with citalopram, paroxetine, amitriptyline, or venlafaxine (substrates of the protein encoded by ABCB1), a highly statistically significant association between the overall genetic variability of these SNPs and the remission was reported by Uhr et al in a study of ~400 German inpatients.',
#   'A well-run, double-blind study of ABCB1 substrate citalopram in depression (STAR-D study) and a following meta-analysis failed to replicate several Uhr et al.'],
#  88: ['Per the / 23andMe blog, the minor allele of this SNP (T) was associated with increased LDL cholesterol {| border=1|-!SNP!Rarer allele!LDL!HDL!TG|-| rs6544713 || T || + || |||-| rs2650000 || A || + || |||-| rs471364 || C || || - |||-| rs1800961 || T || || - |||-| rs7679 || C || || - || +|-| rs2967605 || T || || - |||-| rs2409722 || T || || || -|-| rs10903129 || A || - || - || -|-| rs6756629 || A || - || + || -|-| rs12670798 || C || + || + || +|-| rs7395662 || A || - || + || +|-| rs174570 || T || - || - || +|-| rs2271293 || A || - || + || -|-| rs2624265 || C || || || +|-| rs2167079 || T || || + |||-| rs9891572 || T || || + |||-| rs4844614 || T || + || |||-| rs5031002 || G || + || |||-|} Analysis of recently identified dyslipidemia alleles reveals two loci that contribute to risk for carotid artery disease.'],
#  1228: ['These studies provide data to suggest that the CNR1 receptor gene may be significantly associated with impulsivity in SWC Indians.'],
#  1609: ['Regardless of the polymorphism of rs2235544, the fT3:fT4 ratio and fT3 levels were consistently and significantly lower in hypothyroid patients on L-T4 therapy than in healthy controls, and patients mean TSH was also lower than in controls.'],
#  499: [],
#  614: ['Brain-derived neurotrophic factor: role in depression and suicide.'],
#  2458: ['Modeling effects of human single nucleotide polymorphisms on protein-protein interactions.'],
#  1885: ['FcepsilonRIalpha gene (FCER1A) promoter polymorphisms and total serum IgE levels in Japanese atopic dermatitis patients.'],
#  5255: ['rs11892031A on chromosome 2q37 in an intronic region of the UGT1A locus is associated with urinary bladder cancer risk.'],
#  3689: ['rs2240338 increases susceptibility to Rheumatoid Arthritis 1.82 times for carriers of the G allele.'],
#  3353: ['A simple and accurate SNP scoring strategy based on typeIIS restriction endonuclease cleavage and matrix-assisted laser desorption/ionization mass spectrometry.'],
#  2994: ['Leptin is associated with blood pressure and hypertension in women from the National Heart, Lung, and Blood Institute Family Heart Study.'],
#  675: ['rs273900730, also known as 4510delCTAinsTT, c.4391_4393delCTAinsTT and p.Pro1464_Ile1465LeuTerfs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  3046: ['rs4752946 is in linkage disequilibrium with a polymorphism that increases susceptibility to Osteoporotic fractures 1.11 times for carriers of the G allele.'],
#  984: ['Also known as c.2064_2065delTG, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer in ClinVar.'],
#  5240: ['UBA5 gene, c.736C>T (p.Arg246Ter) The minor allele is reported in ClinVar as being pathogenic for autosomal recessive spinocerebellar ataxia-24.'],
#  3589: ['The C allele of this SNP in the NR1H3 gene is associated with increased (but still low) risk of progressive supranuclear palsy.'],
#  3788: ['rs28942112, also known as c.646T>C, p.Phe216Leu and F216L, is one of the first mutations in the PCSK9 gene reported to lead to autosomal dominantly inherited familial hypercholesterolemia.See OMIM 607786.0002 for more information.This SNP is referred to as i5000370 by 23andMe.'],
#  4377: ['rs118192162, aka c.1565A>C (p.Tyr522Ser or Y522S) and also c.1565A>G (p.Tyr522Cys or Y522C), is a SNP in the RYR1 gene leading to increased susceptibility to malignant hyperthermia when heterozygous.23andMe name for c.1565A>G: i6017825.'],
#  2028: ['rs142133355, also known as c.2 T>C or p.M1T, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  4427: ['Scavenger receptor class B type I protein as an independent predictor of high-density lipoprotein cholesterol levels in subjects with hyperalphalipoproteinemia.'],
#  1252: ['rs42524 is a SNP in the COL1A2 gene.This SNP has been associated with familial intracranial aneurysms (IA) in both Japanese and Chinese populations; in Chinese patients, the odds ratio is 2.579 (CI: 1.48-4.47).'],
#  441: ['The minor allele of this SNP is one of 84 rare variants speculated to have an impact (positive or negative; see publication for specific SNP details) on risk for bipolar disorder.'],
#  5172: ['An additional mention is found in OMIM 606936.0005.'],
#  4177: ['rs63749967, also known as c.244G>C, p.Val82Leu or V82L, is a SNP in the presenilin 1 PSEN1 gene.Inherited as an autosomal dominant, the rare rs63749967 (C) allele is considered pathogenic for Alzheimers disease, potentially early-onset, according to AlzForum.Reported in to be a definitely pathogenic mutation.'],
#  1665: ['rs10260404, a SNP in the region of the DPP6 gene on chromosome 7, has been associated with the sporadic form of ALS (Lou Gehrigs disease) in a study of 1000+ European patients.',
#   'When broken down by genotype, the odds ratios for heterozygotes are 1.20 (CI: 1.06-1.41), and for rs10260404 (C;C) homozygotes, 1.60 (CI: 1.32-1.92).A C-C haplotype for this SNP and that of its neighbor rs10239794 is also highly (statistically; p=10e-9) associated with ALS.'],
#  2008: ['This allele is in strong linkage disequilibrium with the FUT2 nonsecretor variant encoding W143X, suggesting a plausible mechanism for altered B (12) absorption and plasma levels.'],
#  833: ['Mutation pattern in the Brutons tyrosine kinase gene in 26 unrelated patients with X-linked agammaglobulinemia.',
#   'Clinical and mutational characteristics of X-linked agammaglobulinemia and its carrier identified by flow cytometric assessment combined with genetic analysis.',
#   'Identification of mutations of Brutons tyrosine kinase gene (BTK) in Brazilian patients with X-linked agammaglobulinemia.'],
#  838: ['A SNP in the C3 gene, rs11569562, has been associated with increased risk for adult bronchial asthma in a study of Japanese patients.'],
#  3384: ['Pathogenic variant is also known as c.284C>G (p.Pro95Arg). note that c.284C>T (p.Pro95Leu) is a variant of uncertain significance according to ClinVar.'],
#  2563: ['rs9268839 (G) was the variant most strongly associated in Europeans with risk for rheumatoid arthritis in this GWAS study of ~30,000 patients (OR 2.47, CI: 2.39-2.55, p = 1.5 × 10−e300).'],
#  2267: ['Aka c.556C>T (p.Arg186Ter or R186X) This mutation is a very rare variant strongly associated with late-onset noninsulin-dependent diabetes (odds ratio ~68, CI: 14-328, p = 2x10e-8). see ClinVar and OMIM links.'],
#  2046: ['rs150676454, also known as c.165_+_5 G>C or, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  5142: ['The heterozygous polymorphism (AC) gave 0.87x lower risk of hypothyroidism among Italians, but 2x increased risk among Spanish.',
#   'Thyroid cancer risk 0.93 among Italians, 1.7 among Spanish.'],
#  317: ['I6006926, also known as c.667C>T or p.R223W, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the perinatal form of hypophosphatasia.'],
#  1232: ['This snp, located in intron 2 of the central cannabinoid receptor CNR1 gene, has been linked to cannabis dependence.',
#   'The (G) allele is reported to have a protective effect, and is a defining part of a haplotype that is associated with lower odds of developing cannabis dependence.'],
#  420: ['rs193922916, also known as c.2018C>T, p.Ala673Val and A673V, represents a rare mutation in the APP gene on chromosome 21.Most APP mutations leading to Alzheimers disease are inherited dominantly, but A673V is an exception, as it appears to be inherited recessively.'],
#  4840: ['rs869025321, also known as c.1021G>T, p.Gly341Ter and G341X, represents a very rare mutation in the SOX5 gene on chromosome 12.Inherited as an autosomal dominant mutation, rs869025321 (T) is reported to lead to Lamb-shaffer syndrome, a disorder characterized by global developmental delay, intellectual disability, language and motor impairment, and distinct facial features.'],
#  567: ['Attention-deficit hyperactivity disorder in adults: A systematic review and meta-analysis of genetic, phrmcgntc and biochemical studies.We obtained a positive association between adult ADHD and rs8079781 in BAIAP2 and with the rs8079626 - rs7210438 GC haplotype, even after Bonferroni correction; carriers of a rs8079781 (T) allele have slightly lower (0.8-0.87x) risk for adult ADHD.'],
#  3669: ['This association was independent of age and ApoE status.'],
#  4774: ['For SNPs rs363039 - rs363043 - rs353016, respectively, the haplotype C-T-T is most associated with higher intelligence in children, whereas the haplotype C-C-T is most associated in adults (SNPs oriented as in dbSNP).'],
#  2429: ['PMID 15351432, PMID 14729229Also known as the -50T/C SNP from this GSK3-beta (GSK3B) gene.may effect lithium treatment response - C allele carriers showed considerably greater response with lithium treatment, with remissions of 56.25% after 4 weeks compared to 31% for T/T carriers.'],
#  2120: ['Its biochemical characterization was reviewed by Chiu et al.'],
#  232: ['Age and gender may also influence risk, as discussed in a review of AGTR1 SNPs and their role in hypertension and related disorders.Pregnant women who are rs5186 (C) allele carriers are more likely to develop pregnancy-induced hypertension.However, rs5186 does not appear to modify risk for developing coronary heart disease (CHD).'],
#  4227: ['Genetic variation in immune regulation and DNA repair pathways and stomach cancer in China.'],
#  2916: ['Associations between variants in KITLG, SPRY4, BAK1, and DMRT1 and pediatric germ cell tumors.'],
#  4816: ['Like the Japanese study by Takata et al., the minor allele (T) was found to be associated with bipolar disease.'],
#  2109: [],
#  2440: ['GUCY2D c.389delC.'],
#  353: ['Aka c.762+1G>A.'],
#  5297: [],
#  2319: ['rs111033451 recessive GJB2 gene variant associated with deafness.'],
#  2324: ['rs786204597 recessive GJB2 gene variant associated with deafness.'],
#  4081: ['rs267606980, G127V appears to protect against kuru.'],
#  4403: [],
#  2968: ['Aka c.715C>T (p.Gln239Ter).'],
#  991: [],
#  4514: ['NM_000062.2 (SERPING1) :c.936delC (p.His314Thrfs).'],
#  3388: ['Aka c.280G>A, p.Gly94Arg or G94R; mutation seen in Hispanics.'],
#  654: ['Aka c.736G>C (p.Ala246Pro) 23andMe name: i5000379.'],
#  3760: ['rs74315354, but note ClinVar entry is for haplotypeParkinsons disease, type 7.'],
#  3896: ['Aka c.1213C>T (p.Gln405Ter) 23andMe name: i5002465.'],
#  4285: ['Aka c.781C>T (p.Pro261Ser) 23andMe name: i5008105.'],
#  997: ['Suspected of reproducibility problems based on end user analysis rs11149566 rs4458717 rs4660646 rs754499.'],
#  4230: [],
#  4519: [],
#  4341: ['Investigation of reported associations between the 20q13 and 21q22 loci and pediatric-onset Crohns disease in Canadian children.'],
#  4301: ['Identification of 15 genetic loci associated with risk of major depression in individuals of European descent.'],
#  5274: ['Aka c.1389+1G>Aconsidered pathogenic for familial hemophagocytic lymphohistiocytosis (HLH) in ClinVar.'],
#  205: ['G.-7309A>G ( rs75172865 ) associated with lower insulin resistance and reduced the promoter activity.g.33447T ( rs1044471 ) associated with smaller waist circumference.'],
#  1531: [],
#  3381: ['Aka c.655A>T, p.Asn219Tyr or N219Y; identified with increased frequency in persons of northern European heritage23andMe name: i5000071.'],
#  3597: ['Gwas, among 738 schizophrenics genotyped for 492K SNPs, this SNP attained a p-val of 5 x 10^-7 for hemoglobin A1c as a result of risperidone use.'],
#  5062: ['Germline mutations in the extracellular domains of the 55 kDa TNF receptor, TNFR1, define a family of dominantly inherited autoinflammatory syndromes.'],
#  3618: ['Gene NRXN3Minor allele TMAF (case) 0.29Joint P-value 4.83E-05 (a) Meta P—value 6.24E-06 (a) P-value Rank 35AA 58.12±0.27Aa 57.15±0.31aa 55.26±0.65From the “ Supplemental Table S10 Top 2,000 SNPs associations with age of ALS onset, adjusting for first two principal component and center.”.'],
#  2039: ['rs147211454, also known as c.340_352 del13 or p.A114TfsX15, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  5349: [],
#  311: ['I6006890, also known as c.1112C>T or p.T371I, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the infantile form of hypophosphatasia.'],
#  4448: ['rs121908908, also known as c.1376C>G, p.Ser459Ter and S459X, is a rare mutation in the SCN9A gene on chromosome 2.Inherited in a recessive manner, the homozygous minor genotype for this SNP is reported to result in insensitivity to pain.'],
#  4224: [],
#  1951: ['rs9834312 is a SNP in the filamin B, beta (actin binding protein 278) FLNB gene.Based on a study of 1,000+ Caucasians and 2,000+ Chinese, rs9834312 was associated with height in both Caucasian populations (p=0.008) and Chinese populations (p=0.017) / 23andMe blog rs1867138 (T;T) or rs1867137 (G;G) were approximately one inch taller than rs1867138 (C;C) rs9834312 (G;G) or rs939882 (G;G) increased height.'],
#  5088: ['For more information, see OMIM 191044.0002.This mutation is referred to as i5007728 by 23andMe.'],
#  16: ['Aka c.7093G>A (p.Asp2365Asn) The variant allele was reported over a decade ago as being a recessive mutation associated with a form of ichthyosis; however, more recent annotations have come to the conclusion that it is actually likely to be benign, in part since its seen far more frequently than would be expected given how rare the actual condition is.'],
#  2691: ['rs137853022, also known as R696P or Arg696Pro, is a SNP in the inhibitor of kappa light polypeptide gene enhancer in B-cells, kinase complex-associated protein IKBKAP gene.This is reported as one of two mutations accounting for 99% of the cases of familial dysautonomia in Ashkenazi Jews; in 23andMe, it is reported as i4000400.'],
#  61: ['A K (ATP) channel gene effect on sleep duration: from genome-wide association studies to function in Drosophila.'],
#  4852: ['rs35948326, also known as c.2909C>A, p.Ala970Asp, A970D and alpha-IIa, represents a variant in the SPTA1 gene on chromosome 1.Although reported as associated with autosomal recessive spherocytosis, the rs35948326 (A) allele (as reported in dbSNP orientation) may actually be more of a proxy for a truly defective variant that is co-inherited as a result of linkage.'],
#  140: ['This SNP in the ACE gene, also known as G12269A, is reported to influence how quickly African Americans respond to the anti-hypertensive drug ramipril.'],
#  2736: ['Also known as the +2018T/C SNP.In a study of 113 Japanese patients with chronic periodontitis (CP), individuals with the rs419598 (C) allele are at 0.29x lower CP risk (p = 0.016).IL1B -511 allele heterozygotes have a 4 fold higher chance of surviving bacterial meningitis than (either) homozygote.',
#   'SO whats this have to do with rs419598 ?.',
#   'Odds of surviving meningitis apparently further increase 2X for IL1B -511 heterozygotes who are also rs419598 (T;T), i.e.',
#   'Homozygous for IL1RN +2018 rs419598 (T) allele (the most common one; also known as +8006).'],
#  3668: ['rs8069176 is one of several SNPs from a region on chromosome 17q21 that has been linked to risk for asthma.A total of 651 French patients with asthma, from among 1,621 subjects in 388 families, were analyzed for SNPs in the (17q21) region.'],
#  4778: ['For SNPs rs363039 - rs363043 - rs353016, respectively, the haplotype C-T-T is most associated with higher intelligence in children, whereas the haplotype C-C-T is most associated in adults (SNPs oriented as in dbSNP).'],
#  5025: [],
#  1288: ['rs2709376 (C), rs2253206 (A), rs7569963 (A), rs7594560 (T), rs4675690 (C) - common haplotype, reduced chance of suicide in males, p = 0.004 rs2709376 (C), rs2253206 (A), rs7569963 (G), rs7594560 (T), rs4675690 (T) - increased chance of suicide in males, p = 0.009 strongly associated with anger expression in male MDD patients A preliminary investigation of the influence of CREB1 gene on treatment resistance in major depression.'],
#  2672: ['A genome-wide association study of nonsynonymous SNPs identifies a type 1 diabetes locus in the interferon-induced helicase (IFIH1) region.',
#   'The association between the IFIH1 locus and type 1 diabetes.',
#   'A human type 1 diabetes susceptibility locus maps to chromosome 21q22.3.',
#   'Joint genetic susceptibility to type 1 diabetes and autoimmune thyroiditis: from epidemiology to mechanisms.',
#   'Follow-up analysis of genome-wide association data identifies novel loci for type 1 diabetes.',
#   'IFIH1 polymorphisms are significantly associated with type 1 diabetes and IFIH1 gene expression in peripheral blood mononuclear cells.',
#   'Shared and distinct genetic variants in type 1 diabetes and celiac disease.',
#   'Rare variants of IFIH1, a gene implicated in antiviral responses, protect against type 1 diabetes.',
#   'IFIH1 gene polymorphisms in type 1 diabetes: genetic association analysis and genotype-phenotype correlation in the Belgian population.',
#   'IFIH1 gene polymorphisms in type 1 diabetes: genetic association analysis and genotype-phenotype correlation in Chinese Han population.'],
#  3711: ['Phenylketonuria rs62516095.'],
#  5079: ['rs104894728 familial hypertrophic cardiomyopathy, type 7.'],
#  2943: ['KRAS variation and risk of endometriosis.'],
#  4838: ['rs11047102 is associated with systemic sclerosis.'],
#  2334: ['C.269dupT (p.Val91Serfs) ClinVar pathogenic/likely pathogenic for deafness, DFNB1A.'],
#  2867: ['Relapsing diabetes can result from moderately activating mutations in KCNJ11.'],
#  4988: ['New TFR2 mutations in young Italian patients with hemochromatosis.'],
#  1758: ['Genome-wide association analysis implicates elastic microfibrils in the development of nonsyndromic striae distensae.'],
#  1146: ['Schizophrenia 375 case and 812 control subjects rs10399805 p =.018 and rs2275351. p =.008.'],
#  1662: ['Genetic polymorphisms of DNMT3L involved in hypermethylation of chromosomal ends are associated with greater risk of developing ovarian endometriosis.'],
#  197: ['This 2008 article found that the minor C allele of rs17366743 had a hazard ratio of 1.94 for incident diabetes (95% CI 1.16–3.25; Pn = 0.01) .'],
#  788: ['rs80357977, also known as 4370delGT, c.4251_4252delGT and p.Val1417_Leu1418ValArgfs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  2441: ['rs7658293 is a SNP on the GYPA gene known as 72T>G, which can be used to define the MN blood group.'],
#  5425: ['Base excision repair genes and risk of lung cancer among San Francisco Bay Area Latinos and African-Americans.'],
#  300: ['I5002770, also known as c.98C>T or p.A33V, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the childhood form of hypophosphatasia.'],
#  3231: ['rs1836915 is a SNP in the membrane metalloendopeptidase MME gene, which is also known as CD10, CALLA or neprilysin. rs1836915 showed the strongest association among several MME SNPs to Alzheimers disease in a study of 298 Caucasian patients.'],
#  2975: ['Variant in the C13orf31 region associated with increased susceptibility to leprosy, according to the 23andMe blog / 23andMe blog.',
#   'The risk allele is G, and the odds ratio is 1.68.Other genes associated with both Crohns disease and leprosy include NOD2 and TNFSF15, according to / 23andMes blog.Leprosy Susceptibility.'],
#  2257: ['Dopa-responsive dystonia in British patients: new mutations of the GTP-cyclohydrolase I gene and evidence for genetic heterogeneity.Autosomal dominant GTP-CH deficiency presenting as a dopa-responsive myoclonus-dystonia syndrome.'],
#  3996: ['The minor (A) allele is a very rare variant, seen only 34 times out of 121358 alleles in ExAC, with 0 homozyotes observed and a MAF of 0.00028.When inherited recessively or as a compound heterozygote, the rs138249161 (A) allele is considered a causative mutation leading to hypomyelinating leukodystrophy, type 8.See information at OMIM 614366.0005.'],
#  3087: ['rs4141463 is a SNP within an intron of the MACROD2 gene.A 2010 study by the Autism Genome Project of 1,558 rigorously defined autism spectrum disorder families found some - but slight - evidence for an association between rs4141463 and risk for autism.However, an independent case-control study published in 2011 of 1,170 cases of autism spectrum disorder patients failed to replicate any association between autism risk and rs4141463.'],
#  5390: ['Its inheritance alone may be insufficient for the diagnosis of Von Willebrand disease, but it does appear to be associated with a further VWF level reduction in individuals with a second VWF mutation and it also contributes to population variance in VWF and FVIII levels according to a 2010 publication.This SNP is referred to as i5049145 by 23andMe.'],
#  912: ['Some individuals believe it leads to upregulation of the CBS gene, and (eventually) an overproduction of ammonia and/or a decrease in glutathione.'],
#  393: ['Pretty low on the 0-10 magnitude scale).In a Chinese study, post-menopausal women were significantly more likely to have low bone mineral density if they had CC-AA genotypes in rs1799724 - rs1800629 a haplotype of rs1799724 - rs1800629 - rs6254 - rs6256 -IL-1ra- rs2227956 - rs1801197 news cigarette smoking and gastric cancer risk.'],
#  5184: ['They also provided preliminary evidence that the disease-associated genotypes of rs179247 (AA) and rs12101255 (TT) show reduced mRNA expression ratios of flTSHR relative to two alternate TSHR mRNA splice variants..'],
#  504: ['Note that a benign variant of this SNP (c.693C>T) also exists as discussed below.Only the A allele at rs12948217 confers risk to Canavan disease.'],
#  3603: ['Genetic modulation of neural response during working memory in healthy individuals: interaction of glucocorticoid receptor and dopaminergic genes.'],
#  4956: ['Key papers include: is the paper which links it to Breast cancer.'],
#  669: ['rs80357856 breast cancer.'],
#  5354: ['rs1800386 Von Willebrand disease type 1.'],
#  2849: ['A novel dominant mutation in plakoglobin causes arrhythmogenic right ventricular cardiomyopathy.'],
#  5278: ['Aka c.118-308C>Tconsidered pathogenic for familial hemophagocytic lymphohistiocytosis (HLH) in ClinVar.'],
#  3778: ['Identification of genetic variants contributing to cisplatin-induced cytotoxicity by use of a genomewide approach.'],
#  1256: ['Mutations in the type IV collagen alpha 3 (COL4A3) gene in autosomal recessive Alport syndrome.'],
#  2264: ['Aka c.631_632delAT (p.Met211Valfs) Considered definitely pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal dominant dopa-responsive dystonia.'],
#  796: ['rs80359874, also known as 1294del40, c.1175_1214del and p.Leu392_Ser405?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  795: ['rs80359872, also known as 1071del64, c.952_1015del and p.His318_Lys339?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  1743: ['Leukoencephalopathy with vanishing white matter: from magnetic resonance imaging pattern to five genes.'],
#  904: ['A CAV3 microdeletion differentially affects skeletal muscle and myocardium.',
#   'A CAV3 microdeletion differentially affects skeletal muscle and myocardium.',
#   'A CAV3 microdeletion differentially affects skeletal muscle and myocardium.'],
#  2984: ['A 2009 study of 11,163 Dutch participants found no evidence to support previous data indicating a role for SNPs in this gene (LARS2) in type 2 diabetes susceptibility.'],
#  4802: ['A study of ~2800 Japanese adults concluded that rs1041740 (T;T) was associated with cardiovascular mortality (adjusted HR, 2.07, CI: 1.10–3.91, p = 0.0244).'],
#  3073: ['C.4309A>C (p.Asn1437His or N1437H) Considered definitely pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal dominant Parkinson disease (type 8).'],
#  2417: ['rs193026789, also known as c.1212C>A and p.Cys404Ter, represents a very rare mutation in the GRN gene on chromosome 17.The rs193026789 (A) mutation is reported in ClinVar as a dominant mutation pathogenic for frontotemporal dementia.'],
#  959: ['rs12044852 has been reported in a large study to be associated with multiple sclerosis.The risk allele (oriented to the dbSNP entry) is (C). the odds ratio associated with this allele is 1.24 (CI 1.12-1.37).'],
#  4002: ['Reports that one or two copies of a common variation (glycine replacing alanine) present at amino acid 148 of the PON2 protein, rs12026, exacerbates glycemia in non-insulin dependent diabetes mellitus (NIDDM).'],
#  4726: ['A pharmacogenetic study implicates SLC9A9 in multiple sclerosis disease activity.An association was observed between rs9828519 (G) and nonresponse to IFN&#946; treatment for multiple sclerosis (p discovery&#8201;=&#8201;4.43 &#215; 10e&#8722;8), which was then confirmed in a meta-analysis across 3 replication data sets (p replication&#8201;=&#8201;7.78 &#215; 10e&#8722;4).'],
#  2409: ['Association between NMDA receptor subunit 2b gene polymorphism and Alzheimers disease in Chinese Han population in Shanghai.'],
#  160: ['rs17388568 has been reported in a large study to be associated with type-1 diabetes.The risk allele (oriented to the dbSNP entry) is (A). the odds ratio associated with heterozygotes is 1.26 (CI 1.11-1.42), and for homozygotes, 1.58 (CI 1.27-1.95).'],
#  4297: ['They were also nominally associated with a lower waist-to-hip ratio (p =.0295).'],
#  3831: ['Distribution and effects of nonsense polymorphisms in human genes.'],
#  526: ['For details of all 25 SNPs in this group, along with the two methods used to calculate overall risk estimates for breast cancer, refer to the SNPedia breast cancer entry.For this particular SNP, the risk (minor) allele is (C).Another large meta-analysis published in 2011, comprising 26,000+ breast cancer cases and almost 30,000 controls from 23 studies in the Breast Cancer Association Consortium, found average odds ratios of 1.05 for heterozygotes and 1.51 for homozygotes of each of 5 ATM gene SNPs, of which this is one.'],
#  5228: ['Aka c.3310C>G (p.Pro1104Ala or P1104A) Inherited recessively, this variant appears to greatly increase (OR 89.3, CI: 14.7 - 1725, p=8.3x10e-8) the risk of developing tuberculosis according to a 2018 study, if the carrier of the minor homozygote genotype is exposed to the tuberculosis mycobacterium.'],
#  38: ['A Danish case-control study comprising 373 Crohns disease and 541 ulcerative colitis patients (and 796 healthy controls) concluded that carriers of the homozygous COX-2 and MDR1 intron 3 variant ( rs3789243 ) had a relatively high risk of CD, odds ratio (95% CI) (OR (95% CI) ) =2.86 ( (1.34-5.88) p=0.006) and 1.39 ( (0.99-1.92) p=0.054), respectively, and for UC of 2.63 ( (1.33-5.26) p=0.005) and 1.28 ( (0.96-1.51) p=0.093), respectively, assuming complete dominance.'],
#  5152: ['The excess mortality was attributed to deaths due to malignancies and sepsis but not cardiovascular disease (CVD).'],
#  3357: ['rs3781638 displayed significant association with lower fasting plasma glucose levels and increased OGTT-induced insulin release A study totaling 19,000+ Europeans concluded that rs10830963 had the most influence of any MTNR1B gene SNP on the risk for type-2 diabetes.'],
#  4031: ['Meta-analysis of association studies between five candidate genes and type 2 diabetes in Chinese Han population.'],
#  2371: ['rs5443 (C;T) genotypes are more prevalent in gastroesophageal reflux disease (GERD) patients relative to healthy controls (odds ratio 1.43, CI: 1.04&#8211;1.98).'],
#  681: ['There are breast cancer patients harboring the BRCA1 V1736G mutation, but to our knowledge, to date there is no pedigree or other direct evidence confirming pathogenicity.'],
#  5051: [],
#  538: ['C.2552_2553delTT (p.Phe851Cysfs).'],
#  1861: ['Tyrosinemia Type I rs80338899.'],
#  5376: ['rs61754002 Von Willebrand disease.'],
#  2318: ['rs111033293 recessive GJB2 gene variant associated with deafness.'],
#  4863: ['C.561delC (p.Gln188Argfs).'],
#  1208: ['Aka c.1175_1176delAT (p.Tyr392Terfs).'],
#  2962: ['Aka c.1807delC (p.His603Metfs).'],
#  995: ['CDH1 gene; aka c.1488_1494delCGAGGAC.'],
#  4666: ['Aka c.1576G>A (p.Gly526Arg).'],
#  2280: ['Aka c.703C>T (p.Arg235Ter or R235X).'],
#  4849: ['Aka c.304G>T (p.Gly102Cys).'],
#  1900: ['Aka c.386C>T (p.Ser129Phe or S129F).'],
#  5299: ['Aka c.2653C>T (p.Leu885Phe or L885F).'],
#  4913: ['C.367C>T (p.Gln123Ter) 23andMe name: i6018865.'],
#  4099: ['Aka c.659G>A (p.Arg220Gln) 23andMe name: i5003621.'],
#  543: ['Association of the polymorphisms of sodium transport related genes with essential hypertension.'],
#  4398: ['Aka c.1201C>T (p.Arg401Cys or R401C) 23andMe name: i6017662.'],
#  1795: ['rs1709183 associated with EDV endothelium-dependent vasodilation in resistance, but not conduit arteries.'],
#  3910: ['Polycystic Kidney diseaseIt is not clear if 23andMe is reporting on this SNP. rs398124502.'],
#  3596: ['Glucocorticoid receptor gene variant in the 3 untranslated region is associated with multiple measures of blood pressure.'],
#  4282: ['Genome-wide scan on total serum IgE levels identifies FCER1A as novel susceptibility locus.'],
#  1637: ['Aka NM_015512.4 (DNAH1) :c.11726_11727delCT or (p.Pro3909Argfs) OMIM pathogenic variant.'],
#  3432: ['Aka NM_032608.6 (MYO18B) :c.6496G>T or (p.Glu2166Ter) OMIM pathogenic variant.'],
#  2633: ['Genetic variation in the serotonin 2A receptor and suicidal ideation in a sample of 270 Irish high-density schizophrenia families.'],
#  4012: ['667 cases and 862 controls (OR=0.87, P=0.046, 95% CI=0.72-0.99 for rs135551. OR=0.80, P=0.034, 95% myocardial infarction in a European population.'],
#  4411: ['rs193922878, aka p.Leu4838Val or p.L4838V, is a SNP in the RYR1 gene considered causative for malignant hyperthermia.23andMe name: i5000024.'],
#  1444: ['Bisphosphonate-related osteonecrosis of the jaw is associated with polymorphisms of the cytochrome P450 CYP2C8 in multiple myeloma: a genome-wide single nucleotide polymorphism analysis.'],
#  4318: ['Association of RGS2 and RGS5 variants with schizophrenia symptom severity.'],
#  1695: ['rs554375713 designates a variant consisting of a 13-bp deletion of bases 235 to 247 in exon 1 of the DRD4 gene on chromosome 11.'],
#  12: ['A survey of ABCA1 sequence variation confirms association with dementia.'],
#  751: ['rs80357724, also known as c.787+12del, c.787+10dup, c.798_799del, 917delTT, c.798_799delTT and p.Val266_Ser267ValLysfs, all of which are variants in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  4643: ['rs111033220, also known as c.1229C>T, p.Thr410Met and T410M, represents a rare mutation in the SLC26A4 gene.Inherited recessively, this variant is considered pathogenic for Pendred Syndrome, manifest as hearing loss and enlarged vestibular aqueduct syndrome.'],
#  578: ['Aka c.711C>A (p.Cys237Ter). note a benign, synonymous variant, c.711C>T, is also knownLutheran Null blood group mutation23andMe name for c.711C>A variant: i5000663.'],
#  829: ['rs9394492, a SNP located in the BTBD9 gene region, has been linked to a lower frequency of restless legs syndrome, a common sleep disorder, with an overall odds ratio of 0.76 (CI: 0.64-0.87) for the (T) minor allele.'],
#  1235: ['Speech development rs4431523, rs17236239 and significant associations (with P values from 0.01 to 5.0x10&#8211;5) between nonsense-word repetition and nine intronic SNPs ( rs851715, rs10246256, rs2710102, rs759178, rs1922892, rs2538991, rs17236239, rs2538976, and rs2710117 ).'],
#  2372: ['rs28937594, also known as c.2228T>C, p.Met743Thr, M743T and most commonly in the literature M712T, is a mutation in the GNE gene on chromosome 9.The very rare rs28937594 (C) allele is the most common mutation leading to autosomal recessive inclusion body myopathy 2 (IBM2 or HIBM) in Middle Eastern populations.See also OMIM 603824.0005.'],
#  58: ['Permanent neonatal diabetes caused by dominant, recessive, or compound heterozygous SUR1 mutations with opposite functional effects.'],
#  1315: ['This gene encodes the CD152 antigen.A study of 165 Swedish myasthenia gravis patients concluded that the rs733618 (A;G) heterozygotes had an odds ratio of 1.87 (CI: 1.01-3.49, p=0.049) for the disease compared to healthy individuals, yet neither allele on its own showed increased risk.'],
#  2754: ['rs11805303 has been reported in a large study to be associated with Crohns disease.The risk allele (oriented to the dbSNP entry) is (T). the odds ratio associated with heterozygotes is 1.39 (CI 1.22-1.58), and for homozygotes, 1.86 (CI 1.54-2.24).'],
#  5234: ['Among 120 (likely Japanese) first-episode neuroleptic-naive schizophrenics treated with risperidone genotyped for 30 variants in misc.'],
#  4174: ['There are two known mutations considered c.833G>T (p.Arg278Ile) Inherited as an autosomal dominant, there are three known mutations in rs63749891 associated with early-onset Alzheimers disease: rs63749891 (T), also known as c.833G>T, p.Arg278Ile or R278I (ClinVar) rs63749891 (C), also known as c.833G>C, p.Arg278Thr or R278T (ClinVar) rs63749891 (A), also known as c.833G>A, p.Arg278Lys or R278K (DIAN).'],
#  1677: ['These data identify rs1076560 as a potentially important variable in the development of alcoholism.'],
#  3032: ['Single-nucleotide polymorphisms in LPA explain most of the ancestry-specific variation in Lp (a) levels in African Americans.'],
#  5049: ['TMPRSS6, but not TF, TFR2 or BMP2 variants are associated with increased risk of iron-deficiency anemia.'],
#  3786: ['Longitudinal association of PCSK9 sequence variations with low-density lipoprotein cholesterol levels: the Coronary Artery Risk Development in Young Adults Study.'],
#  2220: ['When one of the mutations is the D409H mutation, the clinical description may be Gaucher disease type 3C, involving valvular heart disease.'],
#  918: ['The only coding SNP in this protective haplotype associated with delayed AD onset was rs1129844.',
#   'The only SNP within a coding region of a gene in this protective haplotype associated with delayed AD onset was rs1129844, The protective haplotype occurred in 1 in 4 carriers; the A allele also occurs with a frequency of approximately 25%.',
#   'A follow-on study confirmed the protection of rs1129844 in 152 AD patients.'],
#  4942: ['rs10246939 is one of three SNPs that form the main haplotypes behind the ability to perceive as bitter the taste of the compound phenylthiocarbamide (PTC) and similar molecules in foods (like cabbage and raw broccoli) or drinks (like coffee and dark beers).The rs10246939 (C) allele, in the orientation shown in dbSNP, is the tasting allele, and it is dominant to the non-tasting allele rs10246939 (T), so having one copy is enough to have the bitter tasting ability.'],
#  4728: ['UGT1A1, SLCO1B1, and SLCO1B3 polymorphisms versus neonatal hyperbilirubinemia: is there an association?.'],
#  2269: ['The glucokinase gene promoter polymorphism -30G>A ( rs1799884 ) is associated with fasting glucose in healthy pregnant women but not with gestational diabetes.'],
#  1178: ['Myotonia congenita rs80356706.'],
#  1401: ['Congenital adrenal hyperplasia rs7769409.'],
#  397: ['The ancestral allele is A.'],
#  5186: ['rs2268458 was associated with Graves disease.'],
#  3358: ['Genetic variation in the one-carbon transfer pathway and ovarian cancer risk.'],
#  2804: ['Genetic polymorphisms influence mycophenolate mofetil-related adverse events in pediatric heart transplant patients.'],
#  1633: ['Detecting disease-associated genotype patterns.'],
#  3671: ['Variation of the oxytocin/neurophysin I (OXT) gene in four human populations.'],
#  3425: ['Familial hypertrophic cardiomyopathysee also OMIM 160781.0005Note: this SNP, rs28932774, appears to tag the same polymorphism as rs104894370.'],
#  1855: ['Genetic variation in lipid desaturases and its impact on the development of human disease.'],
#  4619: ['rs2631372 increases susceptibility to Crohns disease 1.28 times for carriers of the C allele.'],
#  3365: ['rs326118 is reported to represent a risk factor for abdominal aortic aneurysm (AAA), with odds ratio of 0.47 (CI: 0.29-0.77).'],
#  1026: ['rs10757272 increases susceptibility to Coronary artery disease 1.30 times for heterozygotes (CT) and 1.54 times for homozygotes (TT).'],
#  620: ['Variant BHMT allele may increase risk for neural tube defects, apparently only in folate rich environments, and possibly in conjunction with rs1801133.'],
# ...
#  3197: ['Missense mutations in the MEFV gene are associated with fibromyalgia syndrome and correlate with elevated IL-1beta plasma levels.',
#   'Missense mutations in the MEFV gene are associated with fibromyalgia syndrome and correlate with elevated IL-1beta plasma levels.'],
#  5182: ['A meta-analysis including eight studies (totaling 6,976 cases and 7,089 controls) reported an association between rs12101255 (T) with Graves disease (odds ratio 1.5, CI: 1.410-1.600, p<0.001), and the associations were the same under dominant, recessive and co-dominant models..'],
#  2480: ['Correlations with skin, eye, and hair color variation.The h-1 haplotype found in homozygous state in 97% of individuals with blue eye color is composed as follows : rs4778241 (C) <br> rs1129038 (A) <br> rs12593929 (A) <br> rs12913832 (G) <br> rs7183877 (C) <br> rs3935591 (G) <br> rs7170852 (A) <br> rs2238289 (T) <br> rs3940272 (C) <br> rs8028689 (T) <br> rs2240203 (A) <br> rs11631797 (G) <br> rs916977 (G) <br> blog coverage A genome-wide association scan in admixed Latin Americans identifies loci influencing facial and scalp hair features.'],
#  1370: ['Genetic polymorphisms involved in carcinogen metabolism and DNA repair and lung cancer risk in a Japanese population.'],
#  5381: ['rs61750101 Von Willebrand disease.'],
#  3702: ['Phenylketonuria rs62514952.'],
#  1398: ['Congenital adrenal hyperplasia rs72552757.'],
#  3822: ['Rhizomelic chondrodysplasia punctata type 1 rs267608255.'],
#  2286: ['ADHD GIT1 is associated with ADHD in humans and ADHD-like behaviors in mice.'],
#  1688: ['rs6275 /DRD2 and rs4680 /COMT useful in predicting disease risk among schizophrenia patientsSee also rs6277.'],
#  1785: ['DNA polymorphism and risk of esophageal squamous cell carcinoma in a population of North Xinjiang, China.'],
#  1133: ['Aka c.1002G>A (p.Trp334Ter) Considered pathogenic in ClinVar for a form of autosomal dominant mental retardation.'],
#  2837: ['Mutation of CERKL, a novel human ceramide kinase gene, causes autosomal recessive retinitis pigmentosa (RP26).'],
#  2635: ['Polymorphisms in the serotonin receptor gene HTR2A are associated with quantitative traits in panic disorder.'],
#  2181: ['Aka c.1796T>G, p.Ile599SerIdentified in ClinVar as likely pathogenic/pathogenic for Krabbe disease (when inherited in two copies or as a compound heterozygote).'],
#  793: ['rs80358158, also known as c.135-1G>T and c.135-1G>C, represents a variant in the BRCA1 gene.Both minor alleles are considered pathogenic for breast cancer in ClinVar.'],
#  1404: ['Aka c.844G>T, p.Val282Leu and V282L; also known in older literature as Val281Leu or V281Lassociated with non-classic 21-OH CAH; see / GeneReviews as well as OMIM.'],
#  434: ['Known as I716T, and reported in AlzForum based on a 2002 abstract to be a pathogenic mutation for early-onset Alzheimers disease.'],
#  607: ['The odds ratio for carriers of the minor allele (C) are reported as 1.28 (p=0.031) based on a study of 329 Japanese patients.'],
#  312: ['I6006895, also known as c.215T>C or p.I72T, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the odonto form of hypophosphatasia.'],
#  1042: ['rs4977756 is a SNP near the CDKN2BAS gene.A (GWA) study for open-angle glaucoma (OAG) blindness ultimately based on ~1500 cases concluded that the rather common rs4977756 (A) allele was statistically associated with the condition, with a per allele odds ratio of 1.39 (CI: 1.28&#8211;1.51, p = 1.35 &#215; 10e?14).'],
#  1409: ['CYP2B6 (c.516G-->T) and CYP2A6 ( 9B and/or 17) polymorphisms are independent predictors of efavirenz plasma concentrations in HIV-infected patients.'],
#  4795: ['rs772724819, also known as c.212+1G>T, is a rare variant in the SNX10 gene. rs772724819 (T) is considered a recessively inherited mutation pathogenic for osteopetrosis, type 8.In Northern Sweden, a study of nine individuals with this mutation showed (via haplotype analysis) that all cases originated from a single mutational event, and the age of the mutation was estimated to be approximately 950 years.'],
#  1202: ['778 Common variable immunodeficiency disorder (CVID) cases compared with 10,999 controls using the Illumina Immunochip; the first non-HLA genome-wide significant risk for CVID locus was found within the CLEC16A gene, namely rs17806056.'],
#  2202: ['rs111033690, also known as c.404C>T, p.Ser135Leu and S135L, represents a variant in the GALT gene on chromosome 9.The rs111033690 (T) allele is considered a pathogenic mutation associated with galactosemia, a recessively inherited disorder typically first diagnosed in newborns.'],
#  3968: ['Screening for germline mutations of MLH1, MSH2, MSH6 and PMS2 genes in Slovenian colorectal cancer patients: implications for a population specific detection strategy of Lynch syndrome.',
#   'Quantification of sequence exchange events between PMS2 and PMS2CL provides a basis for improved mutation scanning of Lynch syndrome patients.'],
#  798: ['The genotypes containing the causal/pathogenic variants are (D;I) and the even rarer (D;D).For information about causal/pathogenic BRCA2 mutations and what they imply about the odds of developing breast cancer, please see the BRCA2 page and links from that page.i4000379 is the identifier used by 23andMe for the 6174delT mutation that is rs80359550 as identified in public SNP databases.Additional BRCA information may be found in numerous places online, and within 23andMe, / here.In addition to i4000379, the other names used by 23andMe for the most common causal mutations are i4000377 and i4000378.'],
#  4708: ['Genome-wide and candidate gene association study of cigarette smoking behaviors.'],
#  3723: ['This variant is among the most common PKU-associated mutations seen in Scandinavia.While other mutations in the PAH gene may cause phenylketonuria, when inherited recessively, the rs5030860 (G) mutation is associated with non-phenylketonuria hyperphenylalaninemia.'],
#  4651: ['See also: / 23andMe blog goutIndependently, a large study totaling 7,699 participants in the Framingham cohort and 4,148 participants in the Rotterdam cohort was conducted, with genome-wide significant SNPs then replicated in 11,000+ Caucasian and ~4,000 African-American individuals who took part in the study of Atherosclerosis Risk in Communities (ARIC).'],
#  2526: ['rs7923837 and rs1111875 were significantly associated with decreased insulin secretion and lower insulinogenic index in a study of 420 Germans in the MESYBEOP cohort.'],
#  1036: ['This risk was magnified in subjects who were males, less than 60 years old, overweight, or smokers.'],
#  4581: ['This study also found that rs2448490 can be combined with an independent predictor of metastasis free survival, rs9306160, to yield an even stronger prognostic.'],
#  1888: ['Hemophilia A In a case-control study of 85 individuals a more than 3-fold increased risk of inhibitor development was found compared to patients with the RR genotype Malaria Based on a study of more than 1,800 individuals in India, rs1801274 (T;T) homozgyotes were significantly associated with protection from disease manifestation, with stronger association observed in the malaria non-endemic region.',
#   'Malaria Complications.'],
#  1250: ['Associated with Accelerated Bone Mineral Density Loss after Hematopoietic Cell Transplantation.'],
#  4329: ['This snp is on the 23andMe microarray but lacks a dbSNP identifier.'],
#  4415: ['Genome-wide association of echocardiographic dimensions, brachial artery endothelial function and treadmill exercise responses in the Framingham Heart Study.'],
#  3972: ['Association study between reward dependence temperament and a polymorphism in the phenylethanolamine N-methyltransferase gene in a Japanese female population.'],
#  3247: ['Chinese breast cancer rs11568818 (G;G) significantly worse prognosis (OS HR: 6.7, 95% CI: 2.4-18.6) than patients homozygous for the common allele (A).'],
#  4257: ['The rare (deletion) allele for this PTPRQ gene variant is reported to be causative for a recessive form of deafness; see PTPRQ for details and sources.'],
#  5134: ['Familial hypertrophic cardiomyopathysee also OMIM 191010.0001Note: This SNP, rs28934269, appears to identify the exact same polymorphic location as rs104894502.'],
#  4422: ['rs149391396, also known as R723X, is a variant in the sarcosine dehydrogenase SARDH gene that has been reported to cause sarcosinemia, a condition brought about through autosomal recessive inheritance.In dbSNP orientation for this SNP, the variant (rare) allele is rs149391396 (A).'],
#  3677: ['Alcohol and aggressive behavior in men--moderating effects of oxytocin receptor gene (OXTR) polymorphisms.'],
#  2038: ['rs146948377, also known as c.482_+_3 delA or, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  574: ['/ 23andMe blog Each copy of a G at this SNP increases the odds of aggressive neuroblastoma by 1.68 times.allelic odds ratio of 1.68 (p = 2.74 x 10 (-16) ) Chromosome 6p22 locus associated with clinically aggressive neuroblastoma.'],
#  323: ['I6006947, also known as c.526G>A or p.A176T, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the childhood form of hypophosphatasia.'],
#  2832: ['Over 85 years old) or not (less than 85) somehow concluded that rs1805097 (A;A) individuals were about twice as likely to reach extreme old age (odds ratio 2.03, CI:1.39-2.99, p =.0003).'],
#  1623: ['Effect of DISC1 on the P300 Waveform in Psychosis.'],
#  2704: ['rs568408 (A) and rs3212227 (C) variant genotypes were associated with a significantly increased risk of cervical cancer adjusted odds ratio, 1.43; 95% confidence interval (CI), 1.06-1.93; and adjusted odds ratio, 1.30; 95% CI, 0.97-1.75, respectively.',
#   'Subjects carrying variant genotypes of both loci had a 1.82-fold (95% CI, 1.28-2.57) increased risk of cervical cancer.'],
#  1268: ['Although initial reports associated the rs137853213 variant allele with intervertebral disc disease, subsequent studies have questioned this, and currently ClinVar indicates that this is considered a variant of uncertain significance.'],
#  4699: ['rs27048, a SNP in the dopamine transporter SLC6A3 gene, has been associated with more severe symptoms upon alcohol withdrawal, such as seizures, in a study of 250 Caucasian alcohol-dependent patients.'],
#  4202: ['Note the presence of another variant for this SNP, c.640G>A, of unknown pathogenicity.The minor allele is reported as pathogenic for Alzheimers disease in the AlzForum database, based on two publications, including.'],
#  3473: [],
#  1021: ['There do appear to be modifiers in the genomes of some individuals that can reduce the cancer risk of this allele.Increased screening of individuals with the p16-Leiden for both moles and pancreatic cancer is likely to be beneficial.A detailed description of this allele and studies about it can be found in OMIM 600160.0003.'],
#  1831: ['A meta-analysis of publications through July 2009, totaling 4,386 cases (vs 40,089 controls) concluded that apart from a very weak association with myocardial infarction for the rs1801020 (T;T) + (C;T) compared with (C;C) genotype, (odds ratio 1.13, CI: 1.00 - 1.27), the evidence for an association between F12 -4C>T and venous thromboembolism and myocardial infarction was weak.'],
#  251: ['The authors postulate that rs3803304 s effects may result from disruptions with an RNA regulatory mechanism, based upon its close proximity to a conserved exon-intron boundary in an area of high predicted regulatory potential.'],
#  3023: ['SNCA polymorphisms, smoking, and sporadic Parkinsons disease in Japanese.'],
#  1010: ['Polycystic Kidney disease rs7756992 significantly p = 0.0363 associated with type-2 diabetes in 1,630 Japanese subjects and in 1,064 controls rs7756992 replicated as significant for type-2 diabetes risk in 1,900 Japanese patients, with odds ratio of 1.27 (CI: 1.15-1.40, p = 9.8 x 10e-7) 1,638 type 2 diabetes patients and 1,858 controls rs7756992 non-significant T2D and normal glucose tolerant (NGT) individuals.'],
#  1973: ['(T) shorter lifespan (G) longer lifespanQuoted from the geneticfuture article:No-one should consider this association to be definitive until its been replicated in independent cohorts.Secondly, the effects of this variant are likely to differ between groups.'],
#  1390: ['This report cites another study as indicating that rs1056836 (C;C) high-risk stage III and IV breast cancer patients receiving dose-intense paclitaxel in combination with doxorubicin and cyclophosphamide experience a longer progression-free survival compared with patients with (C;G) or (G;G) genotypes. rs1056836 increases susceptibility to lung cancer among those who never smoked 2.7x times for (C:G) heterozygotes and 3.1x times for (G;G) homozygotes, based on a study of 160 US patients.'],
#  919: ['Monocyte chemoattractant protein-1 in schizophrenia: -2518A/G genetic variant and protein levels in Armenian population.'],
#  2622: ['rs1043618 in HSP70-1, resulted in a significant association with noise-induced hearing loss.'],
#  947: ['rs2282055 and rs4143815 may be biomarkers for the efficacy of nivolumab.'],
#  1666: ['Haplotype-sharing analysis implicates chromosome 7q36 harboring DPP6 in familial idiopathic ventricular fibrillation.'],
#  3950: ['Aka NM_012268.3 (PLD3) :c.923T>C or (p.Leu308Pro) OMIM pathogenic variant.'],
#  5159: ['Aka NM_004237.3 (TRIP13) :c.1060C>T or (p.Arg354Ter) OMIM pathogenic variant.'],
#  1032: ['Novel susceptibility variants at 10p12.31-12.2 for childhood acute lymphoblastic leukemia in ethnically diverse populations.'],
#  1642: ['Aka c.48+2dupT (p.Ser17ValfsTer12) This SNP may represent the most common DNAI1 gene mutation associated with primary ciliary dyskinesia.'],
#  1471: ['Involved in a number of decreased and non-functioning CYP2D6 variants.'],
#  4334: ['Renalase gene is a novel susceptibility gene for essential hypertension: a two-stage association study in northern Han Chinese population.'],
#  239: ['AdoHcy hydrolysis serves not only to sustain the flux of methionine sulfur toward cysteine, but is believed also to play a critical role in the regulation of biologic methylations.'],
#  5105: ['The TOR1A polymorphism rs1182 and the risk of spread in primary blepharospasm.'],
#  886: ['rs387907240, also known as c.467T>C, p.Leu156Pro and L156P, represents a very rare mutation in the CARD14 gene on chromosome 17.Found through sequencing of 2 unrelated 3-generation families with autosomal dominant pityriasis rubra pilaris, the rs387907240 (C) mutation is considered causative for the condition.'],
#  2474: ['Genome-wide association study provides evidence for a breast cancer risk locus at 6q22.33.',
#   'Combined effect of low-penetrant SNPs on breast cancer risk.'],
#  2898: ['The K antigen is more potent at triggering an immune reaction than the k antigen.'],
#  3173: ['rs17435 is one of several SNPs in the methyl CpG binding protein 2 (MECP2) that have been associated with risk for systemic lupus erythromatosis (SLE).'],
#  4946: ['Study A common Greenlandic TBC1D4 variant confers muscle insulin resistance and type 2 diabetes found association with higher 2 hour plasma glucose (&#946; = 3.8&#8201;mmol&#8201;l&#8722;1, P = 2.5&#8201;&#215;&#8201;10&#8722;35 homozygous) and serum insulin (&#946; = 165&#8201;pmol&#8201;l&#8722;1, P = 1.5&#8201;&#215;&#8201;10&#8722;20 homozygous) and subset of diabetes that features deterioration of postprandial glucose homeostasis among Greenlandic population.'],
#  2231: ['Genetic and environmental predictors of serum 25-hydroxyvitamin D concentrations among middle-aged and elderly Chinese in Singapore.'],
#  4025: ['Association of PPAR-gamma gene polymorphisms with obesity and obesity-associated phenotypes in north indian population.'],
#  ...}

# %%
# We need the unprocessed CSV file exported from Qualtrics for some of the following information.
# Specifically, let's use this to get the mapping betweeen response IDs (from Qualtrics) and user IDs (from Prolific).
exported_df = pd.read_csv(QUALTRICS_RAW_CSV_EXPORT_PATH)
exported_df.drop(df.index[[0,1]], inplace=True)
prolific_pid_column = "Q564"
response_id_column = "ResponseId"
response_id_to_prolific_pid = dict(zip(exported_df[response_id_column], exported_df[prolific_pid_column]))
response_id_to_prolific_pid
# Out:
# {'R_2eUMgNrFozgjPf3': '5ecba4b6ef75d53505406d57',
#  'R_utbyJnQ1UKOs1mp': '5cdc5a76fa9e8d0001bcb934',
#  'R_3nAyzwespvUg02B': '5bf5adc9d944c30001263593',
#  'R_32XGNR4nwZcoLZI': '5ebf84f79a8ebe3610e2c79b',
#  'R_3oYnbK47VvX8jrt': '5bf9c3137618a60001608942',
#  'R_3rDF5fdF3oDgOuR': '5f3a820565d604693631d6fb',
#  'R_YWGiyoyuJx2FDIR': '5ec5ca6abbd42f64282295d7',
#  'R_1CkzzlePivYgMZr': '5e67d5ca0ec2fc0801580430',
#  'R_3EFFKjKVN3PQ0In': '5f2be37b1e52920009dadba6',
#  'R_32JAcjfY3df6fzg': '5e9f3b738bee310bed8379ad',
#  'R_2Yt7JOaXOeN5jJ2': '5e032eefdfdc95e5e0c31dfd',
#  'R_1IXCuSnWZ7cyfh3': '5f74e009929e1012397c31e9',
#  'R_32MejXkqXetplmo': '5e98bfdee3aef30fc9a99e28',
#  'R_2U4sdhbvxYpTR5O': '5865dd647fbbcd00013973b8',
#  'R_1PZ7OJP8e7aeIjO': '5be385ba24f70e00018b0024',
#  'R_3GpR4HRv21NuLtm': '5e93301515768a1680c9705a',
#  'R_1pWmg4wjRUOa542': '5ec6b3ce04e80f0c9a211c5b',
#  'R_R8j0APpr9g9xfc5': '5df7eeb4cc6822000ac81b07',
#  'R_1H0Opfec4YYU02C': '5edede64402f7d18f040266e',
#  'R_RUdmhInXoPo1WwN': '5d2b153afa24ba00173e8ee0',
#  'R_1LGAwDpbJTS9frP': '5d6c12352e6bbb001a122cef',
#  'R_2yjBPHu6DffFx8u': '5f2097ac626bc33b28c2cbf9',
#  'R_1rk9ABpZImGhqxT': '5d722d644fee74001adb559d',
#  'R_2PuvY0XMCEk2V8i': '5dc1e711900e3e15813f7c38',
#  'R_TwwLZCED6Zcddv3': '5f20a219f055ba1937476de0',
#  'R_1f8hE2fGENZJBDD': '5eb0cb5afb9e2418da928edb',
#  'R_2rl8NzStbxg2A5z': '5e1a24eb644d102a0efee857',
#  'R_3n2zNVB0rS9PRDT': '5e830913ff38e3016d1a69f2',
#  'R_2ysaHUweAg7K4HR': '5eed7950a383181a9932bc1b',
#  'R_11dXvVViUxpvhcI': '5d8c7194caeeef001985baf6',
#  'R_1rCGrMTNCSgzlep': '5f23f9035554f32008f8a35e',
#  'R_1HksZPLwptmI0jX': '5bc0878f85819f0001352ab4',
#  'R_3nrvRB9rp1gIjBs': '5eee7e5812de8e32ecde556c',
#  'R_21ogAvLp7d36qqW': '5d60061e45714d00019ad6a4',
#  'R_XuZn2HckP0Kb94d': '5d7b76581390440019b3b928',
#  'R_2i6loraoiQh4mtz': '5f450efcb34be707606d05d4    ',
#  'R_3kqdN5s9rIMxIbW': '5e3844c9244f9d04ebae9b97',
#  'R_3fZTS7YZsOgvgLM': '5ef50bc0cb480c14a8f60d38',
#  'R_ex4O7yqMdnNIAfL': '5eccb086d314a0887ac5c3b5',
#  'R_3HidL2LaGIlqCy0': '5ec32348079dcc17451cac16',
#  'R_3kH6y9Wi0TBwgnH': '5eb2c8d889123905858e3c20',
#  'R_3gLt41UA6aTK5iw': '5eeb082290a5841cc8b050eb',
#  'R_2dzu9r3ccYAkv4Q': '5ec4492f675098327a7215d4',
#  'R_QhMoKyWgriJMaad': '5f4d12488c7b550aec05845d',
#  'R_277D0uNSAuCYkRj': '5f05fa1557d36f0f2bacae60',
#  'R_1r1gOcKhQUnlMYm': '5b903f42e4af15000161b7e3',
#  'R_1rufxy3l5GJD63n': '5f1f8b9757a75219b864718c',
#  'R_3GjrMwjY0f2fmmX': '5ed307fdb265ab1797983f68',
#  'R_3s4UHRB7BlobVWb': '5e5bd012663c673b04bcdf42',
#  'R_xFuvGzQaNzAuZyh': '5f623039ea3ae10fb5bde11d',
#  'R_26kTPGkH8j9qeIV': '5e89e620419be567b408e236',
#  'R_1QQ48w7zPEZ7kGt': '5f3020ed291f7344af6d82e1',
#  'R_R3KuOywbfyopApr': '5ee3348f8cfe2d49e6dc98ff',
#  'R_3HBaK6jQIamXIps': '5a0ccf780fff620001a6c8a9',
#  'R_Tpi9jG206VKmz9D': '5e6d403dfc5eff000b8329a5',
#  'R_3F4FT2lUXu8U23s': '5f5797583cbc65245d493954',
#  'R_sR6RH8z89Ulq8vf': '5f6b3dbc7a71cb2393732fa5',
#  'R_3q8zcT1bRayhWk8': '5eb1550ac73caa039c6986db',
#  'R_p9rDLmewYA2Fagh': '5f661b5e3512a71b39229e76',
#  'R_3lXJ5hWuepJ6WLa': '5f53bb278de59a6d87e53aab',
#  'FS_21dq7qRt9wOKYwr': '5f1f8b9757a75219b864718c',
#  'FS_Pvvf27klRGTjmIp': '5cbb779ffb8dfe0015839672',
#  'FS_Xk4jjhD7d54HjJT': '5f23f9035554f32008f8a35e',
#  'FS_1dBlMB6Zi7jyiCJ': '5cffec8eb5f15d0017b5dbca',
#  'FS_3QFNaOgC6T3oekz': '5f6b3dbc7a71cb2393732fa5',
#  'FS_1CkGU9TH8KZkAxg': '5eb2c8d889123905858e3c20',
#  'FS_6M5wWODpI0j9r6F': '5a0ccf780fff620001a6c8a9'}

# %%
exported_df
# Out:
#         StartDate        EndDate      Status       IPAddress Progress  \
# 2   10/1/20 13:24  10/1/20 13:40  IP Address    78.154.94.55      100
# 3   10/1/20 13:32  10/1/20 13:43  IP Address   93.56.134.178      100
# 4   10/1/20 13:36  10/1/20 13:44  IP Address  85.202.110.140      100
# 5   10/1/20 13:37  10/1/20 13:47  IP Address      83.6.53.20      100
# 6   10/1/20 13:23  10/1/20 13:49  IP Address     37.30.39.19      100
# ..            ...            ...         ...             ...      ...
# 64  10/1/20 13:37  10/1/20 14:09  IP Address    83.28.238.92        1
# 65  10/1/20 13:40  10/1/20 15:16  IP Address   99.225.196.73        1
# 66  10/1/20 13:41  10/1/20 17:00  IP Address    89.68.167.54        1
# 67  10/1/20 13:45  10/1/20 13:45  IP Address   188.83.156.96        1
# 68  10/1/20 13:46  10/1/20 13:47  IP Address    51.7.154.139        1
#
#    Duration (in seconds) Finished   RecordedDate          ResponseId  \
# 2                    973     TRUE  10/1/20 13:40   R_2eUMgNrFozgjPf3
# 3                    653     TRUE  10/1/20 13:43   R_utbyJnQ1UKOs1mp
# 4                    454     TRUE  10/1/20 13:44   R_3nAyzwespvUg02B
# 5                    615     TRUE  10/1/20 13:47   R_32XGNR4nwZcoLZI
# 6                   1524     TRUE  10/1/20 13:49   R_3oYnbK47VvX8jrt
# ..                   ...      ...            ...                 ...
# 64                     1    FALSE            NaN  FS_Xk4jjhD7d54HjJT
# 65                     1    FALSE            NaN  FS_1dBlMB6Zi7jyiCJ
# 66                     1    FALSE            NaN  FS_3QFNaOgC6T3oekz
# 67                     1    FALSE            NaN  FS_1CkGU9TH8KZkAxg
# 68                     1    FALSE            NaN  FS_6M5wWODpI0j9r6F
#
#    RecipientLastName  ... LocationLongitude DistributionChannel UserLanguage  \
# 2                NaN  ...       19.76759338           anonymous           EN
# 3                NaN  ...       8.944396973           anonymous           EN
# 4                NaN  ...       22.27319336           anonymous           EN
# 5                NaN  ...       21.00149536           anonymous           EN
# 6                NaN  ...       20.92379761           anonymous           EN
# ..               ...  ...               ...                 ...          ...
# 64               NaN  ...      -79.43430328           anonymous           EN
# 65               NaN  ...      -79.43430328           anonymous           EN
# 66               NaN  ...      -79.43430328           anonymous           EN
# 67               NaN  ...      -79.43430328           anonymous           EN
# 68               NaN  ...      -79.43430328           anonymous           EN
#
#                         Q564  \
# 2   5ecba4b6ef75d53505406d57
# 3   5cdc5a76fa9e8d0001bcb934
# 4   5bf5adc9d944c30001263593
# 5   5ebf84f79a8ebe3610e2c79b
# 6   5bf9c3137618a60001608942
# ..                       ...
# 64  5f23f9035554f32008f8a35e
# 65  5cffec8eb5f15d0017b5dbca
# 66  5f6b3dbc7a71cb2393732fa5
# 67  5eb2c8d889123905858e3c20
# 68  5a0ccf780fff620001a6c8a9
#
#                                              hilights  \
# 2   [["3279","prone to miscalls",0],["957","vaccin...
# 3   [["4315","Hirschsprung disease",32],["2617","H...
# 4   [["499"," 2T>",11],["614","Brain-derived",0],[...
# 5   [["838","adult bronchial asthma",78],["3384","...
# 6                                                  []
# ..                                                ...
# 64  [["3433","aka c.3126T>G",0],["1636","Can",11],...
# 65  [["3712","Phenylketonuria",0],["2415","contrib...
# 66                                                 []
# 67                                                 []
# 68                                                 []
#
#                 PROLIFIC_PID                  STUDY_ID  \
# 2   5ecba4b6ef75d53505406d57  5f7618a006b78606c8f1c588
# 3   5cdc5a76fa9e8d0001bcb934  5f7618a006b78606c8f1c588
# 4   5bf5adc9d944c30001263593  5f7618a006b78606c8f1c588
# 5   5ebf84f79a8ebe3610e2c79b  5f7618a006b78606c8f1c588
# 6   5bf9c3137618a60001608942  5f7618a006b78606c8f1c588
# ..                       ...                       ...
# 64  5f23f9035554f32008f8a35e  5f7618a006b78606c8f1c588
# 65  5cffec8eb5f15d0017b5dbca  5f7618a006b78606c8f1c588
# 66  5f6b3dbc7a71cb2393732fa5  5f7618a006b78606c8f1c588
# 67  5eb2c8d889123905858e3c20  5f7618a006b78606c8f1c588
# 68  5a0ccf780fff620001a6c8a9  5f7618a006b78606c8f1c588
#
#                   SESSION_ID client_errors  \
# 2   5f762cd1f653f2096918d838            []
# 3   5f762eccceb01f09da5a4f41            []
# 4   5f762fbfa6eafb0afbdf038c            []
# 5   5f762ff476442d0a541dc2d6            []
# 6   5f762cb772893609ceca96ae            []
# ..                       ...           ...
# 64  5f763009fb2b4b0a21271d19            []
# 65  5f7630953923650a6c5d318b            []
# 66  5f7630f275b83a09be15de74            []
# 67  5f76302fc3a3e109fc642a48            []
# 68  5f76314f16f58b0b128ff22f            []
#
#                                        navigator_info
# 2   {"userAgent":"Mozilla/5.0 (Windows NT 10.0; Wi...
# 3   {"userAgent":"Mozilla/5.0 (Windows NT 10.0; Wi...
# 4   {"userAgent":"Mozilla/5.0 (Windows NT 6.3; Win...
# 5   {"userAgent":"Mozilla/5.0 (Windows NT 10.0; Wi...
# 6   {"userAgent":"Mozilla/5.0 (Windows NT 10.0; Wi...
# ..                                                ...
# 64  {"userAgent":"Mozilla/5.0 (Windows NT 6.1; Win...
# 65  {"userAgent":"Mozilla/5.0 (Macintosh; Intel Ma...
# 66  {"userAgent":"Mozilla/5.0 (Linux; Android 9; F...
# 67  {"userAgent":"Mozilla/5.0 (Windows NT 10.0; Wi...
# 68  {"userAgent":"Mozilla/5.0 (Linux; Android 10; ...
#
# [67 rows x 24 columns]

# %%
# Breaking it down by specific users who took the survey.
users_df = df.copy(deep=True)[["response_id","recorded_datetime","status","progress","is_finished","duration"]]
users_df.drop_duplicates(inplace=True)
users_df.reset_index(inplace=True, drop=True)

# Some extra information to know, the duration, and the number of total highlights in each response, and Prolific IDs.
users_df["duration_min"] = users_df["duration"].map(lambda x: math.ceil(x/60))
response_id_to_num_snippets = dict(df.groupby("response_id").size())
users_df["num_snippets"] = users_df["response_id"].map(response_id_to_num_snippets)
users_df["prolific_id"] = users_df["response_id"].map(response_id_to_prolific_pid)
users_df.to_csv(SURVEY_TAKERS_OUTPUT_PATH, index=False)
users_df.tail(50)
# Out:
#            response_id recorded_datetime      status  progress is_finished  \
# 11   R_2U4sdhbvxYpTR5O     10/1/20 13:59  IP Address       100        TRUE
# 12   R_1PZ7OJP8e7aeIjO     10/1/20 14:00  IP Address       100        TRUE
# 13   R_3GpR4HRv21NuLtm     10/1/20 14:01  IP Address       100        TRUE
# 14   R_1pWmg4wjRUOa542     10/1/20 14:01  IP Address       100        TRUE
# 15   R_R8j0APpr9g9xfc5     10/1/20 14:01  IP Address       100        TRUE
# 16   R_1H0Opfec4YYU02C     10/1/20 14:02  IP Address       100        TRUE
# 17   R_RUdmhInXoPo1WwN     10/1/20 14:02  IP Address       100        TRUE
# 18   R_1LGAwDpbJTS9frP     10/1/20 14:03  IP Address       100        TRUE
# 19   R_2yjBPHu6DffFx8u     10/1/20 14:04  IP Address       100        TRUE
# 20   R_1rk9ABpZImGhqxT     10/1/20 14:05  IP Address       100        TRUE
# 21   R_2PuvY0XMCEk2V8i     10/1/20 14:05  IP Address       100        TRUE
# 22   R_TwwLZCED6Zcddv3     10/1/20 14:05  IP Address       100        TRUE
# 23   R_1f8hE2fGENZJBDD     10/1/20 14:05  IP Address       100        TRUE
# 24   R_2rl8NzStbxg2A5z     10/1/20 14:05  IP Address       100        TRUE
# 25   R_3n2zNVB0rS9PRDT     10/1/20 14:05  IP Address       100        TRUE
# 26   R_2ysaHUweAg7K4HR     10/1/20 14:06  IP Address       100        TRUE
# 27   R_11dXvVViUxpvhcI     10/1/20 14:07  IP Address       100        TRUE
# 28   R_1rCGrMTNCSgzlep     10/1/20 14:07  IP Address       100        TRUE
# 29   R_1HksZPLwptmI0jX     10/1/20 14:08  IP Address       100        TRUE
# 30   R_3nrvRB9rp1gIjBs     10/1/20 14:08  IP Address       100        TRUE
# 31   R_21ogAvLp7d36qqW     10/1/20 14:08  IP Address       100        TRUE
# 32   R_XuZn2HckP0Kb94d     10/1/20 14:09  IP Address       100        TRUE
# 33   R_2i6loraoiQh4mtz     10/1/20 14:10  IP Address       100        TRUE
# 34   R_3kqdN5s9rIMxIbW     10/1/20 14:10  IP Address       100        TRUE
# 35   R_3fZTS7YZsOgvgLM     10/1/20 14:10  IP Address       100        TRUE
# 36   R_ex4O7yqMdnNIAfL     10/1/20 14:11  IP Address       100        TRUE
# 37   R_3HidL2LaGIlqCy0     10/1/20 14:11  IP Address       100        TRUE
# 38   R_3kH6y9Wi0TBwgnH     10/1/20 14:12  IP Address       100        TRUE
# 39   R_3gLt41UA6aTK5iw     10/1/20 14:12  IP Address       100        TRUE
# 40   R_2dzu9r3ccYAkv4Q     10/1/20 14:13  IP Address       100        TRUE
# 41   R_QhMoKyWgriJMaad     10/1/20 14:13  IP Address       100        TRUE
# 42   R_277D0uNSAuCYkRj     10/1/20 14:14  IP Address       100        TRUE
# 43   R_1r1gOcKhQUnlMYm     10/1/20 14:14  IP Address       100        TRUE
# 44   R_1rufxy3l5GJD63n     10/1/20 14:14  IP Address       100        TRUE
# 45   R_3GjrMwjY0f2fmmX     10/1/20 14:16  IP Address       100        TRUE
# 46   R_3s4UHRB7BlobVWb     10/1/20 14:16  IP Address       100        TRUE
# 47   R_xFuvGzQaNzAuZyh     10/1/20 14:17  IP Address       100        TRUE
# 48   R_26kTPGkH8j9qeIV     10/1/20 14:17  IP Address       100        TRUE
# 49   R_1QQ48w7zPEZ7kGt     10/1/20 14:17  IP Address       100        TRUE
# 50   R_R3KuOywbfyopApr     10/1/20 14:19  IP Address       100        TRUE
# 51   R_3HBaK6jQIamXIps     10/1/20 14:22  IP Address       100        TRUE
# 52   R_Tpi9jG206VKmz9D     10/1/20 14:33  IP Address       100        TRUE
# 53   R_3F4FT2lUXu8U23s     10/1/20 14:36  IP Address       100        TRUE
# 54   R_sR6RH8z89Ulq8vf     10/1/20 14:38  IP Address       100        TRUE
# 55   R_3q8zcT1bRayhWk8     10/1/20 14:44  IP Address       100        TRUE
# 56   R_p9rDLmewYA2Fagh     10/1/20 14:45  IP Address       100        TRUE
# 57   R_3lXJ5hWuepJ6WLa     10/1/20 15:34  IP Address       100        TRUE
# 58  FS_Pvvf27klRGTjmIp                    IP Address         1       FALSE
# 59  FS_Xk4jjhD7d54HjJT                    IP Address         1       FALSE
# 60  FS_1dBlMB6Zi7jyiCJ                    IP Address         1       FALSE
#
#     duration  duration_min  num_snippets                   prolific_id
# 11      1511            26            97      5865dd647fbbcd00013973b8
# 12      1160            20           108      5be385ba24f70e00018b0024
# 13      1310            22           169      5e93301515768a1680c9705a
# 14      1343            23           151      5ec6b3ce04e80f0c9a211c5b
# 15      1229            21            42      5df7eeb4cc6822000ac81b07
# 16      1696            29            87      5edede64402f7d18f040266e
# 17      1457            25            88      5d2b153afa24ba00173e8ee0
# 18      1181            20            68      5d6c12352e6bbb001a122cef
# 19      1748            30           112      5f2097ac626bc33b28c2cbf9
# 20      1347            23            65      5d722d644fee74001adb559d
# 21      1778            30            32      5dc1e711900e3e15813f7c38
# 22      1731            29            83      5f20a219f055ba1937476de0
# 23      1483            25            99      5eb0cb5afb9e2418da928edb
# 24      1358            23            96      5e1a24eb644d102a0efee857
# 25      1666            28            69      5e830913ff38e3016d1a69f2
# 26      1670            28            65      5eed7950a383181a9932bc1b
# 27      1395            24           169      5d8c7194caeeef001985baf6
# 28      1531            26           250      5f23f9035554f32008f8a35e
# 29      1814            31            70      5bc0878f85819f0001352ab4
# 30      1495            25            93      5eee7e5812de8e32ecde556c
# 31      1803            31            50      5d60061e45714d00019ad6a4
# 32      1783            30            74      5d7b76581390440019b3b928
# 33      1717            29            95  5f450efcb34be707606d05d4
# 34      1738            29            88      5e3844c9244f9d04ebae9b97
# 35      1896            32            85      5ef50bc0cb480c14a8f60d38
# 36      1925            33            69      5eccb086d314a0887ac5c3b5
# 37      1647            28            93      5ec32348079dcc17451cac16
# 38      2004            34            79      5eb2c8d889123905858e3c20
# 39      1698            29           134      5eeb082290a5841cc8b050eb
# 40      2283            39           141      5ec4492f675098327a7215d4
# 41      1921            33            58      5f4d12488c7b550aec05845d
# 42      2139            36           144      5f05fa1557d36f0f2bacae60
# 43      1897            32           131      5b903f42e4af15000161b7e3
# 44      2107            36           105      5f1f8b9757a75219b864718c
# 45      2150            36           193      5ed307fdb265ab1797983f68
# 46      2390            40           144      5e5bd012663c673b04bcdf42
# 47      2294            39           103      5f623039ea3ae10fb5bde11d
# 48      1724            29           110      5e89e620419be567b408e236
# 49      2216            37           160      5f3020ed291f7344af6d82e1
# 50      2175            37           306      5ee3348f8cfe2d49e6dc98ff
# 51       910            16           108      5a0ccf780fff620001a6c8a9
# 52      3403            57            96      5e6d403dfc5eff000b8329a5
# 53      3716            62           426      5f5797583cbc65245d493954
# 54      2973            50           111      5f6b3dbc7a71cb2393732fa5
# 55      3649            61           100      5eb1550ac73caa039c6986db
# 56      4273            72           459      5f661b5e3512a71b39229e76
# 57      1492            25            86      5f53bb278de59a6d87e53aab
# 58         1             1             1      5cbb779ffb8dfe0015839672
# 59         1             1            19      5f23f9035554f32008f8a35e
# 60         1             1           101      5cffec8eb5f15d0017b5dbca

# %%
# Create a mapping from unique text IDs to all of the text snippets that were hilighted in these survey results.
unique_text_id_to_snippet_list = {}
for unique_text_id,row_indices in df.groupby("id", axis=0).groups.items():
    hilighted_texts_list = list(df.iloc[row_indices]["snippet"].values)
    unique_text_id_to_snippet_list[unique_text_id] = hilighted_texts_list
print(unique_text_id_to_snippet_list)
# Out:
# {1: ['sleep disorder', 'sleep phase syndrome'], 8: ['Apolipoprotein E levels in cerebrospinal fluid ', 'effects of ABCA1 polymorphisms.', 'HDL cholesterol level', 'ABCA1 sequence variation confirms association with dementia.'], 12: ['dementia'], 14: ['C allele', 'HDL cholesterol'], 16: ['aka c.7093G>', 'p.Asp2365Asn'], 18: ['rare mutation', 'surfactant metabolism dysfunction', 'pulmonary', 'type 3', 'disorder involving severe neonatal distress', 'death of a newborn', 'ambiguous flip confusion'], 20: ["late-onset Alzheimer's disease", 'could result in defective protein function'], 23: ["late onset Alzheimer's disease"], 24: ["Alzheimer's disease", 'ABCA7', 'rs72973581(A)', ' p.G215S'], 30: ['adverse side effects', 'depression ', 'depression ', 'depression '], 33: ['intracerebral concentrations of certain drugs', 'relationships for selective serotonin reuptake inhibitors', 'antidepressant drugs'], 34: ['were more likely to remit', 'depression', 'major depression'], 38: ["A Danish case-control study comprising 373 Crohn's disease"], 40: ['depression', 'depression', 'depression'], 41: ['depression'], 43: ['woman at between 2-fold to 16-fold', 'intrahepatic cholestasis of pregnancy'], 44: ['rs58238559(C) allele', '3.75-fold increase in the probability of developing atrial fibrillation/flutter'], 45: ['wet vs dry earwax', 'sweat production', 'lipid secretion', 'wet vs dry earwax', 'sweat production', 'lipid secretion', 'East Asians and (C;C) for Europeans and Africans', '(T;T) for ', 'genotypically nonodorous', 'risk of breast cancer', 'Caucasian women'], 47: ['invasive breast cancer', 'shorter recurrence-free survival', 'higher risk of recurrence'], 48: ['intrahepatic cholestasis of pregnancy (ICP)', 'remature birth', 'intrauterine death', 'intrahepatic cholestasis of pregnancy (ICP)', 'Argentinian', 'premature birth', 'intrauterine death'], 50: ['myocardial infarction', 'human multidrug resistance protein', 'multidrug resistance', 'myocardial infarction'], 52: ['familial combined hyperlipidemia'], 58: ['chronic renal insufficiency', 'focal or diffuse congenital hyperinsulinism', 'neonatal diabetes', 'dominant, recessive, or compound heterozygous SUR1 mutations'], 61: ['rs11046205', 'Drosophila'], 66: ['deafness', 'dystonia', 'cerebral hypomyelination (DDCH)', 'Chromosome Xq28 deletion syndrome'], 69: ['adrenoleukodystrophy', 'mutation'], 79: ['ALD Mutation'], 81: ['uric acid concentrations'], 85: ['significantly associated with gout', 'associated with the ROL gout subtype', 'urinary urate excretion (UUE) is over 25.0\u2005mg/h/1.73\u2005m2'], 88: ['dyslipidemia ', 'carotid artery disease'], 90: ['Influences ABO blood groupABO Blood Type', 'Influences ABO blood group', 'ABO Blood Type'], 100: ['ABO blood group'], 104: ['infection', 'cystic fibrosis lung disease severity'], 105: ['SNP', 'ABO gene', 'blood group type', 'genosets'], 110: ['polymorphisms'], 115: ['Medium-Chain', 'Acyl-CoA', 'Dehydrogenase Deficiency'], 116: ['Acyl-CoA', 'Dehydrogenase', 'eficiencyrs', 'Medium-Chain Acyl-CoA Dehydrogenase Deficiency'], 117: ['Medium-Chain Acyl-CoA Dehydrogenase Deficiency'], 118: ['Dehydrogenase Deficiency'], 127: ['c.848T>C (p.Val283Ala or V283A)'], 131: ['pathogenic variant', 'NM_000019', 'ACAT1', '149delC ', 'Thr50Asnfs', 'OMIM', 'pathogenic '], 139: ['diabetic nephropathy'], 140: ['G12269A'], 143: ['obesity', 'the highest carbohydrate intake', 'respond better to Viagra', 'erectile dysfunction', 'higher risk for early-onset psoriasis', 'carbohydrate intake', 'morbidly obese', 'extreme obesity with the highest carbohydrate intake'], 146: ['infection by malaria', 'Duffy blood group FY(bwk) phenotype', 'Duffy blood group (antigen) on red blood cells', 'lower amounts of DARC protein', 'lower antigen expression', 'chemokine binding ability', 'malaria'], 154: ['Focal segmental glomerulosclerosis'], 155: ['Focal segmental glomerulosclerosis'], 160: ['type-1 diabetes'], 164: ["Alzheimer's disease"], 167: ['asthma', 'bronchial hyperresponsive ...

# %%
# Use that mapping to create a version of the original dataframe with just the hilighted text snippets.
subset_df = original_df.copy(deep=True)[original_df["id"].isin(unique_text_id_to_snippet_list.keys())]
subset_df["n"] = subset_df["id"].map(lambda x: len(unique_text_id_to_snippet_list[x]))
text_snippets = flatten([unique_text_id_to_snippet_list[i] for i in subset_df["id"].values])

# Extend the dataframe to duplicate each row n times where n is the number of text hilight results from the surveys.
modified_df = subset_df.reindex(np.repeat(subset_df.index.values, subset_df["n"]), method="ffill")

# Make sure that the extension occured as expected based on the number of text snippets, and add them as a new column.
assert len(modified_df) == len(text_snippets)
modified_df["snippet"] = text_snippets
modified_df.head(20)
# Out:
#       gene          snp                                               text  \
# 0    AANAT   Rs28936679  rs28936679, also known as Ala129Thr or A129T (...
# 0    AANAT   Rs28936679  rs28936679, also known as Ala129Thr or A129T (...
# 7    ABCA1    Rs2066715  Apolipoprotein E levels in cerebrospinal fluid...
# 7    ABCA1    Rs2066715  Apolipoprotein E levels in cerebrospinal fluid...
# 7    ABCA1    Rs2066715  Apolipoprotein E levels in cerebrospinal fluid...
# 7    ABCA1    Rs2066715  Apolipoprotein E levels in cerebrospinal fluid...
# 11   ABCA1     Rs363717  Examining the effect of linkage disequilibrium...
# 13   ABCA1    Rs4149274  C allele is associated with 1.51mg/dl increase...
# 13   ABCA1    Rs4149274  C allele is associated with 1.51mg/dl increase...
# 19  ABCA12     Rs726070  aka c.7093G>A (p.Asp2365Asn)The variant allele...
# 19  ABCA12     Rs726070  aka c.7093G>A (p.Asp2365Asn)The variant allele...
# 21   ABCA3  Rs149989682  rs149989682, also known as c.875A>T, p.Glu292V...
# 21   ABCA3  Rs149989682  rs149989682, also known as c.875A>T, p.Glu292V...
# 21   ABCA3  Rs149989682  rs149989682, also known as c.875A>T, p.Glu292V...
# 21   ABCA3  Rs149989682  rs149989682, also known as c.875A>T, p.Glu292V...
# 21   ABCA3  Rs149989682  rs149989682, also known as c.875A>T, p.Glu292V...
# 21   ABCA3  Rs149989682  rs149989682, also known as c.875A>T, p.Glu292V...
# 21   ABCA3  Rs149989682  rs149989682, also known as c.875A>T, p.Glu292V...
# 23   ABCA7  Rs115550680  A 2013 meta-analysis comprising a total of ~2,...
# 23   ABCA7  Rs115550680  A 2013 meta-analysis comprising a total of ~2,...
#
#     id  n                                            snippet
# 0    1  2                                     sleep disorder
# 0    1  2                               sleep phase syndrome
# 7    8  4    Apolipoprotein E levels in cerebrospinal fluid
# 7    8  4                    effects of ABCA1 polymorphisms.
# 7    8  4                              HDL cholesterol level
# 7    8  4  ABCA1 sequence variation confirms association ...
# 11  12  1                                           dementia
# 13  14  2                                           C allele
# 13  14  2                                    HDL cholesterol
# 19  16  2                                       aka c.7093G>
# 19  16  2                                       p.Asp2365Asn
# 21  18  7                                      rare mutation
# 21  18  7                  surfactant metabolism dysfunction
# 21  18  7                                          pulmonary
# 21  18  7                                             type 3
# 21  18  7        disorder involving severe neonatal distress
# 21  18  7                                 death of a newborn
# 21  18  7                           ambiguous flip confusion
# 23  20  2                     late-onset Alzheimer's disease
# 23  20  2         could result in defective protein function

# %%
# Check all IDs for unique texts and see how many times they were annotated here.
id_to_num_annotations = {}
for i in original_df["id"].values:
    # This ID was annotated atleast once, it was in the results dataframe for this survey.
    if i in snippets_per_id:
        id_to_num_annotations[i] = snippets_per_id[i]
    else:
        id_to_num_annotations[i] = 0

# Save that information to a file.
num_ann_df = pd.DataFrame({"id":list(id_to_num_annotations.keys()),"num_highlights":list(id_to_num_annotations.values())})
num_ann_df.to_csv(NUM_ANNOTATIONS_PATH, index=False)
num_ann_df.head(10)
# Out:
#    id  num_highlights
# 0   1               2
# 1   2               0
# 2   3               0
# 3   4               0
# 4   5               0
# 5   6               0
# 6   7               0
# 7   8               4
# 8   9               0
# 9  10               0

# %%
# Save that dataframe as a new CSV file with just the final cleaned text snippets for each gene and SNP.
modified_df = modified_df[["gene","snp","snippet"]]
modified_df.sort_values(by="gene", inplace=True)
modified_df.to_csv(SNPS_AND_SNIPPETS_OUTPUT_PATH, index=False)
modified_df.head(20)
# Out:
#       gene          snp                                            snippet
# 0    AANAT   Rs28936679                                     sleep disorder
# 0    AANAT   Rs28936679                               sleep phase syndrome
# 7    ABCA1    Rs2066715    Apolipoprotein E levels in cerebrospinal fluid
# 7    ABCA1    Rs2066715                    effects of ABCA1 polymorphisms.
# 7    ABCA1    Rs2066715                              HDL cholesterol level
# 7    ABCA1    Rs2066715  ABCA1 sequence variation confirms association ...
# 11   ABCA1     Rs363717                                           dementia
# 13   ABCA1    Rs4149274                                           C allele
# 13   ABCA1    Rs4149274                                    HDL cholesterol
# 19  ABCA12     Rs726070                                       aka c.7093G>
# 19  ABCA12     Rs726070                                       p.Asp2365Asn
# 21   ABCA3  Rs149989682                           ambiguous flip confusion
# 21   ABCA3  Rs149989682                                 death of a newborn
# 21   ABCA3  Rs149989682                                             type 3
# 21   ABCA3  Rs149989682        disorder involving severe neonatal distress
# 21   ABCA3  Rs149989682                  surfactant metabolism dysfunction
# 21   ABCA3  Rs149989682                                      rare mutation
# 21   ABCA3  Rs149989682                                          pulmonary
# 27   ABCA7   Rs72973581                                      rs72973581(A)
# 23   ABCA7  Rs115550680                     late-onset Alzheimer's disease

# %%
# How many genes had atleast one snippet associated to it in these results?
len(modified_df["gene"].unique())
# Out:
# 814

# %%
# Create a version of the dataset with mapping genes and SNPs to context sentences.
subset_df = original_df.copy(deep=True)[original_df["id"].isin(id_to_context_sentences.keys())]
subset_df["n"] = subset_df["id"].map(lambda x: len(id_to_context_sentences[x]))
sentences = flatten([id_to_context_sentences[i] for i in subset_df["id"].values])

# Extend the dataframe to duplicate each row n times where n is the number of text hilight results from the surveys.
modified_df = subset_df.reindex(np.repeat(subset_df.index.values, subset_df["n"]), method="ffill")

# Make sure that the extension occured as expected based on the number of text snippets, and add them as a new column.
assert len(modified_df) == len(sentences)
modified_df["context"] = sentences
modified_df.head(20)
# Out:
#       gene          snp                                               text  \
# 0    AANAT   Rs28936679  rs28936679, also known as Ala129Thr or A129T (...
# 7    ABCA1    Rs2066715  Apolipoprotein E levels in cerebrospinal fluid...
# 11   ABCA1     Rs363717  Examining the effect of linkage disequilibrium...
# 13   ABCA1    Rs4149274  C allele is associated with 1.51mg/dl increase...
# 19  ABCA12     Rs726070  aka c.7093G>A (p.Asp2365Asn)The variant allele...
# 21   ABCA3  Rs149989682  rs149989682, also known as c.875A>T, p.Glu292V...
# 23   ABCA7  Rs115550680  A 2013 meta-analysis comprising a total of ~2,...
# 26   ABCA7    Rs4147929  rs4147929 is a SNP in the ATP-binding cassette...
# 27   ABCA7   Rs72973581  A sequencing study of 332 sporadic Alzheimer's...
# 33   ABCB1   Rs11983225  rs11983225 is a SNP in the ABCB1 gene (also kn...
# 33   ABCB1   Rs11983225  rs11983225 is a SNP in the ABCB1 gene (also kn...
# 33   ABCB1   Rs11983225  rs11983225 is a SNP in the ABCB1 gene (also kn...
# 36   ABCB1    Rs2032583  rs2032583 is a SNP in the ABCB1 gene (also kno...
# 37   ABCB1    Rs2235015  rs2235015 is a SNP in the ABCB1 gene (also kno...
# 41   ABCB1    Rs3789243  A Danish case-control study comprising 373 Cro...
# 43   ABCB1    Rs4148739  rs4148739 is a SNP in the ABCB1 gene (also kno...
# 43   ABCB1    Rs4148739  rs4148739 is a SNP in the ABCB1 gene (also kno...
# 43   ABCB1    Rs4148739  rs4148739 is a SNP in the ABCB1 gene (also kno...
# 44   ABCB1    Rs4148740  is a SNP in the ABCB1 gene (also known as the ...
# 44   ABCB1    Rs4148740  is a SNP in the ABCB1 gene (also known as the ...
#
#     id  n                                            context
# 0    1  1  Its activity increases 10- to 100-fold at nigh...
# 7    8  1  A survey of ABCA1 sequence variation confirms ...
# 11  12  1  A survey of ABCA1 sequence variation confirms ...
# 13  14  1  C allele is associated with 1.51mg/dl increase...
# 19  16  1  Aka c.7093G>A (p.Asp2365Asn) The variant allel...
# 21  18  1  rs149989682, also known as c.875A>T, p.Glu292V...
# 23  20  1  The deleted allele could result in defective p...
# 26  23  1  rs4147929 is a SNP in the ATP-binding cassette...
# 27  24  1  A sequencing study of 332 sporadic Alzheimers ...
# 33  30  3  According to a recent review, ten studies repo...
# 33  30  3  The list of the 9 SNPs is shown below.When tre...
# 33  30  3  A well-run, double-blind study of ABCB1 substr...
# 36  33  1  Clinical studies on antidepressant drug dosage...
# 37  34  1  However, this result could not be reproduced i...
# 41  38  1  A Danish case-control study comprising 373 Cro...
# 43  40  3  According to a recent review, ten studies repo...
# 43  40  3  The list of the 9 SNPs is shown below.When tre...
# 43  40  3  A well-run, double-blind study of ABCB1 substr...
# 44  41  3  According to a recent review, ten studies repo...
# 44  41  3  The list of the 9 SNPs is shown below.When tre...

# %%
# Save that dataframe as a new CSV file with just the contexts for each gene and SNP.
modified_df = modified_df[["gene","snp","context"]]
modified_df.sort_values(by="gene", inplace=True)
modified_df.to_csv(SNPS_AND_CONTEXTS_OUTPUT_PATH, index=False)
modified_df.head(20)
# Out:
#       gene          snp                                            context
# 0    AANAT   Rs28936679  Its activity increases 10- to 100-fold at nigh...
# 7    ABCA1    Rs2066715  A survey of ABCA1 sequence variation confirms ...
# 11   ABCA1     Rs363717  A survey of ABCA1 sequence variation confirms ...
# 13   ABCA1    Rs4149274  C allele is associated with 1.51mg/dl increase...
# 19  ABCA12     Rs726070  Aka c.7093G>A (p.Asp2365Asn) The variant allel...
# 21   ABCA3  Rs149989682  rs149989682, also known as c.875A>T, p.Glu292V...
# 23   ABCA7  Rs115550680  The deleted allele could result in defective p...
# 26   ABCA7    Rs4147929  rs4147929 is a SNP in the ATP-binding cassette...
# 27   ABCA7   Rs72973581  A sequencing study of 332 sporadic Alzheimers ...
# 44   ABCB1    Rs4148740  A well-run, double-blind study of ABCB1 substr...
# 44   ABCB1    Rs4148740  The list of the 9 SNPs is shown below.When tre...
# 43   ABCB1    Rs4148739  A well-run, double-blind study of ABCB1 substr...
# 43   ABCB1    Rs4148739  The list of the 9 SNPs is shown below.When tre...
# 43   ABCB1    Rs4148739  According to a recent review, ten studies repo...
# 44   ABCB1    Rs4148740  According to a recent review, ten studies repo...
# 37   ABCB1    Rs2235015  However, this result could not be reproduced i...
# 36   ABCB1    Rs2032583  Clinical studies on antidepressant drug dosage...
# 33   ABCB1   Rs11983225  A well-run, double-blind study of ABCB1 substr...
# 41   ABCB1    Rs3789243  A Danish case-control study comprising 373 Cro...
# 33   ABCB1   Rs11983225  The list of the 9 SNPs is shown below.When tre...
