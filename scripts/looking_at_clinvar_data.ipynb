# %%
import pandas as pd

# %%
CLINVAR_FILEPATH = "../other/gene_condition_source_id.txt"

# %%
df = pd.read_table(CLINVAR_FILEPATH)
df.head(10)
# Out:
#    #GeneID AssociatedGenes RelatedGenes ConceptID  \
# 0        2             A2M          NaN  C0002395
# 1   144568           A2ML1          NaN  C1833692
# 2    53947          A4GALT          NaN  C3549485
# 3     8086            AAAS          NaN  C0271742
# 4    79719           AAGAB          NaN  C1835662
# 5       16           AARS1          NaN  C4225361
# 6       16           AARS1          NaN  C2750090
# 7    57505           AARS2          NaN  C3279793
# 8    57505           AARS2          NaN  C4014588
# 9    10157            AASS          NaN  C0543533
#
#                                          DiseaseName  \
# 0                                  Alzheimer disease
# 1                    Otitis media, susceptibility to
# 2                                        p phenotype
# 3           Glucocorticoid deficiency with achalasia
# 4                  Keratosis palmoplantaris papulosa
# 5      Epileptic encephalopathy, early infantile, 29
# 6               Charcot-Marie-Tooth disease, type 2N
# 7    Combined oxidative phosphorylation deficiency 8
# 8  Leukoencephalopathy, progressive, with ovarian...
# 9                                     Hyperlysinemia
#
#                  SourceName    SourceID  DiseaseMIM  LastUpdated
# 0  Human Phenotype Ontology  HP:0002511    104300.0  Feb 19 2020
# 1             NCBI curation         NaN    166760.0  Feb 16 2016
# 2             NCBI curation         NaN    111400.0  Feb 16 2016
# 3                       NaN         NaN    231550.0  Feb 16 2016
# 4                       NaN         NaN    148600.0  Feb 16 2016
# 5             NCBI curation         NaN    616339.0  Feb 16 2016
# 6             NCBI curation         NaN    613287.0  Feb 16 2016
# 7             NCBI curation         NaN    614096.0  Feb 16 2016
# 8             NCBI curation         NaN    615889.0  Feb 16 2016
# 9  Human Phenotype Ontology  HP:0002161    238700.0  Feb 16 2016

# %%
df = df[["AssociatedGenes","DiseaseName"]]
df.columns = ["gene", "disease"]
df.to_csv("../genes_and_diseases.tsv", sep="\t", index=False)
df.head(10)
# Out:
#      gene                                            disease
# 0     A2M                                  Alzheimer disease
# 1   A2ML1                    Otitis media, susceptibility to
# 2  A4GALT                                        p phenotype
# 3    AAAS           Glucocorticoid deficiency with achalasia
# 4   AAGAB                  Keratosis palmoplantaris papulosa
# 5   AARS1      Epileptic encephalopathy, early infantile, 29
# 6   AARS1               Charcot-Marie-Tooth disease, type 2N
# 7   AARS2    Combined oxidative phosphorylation deficiency 8
# 8   AARS2  Leukoencephalopathy, progressive, with ovarian...
# 9    AASS                                     Hyperlysinemia
