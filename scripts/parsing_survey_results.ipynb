# %%
import pandas as pd
import numpy as np
import json
import math
import random
import datetime
import re
from collections import Counter
from utils import flatten
from nltk.tokenize import sent_tokenize

# %%
# JSON file from parsing the results of the qualtrics survey designed for extracting phenotypes from text.
QUALTRICS_RAW_CSV_EXPORT_PATH = "../qualtrics/results_raw_qualtrics_exports/SNPedia Survey_September 22, 2020_13.29.csv"
QUALTRICS_RESULTS_JSON_PATH = "../qualtrics/results_processed_json_files/snpedia_survey_september_22_2020_h13_m29.json"

# What the survey was built from, the IDs in this refer to unique text strings so that duplicates weren't part of it.
SURVEY_SOURCE_DATA_PATH = "../data/4_binned_and_blocked_texts.csv"

# This is the original data with duplicate text strings because IDs refer to particular SNPs from particular genes.
ORIGINAL_DATA_PATH = "../data/2_snps_and_cleaned_text.csv"

# Where to send the resulting output dataframes as CSV files.
random_six_digit_number = random.randrange(100000,999999)
datetime_str = datetime.datetime.now().strftime('%m_%d_%Y_h%Hm%Ms%S')

FILENAMES_OUTPUT_PATH = "../data/S{}_input_file_paths_{}.txt".format(random_six_digit_number, datetime_str)
RESPONSES_OUTPUT_PATH = "../data/S{}_processed_survey_responses_{}.csv".format(random_six_digit_number, datetime_str)
SURVEY_TAKERS_OUTPUT_PATH = "../data/S{}_processed_survey_takers_{}.csv".format(random_six_digit_number, datetime_str)
SNPS_AND_SNIPPETS_OUTPUT_PATH = "../data/S{}_snps_and_snippets_{}.csv".format(random_six_digit_number, datetime_str)
SNPS_AND_CONTEXTS_OUTPUT_PATH = "../data/S{}_snps_and_contexts_{}.csv".format(random_six_digit_number, datetime_str)

# %%
with open(FILENAMES_OUTPUT_PATH, "w") as f:
    filenames = [
        ORIGINAL_DATA_PATH,
        SURVEY_SOURCE_DATA_PATH,
        QUALTRICS_RAW_CSV_EXPORT_PATH,
        QUALTRICS_RESULTS_JSON_PATH]
    filenames = "\n".join(filenames)
    f.write(filenames)

# %%
# Make sure the mapping between the unique texts used to create the survey and the original SNP data exists.
original_df = pd.read_csv(ORIGINAL_DATA_PATH)
survey_df = pd.read_csv(SURVEY_SOURCE_DATA_PATH)
text_to_unique_text_id = dict(zip(survey_df.text, survey_df.id))
unique_text_id_to_text = dict(zip(survey_df.id, survey_df.text))
original_df["id"] = original_df["text"].map(text_to_unique_text_id)
original_df.head(20)
# Out:
#       gene         snp                                               text  \
# 0    AANAT  Rs28936679  rs28936679, also known as Ala129Thr or A129T (...
# 1    AANAT   Rs3760138  Genetic differences in human circadian clock g...
# 2    AANAT   Rs4238989  Genetic differences in human circadian clock g...
# 3    ABCA1   Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...
# 4    ABCA1   Rs1883025  Apolipoprotein E levels in cerebrospinal fluid...
# 5    ABCA1   Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...
# 6    ABCA1   Rs2066714  Apolipoprotein E levels in cerebrospinal fluid...
# 7    ABCA1   Rs2066715  Apolipoprotein E levels in cerebrospinal fluid...
# 8    ABCA1   Rs2230806  rs2230806, also known as Arg219Lys or R219K, i...
# 9    ABCA1   Rs2230808  rs2297404, rs2230808, and rs2020927 haplotype ...
# 10   ABCA1   Rs2297404  rs2297404, rs2230808, and rs2020927 haplotype ...
# 11   ABCA1    Rs363717  Examining the effect of linkage disequilibrium...
# 12   ABCA1   Rs4149268  G allele is associated with 0.82mg/dl increase...
# 13   ABCA1   Rs4149274  C allele is associated with 1.51mg/dl increase...
# 14  ABCA12  Rs28940268  This is a recessive SNP for congenital Lamella...
# 15  ABCA12  Rs28940269  This is a recessive SNP for congenital Lamella...
# 16  ABCA12  Rs28940270  This is a recessive SNP for congenital Lamella...
# 17  ABCA12  Rs28940271  This is a recessive SNP for congenital Lamella...
# 18  ABCA12  Rs28940568  This is a recessive SNP for congenital Lamella...
# 19  ABCA12    Rs726070  aka c.7093G>A (p.Asp2365Asn)The variant allele...
#
#       id
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    7.0
# 7    8.0
# 8    9.0
# 9   10.0
# 10  11.0
# 11  12.0
# 12  13.0
# 13  14.0
# 14  15.0
# 15  15.0
# 16  15.0
# 17  15.0
# 18  15.0
# 19  16.0

# %%
# Create a dictionary using the JSON data output from a qualtrics survey.
with open(QUALTRICS_RESULTS_JSON_PATH) as f:
    responses = json.load(f)
responses
# Out:
# [{'response_id': 'R_eOSosrnczqYqE9P',
#   'recorded_datetime': '2020-09-22 10:37:23',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 1252,
#   'hilights': [{'qid': 4769, 'selection': 'Disease ', 'selection_index': 13},
#    {'qid': 5162,
#     'selection': 'Focal segmental glomerulosclerosis',
#     'selection_index': 0},
#    {'qid': 2451, 'selection': ' Alpha Thalassemia', 'selection_index': 23},
#    {'qid': 3964,
#     'selection': 'Congenital Disorder of Glycosylation',
#     'selection_index': 0},
#    {'qid': 5448, 'selection': 'schizophrenia.', 'selection_index': 54},
#    {'qid': 3027, 'selection': 'glaucoma', 'selection_index': 29},
#    {'qid': 2287,
#     'selection': 'Nonsyndromic Sensorineural',
#     'selection_index': 33},
#    {'qid': 2287, 'selection': 'Connexin', 'selection_index': 13},
#    {'qid': 1783, 'selection': 'schizophrenia', 'selection_index': 10},
#    {'qid': 628, 'selection': 'cholesterol', 'selection_index': 4},
#    {'qid': 628, 'selection': 'cholesterol', 'selection_index': 26},
#    {'qid': 628, 'selection': 'LDL ', 'selection_index': 0},
#    {'qid': 2515, 'selection': 'hemochromatosis', 'selection_index': 0},
#    {'qid': 3684, 'selection': 'Rheumatoid Arthritis', 'selection_index': 38},
#    {'qid': 4613, 'selection': 'rheumatoid arthritis', 'selection_index': 39},
#    {'qid': 2261, 'selection': 'cyclohydrolase', 'selection_index': 4},
#    {'qid': 2261, 'selection': 'tetrahydrobiopterin', 'selection_index': 23},
#    {'qid': 2215, 'selection': "Gaucher's disease", 'selection_index': 73},
#    {'qid': 2255, 'selection': 'Vasoocclusive Pain', 'selection_index': 51},
#    {'qid': 2255,
#     'selection': 'Impaired Vascular Function in Sickle Cell Anemia',
#     'selection_index': 74},
#    {'qid': 3271, 'selection': 'allopurinol.', 'selection_index': 87},
#    {'qid': 3271, 'selection': 'allele', 'selection_index': 11},
#    {'qid': 1380, 'selection': 'allele', 'selection_index': 83},
#    {'qid': 1840, 'selection': 'Hemophilia', 'selection_index': 78},
#    {'qid': 4559,
#     'selection': 'Lymphoproliferative syndrome',
#     'selection_index': 59},
#    {'qid': 2620, 'selection': 'chromosome 1', 'selection_index': 109},
#    {'qid': 838, 'selection': 'bronchial asthma', 'selection_index': 84},
#    {'qid': 2187, 'selection': 'Krabbe disease', 'selection_index': 73},
#    {'qid': 762, 'selection': 'breast cancer', 'selection_index': 128},
#    {'qid': 3780, 'selection': 'spitoonObesity', 'selection_index': 123},
#    {'qid': 730, 'selection': 'breast cancer', 'selection_index': 126},
#    {'qid': 4644, 'selection': 'Pendred Syndrome', 'selection_index': 142},
#    {'qid': 22, 'selection': "Alzheimer's disease", 'selection_index': 0},
#    {'qid': 5194, 'selection': 'Asthenozoospermia', 'selection_index': 157},
#    {'qid': 5015, 'selection': 'Polymorphisms', 'selection_index': 0},
#    {'qid': 5015, 'selection': ' breast cancer', 'selection_index': 69},
#    {'qid': 5015, 'selection': 'polymorphism', 'selection_index': 124},
#    {'qid': 5015,
#     'selection': 'thoracic adolescent idiopathic scoliosis.',
#     'selection_index': 216},
#    {'qid': 2023, 'selection': "Friedreich's ataxia", 'selection_index': 143},
#    {'qid': 2260, 'selection': 'capsaicin pain', 'selection_index': 219},
#    {'qid': 2260, 'selection': 'Polymorphisms', 'selection_index': 136},
#    {'qid': 2039, 'selection': "Friedreich's ataxia", 'selection_index': 154},
#    {'qid': 569, 'selection': 'rheumatic diseases', 'selection_index': 138},
#    {'qid': 1355, 'selection': 'breast cancer', 'selection_index': 18},
#    {'qid': 2793, 'selection': 'diabetes', 'selection_index': 148},
#    {'qid': 2568,
#     'selection': 'intermittent porphyria.',
#     'selection_index': 221},
#    {'qid': 3797, 'selection': ' type-2 diabetes', 'selection_index': 66},
#    {'qid': 3965, 'selection': 'Congenital disorder', 'selection_index': 186},
#    {'qid': 2512, 'selection': 'Tay Sachs', 'selection_index': 62},
#    {'qid': 5107, 'selection': 'torsion dystonia', 'selection_index': 191},
#    {'qid': 2919, 'selection': 'priapism', 'selection_index': 160},
#    {'qid': 3533, 'selection': 'Crohn disease', 'selection_index': 50},
#    {'qid': 3367, 'selection': 'abetalipoproteinemia', 'selection_index': 182},
#    {'qid': 3979, 'selection': 'endometrial cancer', 'selection_index': 369},
#    {'qid': 3979, 'selection': 'colorectal cancer', 'selection_index': 249},
#    {'qid': 858, 'selection': 'hypertension', 'selection_index': 169},
#    {'qid': 289, 'selection': 'breast cancer', 'selection_index': 184},
#    {'qid': 3836, 'selection': 'endometrial cancer', 'selection_index': 49},
#    {'qid': 3836, 'selection': 'breast cancer risk', 'selection_index': 623},
#    {'qid': 5430,
#     'selection': 'epithelial ovarian cancer',
#     'selection_index': 356},
#    {'qid': 2853, 'selection': 'cardiac arrhythmias', 'selection_index': 257},
#    {'qid': 2375, 'selection': 'stuttering', 'selection_index': 197},
#    {'qid': 4594, 'selection': 'Andermann syndrome', 'selection_index': 192},
#    {'qid': 3078, 'selection': " Raynaud's phenomenon", 'selection_index': 390},
#    {'qid': 1276,
#     'selection': 'Schizophrenia Susceptibility Genetic',
#     'selection_index': 555},
#    {'qid': 3985,
#     'selection': 'cumulative risk of developing CRC',
#     'selection_index': 415},
#    {'qid': 4718,
#     'selection': 'Association of serotonin transporter gene variation with smoking, chronic obstructive pulmonary disease, and its depressive symptoms',
#     'selection_index': 782},
#    {'qid': 3551, 'selection': 'lung cancer.', 'selection_index': 1379},
#    {'qid': 3551,
#     'selection': 'rinary bladder cancer pathogenesis',
#     'selection_index': 1741},
#    {'qid': 3551,
#     'selection': 'diabetes-associated combination of SNPs',
#     'selection_index': 1047},
#    {'qid': 3551,
#     'selection': 'synthase gene polymorphisms and prostate cancer risk.',
#     'selection_index': 866},
#    {'qid': 3551, 'selection': "Parkinson's disease", 'selection_index': 607},
#    {'qid': 5031, 'selection': 'leukemia', 'selection_index': 1476},
#    {'qid': 5031, 'selection': 'prostate cancer', 'selection_index': 576},
#    {'qid': 83, 'selection': 'heterozygotes', 'selection_index': 834},
#    {'qid': 83, 'selection': 'Atherosclerosis Risk', 'selection_index': 500},
#    {'qid': 4475,
#     'selection': 'chronic liver disease',
#     'selection_index': 1082},
#    {'qid': 4475,
#     'selection': 'Granulomatosis with Polyangiitis',
#     'selection_index': 615},
#    {'qid': 4475,
#     'selection': 'emphysema and liver disease.',
#     'selection_index': 333},
#    {'qid': 2840, 'selection': 'Bipolar Disorder', 'selection_index': 2613},
#    {'qid': 2840,
#     'selection': 'Autism-spectrum disorders',
#     'selection_index': 1769},
#    {'qid': 2840, 'selection': 'depressive disorder.', 'selection_index': 3235},
#    {'qid': 2840,
#     'selection': 'major depressive disorder',
#     'selection_index': 3423},
#    {'qid': 2840, 'selection': 'psychiatric illness,', 'selection_index': 1012},
#    {'qid': 2759, 'selection': "Crohn's disease", 'selection_index': 221},
#    {'qid': 2759, 'selection': "Crohn's Disease", 'selection_index': 540},
#    {'qid': 1158, 'selection': 'lung cancer', 'selection_index': 903},
#    {'qid': 1158, 'selection': 'Artery Disease', 'selection_index': 1927},
#    {'qid': 2475,
#     'selection': 'argely unexplained difference is the level of circulating virus in the plasma during the non-symptomatic phase preceding progression to AIDS.',
#     'selection_index': 1073},
#    {'qid': 2475,
#     'selection': 'This SNP is thought to be involved in determining the HIV viral load set point during the asymptomatic period of infection.',
#     'selection_index': 715},
#    {'qid': 2475,
#     'selection': 'This HLA allele, in turn, has been associated with several conditions',
#     'selection_index': 251},
#    {'qid': 28,
#     'selection': 'Polymorphisms in genes that regulate cyclosporine metabolism affect cyclosporine blood levels and clinical outcomes in patients who receive allogeneic hematopoietic stem cell transplantation.',
#     'selection_index': 6612},
#    {'qid': 28, 'selection': 'esophageal cancer.', 'selection_index': 5791},
#    {'qid': 28,
#     'selection': ' Pharmacogenetics of antidepressant response. Correlation between genetic polymorphisms',
#     'selection_index': 5465},
#    {'qid': 28,
#     'selection': 'rs1045642, also known as C3435T, is a SNP located in the ABCB1 gene. It is often studied in conjunction with rs2032582. C3435T has been mentioned by: A "Silent" Polymorphism in the MDR1 Gene Changes Substrate Specificity (for example, to verapamil) (R)-lansoprazole (Prevacid) concentrations are significantly increased in CYP2C19 extensive metabolizers with ABCB1 C3435T C allele. In a Korean population, plasma concentrations of fexofenadine (Allegra) were 17% lower in 2677AA/3435CC subjects and 47% higher in the 2677TT/3435TT subjects compared to 2677GG/3435CC subjects. In contrast, in this study no association was observed between the C3435T polymorphism and fexofenadine plasma or urine concentrations in a German Caucasian population. A meta-analysis including 9 case-control studies (totaling ~2,500 patients) found no association between rs1045642 and epilepsy riskA study of 98 methadone-maintaining patients concluded that the higher (>150 mg/day) and lower (< or =150 mg/day) methadone dose groups differed significantly in their rs1128503 status (experiment-wise p = 0.0325). Furthermore, individuals with the 3-locus genotype pattern (T;T)-(T;T)-(T;T) for SNPs rs1045642, rs2032582 and rs1128503, respectively, had an approximately 5-fold chance of requiring the \'higher\' methadone dose, while individuals heterozygous for these three SNPs have an approximately 3-fold chance of stabilizing at the \'lower\' methadone dose (point-wise p-value = 0.026). Identifying candidate causal variants responsible for altered activity of the ABCB1 multidrug resistance gene. Genetic predictors of the maximum doses patients receive during clinical use of the anti-epileptic drugs carbamazepine and phenytoin. ABCB1 genotypes and haplotypes in patients with dementia and age-matched non-demented control patients. Association of MDR1 genotypes with susceptibility to colorectal cancer in older non-smokers. Genetic studies of a cluster of acute lymphoblastic leukemia cases in Churchill County, Nevada. MDR1 gene variants, indoor insecticide exposure, and the risk of childhood acute lymphoblastic leukemia. No association between MDR1 (ABCB1) 2677G>T and 3435C>T polymorphism and sporadic colorectal cancer among Bulgarian patients. ABCB1 (MDR1) gene polymorphisms are associated with the clinical response to paroxetine in patients with major depressive disorder. Pharmacogenetics of minimal residual disease response in children with B-precursor acute lymphoblastic leukemia: a report from the Children\'s Oncology Group. Multiplexed genotyping of ABC transporter polymorphisms with the Bioplex suspension array. A PAI-1 (SERPINE1) polymorphism predicts osteonecrosis in children with acute lymphoblastic leukemia: a report from the Children\'s Oncology Group. Association of ABCB1 genetic variants with renal function in Africans and in Caucasians. Genotyping panel for assessing response to cancer chemotherapy. Polymorphisms affecting gene transcription and mRNA processing in pharmacogenetic candidate genes: detection through allelic expression imbalance in human target tissues. Bidirectional translational research: Progress in understanding addictive diseases. The pharmacokinetics and pharmacogenomics of efavirenz and lopinavir/ritonavir in HIV-infected persons requiring hemodialysis. No association of ABCB1 polymorphisms with drug-refractory epilepsy in a north Indian population. Germline genetic variations in drug action pathways predict clinical outcomes in advanced lung cancer treated with platinum-based chemotherapy. Prevalence in the United States of selected candidate gene variants: Third National Health and Nutrition Examination Survey, 1991-1994. Opiate and cocaine addiction: from bench to clinic and back to the bench. Investigation of candidate polymorphisms and disease activity in rheumatoid arthritis patients on methotrexate. Steroid biosynthesis and renal excretion in human essential hypertension: association with blood pressure and en ...
#     'selection_index': 0},
#    {'qid': 28, 'selection': 'arthritis', 'selection_index': 3838}]},
#  {'response_id': 'R_2XjJU6SMJAlU4I2',
#   'recorded_datetime': '2020-09-22 10:40:27',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 1074,
#   'hilights': [{'qid': 4622, 'selection': 'Skin color', 'selection_index': 0},
#    {'qid': 5199, 'selection': 'cardiac amyloidosis', 'selection_index': 12},
#    {'qid': 162,
#     'selection': "Alzheimer's disease assocation",
#     'selection_index': 10},
#    {'qid': 5160,
#     'selection': 'Focal segmental glomerulosclerosis',
#     'selection_index': 0},
#    {'qid': 5083, 'selection': 'dilated cardiomyopathy', 'selection_index': 11},
#    {'qid': 2151, 'selection': "Alzheimer's risk", 'selection_index': 20},
#    {'qid': 4923, 'selection': 'Leigh syndrome', 'selection_index': 0},
#    {'qid': 5133,
#     'selection': 'dilated cardiomyopathy.',
#     'selection_index': 81},
#    {'qid': 1766, 'selection': 'arterial calcification', 'selection_index': 56},
#    {'qid': 1766,
#     'selection': 'hypophosphatemic rickets',
#     'selection_index': 114},
#    {'qid': 75, 'selection': 'adrenoleukodystrophy', 'selection_index': 69},
#    {'qid': 3536,
#     'selection': 'inflammatory bowel disease',
#     'selection_index': 67},
#    {'qid': 4558,
#     'selection': 'Lymphoproliferative syndrome',
#     'selection_index': 60},
#    {'qid': 15,
#     'selection': 'congenital Lamellar ichthyosis',
#     'selection_index': 28},
#    {'qid': 15, 'selection': 'skin condition', 'selection_index': 109},
#    {'qid': 4534, 'selection': 'schizophrenia', 'selection_index': 61},
#    {'qid': 4534,
#     'selection': 'developmental disorders',
#     'selection_index': 79},
#    {'qid': 2685, 'selection': 'obesity', 'selection_index': 42},
#    {'qid': 2685, 'selection': 'insulin sensitivity', 'selection_index': 17},
#    {'qid': 3011,
#     'selection': 'Elevated HDL-Cholesterol',
#     'selection_index': 37},
#    {'qid': 983,
#     'selection': 'pathogenic rare mutation',
#     'selection_index': 73},
#    {'qid': 983,
#     'selection': 'hereditary diffuse gastric cancer',
#     'selection_index': 102},
#    {'qid': 2346, 'selection': 'fabry disease', 'selection_index': 14},
#    {'qid': 2346,
#     'selection': 'hypertrophic cardiomyopathy',
#     'selection_index': 71},
#    {'qid': 2346, 'selection': 'mental retardation', 'selection_index': 178},
#    {'qid': 1965,
#     'selection': 'glomerulopathy with fibronectin deposits',
#     'selection_index': 92},
#    {'qid': 5223, 'selection': 'gastric cancer.', 'selection_index': 183},
#    {'qid': 5223, 'selection': 'Polymorphisms', 'selection_index': 108},
#    {'qid': 385, 'selection': 'longevity', 'selection_index': 27},
#    {'qid': 1283, 'selection': 'hearing loss', 'selection_index': 136},
#    {'qid': 1283, 'selection': 'Cisplatin', 'selection_index': 185},
#    {'qid': 1762,
#     'selection': 'intracranial aneurysms',
#     'selection_index': 115},
#    {'qid': 3360,
#     'selection': 'single nucleotide polymorphisms',
#     'selection_index': 18},
#    {'qid': 3360, 'selection': 'prostate cancer risk', 'selection_index': 86},
#    {'qid': 3360,
#     'selection': 'pseudoexfoliation syndrome',
#     'selection_index': 183},
#    {'qid': 3360, 'selection': 'glaucoma', 'selection_index': 214},
#    {'qid': 1505, 'selection': 'myocardial infarction', 'selection_index': 114},
#    {'qid': 5174,
#     'selection': 'progressive familial heart block',
#     'selection_index': 172},
#    {'qid': 2753,
#     'selection': 'ankylosing spondylitis',
#     'selection_index': 143},
#    {'qid': 3874,
#     'selection': 'utosomal dominant polycystic kidney disease',
#     'selection_index': 146},
#    {'qid': 3868, 'selection': 'talipes equinovarus', 'selection_index': 170},
#    {'qid': 2568,
#     'selection': 'acute intermittent porphyria',
#     'selection_index': 215},
#    {'qid': 1917, 'selection': 'achondroplasia', 'selection_index': 184},
#    {'qid': 2048, 'selection': "Friedreich's ataxia", 'selection_index': 142},
#    {'qid': 1735,
#     'selection': 'pulmonary hypertension',
#     'selection_index': 163},
#    {'qid': 1735,
#     'selection': 'pulmonary capillary hemangiomatosis',
#     'selection_index': 201},
#    {'qid': 1735,
#     'selection': 'pulmonary venoocclusive disease',
#     'selection_index': 247},
#    {'qid': 2920, 'selection': 'priapism', 'selection_index': 160},
#    {'qid': 5107,
#     'selection': 'developing torsion dystonia',
#     'selection_index': 180},
#    {'qid': 4655, 'selection': 'type-2 diabetes', 'selection_index': 40},
#    {'qid': 3002,
#     'selection': 'familial male precocious puberty',
#     'selection_index': 127},
#    {'qid': 3838, 'selection': 'colorectal cancer', 'selection_index': 179},
#    {'qid': 1828,
#     'selection': 'deficiency-causing mutations',
#     'selection_index': 183},
#    {'qid': 2718, 'selection': "Graves' disease", 'selection_index': 63},
#    {'qid': 2718,
#     'selection': 'nasopharyngeal carcinoma',
#     'selection_index': 131},
#    {'qid': 2718,
#     'selection': 'adiation-induced toxicity',
#     'selection_index': 225},
#    {'qid': 2718,
#     'selection': 'risk of coronary artery disease',
#     'selection_index': 356},
#    {'qid': 2718, 'selection': 'gene polymorphism', 'selection_index': 406},
#    {'qid': 5449, 'selection': 'Pancreatic cancer', 'selection_index': 372},
#    {'qid': 4573,
#     'selection': 'potential breast cancer variant',
#     'selection_index': 12},
#    {'qid': 4573, 'selection': 'Ovarian cancer risk', 'selection_index': 44},
#    {'qid': 4852,
#     'selection': 'autosomal recessive spherocytosis',
#     'selection_index': 163},
#    {'qid': 819,
#     'selection': 'familial breast cancer risk',
#     'selection_index': 25},
#    {'qid': 819, 'selection': 'prostate cancer', 'selection_index': 236},
#    {'qid': 4294,
#     'selection': 'congenital myasthenic syndrome',
#     'selection_index': 354},
#    {'qid': 1732,
#     'selection': 'non-small cell lung cancer',
#     'selection_index': 208},
#    {'qid': 622,
#     'selection': "patient's attention levels.",
#     'selection_index': 474},
#    {'qid': 2773,
#     'selection': 'Visceral leishmaniasis',
#     'selection_index': 238},
#    {'qid': 2773, 'selection': 'Leishmania chagasi', 'selection_index': 276},
#    {'qid': 4857, 'selection': "Parkinson's disease", 'selection_index': 532},
#    {'qid': 3003,
#     'selection': 'mutations of the LH receptor gene',
#     'selection_index': 644},
#    {'qid': 565,
#     'selection': "increased risk for late-onset Alzheimer's disease",
#     'selection_index': 134},
#    {'qid': 3041,
#     'selection': 'altered risk for celiac disease',
#     'selection_index': 383},
#    {'qid': 3161,
#     'selection': 'undergo menopause early',
#     'selection_index': 484},
#    {'qid': 196,
#     'selection': 'increased risk of insulin resistance',
#     'selection_index': 195},
#    {'qid': 2845, 'selection': 'rheumatoid arthritis', 'selection_index': 486},
#    {'qid': 2158, 'selection': 'Alcoholism', 'selection_index': 47},
#    {'qid': 4166, 'selection': "Alzheimer's disease", 'selection_index': 289},
#    {'qid': 5424,
#     'selection': 'squamous cell cancer risk',
#     'selection_index': 301},
#    {'qid': 5424, 'selection': 'oral cancer risk', 'selection_index': 500},
#    {'qid': 5424, 'selection': 'gastric cancer', 'selection_index': 1071},
#    {'qid': 1403,
#     'selection': 'congenital adrenal hyperplasia',
#     'selection_index': 897},
#    {'qid': 4209, 'selection': "Alzheimer's disease", 'selection_index': 206},
#    {'qid': 4209,
#     'selection': 'dilated cardiomyopathy',
#     'selection_index': 240},
#    {'qid': 4209, 'selection': 'incomplete penetrance', 'selection_index': 432},
#    {'qid': 3010, 'selection': 'higher HDL levels', 'selection_index': 236},
#    {'qid': 3010,
#     'selection': 'coronary artery disease',
#     'selection_index': 401},
#    {'qid': 3010,
#     'selection': 'risk for carotid artery disease',
#     'selection_index': 2969},
#    {'qid': 3010,
#     'selection': 'coronary heart disease',
#     'selection_index': 3294},
#    {'qid': 3010, 'selection': 'colorectal cancer', 'selection_index': 3447},
#    {'qid': 5324, 'selection': 'increased risk', 'selection_index': 261},
#    {'qid': 5324, 'selection': 'macular degeneration', 'selection_index': 97},
#    {'qid': 5324, 'selection': 'bladder cancer risk', 'selection_index': 1024},
#    {'qid': 5324,
#     'selection': 'non-small-cell lung cancer',
#     'selection_index': 1375},
#    {'qid': 5324, 'selection': 'gastric cancer', 'selection_index': 2617},
#    {'qid': 5324,
#     'selection': 'peptic ulcer diseases',
#     'selection_index': 2636},
#    {'qid': 5324,
#     'selection': 'neovascular age-related macular degeneration',
#     'selection_index': 3412},
#    {'qid': 5324, 'selection': 'multiple myeloma', 'selection_index': 4505},
#    {'qid': 5324, 'selection': 'heumatoid arthritis', 'selection_index': 4827},
#    {'qid': 3205, 'selection': 'schizophrenia', 'selection_index': 296},
#    {'qid': 3205,
#     'selection': 'ability to recognize facial emotion',
#     'selection_index': 311},
#    {'qid': 3205,
#     'selection': 'chronic rhinosinusitis',
#     'selection_index': 352},
#    {'qid': 3205, 'selection': 'neurocognition', 'selection_index': 1902},
#    {'qid': 4882, 'selection': 'rheumatoid arthritis', 'selection_index': 814},
#    {'qid': 4882, 'selection': 'type 1 diabetes', 'selection_index': 1196},
#    {'qid': 4882,
#     'selection': 'systemic lupus erythematosus',
#     'selection_index': 1333},
#    {'qid': 4882,
#     'selection': 'Inflammatory Bowel Diseases',
#     'selection_index': 2079},
#    {'qid': 1711, 'selection': 'schizophrenia', 'selection_index': 186},
#    {'qid': 1711,
#     'selection': 'decreased attentional capacity,',
#     'selection_index': 242},
#    {'qid': 1711,
#     'selection': 'worse performance on memory tasks',
#     'selection_index': 274},
#    {'qid': 1711,
#     'selection': 'alterations in schizotypal beliefs and experiences',
#     'selection_index': 313},
#    {'qid': 1711,
#     'selection': 'major depressive disorder',
#     'selection_index': 2020},
#    {'qid': 1711, 'selection': 'neuroticism', 'selection_index': 2308},
#    {'qid': 1711, 'selection': 'anxiety', 'selection_index': 2321},
#    {'qid': 1711, 'selection': 'depression', 'selection_index': 2334},
#    {'qid': 1278,
#     'selection': 'higher dopamine levels;',
#     'selection_index': 706},
#    {'qid': 1278,
#     'selection': 'lower COMT enzymatic activity',
#     'selection_index': 665},
#    {'qid': 1278, 'selection': 'lower pain threshold', 'selection_index': 730},
#    {'qid': 1278,
#     'selection': 'enhanced vulnerability to stress',
#     'selection_index': 752},
#    {'qid': 1278, 'selection': 'schizophrenia', 'selection_index': 2988}]},
#  {'response_id': 'R_25R9SJyLb4p6iv7',
#   'recorded_datetime': '2020-09-22 10:42:30',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 361,
#   'hilights': []},
#  {'response_id': 'R_1CpRIVeWQ8AGNqi',
#   'recorded_datetime': '2020-09-22 10:45:55',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 2002,
#   'hilights': [{'qid': 1115,
#     'selection': 'Cystic Fibrosisrs',
#     'selection_index': 0},
#    {'qid': 1100, 'selection': 'Cystic Fibrosisrs', 'selection_index': 0},
#    {'qid': 3042, 'selection': 'Celiac Disease', 'selection_index': 0},
#    {'qid': 278,
#     'selection': 'Hereditary fructose intolerancers',
#     'selection_index': 0},
#    {'qid': 1117, 'selection': 'Cystic Fibrosisrs', 'selection_index': 0},
#    {'qid': 4658,
#     'selection': 'Glycogen Storage Disease Type 1brs',
#     'selection_index': 0},
#    {'qid': 113,
#     'selection': 'Dehydrogenase Deficiency',
#     'selection_index': 22},
#    {'qid': 1597, 'selection': 'Bipolar disorder', 'selection_index': 0},
#    {'qid': 852,
#     'selection': 'Clinical spectrum of episodic ataxia type 2.',
#     'selection_index': 0},
#    {'qid': 4805,
#     'selection': 'A polymorphism on the SOD1 gene known as A4V.',
#     'selection_index': 0},
#    {'qid': 2901, 'selection': 'developmental dyslexia', 'selection_index': 66},
#    {'qid': 1140, 'selection': 'silent polymorphism', 'selection_index': 22},
#    {'qid': 3824,
#     'selection': 'Rhizomelic chondrodysplasia punctata type 1',
#     'selection_index': 23},
#    {'qid': 3020, 'selection': 'cardiomyopathy', 'selection_index': 125},
#    {'qid': 3646,
#     'selection': 'carriers of the G allele',
#     'selection_index': 82},
#    {'qid': 5211,
#     'selection': 'Human Oocyte Meiotic Arrest',
#     'selection_index': 63},
#    {'qid': 5211,
#     'selection': 'R2K Mutations in TUBB8 ',
#     'selection_index': 36},
#    {'qid': 712, 'selection': 'breast cancer', 'selection_index': 89},
#    {'qid': 2218, 'selection': "Gaucher's disease", 'selection_index': 73},
#    {'qid': 2218, 'selection': 'Gaucher Disease', 'selection_index': 91},
#    {'qid': 4314, 'selection': "Hirschsprung's disease", 'selection_index': 79},
#    {'qid': 857, 'selection': 'arrhythmia disorder', 'selection_index': 7},
#    {'qid': 857, 'selection': 'arrhythmia disorder', 'selection_index': 86},
#    {'qid': 857,
#     'selection': 'cardiac L-type calcium channel mutations',
#     'selection_index': 116},
#    {'qid': 990, 'selection': 'gastric cancer', 'selection_index': 107},
#    {'qid': 2972,
#     'selection': 'decreased total cholesterol levels',
#     'selection_index': 99},
#    {'qid': 766, 'selection': 'breast cancer', 'selection_index': 127},
#    {'qid': 697, 'selection': 'breast cancer', 'selection_index': 119},
#    {'qid': 2956,
#     'selection': 'cerebral cavernous malformation',
#     'selection_index': 125},
#    {'qid': 263, 'selection': 'abnormality of albumin', 'selection_index': 119},
#    {'qid': 3015,
#     'selection': 'hyperalphalipoproteinemia',
#     'selection_index': 59},
#    {'qid': 4785, 'selection': 'Parkinson disease', 'selection_index': 154},
#    {'qid': 351,
#     'selection': 'limb-girdle muscular dystrophy',
#     'selection_index': 197},
#    {'qid': 1762,
#     'selection': 'intracranial aneurysms',
#     'selection_index': 115},
#    {'qid': 1762, 'selection': 'intracranial aneurysm', 'selection_index': 222},
#    {'qid': 2556,
#     'selection': 'azoospermia (lack of sperm)',
#     'selection_index': 103},
#    {'qid': 3770, 'selection': 'Parkinson disease ', 'selection_index': 170},
#    {'qid': 326, 'selection': 'hypophosphatasia', 'selection_index': 201},
#    {'qid': 3219, 'selection': 'AIDS', 'selection_index': 119},
#    {'qid': 303, 'selection': 'hypophosphatasia', 'selection_index': 204},
#    {'qid': 1674, 'selection': 'autism', 'selection_index': 88},
#    {'qid': 606, 'selection': 'depression', 'selection_index': 95},
#    {'qid': 3785, 'selection': 'coronary events.', 'selection_index': 237},
#    {'qid': 2232, 'selection': 'Asthma', 'selection_index': 0},
#    {'qid': 2232, 'selection': 'prostate cancer', 'selection_index': 310},
#    {'qid': 3877,
#     'selection': 'end-stage renal disease (ESRD) ',
#     'selection_index': 84},
#    {'qid': 3877,
#     'selection': ' autosomal dominant polycystic kidney disease',
#     'selection_index': 118},
#    {'qid': 3877, 'selection': 'ADPKD', 'selection_index': 210},
#    {'qid': 3877, 'selection': 'few cysts', 'selection_index': 289},
#    {'qid': 5023, 'selection': ' diabetes ', 'selection_index': 242},
#    {'qid': 5023, 'selection': 'allergic asthma', 'selection_index': 256},
#    {'qid': 2703, 'selection': 'allergy', 'selection_index': 75},
#    {'qid': 2703, 'selection': 'asthma', 'selection_index': 87},
#    {'qid': 4763,
#     'selection': 'type 2 or 3 spinal muscular atrophy',
#     'selection_index': 192},
#    {'qid': 3188,
#     'selection': 'familial Mediterranean fever',
#     'selection_index': 88},
#    {'qid': 414, 'selection': 'lung cancer ', 'selection_index': 51},
#    {'qid': 414, 'selection': 'lung cancer', 'selection_index': 262},
#    {'qid': 3407,
#     'selection': 'familial hypertrophic cardiomyopathy (HCM',
#     'selection_index': 103},
#    {'qid': 3407,
#     'selection': 'Hypertrophic cardiomyopathy',
#     'selection_index': 246},
#    {'qid': 1748, 'selection': "Parkinson's disease", 'selection_index': 183},
#    {'qid': 3236, 'selection': 'lung cancer', 'selection_index': 4},
#    {'qid': 3236, 'selection': ' lung cancer', 'selection_index': 149},
#    {'qid': 225, 'selection': 'pre-eclampsia', 'selection_index': 285},
#    {'qid': 225, 'selection': 'pre-eclampsia,', 'selection_index': 131},
#    {'qid': 2591, 'selection': 'ADHD', 'selection_index': 164},
#    {'qid': 2755,
#     'selection': 'ankylosing spondylitis',
#     'selection_index': 142},
#    {'qid': 2755, 'selection': 'rheumatoid arthriti', 'selection_index': 336},
#    {'qid': 2755, 'selection': "Crohn's Disease", 'selection_index': 457},
#    {'qid': 5200,
#     'selection': 'TTR-related familial amyloid polyneuropathy',
#     'selection_index': 189},
#    {'qid': 5200,
#     'selection': 'heart-related symptoms',
#     'selection_index': 255},
#    {'qid': 4294,
#     'selection': 'congenital myasthenic syndrome',
#     'selection_index': 354},
#    {'qid': 3837, 'selection': 'preterm birth', 'selection_index': 226},
#    {'qid': 3837, 'selection': 'preterm birth', 'selection_index': 543},
#    {'qid': 4073,
#     'selection': 'ubcortical silent brain infarction',
#     'selection_index': 144},
#    {'qid': 4073, 'selection': 'stroke', 'selection_index': 197},
#    {'qid': 4462, 'selection': 'cancers', 'selection_index': 323},
#    {'qid': 4462, 'selection': 'paragangliomas', 'selection_index': 381},
#    {'qid': 4462, 'selection': 'pheochromocytomas', 'selection_index': 400},
#    {'qid': 4887, 'selection': 'rheumatoid arthritis ', 'selection_index': 26},
#    {'qid': 4887,
#     'selection': 'systemic lupus erythematosu',
#     'selection_index': 155},
#    {'qid': 4887, 'selection': 'lupus erythematosus', 'selection_index': 224},
#    {'qid': 4887,
#     'selection': 'ystemic lupus erythematosus ',
#     'selection_index': 595},
#    {'qid': 655, 'selection': 'ovarian cancer', 'selection_index': 212},
#    {'qid': 655, 'selection': 'breast cancer', 'selection_index': 194},
#    {'qid': 4625, 'selection': 'Asperger syndrome', 'selection_index': 152},
#    {'qid': 4625, 'selection': 'Asperger syndrome', 'selection_index': 39},
#    {'qid': 164, 'selection': "Alzheimer's disease", 'selection_index': 272},
#    {'qid': 4453,
#     'selection': 'lower post-operative pain following surgery',
#     'selection_index': 463},
#    {'qid': 4453, 'selection': 'pain', 'selection_index': 445},
#    {'qid': 4453, 'selection': 'mall fiber neuropathy', 'selection_index': 592},
#    {'qid': 4453, 'selection': 'increased pain', 'selection_index': 618},
#    {'qid': 1248,
#     'selection': 'decreased bone mineral density',
#     'selection_index': 333},
#    {'qid': 1248,
#     'selection': 'ntervertebral disc disease.',
#     'selection_index': 418},
#    {'qid': 1248,
#     'selection': 'anterior cruciate ligament ruptures',
#     'selection_index': 572},
#    {'qid': 798, 'selection': 'breast cancer', 'selection_index': 338},
#    {'qid': 4113, 'selection': 'schizophrenia', 'selection_index': 87},
#    {'qid': 4113, 'selection': 'anxiety', 'selection_index': 250},
#    {'qid': 4113, 'selection': 'schizophrenia', 'selection_index': 441},
#    {'qid': 1693, 'selection': 'borderline ', 'selection_index': 608},
#    {'qid': 1693, 'selection': 'schizophrenia', 'selection_index': 1021},
#    {'qid': 521, 'selection': 'breast cancer', 'selection_index': 167},
#    {'qid': 521, 'selection': 'breast cancer', 'selection_index': 296},
#    {'qid': 521, 'selection': 'breast tumour ', 'selection_index': 781},
#    {'qid': 111, 'selection': 'Caucasian', 'selection_index': 695},
#    {'qid': 111,
#     'selection': 'hypersensitivity to ibuprofen',
#     'selection_index': 953},
#    {'qid': 2422,
#     'selection': 'ubiquitin-positive frontotemporal lobar degeneration',
#     'selection_index': 229},
#    {'qid': 2422,
#     'selection': 'amyotrophic lateral sclerosis',
#     'selection_index': 1176},
#    {'qid': 2422, 'selection': 'aphasia', 'selection_index': 1128},
#    {'qid': 2422,
#     'selection': 'extrapyramidal features',
#     'selection_index': 1137},
#    {'qid': 365, 'selection': 'obesity', 'selection_index': 68},
#    {'qid': 365, 'selection': 'heart disease', 'selection_index': 80},
#    {'qid': 365, 'selection': 'obesity', 'selection_index': 289},
#    {'qid': 365, 'selection': 'Body Mass Index ', 'selection_index': 297},
#    {'qid': 365, 'selection': 'heart disease ', 'selection_index': 856},
#    {'qid': 365, 'selection': 'fat ', 'selection_index': 1176},
#    {'qid': 365, 'selection': 'ages 4, 7 and 10', 'selection_index': 1271},
#    {'qid': 952,
#     'selection': ' rheumatoid arthritis (RA)',
#     'selection_index': 34},
#    {'qid': 952, 'selection': 'autoimmune disease', 'selection_index': 72},
#    {'qid': 952, 'selection': 'European ancestry', 'selection_index': 946},
#    {'qid': 952, 'selection': 'Korean ancestry', 'selection_index': 2234},
#    {'qid': 952, 'selection': 'orean ancestry', 'selection_index': 2327},
#    {'qid': 952, 'selection': 'RA ', 'selection_index': 2406},
#    {'qid': 952, 'selection': 'Europeans', 'selection_index': 2412},
#    {'qid': 952, 'selection': 'Korean', 'selection_index': 2431},
#    {'qid': 4729, 'selection': 'myopathy', 'selection_index': 1224},
#    {'qid': 4729, 'selection': 'myopathy', 'selection_index': 1469},
#    {'qid': 5035,
#     'selection': 'infectious and non-infectious diseases',
#     'selection_index': 308},
#    {'qid': 5035, 'selection': 'Diabetic neuropathy ', 'selection_index': 508},
#    {'qid': 5035, 'selection': 'Heart disease ', 'selection_index': 561},
#    {'qid': 5035, 'selection': 'Men ', 'selection_index': 577},
#    {'qid': 5035, 'selection': 'myocardial infarction', 'selection_index': 643},
#    {'qid': 5035, 'selection': 'premature birth', 'selection_index': 1152},
#    {'qid': 5035, 'selection': 'Bacterial vaginosis', 'selection_index': 1171},
#    {'qid': 5035, 'selection': ' Pregnant ', 'selection_index': 1191},
#    {'qid': 5035,
#     'selection': 'pH and a 10 fold higher level ',
#     'selection_index': 1257},
#    {'qid': 5035, 'selection': ' Bacterial infection', 'selection_index': 1307},
#    {'qid': 5035,
#     'selection': 'gram-negative bacterial infections',
#     'selection_index': 1397},
#    {'qid': 5035,
#     'selection': ' Respiratory syncytial virus infection ',
#     'selection_index': 1533},
#    {'qid': 5035,
#     'selection': 'septic shock Respiratory syncytial virus infection ',
#     'selection_index': 1520},
#    {'qid': 5035, 'selection': 'viral infection.', 'selection_index': 1659},
#    {'qid': 5035, 'selection': ' Asthma', 'selection_index': 1676},
#    {'qid': 5035, 'selection': 'lung transplantation', 'selection_index': 1977},
#    {'qid': 1227, 'selection': 'ADHD', 'selection_index': 516},
#    {'qid': 1227, 'selection': 'schizophrenia', 'selection_index': 796},
#    {'qid': 1227, 'selection': 'obesity', 'selection_index': 872},
#    {'qid': 1227, 'selection': 'European', 'selection_index': 912},
#    {'qid': 1227, 'selection': 'nicotine dependence', 'selection_index': 979},
#    {'qid': 1227, 'selection': 'obesity', 'selection_index': 1496},
#    {'qid': 1227,
#     'selection': 'metabolic syndrome in postmenopausal Polish women',
#     'selection_index': 1508},
#    {'qid': 1227, 'selection': 'cocaine addiction', 'selection_index': 1791},
#    {'qid': 249, 'selection': ', schizophrenia', 'selection_index': 270},
#    {'qid': 249,
#     'selection': 'drug-related psychoses,',
#     'selection_index': 291},
#    {'qid': 249,
#     'selection': 'cannabis-related psychosis',
#     'selection_index': 330},
#    {'qid': 249,
#     'selection': 'once-a-month cannabis users',
#     'selection_index': 383},
#    {'qid': 249, 'selection': 'mind-altering symptoms', 'selection_index': 710},
#    {'qid': 249, 'selection': 'psychotic disorde', 'selection_index': 1144},
#    {'qid': 3678, 'selection': 'empathetic', 'selection_index': 142},
#    {'qid': 3678, 'selection': 'feel less lonely', 'selection_index': 154},
#    {'qid': 3678, 'selection': 'Korean ', 'selection_index': 432},
#    {'qid': 3678, 'selection': 'Americans', 'selection_index': 315},
#    {'qid': 3678, 'selection': 'stress', 'selection_index': 1044},
#    {'qid': 3678, 'selection': 'marital discord', 'selection_index': 1946},
#    {'qid': 3678, 'selection': 'depression', 'selection_index': 1963},
#    {'qid': 3678, 'selection': 'Forty-five female', 'selection_index': 2278},
#    {'qid': 3678,
#     'selection': 'Two hundred three healthy German male university students',
#     'selection_index': 2795},
#    {'qid': 3678, 'selection': 'female', 'selection_index': 3066},
#    {'qid': 3678,
#     'selection': 'lower cortisol responses to stress',
#     'selection_index': 3246},
#    {'qid': 3678,
#     'selection': 'grey matter volume in the hypothalamus',
#     'selection_index': 4060},
#    {'qid': 3678,
#     'selection': 'prosocial temperament',
#     'selection_index': 5092},
#    {'qid': 3678, 'selection': 'Caucasian ', 'selection_index': 5212},
#    {'qid': 3678, 'selection': 'autism', 'selection_index': 5202}]},
#  {'response_id': 'R_2wQNxJNyQdjSeq9',
#   'recorded_datetime': '2020-09-22 11:20:01',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 1438,
#   'hilights': [{'qid': 1092,
#     'selection': 'Cystic Fibrosisrs',
#     'selection_index': 0},
#    {'qid': 3416,
#     'selection': 'familial hypertrophic cardiomyopathy',
#     'selection_index': 11},
#    {'qid': 5235, 'selection': 'eye color', 'selection_index': 0},
#    {'qid': 4747,
#     'selection': 'spinal muscular atrophy',
#     'selection_index': 10},
#    {'qid': 4767,
#     'selection': 'Niemann-Pick Disease Type',
#     'selection_index': 0},
#    {'qid': 5368, 'selection': 'Von Willebrand disease', 'selection_index': 10},
#    {'qid': 3849, 'selection': "Parkinson's disease", 'selection_index': 10},
#    {'qid': 2322,
#     'selection': 'associated with deafness',
#     'selection_index': 39},
#    {'qid': 3764, 'selection': "Parkinson's disease", 'selection_index': 11},
#    {'qid': 3764, 'selection': 'recessive/early-onset', 'selection_index': 32},
#    {'qid': 3764, 'selection': 'digenic', 'selection_index': 55},
#    {'qid': 3055, 'selection': 'Leigh syndrome', 'selection_index': 0},
#    {'qid': 259, 'selection': 'analbuminemia', 'selection_index': 31},
#    {'qid': 259, 'selection': 'Novel nonsense mutation', 'selection_index': 0},
#    {'qid': 3873,
#     'selection': 'polycystic kidney disease',
#     'selection_index': 83},
#    {'qid': 5119,
#     'selection': 'bipolar affective disorder',
#     'selection_index': 75},
#    {'qid': 5119, 'selection': 'suicide attempts.', 'selection_index': 107},
#    {'qid': 5119,
#     'selection': 'tryptophan hydroxylase II',
#     'selection_index': 48},
#    {'qid': 544,
#     'selection': 'prone to epigenetic alterations',
#     'selection_index': 82},
#    {'qid': 544,
#     'selection': 'X-inactivation in female human embryonic stem cells',
#     'selection_index': 0},
#    {'qid': 4169, 'selection': 'ALZHEIMER DISEASE', 'selection_index': 38},
#    {'qid': 4169, 'selection': 'Dementia', 'selection_index': 83},
#    {'qid': 4169, 'selection': 'SPASTIC PARAPARESIS', 'selection_index': 93},
#    {'qid': 4169, 'selection': 'APRAXIA', 'selection_index': 114},
#    {'qid': 993,
#     'selection': 'hereditary diffuse gastric cancer',
#     'selection_index': 88},
#    {'qid': 2185, 'selection': 'Krabbe disease', 'selection_index': 72},
#    {'qid': 740, 'selection': 'breast cancer', 'selection_index': 142},
#    {'qid': 982,
#     'selection': 'hereditary diffuse gastric cancer',
#     'selection_index': 109},
#    {'qid': 700, 'selection': 'breast cancer', 'selection_index': 119},
#    {'qid': 5328, 'selection': 'rheumatoid arthritis', 'selection_index': 52},
#    {'qid': 44,
#     'selection': 'atrial fibrillation/flutter',
#     'selection_index': 169},
#    {'qid': 4333,
#     'selection': 'late-onset Alzheimer disease',
#     'selection_index': 81},
#    {'qid': 4333, 'selection': 'chromosome 10', 'selection_index': 10},
#    {'qid': 4333, 'selection': 'Renalase gene', 'selection_index': 111},
#    {'qid': 4333, 'selection': 'hypertension', 'selection_index': 170},
#    {'qid': 4791, 'selection': 'Parkinson disease', 'selection_index': 156},
#    {'qid': 4257, 'selection': 'deafnes', 'selection_index': 107},
#    {'qid': 1964, 'selection': 'trimethylaminuria', 'selection_index': 130},
#    {'qid': 5176,
#     'selection': 'familial heart block type 1B',
#     'selection_index': 178},
#    {'qid': 1210, 'selection': 'obesity', 'selection_index': 170},
#    {'qid': 1210, 'selection': 'overweight', 'selection_index': 15},
#    {'qid': 313, 'selection': 'hypophosphatasia', 'selection_index': 205},
#    {'qid': 313, 'selection': 'rare/minor allele', 'selection_index': 136},
#    {'qid': 3881,
#     'selection': 'Polycystic Kidney disease',
#     'selection_index': 0},
#    {'qid': 4070,
#     'selection': 'post-traumatic stress disorder',
#     'selection_index': 133},
#    {'qid': 4070, 'selection': 'memory capacity', 'selection_index': 81},
#    {'qid': 2026, 'selection': "Friedreich's ataxia", 'selection_index': 140},
#    {'qid': 1739,
#     'selection': 'pulmonary hypertension',
#     'selection_index': 160},
#    {'qid': 1739,
#     'selection': 'pulmonary capillary hemangiomatosis',
#     'selection_index': 198},
#    {'qid': 1739,
#     'selection': 'pulmonary venoocclusive disease',
#     'selection_index': 244},
#    {'qid': 2252, 'selection': "Parkinson's disease", 'selection_index': 65},
#    {'qid': 3651,
#     'selection': 'higher likelihood of smoking initiation and nicotine dependence.',
#     'selection_index': 185},
#    {'qid': 1004,
#     'selection': 'Usher syndrome and nonsyndromic deafness.',
#     'selection_index': 83},
#    {'qid': 1004, 'selection': 'hearing loss', 'selection_index': 212},
#    {'qid': 4464, 'selection': 'thrombotic disorders', 'selection_index': 87},
#    {'qid': 4464,
#     'selection': 'recurrent venous thromboembolism',
#     'selection_index': 192},
#    {'qid': 2034, 'selection': "Friedreich's ataxia", 'selection_index': 171},
#    {'qid': 2423,
#     'selection': 'frontotemporal dementia',
#     'selection_index': 19},
#    {'qid': 2423,
#     'selection': 'primary progressive aphasia',
#     'selection_index': 106},
#    {'qid': 2423,
#     'selection': 'progranulin haploinsufficiency',
#     'selection_index': 251},
#    {'qid': 287,
#     'selection': 'myocardial infarction or ischemic stroke',
#     'selection_index': 140},
#    {'qid': 287,
#     'selection': 'bifurcation intima-media thickness',
#     'selection_index': 275},
#    {'qid': 287, 'selection': 'alcohol consumption', 'selection_index': 314},
#    {'qid': 1921, 'selection': 'prostate cancer', 'selection_index': 25},
#    {'qid': 1921,
#     'selection': 'benign prostate hyperplasia',
#     'selection_index': 164},
#    {'qid': 1988, 'selection': 'Physical activity', 'selection_index': 170},
#    {'qid': 1988, 'selection': 'obesity', 'selection_index': 261},
#    {'qid': 1988, 'selection': 'diabetes', 'selection_index': 318},
#    {'qid': 341, 'selection': 'coron', 'selection_index': 352},
#    {'qid': 341, 'selection': ' artery disease', 'selection_index': 360},
#    {'qid': 1218, 'selection': 'colorblindness', 'selection_index': 187},
#    {'qid': 1218, 'selection': 'photophobia', 'selection_index': 203},
#    {'qid': 1218, 'selection': 'nystagmus', 'selection_index': 216},
#    {'qid': 1218, 'selection': '20/200 visual acuity', 'selection_index': 227},
#    {'qid': 2726, 'selection': 'schizophrenia', 'selection_index': 18},
#    {'qid': 2726, 'selection': 'herpes', 'selection_index': 36},
#    {'qid': 1055, 'selection': 'ischemic stroke', 'selection_index': 297},
#    {'qid': 183, 'selection': 'dyskinesia disorder', 'selection_index': 229},
#    {'qid': 183, 'selection': 'facial myokymia', 'selection_index': 431},
#    {'qid': 2778, 'selection': 'type I diabetes', 'selection_index': 180},
#    {'qid': 4428,
#     'selection': 'gain significant weight',
#     'selection_index': 222},
#    {'qid': 2401, 'selection': 'alcoholism', 'selection_index': 58},
#    {'qid': 3267, 'selection': 'Endometrial cancer', 'selection_index': 0},
#    {'qid': 3267,
#     'selection': 'sporadic renal cell carcinoma',
#     'selection_index': 545},
#    {'qid': 5411, 'selection': 'Frasier syndrome', 'selection_index': 155},
#    {'qid': 5411, 'selection': 'Denys-Drash syndrome', 'selection_index': 199},
#    {'qid': 1144, 'selection': 'schizophrenia ', 'selection_index': 0},
#    {'qid': 1144, 'selection': 'atopy', 'selection_index': 474},
#    {'qid': 4014, 'selection': 'type 2', 'selection_index': 161},
#    {'qid': 4014, 'selection': ' diabetes', 'selection_index': 167},
#    {'qid': 1516, 'selection': 'prostate cancer', 'selection_index': 156},
#    {'qid': 1516, 'selection': 'ovarian cancer', 'selection_index': 383},
#    {'qid': 861, 'selection': 'hyperthermia', 'selection_index': 160},
#    {'qid': 49, 'selection': 'intrahepatic cholestasis', 'selection_index': 86},
#    {'qid': 49,
#     'selection': 'nonalcoholic fatty liver disease',
#     'selection_index': 193},
#    {'qid': 1555, 'selection': 'cerebral infarction', 'selection_index': 147},
#    {'qid': 361, 'selection': 'colorectal cancer', 'selection_index': 37},
#    {'qid': 5226,
#     'selection': 'systemic lupus erythematosus',
#     'selection_index': 136},
#    {'qid': 1936, 'selection': 'ichthyosis vulgaris', 'selection_index': 93},
#    {'qid': 1936, 'selection': 'dermatitis', 'selection_index': 124},
#    {'qid': 1562, 'selection': 'schizophrenia ', 'selection_index': 106},
#    {'qid': 1562, 'selection': 'autism ', 'selection_index': 350},
#    {'qid': 1562,
#     'selection': 'bipolar affective disorder',
#     'selection_index': 463},
#    {'qid': 4295,
#     'selection': 'congenital myasthenic syndrome',
#     'selection_index': 311},
#    {'qid': 1009, 'selection': 'type-2 diabetes', 'selection_index': 231},
#    {'qid': 1403,
#     'selection': 'congenital adrenal hyperplasia',
#     'selection_index': 897},
#    {'qid': 3251, 'selection': "Alzheimer's disease", 'selection_index': 105},
#    {'qid': 3251, 'selection': 'lung cancer', 'selection_index': 260},
#    {'qid': 3251,
#     'selection': 'cutaneous malignant melanoma',
#     'selection_index': 192},
#    {'qid': 3251, 'selection': 'non-atopic asthma', 'selection_index': 845},
#    {'qid': 3251, 'selection': 'breast cancer', 'selection_index': 1136},
#    {'qid': 1693, 'selection': 'personality', 'selection_index': 475},
#    {'qid': 1693, 'selection': 'schizophrenia', 'selection_index': 1021},
#    {'qid': 1693, 'selection': 'Anorexia Nervosa', 'selection_index': 911},
#    {'qid': 3205, 'selection': 'tumor metastasis', 'selection_index': 136},
#    {'qid': 3205, 'selection': 'autism ', 'selection_index': 257},
#    {'qid': 3205, 'selection': 'schizophrenia', 'selection_index': 296},
#    {'qid': 3205, 'selection': 'rhinosinusitis', 'selection_index': 360},
#    {'qid': 3205, 'selection': 'nasal polyps', 'selection_index': 3334},
#    {'qid': 5427, 'selection': 'breast cancer', 'selection_index': 118},
#    {'qid': 5427, 'selection': 'prostate cancer', 'selection_index': 264},
#    {'qid': 5427, 'selection': 'lung cancer', 'selection_index': 1178},
#    {'qid': 3250, 'selection': 'cigarette smoking', 'selection_index': 216},
#    {'qid': 3250,
#     'selection': 'chronic obstructive pulmonary disease',
#     'selection_index': 286},
#    {'qid': 3250, 'selection': 'lung cancer', 'selection_index': 528},
#    {'qid': 3250, 'selection': 'myocardial infarction', 'selection_index': 706},
#    {'qid': 3250, 'selection': 'heart disease', 'selection_index': 947},
#    {'qid': 3250, 'selection': "Alzheimer's disease", 'selection_index': 1497},
#    {'qid': 3250, 'selection': 'malignant melanoma', 'selection_index': 1747},
#    {'qid': 3250,
#     'selection': 'hepatitis B virus infection',
#     'selection_index': 1958},
#    {'qid': 3250, 'selection': 'lymphoma', 'selection_index': 2375},
#    {'qid': 3250, 'selection': 'glaucoma', 'selection_index': 2475},
#    {'qid': 3250, 'selection': 'type 2 diabetes', 'selection_index': 2669},
#    {'qid': 3250, 'selection': 'leukemia', 'selection_index': 3232},
#    {'qid': 3833, 'selection': 'ovarian cancer', 'selection_index': 220},
#    {'qid': 3833, 'selection': 'endometrial cancer', 'selection_index': 1355},
#    {'qid': 5344, 'selection': 'ischemic stroke', 'selection_index': 750},
#    {'qid': 5344,
#     'selection': 'myocardial infarction',
#     'selection_index': 1508},
# ...
#    {'qid': 4169, 'selection': 'ALZHEIMER DISEASE,', 'selection_index': 38},
#    {'qid': 4169, 'selection': 'FAMILIAL', 'selection_index': 57},
#    {'qid': 4169, 'selection': 'Dementia,', 'selection_index': 83},
#    {'qid': 4169, 'selection': 'SPASTIC PARAPARESIS', 'selection_index': 93},
#    {'qid': 4169, 'selection': 'APRAXIA,', 'selection_index': 114},
#    {'qid': 4809, 'selection': "Alzheimer's disease", 'selection_index': 48},
#    {'qid': 4809, 'selection': "Alzheimer's disease.", 'selection_index': 120},
#    {'qid': 4561,
#     'selection': 'Lymphoproliferative syndrome',
#     'selection_index': 61},
#    {'qid': 4394, 'selection': 'malignant hyperthermia', 'selection_index': 90},
#    {'qid': 3345, 'selection': "Alzheimer's disease", 'selection_index': 59},
#    {'qid': 674, 'selection': 'breast cancer ', 'selection_index': 149},
#    {'qid': 3552,
#     'selection': 'inflammatory bowel disease',
#     'selection_index': 155},
#    {'qid': 3981, 'selection': 'colorectal cancer', 'selection_index': 92},
#    {'qid': 772, 'selection': 'breast cancer', 'selection_index': 126},
#    {'qid': 750, 'selection': 'breast cancer', 'selection_index': 128},
#    {'qid': 1411, 'selection': 'HIV', 'selection_index': 127},
#    {'qid': 4180, 'selection': "Alzheimer's disease.", 'selection_index': 157},
#    {'qid': 3630,
#     'selection': 'left ventricular noncompaction',
#     'selection_index': 83},
#    {'qid': 714, 'selection': 'breast cancer', 'selection_index': 119},
#    {'qid': 308, 'selection': 'hypophosphatasia.', 'selection_index': 201},
#    {'qid': 5033,
#     'selection': 'nonfatal myocardial infarction',
#     'selection_index': 60},
#    {'qid': 5033, 'selection': 'postmenopausal women', 'selection_index': 159},
#    {'qid': 5033,
#     'selection': 'hypertensive men/women',
#     'selection_index': 184},
#    {'qid': 340,
#     'selection': 'amyotrophic lateral sclerosis',
#     'selection_index': 132},
#    {'qid': 340, 'selection': 'Irish', 'selection_index': 171},
#    {'qid': 340, 'selection': 'Swedish', 'selection_index': 181},
#    {'qid': 340, 'selection': 'Polish', 'selection_index': 213},
#    {'qid': 135, 'selection': "Alzheimer's disease.", 'selection_index': 100},
#    {'qid': 4134,
#     'selection': 'episodic kinesigenic dyskinesia-1',
#     'selection_index': 192},
#    {'qid': 4134,
#     'selection': 'paroxysmal kinesigenic dyskinesiasee',
#     'selection_index': 229},
#    {'qid': 4134,
#     'selection': 'autosomal dominant dystonia',
#     'selection_index': 139},
#    {'qid': 3255, 'selection': 'Ashkenazi Jewish', 'selection_index': 127},
#    {'qid': 3255, 'selection': 'CAMT', 'selection_index': 164},
#    {'qid': 4186, 'selection': "Alzheimer's disease", 'selection_index': 245},
#    {'qid': 3209, 'selection': 'autism', 'selection_index': 8},
#    {'qid': 3209, 'selection': 'Caucasian', 'selection_index': 180},
#    {'qid': 3209, 'selection': 'schizophrenia', 'selection_index': 266},
#    {'qid': 1737,
#     'selection': 'pulmonary hypertension',
#     'selection_index': 162},
#    {'qid': 1737,
#     'selection': 'ulmonary capillary hemangiomatosis',
#     'selection_index': 201},
#    {'qid': 1737,
#     'selection': 'pulmonary venoocclusive disease',
#     'selection_index': 246},
#    {'qid': 2033, 'selection': "Friedreich's ataxia", 'selection_index': 143},
#    {'qid': 1318, 'selection': 'European', 'selection_index': 280},
#    {'qid': 950, 'selection': "Alzheimer's disease", 'selection_index': 100},
#    {'qid': 4545,
#     'selection': 'Sanfilippo syndrome type A',
#     'selection_index': 238},
#    {'qid': 4545,
#     'selection': 'mucopolysaccharidosis type IIIA',
#     'selection_index': 313},
#    {'qid': 898, 'selection': 'muscular dystrophy', 'selection_index': 14},
#    {'qid': 898,
#     'selection': 'sudden infant death syndrome.',
#     'selection_index': 334},
#    {'qid': 5309,
#     'selection': 'Idiopathic short stature',
#     'selection_index': 59},
#    {'qid': 5309, 'selection': 'Osteonecrosis', 'selection_index': 193},
#    {'qid': 5309,
#     'selection': 'acute lymphoblastic leukemia',
#     'selection_index': 210},
#    {'qid': 5309, 'selection': 'breast cancer', 'selection_index': 359},
#    {'qid': 3192, 'selection': 'Mediterranean fever', 'selection_index': 97},
#    {'qid': 3192, 'selection': 'Turks,', 'selection_index': 239},
#    {'qid': 3192, 'selection': 'Sephardic Jews,', 'selection_index': 246},
#    {'qid': 3192, 'selection': 'Arab and Armenian', 'selection_index': 276},
#    {'qid': 2778, 'selection': 'type 1 diabetes.', 'selection_index': 84},
#    {'qid': 2778, 'selection': 'European ancestry', 'selection_index': 379},
#    {'qid': 2778, 'selection': 'African American', 'selection_index': 401},
#    {'qid': 2778, 'selection': 'children.', 'selection_index': 428},
#    {'qid': 2550,
#     'selection': 'Common variable immunodeficiency disorder ',
#     'selection_index': 4},
#    {'qid': 1055, 'selection': 'ischemic stroke', 'selection_index': 297},
#    {'qid': 1055,
#     'selection': 'candidate gene polymorphisms',
#     'selection_index': 264},
#    {'qid': 5121, 'selection': 'Norwegian female', 'selection_index': 189},
#    {'qid': 5121, 'selection': 'ADHD', 'selection_index': 211},
#    {'qid': 5121, 'selection': 'major depression.', 'selection_index': 227},
#    {'qid': 4798, 'selection': 'Guangxi Bai', 'selection_index': 107},
#    {'qid': 4798, 'selection': 'Ku Yao', 'selection_index': 119},
#    {'qid': 4798, 'selection': 'Han', 'selection_index': 130},
#    {'qid': 4798, 'selection': "Alzheimer's disease", 'selection_index': 364},
#    {'qid': 819, 'selection': 'breast cancer', 'selection_index': 34},
#    {'qid': 819, 'selection': 'prostate cancer.', 'selection_index': 236},
#    {'qid': 819, 'selection': 'Kazakhstan.', 'selection_index': 399},
#    {'qid': 617, 'selection': 'anorexia', 'selection_index': 96},
#    {'qid': 617, 'selection': 'bulimia', 'selection_index': 109},
#    {'qid': 617, 'selection': 'elderly population.', 'selection_index': 615},
#    {'qid': 4980, 'selection': 'pancreatic cancer', 'selection_index': 88},
#    {'qid': 4980, 'selection': 'European', 'selection_index': 116},
#    {'qid': 4980, 'selection': 'Asians', 'selection_index': 479},
#    {'qid': 804, 'selection': 'breast cancer', 'selection_index': 175},
#    {'qid': 1945, 'selection': 'ichthyosis vulgaris', 'selection_index': 182},
#    {'qid': 1945, 'selection': 'atopic dermatitis', 'selection_index': 515},
#    {'qid': 1945, 'selection': 'eczema.', 'selection_index': 537},
#    {'qid': 827, 'selection': 'restless legs syndrome', 'selection_index': 91},
#    {'qid': 139, 'selection': 'diabetic nephropathy', 'selection_index': 587},
#    {'qid': 4120,
#     'selection': 'venous thromboembolism',
#     'selection_index': 496},
#    {'qid': 250, 'selection': 'schizophrenia', 'selection_index': 149},
#    {'qid': 250, 'selection': 'Taiwanese population', 'selection_index': 170},
#    {'qid': 250, 'selection': 'glioblastoma', 'selection_index': 454},
#    {'qid': 250, 'selection': 'polymorphism', 'selection_index': 496},
#    {'qid': 250, 'selection': 'Korean population', 'selection_index': 554},
#    {'qid': 250,
#     'selection': 'non-small cell lung cancer.',
#     'selection_index': 728},
#    {'qid': 655, 'selection': 'breast cancer', 'selection_index': 194},
#    {'qid': 655, 'selection': 'ovarian cancer', 'selection_index': 212},
#    {'qid': 3170,
#     'selection': 'systemic lupus erythromatosis',
#     'selection_index': 117},
#    {'qid': 3170, 'selection': 'female disease', 'selection_index': 257},
#    {'qid': 3170, 'selection': 'Korean', 'selection_index': 297},
#    {'qid': 3170, 'selection': 'Caucasian', 'selection_index': 332},
#    {'qid': 2460, 'selection': 'Cubans', 'selection_index': 388},
#    {'qid': 2460, 'selection': 'Caribbean', 'selection_index': 465},
#    {'qid': 2460, 'selection': 'beta thalassemia', 'selection_index': 729},
#    {'qid': 2460, 'selection': 'Bulgaria', 'selection_index': 816},
#    {'qid': 2460, 'selection': 'South India', 'selection_index': 876},
#    {'qid': 4228, 'selection': 'mild asthma', 'selection_index': 107},
#    {'qid': 4228, 'selection': 'Australian patients.', 'selection_index': 143},
#    {'qid': 4228, 'selection': 'esophageal cancer', 'selection_index': 405},
#    {'qid': 4228, 'selection': 'gastric cancer.', 'selection_index': 543},
#    {'qid': 4228, 'selection': 'acute myeloid leukemi', 'selection_index': 631},
#    {'qid': 4228, 'selection': 'Chinese population.', 'selection_index': 659},
#    {'qid': 4228,
#     'selection': 'breast cancer prognosis:',
#     'selection_index': 721},
#    {'qid': 924,
#     'selection': 'eosinophilic esophagitis,',
#     'selection_index': 166},
#    {'qid': 924, 'selection': 'esophagitis', 'selection_index': 202},
#    {'qid': 924,
#     'selection': 'gastroesophageal reflux disease',
#     'selection_index': 280},
#    {'qid': 924,
#     'selection': 'eosinophilic esophagitis',
#     'selection_index': 430},
#    {'qid': 4599,
#     'selection': 'Native American population',
#     'selection_index': 197},
#    {'qid': 4599, 'selection': 'type-2 diabetes', 'selection_index': 456},
#    {'qid': 4599, 'selection': 'east Asian', 'selection_index': 645},
#    {'qid': 4599, 'selection': 'Europeans', 'selection_index': 672},
#    {'qid': 4599, 'selection': 'Africans.', 'selection_index': 686},
#    {'qid': 4454,
#     'selection': 'congenital insensitivity to pain',
#     'selection_index': 415},
#    {'qid': 4475, 'selection': 'emphysema', 'selection_index': 333},
#    {'qid': 4475, 'selection': 'liver disease.', 'selection_index': 347},
#    {'qid': 4475, 'selection': 'US Caucasians', 'selection_index': 380},
#    {'qid': 4475, 'selection': 'liver disease', 'selection_index': 702},
#    {'qid': 4475, 'selection': 'cystic fibrosis', 'selection_index': 719},
#    {'qid': 4475,
#     'selection': 'alpha-1 antitrypsin deficiency',
#     'selection_index': 799},
#    {'qid': 4475, 'selection': 'lung disease.', 'selection_index': 1410},
#    {'qid': 2749, 'selection': "Crohn's disease", 'selection_index': 73},
#    {'qid': 2749, 'selection': 'Jewish', 'selection_index': 97},
#    {'qid': 2749,
#     'selection': 'non-Jewish populations.',
#     'selection_index': 108},
#    {'qid': 2749,
#     'selection': 'ankylosing spondylitis',
#     'selection_index': 210},
#    {'qid': 2749, 'selection': 'Caucasian patients.', 'selection_index': 264},
#    {'qid': 2749,
#     'selection': 'North American patients',
#     'selection_index': 366},
#    {'qid': 2749, 'selection': "Graves' disease", 'selection_index': 395},
#    {'qid': 2749, 'selection': 'European ancestry', 'selection_index': 750},
#    {'qid': 3415, 'selection': 'Icelandic', 'selection_index': 378},
#    {'qid': 3415, 'selection': 'European descent,', 'selection_index': 960},
#    {'qid': 3415, 'selection': 'atrial fibrillation', 'selection_index': 1282},
#    {'qid': 3415, 'selection': 'ick sinus syndrome', 'selection_index': 1351},
#    {'qid': 3415, 'selection': 'advanced AV block', 'selection_index': 1392},
#    {'qid': 2422,
#     'selection': 'rs63751243, also known as c.26C>A, p.Ala9Asp and A9D, represents a relatively rare mutation in the GRN gene on chromosome 17. OMIM reports the rs63751243(A) allele as representing a dominantly inherited mutation associated with ubiquitin-positive frontotemporal lobar ',
#     'selection_index': 0},
#    {'qid': 2422,
#     'selection': 'rs63751243, also known as c.26C>A, p.Ala9Asp and A9D, represents a relatively rare mutation in the GRN gene on chromosome 17. OMIM reports the rs63751243(A) allele as representing a dominantly inherited mutation associated with ubiquitin-positive frontotemporal loba',
#     'selection_index': 0},
#    {'qid': 2422,
#     'selection': 'extrapyramidal features',
#     'selection_index': 1137},
#    {'qid': 2422,
#     'selection': 'amyotrophic lateral sclerosis.',
#     'selection_index': 1176},
#    {'qid': 2422, 'selection': 'exhibit aphasia,', 'selection_index': 1120},
#    {'qid': 2422,
#     'selection': 'ubiquitin-positive frontotemporal lobar degeneration.',
#     'selection_index': 229},
#    {'qid': 520, 'selection': 'breast cancer.', 'selection_index': 167},
#    {'qid': 520, 'selection': 'radio-sensitivity', 'selection_index': 1003},
#    {'qid': 520, 'selection': 'post-lumpectomy', 'selection_index': 1025},
#    {'qid': 520,
#     'selection': 'radiotolerant prostate brachytherapy',
#     'selection_index': 1277},
#    {'qid': 1484, 'selection': "Parkinson's disease", 'selection_index': 1322},
#    {'qid': 1484, 'selection': "Alzheimer's", 'selection_index': 1197},
#    {'qid': 31, 'selection': 'depression', 'selection_index': 997},
#    {'qid': 31, 'selection': 'German inpatients', 'selection_index': 1277},
#    {'qid': 3168, 'selection': 'apoptosis', 'selection_index': 217},
#    {'qid': 3168, 'selection': 'Europe', 'selection_index': 946},
#    {'qid': 3168, 'selection': 'United States.', 'selection_index': 961},
#    {'qid': 3168, 'selection': 'prostate cancer,', 'selection_index': 1324},
#    {'qid': 3168, 'selection': 'Breast Cancer', 'selection_index': 1856},
#    {'qid': 3168, 'selection': 'ovarian cancer', 'selection_index': 3575},
#    {'qid': 3168,
#     'selection': 'squamous cell carcinoma',
#     'selection_index': 3546},
#    {'qid': 1043, 'selection': 'French Europids', 'selection_index': 206},
#    {'qid': 1043, 'selection': 'type 2 diabetes', 'selection_index': 187},
#    {'qid': 1043, 'selection': 'obesity', 'selection_index': 693},
#    {'qid': 1043, 'selection': 'Asians', 'selection_index': 710},
#    {'qid': 1043,
#     'selection': 'Chinese Han population',
#     'selection_index': 1035},
#    {'qid': 1043, 'selection': 'Western', 'selection_index': 1587},
#    {'qid': 1043, 'selection': 'Korean population', 'selection_index': 1424},
#    {'qid': 1043,
#     'selection': 'gestational diabetes mellitus',
#     'selection_index': 1387},
#    {'qid': 1043, 'selection': 'Han Chinese', 'selection_index': 2722},
#    {'qid': 3471, 'selection': 'Bladder cancer', 'selection_index': 0},
#    {'qid': 3471,
#     'selection': 'oral premalignant lesions',
#     'selection_index': 415},
#    {'qid': 3471, 'selection': 'renal cell carcinoma', 'selection_index': 620},
#    {'qid': 3471, 'selection': 'adult glioma', 'selection_index': 765},
#    {'qid': 3471, 'selection': 'breast cancer', 'selection_index': 889},
#    {'qid': 3471, 'selection': 'French Canadian', 'selection_index': 1197},
#    {'qid': 3471, 'selection': 'bladder cancer', 'selection_index': 1422},
#    {'qid': 3471, 'selection': 'ovarian cancer.', 'selection_index': 1735},
#    {'qid': 3471, 'selection': 'Taiwanese patients.', 'selection_index': 1834},
#    {'qid': 3471,
#     'selection': "non-Hodgkin's lymphoma.",
#     'selection_index': 2272},
#    {'qid': 4247, 'selection': 'Type-1 diabetes', 'selection_index': 175},
#    {'qid': 4247,
#     'selection': 'Autoimmune thyroiditis',
#     'selection_index': 192},
#    {'qid': 4247,
#     'selection': 'Systemic lupus erythematosus',
#     'selection_index': 220},
#    {'qid': 4247,
#     'selection': 'systemic lupus erythematosus',
#     'selection_index': 371},
#    {'qid': 4247, 'selection': 'vasculitis', 'selection_index': 401},
#    {'qid': 4247, 'selection': 'autoimmune diseases', 'selection_index': 422},
#    {'qid': 4247, 'selection': 'British population', 'selection_index': 2315},
#    {'qid': 4247, 'selection': 'British Caucasian', 'selection_index': 4951},
#    {'qid': 4247,
#     'selection': 'rheumatoid arthritis and juvenile idiopathic arthritis',
#     'selection_index': 5230},
#    {'qid': 4247, 'selection': 'UK population:', 'selection_index': 5290},
#    {'qid': 4247,
#     'selection': 'Choctaw Indian individuals',
#     'selection_index': 7288},
#    {'qid': 4247, 'selection': 'US white', 'selection_index': 7257},
#    {'qid': 4247, 'selection': 'black,', 'selection_index': 7267},
#    {'qid': 4247, 'selection': 'Hispanic,', 'selection_index': 7274},
#    {'qid': 4247, 'selection': 'Japanese patients', 'selection_index': 7542},
#    {'qid': 4247, 'selection': "Crohn's disease,", 'selection_index': 7562},
#    {'qid': 4247, 'selection': 'Ulcerative colitis,', 'selection_index': 7579},
#    {'qid': 4247,
#     'selection': 'Inflammatory bowel disease',
#     'selection_index': 7603},
#    {'qid': 4247, 'selection': "Addison's disease", 'selection_index': 8451}]}]

# %%
# Load the original source CSV that was used in creating the survey. This will used to check against the results.
# We want to make sure there is no discrepency in which IDs are referring to which texts.
source_df = pd.read_csv(SURVEY_SOURCE_DATA_PATH)
#source_df.reset_index(drop=False, inplace=True)

# Question IDs in the actual survey will use the 
#source_df["qid"] = source_df["index"]
#source_df.drop(labels=["index"], axis=1, inplace=True)
#qid_to_source_text = {i:text for i,text in zip(source_df["qid"].values, source_df["text"].values)}
#qid_to_unique_text_id = {qid:i for qid,i in zip(source_df["qid"].values, source_df["id"].values)}
source_df.head(10)
# Out:
#      id                       text  bin_id  bin_size  block_id  block_size  \
# 0  1169                    smoking       1       988         1         247
# 1  3702  Phenylketonuriars62514952       1       988         1         247
# 2  3701   Phenylketonuriars5030860       1       988         1         247
# 3  3700   Phenylketonuriars5030859       1       988         1         247
# 4  3699   Phenylketonuriars5030856       1       988         1         247
# 5  3698   Phenylketonuriars5030851       1       988         1         247
# 6  3697   Phenylketonuriars5030850       1       988         1         247
# 7  3696   Phenylketonuriars5030847       1       988         1         247
# 8  3695   Phenylketonuriars5030846       1       988         1         247
# 9  3694   Phenylketonuriars5030843       1       988         1         247
#
#    block_sample
# 0             5
# 1             5
# 2             5
# 3             5
# 4             5
# 5             5
# 6             5
# 7             5
# 8             5
# 9             5

# %%
# Put the responses into a dataframe.
row_tuples = []
for response in responses:
    
    # Metadata associated with this response.
    response_id = response["response_id"]
    recorded_datetime = response["recorded_datetime"]
    status = response["status"]
    progress = response["progress"]
    is_finished = response["is_finished"]
    duration = response["duration"]


    # The actual highlighted text strings from this response.
    for hilight in response["hilights"]:

        # The information about this one particular highlight.
        qid = hilight["qid"]
        hilighted_text = hilight["selection"]
        index_of_first_selected_char = hilight["selection_index"]
        source_text = unique_text_id_to_text[qid]        

        # First check that the question IDs are correct so we know what the source text was for this question.
        # Then additionally make sure the location of the highlight makes sense as well.
        #assert hilighted_text in source_text
        #assert source_text[index_of_first_selected_char:index_of_first_selected_char+len(hilighted_text)] == hilighted_text
       
        # Those asserts don't pass 100% of the time due to special cases with the text.
        # Save them to variables instead and check how often they don't pass, should be very infrequently.
        # Look at the special cases by hand.
        text_match = (hilighted_text in source_text)
        indices_match = (source_text[index_of_first_selected_char:index_of_first_selected_char+len(hilighted_text)] == hilighted_text)
        
        # Add this as a row.
        row_tuples.append((response_id, recorded_datetime, status, progress, is_finished, duration, qid, hilighted_text, text_match, indices_match))

columns = ["response_id", "recorded_datetime", "status", "progress", "is_finished", "duration", "id", "snippet", "text_match", "idx_match"]
df = pd.DataFrame(row_tuples, columns=columns)
df.to_csv(RESPONSES_OUTPUT_PATH, index=False)
df.head(10)
# Out:
#          response_id    recorded_datetime      status  progress is_finished  \
# 0  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 1  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 2  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 3  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 4  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 5  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 6  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 7  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 8  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 9  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
#
#    duration    id                               snippet  text_match  idx_match
# 0      1252  4769                              Disease         True       True
# 1      1252  5162    Focal segmental glomerulosclerosis        True       True
# 2      1252  2451                     Alpha Thalassemia        True       True
# 3      1252  3964  Congenital Disorder of Glycosylation        True       True
# 4      1252  5448                        schizophrenia.        True       True
# 5      1252  3027                              glaucoma        True       True
# 6      1252  2287            Nonsyndromic Sensorineural        True       True
# 7      1252  2287                              Connexin        True       True
# 8      1252  1783                         schizophrenia        True       True
# 9      1252   628                           cholesterol        True       True

# %%
# How many times did the asserts not evaluate to true?
print(Counter(df["text_match"].values))
print(Counter(df["idx_match"].values))
# Out:
# Counter({True: 1564, False: 8})
# Counter({True: 1468, False: 104})

# %%
# Preparing a dataset of context sentences that include the highlighted text snippets.
def get_contexts(i, snippet, text):
    sentences = sent_tokenize(text)
    sentences_with_snippet = [s for s in sentences if snippet in s]
    
    # Some additional processing to clean up the context sentences. Can insert more steps here if needed.
    snp_pattern = re.compile(r"rs[0-9]+")
    whitespace_pattern = re.compile(r"\s+")
    whitespace_before_period_pattern = re.compile(r"\s+[\.\;]")
    whitespace_before_comma_pattern = re.compile(r"\s+[\.\;]")
    sentences_with_snippet = [snp_pattern.sub(r" [SNP] ", s) for s in sentences_with_snippet]
    sentences_with_snippet = [s.replace("("," (") for s in sentences_with_snippet]
    sentences_with_snippet = [s.replace(")",") ") for s in sentences_with_snippet]
    sentences_with_snippet = [whitespace_pattern.sub(r" ", s) for s in sentences_with_snippet]
    sentences_with_snippet = [whitespace_before_period_pattern.sub(r".", s) for s in sentences_with_snippet]
    sentences_with_snippet = [whitespace_before_comma_pattern.sub(r".", s) for s in sentences_with_snippet]
    sentences_with_snippet = [s.strip() for s in sentences_with_snippet]
    sentences_with_snippet = ["{}{}".format(s[0].upper(),s[1:]) for s in sentences_with_snippet]
    add_end_character = lambda x: "{}.".format(x[:len(x)-1]) if (x[len(x)-1]==".") or (x[len(x)-1]==";") else "{}.".format(x)
    sentences_with_snippet = [add_end_character(s) for s in sentences_with_snippet]
    sentences_with_snippet = [s.replace('"', '') for s in sentences_with_snippet]
    sentences_with_snippet = [s.replace("'", "") for s in sentences_with_snippet]
    return((i,sentences_with_snippet))

# Create a mapping between text IDs and lists of the context sentences that relevant snippets were found in.
obj = df.apply(lambda row: get_contexts(row.id, row.snippet, unique_text_id_to_text[row.id]), axis=1)
id_to_context_sentences = dict(obj.values)
id_to_context_sentences
# Out:
# {4769: ['Niemann-Pick Disease Type A [SNP].'],
#  5162: ['Focal segmental glomerulosclerosis 2 [SNP].'],
#  2451: ['[SNP] see HBA2 and Alpha Thalassemia.'],
#  3964: ['Congenital Disorder of Glycosylation Type 1a [SNP].'],
#  5448: ['Evidence of sex-modulated association of ZNF804A with schizophrenia.'],
#  3027: ['Association with exfoliation glaucoma; possible genoset partner with [SNP].'],
#  2287: ['Hearing loss?Connexin 26-Related Nonsyndromic Sensorineural Hearing Losssee [SNP].'],
#  1783: ['Linked to schizophrenia with [SNP] , [SNP] , and [SNP].'],
#  628: ['LDL cholesterol and total cholesterol levels being the quantitative trait associated with in.'],
#  2515: ['Hemochromatosis related; better known in dbSNP nomenclature as [SNP] / discussion at 23andMe.'],
#  3684: ['[SNP] increases susceptibility to Rheumatoid Arthritis 1.89 times for carriers of the G allele.'],
#  4613: ['[SNP] and [SNP] replicated for rheumatoid arthritis in Japanese, but not Caucasian populations.'],
#  2261: ['GTP cyclohydrolase and tetrahydrobiopterin regulate pain sensitivity and persistence.'],
#  2215: ['I4000386, also known as R496H (risk genotype AA) Possibly associated with Gauchers disease.Gaucher Disease [SNP].'],
#  2255: ['A GCH1 Haplotype Associated with Susceptibility to Vasoocclusive Pain and Impaired Vascular Function in Sickle Cell Anemia.'],
#  3271: ['HLA-B 5801 allele as a genetic marker for severe cutaneous adverse reactions caused by allopurinol.'],
#  1380: ['[SNP] , also known as -2467delT, is a SNP in the CYP1A2 gene.The [SNP] (-) allele defines the CYP1A2 1D variant.'],
#  1840: ['[SNP] The (G) allele represents a very rare - possibly extinct - form of Hemophilia B.'],
#  4559: ['Aka c.95G>C (p.Arg32Thr) considered pathogenic for X-linked Lymphoproliferative syndrome, type 1 in ClinVar23andMe name: i5003046.'],
#  2620: ['[SNP] , also known as c.555_556insC and p.Thr187Hisfs, represents a rare mutation in the HSD3B2 gene on chromosome 1.'],
#  838: ['A SNP in the C3 gene, [SNP] , has been associated with increased risk for adult bronchial asthma in a study of Japanese patients.'],
#  2187: ['Aka c.1591C>T, p.Arg531CysIdentified in ClinVar as likely pathogenic for Krabbe disease (when inherited in two copies or as a compound heterozygote).'],
#  762: ['[SNP] , also known as 3109insAA, c.2990_2991insAA and p.Asn997?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  3780: ['[SNP] G allele (in dbSNP orientation) linked to 1.34x increased risk of obesity [SNP] / [SNP] (or [SNP] ) see also: / spitoonObesity: Preliminary Research.'],
#  730: ['[SNP] , also known as 1459insG, c.1340_1341insG and p.Val447?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  4644: ['[SNP] , also known as c.1151A>G, p.Glu384Gly and E384G, is a SNP in the SLC26A4 gene associated with the hearing loss condition known as Pendred Syndrome.'],
#  22: ['Alzheimers disease associated, based on large 2011 study The minor allele of Rs3764650 in ABCA7 was associated with a later age at onset and shorter disease course according to /.'],
#  5194: ['Note: cDNA is on reverse strand: Mutations in TTC29, Encoding an Evolutionarily Conserved Axonemal Protein, Result in Asthenozoospermia and Male Infertility.'],
#  5015: ['A promoter polymorphism of tissue inhibitor of metalloproteinase-2 gene is associated with severity of thoracic adolescent idiopathic scoliosis.'],
#  2023: ['[SNP] , also known as c.443_A>G or p.Q148R, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  2260: ['T allele associated with higher tolerance to pain.Polymorphisms in the GTP cyclohydrolase gene (GCH1) are associated with ratings of capsaicin pain.'],
#  2039: ['[SNP] , also known as c.340_352 del13 or p.A114TfsX15, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  569: ['BAK1 gene SNPs [SNP] OR=0.57 (0.46-0.72) , p=8.57x10 (-7) and [SNP] OR=1.61 (1.26-2.04) , p=1.08x10 (-4) were associated with autoimmune rheumatic diseases (AIRDs) in a study of 719 Colombian women.'],
#  1355: ['Increased risk of breast cancer with concurrent proliferative fibrocystic conditions [SNP] (C) 2.19 (1.24-3.85) [SNP] (C) 2.20 (1.27-3.82) [SNP] (T) 1.94 (1.13-3.30) [SNP] (C) 1.95 (1.07-3.58).'],
#  2793: ['Interleukin-6 receptor gene, plasma C-reactive protein, and diabetes risk in women.'],
#  2568: ['Aka c.532G>A, p.Asp178Asn, D178NHMBS enzyme from the variant allele of this SNP is reported to have 81% of the activity of the normal, wild-type; it is reported as likely to be pathogenic in ClinVar, presumably for acute intermittent porphyria.'],
#  3797: ['[SNP] has been reported in a large study to be associated with type-2 diabetes.The risk allele (oriented to the dbSNP entry) is (G). the odds ratio associated with heterozygotes is 1.37 (CI 1.17-1.59) , and for homozygotes, 2.33 (CI 1.23-4.42).'],
#  3965: ['[SNP] , also known as c.422G>A, p.Arg141His and R141H, represents a rare variant in the PMM2 gene on chromosome 16.ClinVar and other sources designate this variant as pathogenic for Congenital disorder of glycosylation, type 1a, which is a recessive disorder.'],
#  2512: ['Aka c.672+30T>GAlthough reported in ClinVar as pathogenic for Tay Sachs, the consensus seems to be that this variant is likely to be benign, because its seen at a higher frequency in general and because minor homozygotes have been observed in large-scale sequencing projects.'],
#  5107: ['Specifically, the 216H allele (c.646C) appears to reduce the odds of developing torsion dystonia in [SNP] (-;GAG) carriers, while the 216D allele appears to increase the odds.,,.'],
#  2919: ['[SNP] is one of 2 SNPs (the other is [SNP] ) in the KLOTHO gene found in a study of ~150 sickle cell anemia (SCA) patients to be associated with risk for priapism.'],
#  3533: ['A novel NOD2/CARD15 haplotype conferring risk for Crohn disease in Ashkenazi Jews.'],
#  3367: ['Aka c.2593G>T, p.Gly865Ter and G865XWith a carrier frequency of 1 in 131 among Ashkenazi Jews, the recessively inherited [SNP] (T) variant is the basis of an incidence rate for abetalipoproteinemia of about 1 in 70,000 in this population.'],
#  3979: ['[SNP] , also known as c.1433G>A, p.Ser478Asn or S478N, represents a very rare variant in the POLD1 gene on chromosome 19.The [SNP] (A) allele is considered to be a high penetrance, dominant mutation significantly increasing ones risk for colorectal cancer, manifesting primarily as tumors occuring predominantly or exclusively in the large bowel, as well as endometrial cancer.'],
#  858: ['[SNP] is a SNP in the calcium channel, voltage-dependent, L type, alpha 1D subunit CACNA1D gene.A study of 161 Japanese patients (85 men, 76 women) being treated for hypertension with L-type dCCBs (calcium channel blockers) concluded that individuals with [SNP] (C;C) genotypes responded better, as measured by lowered systolic and diastolic blood pressure readings.'],
#  289: ['Based on a mixed-ethnicity study, women consuming a diet high in linoleic acid (top quartile of intake, >17.4 g/d) and carrying the [SNP] (A;A) genotype were associated with higher breast cancer risk (age- and race-adjusted odds ratio, 1.8, CI: 1.2-2.9) compared with (A;G) and (G;G) genotypes.',
#   'Among women consuming </=17.4 g/d of linoleic acid, there was no association with breast cancer risk.'],
#  3836: ['Association of progesterone receptor gene polymorphism with male infertility and clinical outcome of ICSI Progesterone receptor polymorphisms and clinical response to 17-alpha-hydroxyprogesterone caproate Clarifying the PROGINS allele association in ovarian and breast cancer risk: a haplotype-based analysis.'],
#  5430: ['The odds ratio for the His-encoding [SNP] (A) allele carriers is homozygote is 0.79, CI: 0.62-1.00, p=0.05. [SNP] (A) carriers also appear to be at lower risk for epithelial ovarian cancer.'],
#  2853: ['This SNP, also known as P532L, affecting an amino acid in exon 1 of the KCNA5 potassium channel gene, may mediate the response to drugs such as quinidine.The risk allele is [SNP] (T) , and carriers receiving quinidine or propafenone for the treatment of cardiac arrhythmias may be resistant to the drug (and thus treatment).'],
#  2375: ['[SNP] , also known as c.961A>G, Ser321Gly or S321G, is a variant in the GNPTAB gene on chromosome 12.The minor (G) allele of [SNP] was a rare mutation in the GNPTAB gene associated with stuttering in a 2010 study.',
#   'Note that inheritance was neither dominant or recessive; this variant increased the risk of stuttering when present in either one or two copies, consistent with an additive genetic effect.'],
#  4594: ['Aka c.963C>A (p.Tyr321Ter or Y321X) and also c.963C>T (p.Tyr321=). the latter is annotated in ClinVar as likely to be benign, while the former has been reported as likely to be pathogenic for Andermann syndrome, a recessively inherited disorder.Note that the ref and alt alleles that are tested by both Ancestry and 23andMe are G and A, respectively, which means they represent the benign c.963C>T variant, since the alleles are reported by these companies based on the forward/plus strand, whereas the cDNA for the SLC12A6 gene is reported on the reverse/minus strand.'],
#  3078: ['[SNP] is a SNP upstream of the tumor necrosis alpha (TNF) gene; this SNP is also typically called the -863 variant.In a study of 154 Thai patients with systemic lupus erythematosus (SLE) , [SNP] (A) allele frequency was significantly increased, with an odds ratio of 1.85 (CI: 1.21-2.83, p (corr) = 0.009).',
#   'This allele was also found to be significantly increased in the SLE group with Raynauds phenomenon compared to SLE without Raynauds phenomenon ( odds ratio of 2.23, CI: 1.21-4.10, p (corr) = 0.048).Separately, a meta-analysis of 10 case-control studies, including over 2,200 Graves disease cases, concluded that [SNP] (A) carriers were associated with the disease.'],
#  1276: ['Pubmed 1180576 Schizophrenia Susceptibility Genetic basis for individual variations in pain perception and the development of a chronic pain condition.'],
#  3985: ['In a 2017 publication, carriers of a [SNP] (G) mutation had an estimated cumulative risk of developing CRC by age 70 years of 97% (CI: 85%–99%) for males and 92% (CI: 75%–99%) for females.Note: as a C/G mutation oriented on the minus strand in dbSNP, be wary of ambiguous flips when interpreting data from this SNP.'],
#  4718: ['Association of serotonin transporter gene variation with smoking, chronic obstructive pulmonary disease, and its depressive symptoms.'],
#  3551: ['Ser608Leu polymorphisms in the nitric oxide synthase-2 gene may influence urinary bladder cancer pathogenesis.'],
#  5031: ['Toll-like receptor signaling pathway variants and prostate cancer mortality.',
#   'Sequence variants in the TLR4 and TLR6-1-10 genes and prostate cancer risk.',
#   'Sequence variants of Toll-like receptor 4 (TLR4) and the risk of prostate cancer in Korean men.'],
#  83: ['A large study totaling 7,699 participants in the Framingham cohort and 4,148 participants in the Rotterdam cohort was conducted, with genome-wide significant SNPs then replicated in 11,000+ Caucasian and ~4,000 African-American individuals who took part in the study of Atherosclerosis Risk in Communities (ARIC).'],
#  4475: ['Genetic polymorphisms and susceptibility to lung disease.'],
#  2840: ['As genomic data is becoming more abundant, the possibility of diagnosis based on the underlying molecular cause is being discussed.===Familial mental disorders===It has long been known that relatives of mental health patients have a higher chance of having a psychiatric illness, but not necessarily the same illness as the patient.'],
#  2759: ['Each incidence of the G allele was associated with a decrease in Crohns Disease in New Zealand populations studied.'],
#  1158: ['[SNP] (T;T) individuals respond slower to alcohol, which generally is considered to actually increase their long-term risk of alcohol abuse./ 23andMe blog (T;T) makes it harder to quit smokingPeripheral Artery Disease.'],
#  2475: ['This HLA allele, in turn, has been associated with several conditions.A study of 51 cases of flucloxacillin drug-induced liver injury (DILI) , an important cause of serious liver disease, along with a replication study of another 23 cases, found that the [SNP] (G) carriers were at highly increased risk (odds ratio 80, p=8.7x10 (-33) ).'],
#  28: ['ABCB1 (MDR1) [SNP] is associated with increased overall survival in plasma cell myeloma.',
#   'Neither P-gp SNP variants, P-gp expression nor functional P-gp activity predicts MDR in a preliminary study of plasma cell myeloma.'],
#  4622: ['Skin color.'],
#  5199: ['TTR-related cardiac amyloidosis [SNP].'],
#  162: ['[SNP] Alzheimers disease assocation.'],
#  5160: ['Focal segmental glomerulosclerosis 2 [SNP].'],
#  5083: ['[SNP] dilated cardiomyopathy, type 1FF.'],
#  2151: ['GAB2 alleles modify Alzheimers risk in APOE epsilon4 carriers.'],
#  4923: ['Leigh syndrome is more common in some French-Canadian populations.'],
#  5133: ['Mutations that alter the surface charge of alpha-tropomyosin are associated with dilated cardiomyopathy.'],
#  1766: ['Loss-of-function ENPP1 mutations cause both generalized arterial calcification of infancy and autosomal-recessive hypophosphatemic rickets.'],
#  75: ['Aka c.31_46del16 (p.Arg11Serfs) Reported in ClinVar as pathogenic for adrenoleukodystrophy (ALD).'],
#  3536: ['NOD2 SNP, aka R703COne of 11 SNPs used in a genetic risk score for inflammatory bowel disease.'],
#  4558: ['Aka c.163C>T (p.Arg55Ter) considered pathogenic for X-linked Lymphoproliferative syndrome, type 1 in ClinVar.'],
#  15: ['This is a recessive SNP for congenital Lamellar ichthyosis, type 2, also called ichthyosis-4A, a significant skin condition.'],
#  4534: ['Rare loss-of-function variants in SETD1A are associated with schizophrenia and developmental disorders.referred to in the cited paper as 16:30977140_C/G and also as p.Y646X.'],
#  2685: ['Type-2 diabetes, insulin sensitivity, and obesity with body fat decreasing ~1.5-2% per copy of the A allele.'],
#  3011: ['[SNP] increases susceptibility to Elevated HDL-Cholesterol for carriers of the A allele A allele is associated with 1.41mg/dl increase in HDL cholesterol (good cholesterol).'],
#  983: ['Also known as c.2287G>T or p.Glu763Ter, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer in ClinVar.'],
#  2346: ['A systematic, large-scale resequencing screen of X-chromosome coding exons in mental retardation.'],
#  1965: ['Aka c.2918A>G, p.Tyr973Cys and Y973C; autosomal dominant mutation associated with a form of glomerulopathy with fibronectin deposits (type 2). see also OMIM.'],
#  5223: ['Polymorphisms in estrogen- and androgen-metabolizing genes and the risk of gastric cancer.'],
#  385: ['This SNP may be related to longevity.'],
#  1283: ['/ 23andMe blog hearing loss linked to a chemotherapy drug named Cisplatin.'],
#  1762: ['[SNP] (G/C transversion with D366H substitution) of endoglin may play an important role in the pathogenesis of intracranial aneurysms in the Korean population.',
#   'Sequencing of TGF-beta pathway genes in familial cases of intracranial aneurysm.'],
#  3360: ['Lack of association of polymorphisms in homocysteine metabolism genes with pseudoexfoliation syndrome and glaucoma.'],
#  1505: ['A study of 858 cases concluded that SNPs in the intron of the CYP2J2 gene were associated with increased risk for myocardial infarction.'],
#  5174: ['[SNP] , also known as c.2531G>A, p.Gly844Asp and G844D, represents a rare mutation in the TRPM4 gene.The minor allele is considered causative in a dominant manner for progressive familial heart block type 1B in ClinVar.'],
#  2753: ['[SNP] is one of several SNPs in the IL23R gene that has been shown in a large (over 1,000 Caucasian patients) study to be associated with ankylosing spondylitis.'],
#  3874: ['C.12310_12311delGT (p.Val4104Tyrfs) The variant allele of this SNP is considered either definitely pathogenic or highly likely pathogenic for autosomal dominant polycystic kidney disease in the PKD Foundation database as well as in ClinVar.'],
#  3868: ['Aka c.388G>A (p.Glu130Lys) [SNP] represents a variant in the PITX1 gene on chromosome 5; the rare [SNP] (A) allele is considered a dominant mutation leading to talipes equinovarus, based on an analysis of a 5-generation family segregating asymmetric right-sided predominant clubfoot.'],
#  1917: ['[SNP] , also known as Ser279Cys or S279C, is a mutation in the FGFR3 gene on chromosome 4.Acting in an autosomal dominant manner, the [SNP] (T) allele is considered to cause achondroplasia; see also OMIM 134934.0030Note that 23andMe refers to this SNP as i5001264.'],
#  2048: ['[SNP] , also known as c.517 T>G or p.W173G, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  1735: ['Also known as c.1392delT (p.Arg465Valfs) , this rare mutation in the EIF2AK4 gene is reported in ClinVar as leading to - when inherited recessively - rare forms of pulmonary hypertension, specifically, pulmonary capillary hemangiomatosis (PCH) and pulmonary venoocclusive disease (PVOD).'],
#  2920: ['[SNP] is one of 2 SNPs (the other is [SNP] ) in the KLOTHO gene found in a study of ~150 sickle cell anemia (SCA) patients to be associated with risk for priapism.'],
#  4655: ['[SNP] replicated as significant for type-2 diabetes risk in 1,900 Japanese patients, with odds ratio of 1.16 (CI: 1.05-1.27, p = 4.5 x 10e-3) Note: this SNP is fairly tightly linked (r<sup>2</sup> = 0.83) to another SNP in the SLC30A8 gene also linked to type-2 diabetes, [SNP].'],
#  3002: ['Aka c.1733A>G (p.Asp578Gly or D578G) The [SNP] (G) mutation is considered to be a dominantly inherited mutation leading to familial male precocious puberty, and in the US (but not in Europe) , it is the most common such mutation.A 2019 article about a male inheriting such a mutation is here.'],
#  3838: ['p-values account for ethnic heterogenity of study population.In , no evidence for linkage to colorectal cancer in women was found in a study with 158 European subjects and 563 controls.',
#   'Genetic variation in sex-steroid receptors and synthesizing enzymes and colorectal cancer risk in women.'],
#  1828: ['[SNP] , better known as c.1716+1G>A or IVS14DS, G-A, +1, is a SNP in the coagulation factor XI F11 gene.This SNP is reported by 23andMe as one of the three most common factor XI deficiency-causing mutations found in Ashkenazi Jews; it is termed i4000397 by 23andMe.See OMIM 264900.0001.'],
#  2718: ['Association of the interleukin (IL) -16 gene polymorphisms with Graves disease.',
#   'IL-16 [SNP] gene polymorphism is associated with coronary artery disease in the Chinese Han population.'],
#  5449: ['A 2014 study Genome-wide association study identifies multiple susceptibility loci for pancreatic cancer of 7,683 European cases and 14,397 controls found the minor allele [SNP] (T) in ZNRF3 (zinc and ring finger 3) conferring risk of statistically genome-wide significance (per-allele odds ratio (OR) = 1.18, 95% confidence interval (CI) 1.12-1.25, P = 1.2E-8) for Pancreatic cancer.'],
#  4573: ['[SNP] is a potential breast cancer variant Ovarian cancer risk and common variation in the sex hormone-binding globulin gene: a population-based case-control study.'],
#  4852: ['[SNP] , also known as c.2909C>A, p.Ala970Asp, A970D and alpha-IIa, represents a variant in the SPTA1 gene on chromosome 1.Although reported as associated with autosomal recessive spherocytosis, the [SNP] (A) allele (as reported in dbSNP orientation) may actually be more of a proxy for a truly defective variant that is co-inherited as a result of linkage.'],
#  819: ['Thyroid nodules, polymorphic variants in DNA repair and RET-related genes, and interaction with ionizing radiation exposure from nuclear tests in Kazakhstan.'],
#  4294: ['The N88K mutation is the most common one leading, when inherited recessively, to congenital myasthenic syndrome.'],
#  1732: ['Aka c.2573T>A, p.Leu858Gln or L858Q, and also c.2573T>G, p.Leu858Arg or L858RThe L858Q variant (in the EGFR gene) is reported in ClinVar as a germline variant considered likely pathogenic in association with non-small cell lung cancer.The L858R variant is reported in ClinVar primarily as a somatic (not germline) variant, observed in tumors and reported to be predictive of response to various chemotherapeutics used to treat non-small cell lung cancer.'],
#  622: ['Yasko also believes that BHMT-08 is related to the impact that psychological stress has on a patients attention levels.'],
#  2773: ['Visceral leishmaniasis (VL) caused by Leishmania chagasi is endemic to northeast Brazil.'],
#  4857: ['This SNP and [SNP] are reported to affect risk of Parkinsons disease.'],
#  3003: ['Mutation analysis of the LH receptor gene in Leydig cell adenoma and hyperplasia and functional and biochemical studies of activating mutations of the LH receptor gene.'],
#  565: ['[SNP] , a SNP also known as Val262, is located in exon 5 of the BACE1 gene, and is associated in some studies (but not others) with increased risk for late-onset Alzheimers disease.'],
#  3041: ['The LPP protein is involved in cell motility and cell&#8211;cell adhesion, which is crucial to maintaining the barrier integrity of epithelial monolayers such as those in the small intestine.A study of several populations eventually settled on [SNP] as the SNP most likely to be the functional variant at the heart of the haplotypes associated with altered risk for celiac disease.'],
#  3161: ['This also meant that each [SNP] (G) allele yielded an odds ratio of 1.85 (CI: 1.51&#8211;2.2, p = 1.45 x 10e-9) of early menopause, defined as occurring before the age of 46.Overall, women homozygous for the early alleles at all 4 SNPs found in this study were ~4 times more likely to undergo menopause early compared to women who had a total of 3 or less risk alleles.'],
#  196: ['[SNP] , also known as -11391 G/A, is a SNP in the promoter of the adiponectin ADIPOQ gene.A small study of 180 Spanish patients with obesity concluded that [SNP] (G;G) individuals are at increased risk of insulin resistance and MetS complications compared to carriers of an (A) allele.'],
#  2845: ['Individuals with risk genotypes of both [SNP] and [SNP] , in the ITPR3 and NKX2.5 genes, respectively, have even high risk for SLE (odds ratio 5.77).This particular SNP also revealed associations with rheumatoid arthritis (RA) (p=0.0084 with odds ratio of 1.23, CI:1.05-1.43) and with Graves disease (GD) (p=0.00036 with odds ratio of 1.57, CI:1.22-2.02).Note that the orientation of this SNP as published is reversed compared to the dbSNP entry.'],
#  2158: ['This SNP in the GABRA2 gene has been linked to Alcoholism.'],
#  4166: ['They are trying to discover why at least a third of people with Alzheimers disease do not have the an APO E4 allele, and why some people who are homozygotes for APO E4 do not get the disease.'],
#  5424: ['Pseudo-haplotype with AG-CC genotypes in 2.45x risk [SNP] - [SNP] 5.03x risk [SNP] - [SNP] - [SNP] 10.10x risk [SNP] - [SNP] - [SNP] - [SNP] A meta-analysis concludes that this SNP is not associated with risk of gastric cancer.'],
#  1403: ['The allele with impaired function, [SNP] (C) , is the CYP21A2 9 allele.See further details at congenital adrenal hyperplasia.'],
#  4209: ['[SNP] , also known as S130L or Ser130Leu, is a SNP in the presenilin 2 PSEN2 gene.Although based on small numbers of patients, the rare [SNP] (T) allele has been reported to be associated with both Alzheimers disease and a form of dilated cardiomyopathy., However, the Alzheimer pathogenicity is considered unclear, and while the evidence for involvement with dilated cardiomyopathy evidence is strong, the condition has incomplete penetrance.'],
#  3010: ['Genetic polymorphisms in fatty acid metabolism genes and colorectal cancer.'],
#  5324: ['Vascular endothelial growth factor gene polymorphisms and rheumatoid arthritis.',
#   'Interaction between smoking and polymorphism in the promoter region of the VEGFA gene is associated with ischemic heart disease and myocardial infarction in rheumatoid arthritis.',
#   'Polymorphism in the vascular endothelial growth factor A (VEGFA) gene is associated with serum VEGF-A level and disease activity in rheumatoid arthritis: differential effect of cigarette smoking.'],
#  3205: ['According to the authors, this is the first study to suggest that genetic factors can affect performance of facial emotion perception.==Association with chronic rhinosinusitis==The MET gene has been implicated in nasal polyp development , and Castano et al showed that the minor allele at [SNP] is associated with chronic rhinosinusitis in patients with nasal polyps (genotypic P nominal = 0.09, empirical P = 0.04, OR = 1.4, CI = 1.0-1.9).',
#   'Study findings apply to patients with nasal polyps and severe CRS unresponsive to surgery.'],
#  4882: ['Abnormal Genetic and Epigenetic Changes in Signal Transducer and Activator of Transcription 4 in the Pathogenesis of Inflammatory Bowel Diseases.'],
#  1711: ['Association study of candidate variants from brain-derived neurotrophic factor and dystrobrevin-binding protein 1 with neuroticism, anxiety, and depression.',
#   'Dysbindin gene (DTNBP1) in major depression: association with clinical response to selective serotonin reuptake inhibitors.'],
#  1278: ['Some evidence suggests that Val158 alleles are associated with schizophrenia, while Met158 alleles are associated with anxiety.Specific studies include: [SNP] , a functional Val/Met polymorphism, showed modest association with Irish familial schizophrenia.',
#   'Also potentially associated with schizophreniaAs part of a haplotype with [SNP] , the (G) allele is also associated with endometrial cancerIn a study of 2 populations of breast cancer patients (2,000+ patients) , increased risk was associated with [SNP] (G;G) genotypes in both the Ontario odds ratio 2.22, CI: 1.49-3.28 and Finland OR 1.73, CI: 1.08-2.78 populations.',
#   'Gray matter volume and interacts with [SNP] related to extracellular dopamine [SNP] /DRD2 and [SNP] /COMT useful in predicting disease risk among schizophrenia patients [SNP] (G;G) carriers deprived of sleep respond quite well to 2x 100mg modafinil in terms of improved vigor and well-being, and maintained baseline performance with respect to executive functioning, whereas [SNP] (A;A) individuals barely responded to the drug at all.'],
#  1115: ['Cystic Fibrosis [SNP].'],
#  1100: ['Cystic Fibrosis [SNP].'],
#  3042: ['Celiac Disease.'],
#  278: ['Hereditary fructose intolerance [SNP].'],
#  1117: ['Cystic Fibrosis [SNP].'],
#  4658: ['Glycogen Storage Disease Type 1b [SNP].'],
#  113: ['Medium-Chain Acyl-CoA Dehydrogenase Deficiency [SNP].'],
#  1597: ['Bipolar disorder failed to replicate in.'],
#  852: ['Clinical spectrum of episodic ataxia type 2.'],
#  4805: ['A polymorphism on the SOD1 gene known as A4V.'],
#  2901: ['Further evidence that the KIAA0319 gene confers susceptibility to developmental dyslexia.'],
#  1140: ['This SNP represents a silent polymorphism in the cancer-associated cell cycle regulator CHEK2 gene.'],
#  3824: ['PEX7 Arg232Ter or R232XRhizomelic chondrodysplasia punctata type 1This SNP is called i5006212 by 23andMe.'],
#  3020: ['Aka c.1296_1299dupGCAC and also c.1296_1299delGCACGCAC; both are annotated in ClinVar as pathogenic or likely pathogenic for cardiomyopathy.'],
#  3646: ['[SNP] increases susceptibility to Substance dependence, Opioid 3.56 times for carriers of the G allele.'],
#  5211: ['Also known as c.5G>A, p.Arg2Lys and R2K Mutations in TUBB8 and Human Oocyte Meiotic Arrest.'],
#  712: ['C.211A>G (p.Arg71Gly) ClinVar designates this variant as pathogenic/likely pathogenic for breast cancer23andMe name: i5005573.'],
#  2218: ['I4000419, also known as V394L (risk genotype AA) Possibly associated with Gauchers disease.Gaucher Disease [SNP].'],
#  4314: ['Haplotype analysis reveals a possible founder effect of RET mutation R114H for Hirschsprungs disease in the Chinese population.'],
#  857: ['Severe arrhythmia disorder caused by cardiac L-type calcium channel mutations.',
#   'Severe arrhythmia disorder caused by cardiac L-type calcium channel mutations.'],
#  990: ['Also known as c.1999delC, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer in ClinVar.'],
#  2972: ['Gwas among adults residing on Korcula Island in Croatia, cholesterol, the C allele associated with decreased total cholesterol levels<br><br>.'],
#  766: ['[SNP] , also known as 3883insA, c.3764_3765insA and p.Asn1255?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  697: ['[SNP] , also known as S1383X, c.4148C>G and p.Ser1383Ter, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  2956: ['KRIT1 gene, c.987C>A, p.Cys329Ter, C329X mutation [SNP] (A) is considered a dominantly inherited pathogenic mutation for cerebral cavernous malformation.'],
#  263: ['The molecular abnormality of albumin Niigata: 269 Asp----Gly.'],
#  3015: ['Association of an intronic haplotype of the LIPC gene with hyperalphalipoproteinemia in two independent populations.'],
#  4785: ['C.136G>A (p.Glu46Lys or E46K) Considered probably pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal dominant Parkinson disease.See also OMIM 163890.000423andMe calls this i5002552.'],
#  351: ['A founder mutation in Anoctamin 5 is a major cause of limb-girdle muscular dystrophy.'],
#  2556: ['It has been associated with slightly (~30%) higher risk for azoospermia (lack of sperm) and thus male infertility in both Chinese and Japanese men.'],
#  3770: ['C.192G>C (p.Glu64Asp or E64D) Considered definitely pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal recessive, early-onset Parkinson disease (type 7) See also OMIM 602533.000523andMe names this i5047044.'],
#  326: ['I6006953, also known as c.1363G>A or p.G455S, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the adult form of hypophosphatasia.'],
#  3219: ['Shows that the following four SNPs in the MHC region play a particular important role in the protection of developing AIDS: [SNP] , [SNP] , [SNP] , [SNP] also including the two variants in CCR5 [SNP] (delta32) and C927T.'],
#  303: ['I5002773, also known as c.881A>C or p.D294A, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the infantile form of hypophosphatasia.'],
#  1674: ['Implicated as part of a haplotype of the dopamine D1 receptor DRD1 gene associated with autism spectrum disorders in families having only affected males.'],
#  606: ['[SNP] , a SNP in the BCR gene on chromosome 22, has been associated with increased risk for depression.'],
#  3785: ['[SNP] , also known as A443T, is a SNP in the PCSK9 gene.It has been reported in several studies (including and ) to be a loss-of-function mutation leading to modestly (~3%) lowered LDL-C levels and thereby somewhat reduced risk for coronary events.'],
#  2232: ['Vitamin D-related genes, serum vitamin D concentrations and prostate cancer risk.'],
#  3877: ['Aka c.9829C>T, p.Arg3277Cys and R3277CConsidered a hypomorphic mutation in terms of end-stage renal disease (ESRD) and autosomal dominant polycystic kidney disease; when homozygous, associated with adult onset ADPKD and when heterozygous more likely to result in the development of just a few cysts.'],
#  5023: ['[SNP] , also known as 1350T/C, is a SNP in the toll-like receptor 2 TLR2 gene.A study of 700 T1D children, 357 nuclear families with T1D children and 796 children from the Environment and Childhood Asthma study concluded that both type-1 diabetes and allergic asthma were significantly associated with the [SNP] (T) allele.'],
#  2703: ['Dust mite exposure modifies the effect of functional IL10 polymorphisms on allergy and asthma exacerbations.Dust mite exposure significantly modified the relation between 3 SNPs in IL10 ( [SNP] , [SNP] , and [SNP] ).'],
#  4763: ['[SNP] , also known as c.821C>T, p.Thr274Ile and T274I, is a mutation in the SMN1 gene on chromosome 5.The rare [SNP] (T) allele is a mutation associated with the recessively inherited type 2 or 3 spinal muscular atrophy.This SNP is referred to as i5005727 by 23andMe.'],
#  3188: ['[SNP] , also known as c.2076_2078delAAT, is a SNP in the MEFV gene.The symptoms of familial Mediterranean fever are caused by the persons own inflammatory response; it is not an infectious disease.'],
#  414: ['Lung cancer [SNP] P = 4.97 x 10 (-10) Update in lung cancer 2008.',
#   'Role of 5p15.33 (TERT-CLPTM1L) , 6p21.33 and 15q25.1 (CHRNA5-CHRNA3) variation and lung cancer risk in never-smokers.'],
#  3407: ['Hypertrophic cardiomyopathy: distribution of disease genes, spectrum of mutations, and implications for a molecular diagnosis strategy.'],
#  1748: ['A study of several cases of familial Parkinsons disease concluded that [SNP] (C) , a very rare allele, may be a dominant mutation leading to late-onset disease.'],
#  3236: ['635 lung cancer cases with onset of disease below 51 years of age and 1,300 controls.',
#   'Major alleles associated with increased in risk of early-onset lung cancer modified by smoking.'],
#  225: ['[SNP] is a SNP in the AGT gene that, at least when part of a haplotype, has been associated with increased risk for developing pre-eclampsia, but it was not reported to have the most influence of the 3 SNPs in the haplotype.'],
#  2591: ['According to the lack of a C allele for this gene indicates an increase in ADHD behavior for children age 3 and 8/9 when they have been exposed to certain food additives: sunset yellow, carmoisine, tartrazine, ponceau 4R, quinoline yellow, allura red AC and sodium benzoate.'],
#  2755: ['A;A homozygous individuals showed a strongly reduced risk of Crohns Disease compared those who were G;G homozygous.'],
#  5200: ['[SNP] , also known as Thr60Ala, Thr80Ala, T60A, T80A, and 238A>G, is a mutation in the transthyretin TTR gene.The risk allele for this SNP, [SNP] (G) , is considered causative for TTR-related familial amyloid polyneuropathy, often manifesting as heart-related symptoms, in those carrying either one or two copies.'],
#  3837: ['News The effectiveness of 17 alpha-hydroxyprogesterone caproate for prevention of recurrent preterm birth is influenced by SNPs.Black women [SNP] homozygous for the major allele treatment significantly reduced the rate of preterm birth.',
#   '[SNP] who had a least one copy of the major allele, treatment significantly reduced in preterm birthnon-black women a least one copy of the minor allele of [SNP] had a significant reduction with treatment with at least one copy of the minor allele of [SNP] had a significant reduction in very preterm birth.'],
#  4073: ['A common SNP only in Asian populations, this SNP and a close neighbor also in PRKCH gene, [SNP] , have been associated with higher risk for subcortical silent brain infarction, a common form of stroke.The odds ratio for carriers of a risk allele is 1.27 (CI: 1.09-1.48, p=0.0026) compared to individuals homozygous for the non-risk allele, based on studies of ~300 Japanese patients.'],
#  4462: ['The cancers most often mentioned in association with G12S are paragangliomas and pheochromocytomas.'],
#  4887: ['A risk haplotype of STAT4 for systemic lupus erythematosus is over-expressed, correlates with anti-dsDNA and shows additive effects with two risk alleles of IRF5.',
#   'Role of STAT4 polymorphisms in systemic lupus erythematosus in a Japanese population: a case-control association study of the STAT1-STAT4 region.',
#   'Population differences in SLE susceptibility genes: STAT4 and BLK, but not PXK, are associated with systemic lupus erythematosus in Hong Kong Chinese.'],
#  655: ['This is a well known BRCA1 gene variant reported to influence your risk for breast cancer and ovarian cancer.'],
#  4625: ['In a study size of 117 Caucasians with Asperger syndrome and 426 controls Single nucleotide polymorphism [SNP] in SLC25A12 gene is associated with Asperger syndrome found association of this SNPs minor allele (A) in SLC25A12 gene with Asperger syndrome.'],
#  164: ['The [SNP] (G) allele was found in 11 of 16 individuals affected by Alzheimers disease (average onset age 69.5 years) from seven late-onset AD families.'],
#  4453: ['There are at least two publications in which the complex allele carrying both variants is reported to be associated with congenital insensitivity to pain (CIP) and/or lower post-operative pain following surgery.However, there is also a report of a patient carrying this complex allele who had a small fiber neuropathy and increased pain.'],
#  1248: ['[SNP] (T;T) was significantly (p=0.031, OR=0.08, 95%CI <0.01 to 1.46) under-represented in South African participants with anterior cruciate ligament ruptures, based on a study of ~100 patients vs ~100 controls.Summary relevant to intervertebral disc disease for [SNP] (T) , from : odds ratio (OR) 3.6 for TT genotype compared with GT or GG, in study of 966 elderly Dutch T allele associated with more severe IVDD in study of 75 Southern European male patients vs 25 controls.'],
#  798: ['The genotypes containing the causal/pathogenic variants are (D;I) and the even rarer (D;D).For information about causal/pathogenic BRCA2 mutations and what they imply about the odds of developing breast cancer, please see the BRCA2 page and links from that page.i4000379 is the identifier used by 23andMe for the 6174delT mutation that is [SNP] as identified in public SNP databases.Additional BRCA information may be found in numerous places online, and within 23andMe, / here.In addition to i4000379, the other names used by 23andMe for the most common causal mutations are i4000377 and i4000378.'],
#  4113: ['Also referred to as 1766A/G plos [SNP] was most strongly positively associated with schizophrenia in families.',
#   'Structural cerebral variations as useful endophenotypes in schizophrenia: do they help construct extended endophenotypes?.',
#   'Functional polymorphisms in PRODH are associated with risk and protection for schizophrenia and fronto-striatal structure and function.',
#   'Executive function, neural circuitry, and genetic mechanisms in schizophrenia.'],
#  1693: ['Association and synergistic interaction between promoter variants of the DRD4 gene in Japanese schizophrenics.'],
#  521: ['Comprehensive analysis of the ATM, CHEK2 and ERBB2 genes in relation to breast tumour characteristics and survival: a population-based case-control and follow-up study.'],
#  111: ['However, the same study describing the decreased gene activity reported that this variant was not associated with histamine intolerance (HIT) , suggesting that the variant may be necessary but not sufficient (on its own) to lead to actual HIT.No association between the promoter SNP [SNP] and the risk of developing NSAID hypersensitivity was seen in a 2012 study of 442 Caucasian patients.A different 2012 study of ~300 patients with selective NSAID hypersensitivity found no association for [SNP]. however, they reported that logistic regression analyses suggested that [SNP] (C;C) homozygotes were related to selective hypersensitivity to ibuprofen.'],
#  2422: ['OMIM reports the [SNP] (A) allele as representing a dominantly inherited mutation associated with ubiquitin-positive frontotemporal lobar degeneration.'],
#  365: ['No evidence for association between BMI and 10 candidate genes at ages 4, 7 and 10 in a large UK sample of twins.Response to Diet and Exercise.'],
#  952: ['Again, the odds ratio suggests a modest protective affect for the minor allele T.An additional study looked at this SNP and its association with RA in individuals of Korean ancestry.',
#   'This study found no association between [SNP] and RA in patients with Korean ancestry.',
#   'The targeted validation study looked at 5 SNPs associated with RA in Europeans in 1,113 Korean cases and 988 controls, and found a p-value of 0.39 and an odds ratio of 1.06, suggesting no association between the SNP and RA in Koreans.'],
#  4729: ['[SNP] (C) odds ratio for myopathy among 20,000 individuals taking either 40 or 80mg of simvastatin daily was 4.5 (CI: 2.6-7.7) per copy of the C allele, and 16.9 (CI: 4.7-61.1) in (C;C) as compared with (T;T) homozygotes.',
#   'The Gene Sherpa points out a 16x odds ratio for myopathy when taking statins and suggests fenofibrates might be a good alterative.From Coriell (re SLCO1B1 haplotypes) : [SNP] (SLCO1B1 1) AAAA [SNP] (SLCO1B1 3) TTTT [SNP] (SLCO1B1 5) TTTT [SNP] (SLCO1B1 6) TTTT A study of ~500 individuals taking statins concluded that [SNP] (C) , i.e.',
#   'A study of >4000 individuals with type 2 diabetes using routine prescribing data from the Electronic Medical Record in Tayside Scotland suggests high proportion [SNP] (C) homozygotes discontinue or reduce their doses of statins / 23andMe blog discussion of this SNP SLCO1B1 genetic variant associated with statin-induced myopathy: a proof-of-concept study using the clinical practice research datalinkStatin Response.'],
#  5035: ['Allograft rejection Carriers of the risk alleles of either [SNP] or [SNP] have a lower rate of acute allograft rejection following lung transplantation.'],
#  1227: ['Further evidence for association of polymorphisms in the CNR1 gene with cocaine addiction: confirmation in an independent sample and meta-analysis.'],
#  249: ['A case-control study of 489 first-episode psychosis patients concluded that while [SNP] was not associated with an increased risk of a psychotic disorder, with lifetime cannabis use, or with frequency of use, there was a significant association between psychosis and cannabis use.',
#   '[SNP] (C;C) individuals with a history of cannabis use had an increased likelihood of a psychotic disorder (odds ratio 2.18, CI: 1.1 - 4.3) when compared with users who were (T;T) carriers.'],
#  3678: ['Studies have demonstrated that individuals with the G allele are more empathetic, feel less lonely, employ more sensitive parenting techniques, and have lower rates of autism (discussed in ) The blog / Not Exactly Rocket Science discusses that Americans with (G;G) tend to be more sensitive parents, more empathetic and less lonely than those with an &#8216;A&#8217;.',
#   'This study found that there is no association between [SNP] variants and the risk of autism in Caucasian children and adolescents.Followup:.'],
#  1092: ['Cystic Fibrosis [SNP].'],
#  3416: ['[SNP] familial hypertrophic cardiomyopathy.'],
#  5235: ['Eye color.'],
#  4747: ['[SNP] spinal muscular atrophy.'],
#  4767: ['Niemann-Pick Disease Type A [SNP].'],
#  5368: ['[SNP] Von Willebrand disease.'],
#  3849: ['[SNP] Parkinsons disease, type 6.'],
#  2322: ['[SNP] recessive GJB2 gene variant associated with deafness.'],
#  3764: ['[SNP] Parkinsons disease, recessive/early-onset, digenic.'],
#  3055: ['Leigh syndrome, French Canadian Type (LSFC) [SNP].'],
#  259: ['Novel nonsense mutation causes analbuminemia in a Moroccan family.'],
#  3873: ['C.6424delC (p.Gln2142Argfs) Listed in ClinVar as pathogenic for autosomal dominant polycystic kidney disease.'],
#  5119: ['Nested association between genetic variation in tryptophan hydroxylase II, bipolar affective disorder, and suicide attempts.'],
#  544: ['X-inactivation in female human embryonic stem cells is in a nonrandom pattern and prone to epigenetic alterations.'],
#  4169: ['Dementia, SPASTIC PARAPARESIS, APRAXIA,.'],
#  993: ['Also known as c.1064delT, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer in ClinVar.'],
#  2185: ['Aka c.862T>C, p.Trp288ArgIdentified in ClinVar as likely pathogenic for Krabbe disease (when inherited recessively or as a compound heterozygote).'],
#  740: ['[SNP] , also known as 3347delAG, c.3228_3229delAG and p.Arg1076_Gly1077ArgAlafs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  982: ['Also known as c.1003C>T, p.Arg335Ter or R335X, the minor allele is considered a pathogenic rare mutation for hereditary diffuse gastric cancer in ClinVar.'],
#  700: ['[SNP] , also known as E1038X, c.3112G>T and p.Glu1038Ter, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  5328: ['Identification of genes and haplotypes that predict rheumatoid arthritis using random forests.'],
#  44: ['Aka c.523A>G (p.Thr175Ala) Based on a 2015 study of <100 patients, individuals carrying a [SNP] (C) allele have a 3.75-fold increase in the probability of developing atrial fibrillation/flutter.'],
#  4333: ['Renalase gene is a novel susceptibility gene for essential hypertension: a two-stage association study in northern Han Chinese population.'],
#  4791: ['C.152G>A (p.Gly51Asp or G51D) Considered definitely pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal dominant Parkinson diseaseSee also OMIM 163890.0006.'],
#  4257: ['The rare (deletion) allele for this PTPRQ gene variant is reported to be causative for a recessive form of deafness; see PTPRQ for details and sources.'],
#  1964: ['In the homozygous minor genotype, it has been reported to lead to trimethylaminuria.'],
#  5176: ['[SNP] , also known as c.19G>A, p.Glu7Lys and E7K, represents a rare mutation in the TRPM4 gene.The minor allele is considered causative in a dominant manner for progressive familial heart block type 1B in ClinVar.'],
#  1210: ['A study of 391 overweight patients concluded that the haplotype of [SNP] (G) and [SNP] (A) was associated with a 1.8-fold higher risk (CI: 1.31-2.54, p < 0.001) of obesity.'],
#  313: ['I6006897, also known as c.1184T>C or p.I395T, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the perinatal form of hypophosphatasia.'],
#  3881: ['Polycystic Kidney disease; see OMIM 601313.0004NM_001009944.2:c.12682C>TThe variant allele of this SNP is considered either definitely pathogenic or highly likely pathogenic for autosomal dominant polycystic kidney disease in the PKD Foundation database.'],
#  4070: ['It has been linked to memory capacity in healthy subjects and to risk for post-traumatic stress disorder Risk allele is A..'],
#  2026: ['[SNP] , also known as c.482_+_2 T>G or , is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  1739: ['Also known as c.1754G>A (p.Arg585Gln) , this rare mutation in the EIF2AK4 gene is reported in ClinVar as leading to - when inherited recessively - rare forms of pulmonary hypertension, specifically, pulmonary capillary hemangiomatosis (PCH) and pulmonary venoocclusive disease (PVOD).'],
#  2252: ['[SNP] (T) allele carriers show a slight increase in risk for Parkinsons disease, based on a study of ~200 patients; odds ratio 1.23, p = 0.048 (i.e.'],
#  3651: ['[SNP] is a SNP in the opioid receptor, mu 1 OPRM1 gene.A study of 688 Caucasian smokers (and non-smoking controls) indicated that the rare [SNP] (G) allele was associated with higher likelihood of smoking initiation and nicotine dependence.'],
#  1004: ['Mutations in the calcium-binding motifs of CDH23 and the 35delG mutation in GJB2 cause hearing loss in one family.'],
#  4464: ['The [SNP] Ser128Arg variation in this gene, known as E-selectin, is linked to several thrombotic disorders. [SNP] (C;C) homozygous carriers of the Ser128Arg allele are at a 4X higher risk for recurrent venous thromboembolism (VTE). heterozygous carriers are not at increased risk.'],
# ...
#  2572: ['Compared with individuals not taking statins, the unadjusted odds ratio of colorectal cancer among [SNP] (A;A) statin users was 0.3 (CI: 0.18-0.51) and among [SNP] (T;T) statin users, 0.66 (CI: 0.41-1.06, p-interaction 0.0012).Their data may advance the development of personalized statin use for reducing the risk of cancer as well as cardiovascular disease among the approximately 25 million people currently using statins worldwide.'],
#  1561: ['[SNP] (A) was associated with up to a 20% increased risk of the various vascular diseases, with an odds ratio of 1.21 for abdominal aortic aneurysm (AAA) (p = 4.6x10-10) , 1.18 for early onset myocardial infarction (MI) (p = 3.1x10-5) , 1.14 for peripheral arterial disease PAD (p = 3.9x10-5) , and 1.2 for pulmonary embolism (PE) (p = 00030) , but it was not associated with intracranial aneurysm or ischemic stroke.',
#   'Theheart.orgDeCode reports that the [SNP] (A;A) genotype is associated with 1.21x odds of peripheral arterial disease (PAD) and 1.32x odds of abdominal aortic aneurysm (AAA).'],
#  31: ['The list of the 9 SNPs is shown below.When treated for depression with citalopram, paroxetine, amitriptyline, or venlafaxine (substrates of the protein encoded by ABCB1) , a highly statistically significant association between the overall genetic variability of these SNPs and the remission was reported by Uhr et al in a study of ~400 German inpatients.'],
#  27: ['Results for other ABCB1 SNPs.The 9 SNPs in the linkage block identified are : [SNP] [SNP] [SNP] [SNP] [SNP] [SNP] [SNP] [SNP] [SNP] [SNP] and [SNP] associated with colonic disease Identifying candidate causal variants responsible for altered activity of the ABCB1 multidrug resistance gene.'],
#  152: ['ACTN3 R577X polymorphism and performance phenotypes in young Chinese male soldiers.'],
#  2392: ['Antioxidant enzyme polymorphisms and neuropsychological outcomes in medulloblastoma survivors: a report from the Childhood Cancer Survivor Study.'],
#  3241: ['[SNP] (G) , [SNP] (A) and [SNP] were associated with increased risk, and [SNP] (A) with reduced risk of recurrent venous thromboembolism no influence on varicose veins.'],
#  3352: ['This SNP) has been linked at least once to each of the following disorders (though not necessarily reproducibly) : autism cancer, including gastric cancer lung cancer head and neck cancer renal cancer cleft lip and cleft palate coronary artery disease dementia depression hyperhomocysteinemia migraine neural tube defects pre-eclampsia (gestational hypertension) schizophrenia thrombosis down syndromePubMed lists over 3,000 studies linking [SNP] to a long list of disorders in various populations across the world, of which only some are mentioned above.',
#   'MTHFR 677C&#8594;T polymorphism is more prevalent among mothers of children with Down syndrome than among control mothers, with an odds ratio of 1.91Gene-wide association study between the methylenetetrahydrofolate reductase gene (MTHFR) and schizophrenia in the Japanese population, with an updated meta-analysis on currently available data.',
#   '[SNP] shows no consistent association with schizophrenia overall in 12 studies totaling 3,000+ patients.'],
#  1094: ['Cystic Fibrosis [SNP].'],
#  3909: ['[SNP] polycystic kidney disease.'],
#  5370: ['[SNP] Von Willebrand disease.'],
#  965: ['[SNP] CDH1, gastric cancer.'],
#  2713: ['[SNP] susceptibility to radiation dermatitis.'],
#  2581: ['Now considered benign in ClinVar.'],
#  96: ['May influence ABO blood group see gs129ABO Blood Type.'],
#  1302: ['Interaction between interleukin 3 and dystrobrevin-binding protein 1 in schizophrenia.'],
#  5347: ['Associated with carotid artery disease, BMI, and LDL-associated apolipoprotein B.'],
#  1445: ['Cytochrome P450 2C8: a review of clinical studies.'],
#  2791: ['[SNP] coronary artery disease 190 affected Asian Indian sibling pairs.'],
#  3470: ['See extensive discussion at [SNP] Nijmegen breakage syndrome and association with numerous cancers [SNP].'],
#  3167: ['Modifying effect of MDM4 variants on risk of HPV16-associated squamous cell carcinoma of oropharynx.'],
#  5214: ['Also known as c.1088T>C, p.Met363Thr and M363T Mutations in TUBB8 and Human Oocyte Meiotic Arrest.'],
#  1050: ['Non-coding variant assessed as part of Blueprint Genetics Retinal dystrophy (266 gene) panel.'],
#  1091: ['Also known as [SNP] there is a specific medicine to treat this form of cystic fibrosis.'],
#  4809: ['[SNP] [SNP] and [SNP] association with Alzheimers diseaseThe T allele appears to be more common in late-onset Alzheimers disease.'],
#  4561: ['Aka c.302C>T (p.Pro101Leu) considered pathogenic for X-linked Lymphoproliferative syndrome, type 1 in ClinVar23andMe name: i5900495.'],
#  4394: ['[SNP] , aka p.Cys35Arg or p.C35R, is a SNP in the RYR1 gene considered causative for malignant hyperthermia.23andMe name: i6017748.'],
#  3345: ['This SNP in the MTHFD1L gene is associated with late-onset Alzheimers disease, according to an article in PLoS Genetics.'],
#  674: ['[SNP] , also known as 1508delAAinsG, c.1389_1390delAAinsG and p.Lys463_Thr464LysProfs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  3552: ['Chronic lymphocytic leukemia [SNP] [SNP] [SNP] [SNP] [SNP] [SNP] Influence of the inducible nitric oxide synthase gene (NOS2A) on inflammatory bowel disease susceptibility.'],
#  3981: ['Aka c.844C>T, p.Pro282SerHeterozygotes are predicted to have a significantly higher risk of colorectal cancer, based on both patient and theoretical studies.'],
#  772: ['[SNP] , also known as 2224insT, c.2105_2106insT and p.Leu702?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  750: ['[SNP] , also known as 2826insAT, c.2707_2708insAT and p.Cys903?fs, is a variant in the BRCA1 gene considered pathogenic for breast cancer in ClinVar.'],
#  1411: ['CYP2B6 (c.516G-->T) and CYP2A6 ( 9B and/or 17) polymorphisms are independent predictors of efavirenz plasma concentrations in HIV-infected patients.'],
#  4180: ['[SNP] , also known as L392P or Leu392Pro, is a SNP in the presenilin 1 PSEN1 gene.The rare [SNP] (C) allele is reported as a pathogenic mutation for Alzheimers disease.'],
#  3630: ['The rare minor allele of this OBSCN SNP is reported in to be a variant leading to left ventricular noncompaction, acting in a dominant manner (i.e.'],
#  308: ['I5900451, also known as c.323C>T or p.P108L, is a SNP in the ALPL gene on chromosome 1.Based on the ALPL gene mutations database, the rare/minor allele is considered pathogenic for the odonto form of hypophosphatasia.'],
#  5033: ['The [SNP] (T) allele was associated with a lower risk of nonfatal myocardial infarction (odds ratio 0.88, CI: 0.77 - 0.99) in 848 patients composed of both postmenopausal women and hypertensive men/women.'],
#  340: ['The T allele is associated with risk of amyotrophic lateral sclerosis (ALS) in Irish and Swedish populations, but not in Polish populations.'],
#  135: ['This SNP in the antiotensin I converting enzyme (ACE) gene may be associated with a higher risk of Alzheimers disease.'],
#  4134: ['Aka c.649dupC (p.Arg217Profs 8) Considered definitely pathogenic in the Movement Disorder Society Genetic mutation database (MDSGene) for autosomal dominant dystonia (type 10) , also known as episodic kinesigenic dyskinesia-1 or paroxysmal kinesigenic dyskinesiasee also OMIM 614386.0001.'],
#  3255: ['Aka c.79+2T>AThis variant in the thrombopoietin receptor-encoding gene, MPL, was reported in 2011 to be a founder mutation the Ashkenazi Jewish (AJ) population for CAMT (congenital amegakaryocytic thrombocytopenia) , and the carrier frequency was estimated to be 1 in 75.'],
#  4186: ['[SNP] , also known as DellM, I83_M84del, and c.247_252delATCATG, represents a mutation in the PSEN1 gene on chromosome 14.This deletion, located in exon 4 of the PSEN1 gene, is considered to be a dominant mutation pathogenic for early-onset Alzheimers disease.,See also: AlzForum.'],
#  3209: ['Association of genetic variation in the MET proto-oncogene with schizophrenia and general cognitive ability.'],
#  1737: ['Also known as c.567dupG (p.Lys190Glufs) , this rare mutation in the EIF2AK4 gene is reported in ClinVar as leading to - when inherited recessively - rare forms of pulmonary hypertension, specifically, pulmonary capillary hemangiomatosis (PCH) and pulmonary venoocclusive disease (PVOD).'],
#  2033: ['[SNP] , also known as c.593 T>G or p.L198R, is a mutation in the FXN gene on chromosome 9.The minor allele of this SNP is associated with Friedreichs ataxia when inherited in two copies or as a compound heterozygote.'],
#  1318: ['Pdf full paper Genome-wide association and meta-analysis of bipolar disorder in individuals of European ancestry.'],
#  4545: ['[SNP] , also known as c.1139A>G, p.Gln380Arg and Q380R, represents a rare mutation in the SGSH gene on chromosome 17.Although still rare, the Q380R mutation is considered one of the most frequent pathogenic mutations associated with Sanfilippo syndrome type A, a recessively inherited disorder also known as mucopolysaccharidosis type IIIA (MPS3A).'],
#  898: ['Prevalence of long-QT syndrome gene variants in sudden infant death syndrome.'],
#  5309: ['Vitamin D metabolism [SNP] increases susceptibility to Idiopathic short stature 1.33 times for heterozygotes (AG) and 1.90 times for homozygotes (GG) [SNP] increases susceptibility to Osteonecrosis in acute lymphoblastic leukemia 3.93 times for heterozygotes (AG) and 6.56 times for homozygotes (GG) [SNP] aka [SNP] allele (A) observed for breast cancer odds ratio (OR) of 1.26.'],
#  2550: ['778 Common variable immunodeficiency disorder (CVID) cases compared with 10,999 controls using the Illumina Immunochip; confirming the previously reported human leukocyte antigen (HLA) associations on chromosome 6p21.'],
#  5121: ['[SNP] , also known as c.907C>T, p.Arg303Trp and R303W, represents a very rare loss-of-function mutation in the TPH2 gene on chromosome 12.A single [SNP] (T) allele was found in a Norwegian female with ADHD as well as major depression.'],
#  4798: ['C allele associated with lower serum lipids in a specific ethnic group.Genetic association of acyl-coenzyme A: cholesterol acyltransferase with cerebrospinal fluid cholesterol levels, brain amyloid load, and risk for Alzheimers disease.',
#   'A allele associated with lower risk of Alzheimers disease.'],
#  617: ['Brain-derived neurotrophic factor gene polymorphisms, neurotransmitter levels, and depressive symptoms in an elderly population.'],
#  4980: ['A 2014 study Genome-wide association study identifies multiple susceptibility loci for pancreatic cancer of 7,683 European cases and 14,397 controls found the minor allele [SNP] (A) in TERT (telomerase reverse transcriptase) conferring a protective effect of statistically genome-wide significance (per-allele odds ratio (OR) = 0.80, 95% confidence interval (CI) 0.76-0.85, P = 9.8E-14) against Pancreatic cancer.For example indicates the A allele might be risk-factor for Asians but protective for Europeans.'],
#  804: ['Aka c.8503T>C (p.Ser2835Pro) This SNP, a variant in the BRCA2 gene, is 1 of 25 SNPs reported to represent independently minor, but cumulatively significant, increased risk for breast cancer.',
#   'For details of all 25 SNPs in this group, along with the two methods used to calculate overall risk estimates for breast cancer, refer to the SNPedia breast cancer entry.For this particular SNP, the risk (minor) allele is (C).23andMe name: i5009299.'],
#  827: ['[SNP] , a SNP located in the BTBD9 gene region, has been linked to a lower frequency of restless legs syndrome, a common sleep disorder, with an overall odds ratio of 0.62 (CI: 0.52-0.75) for the (C) minor allele.'],
#  139: ['More specifically: the [SNP] (A) allele is associated with the ACE-I (insertion) allele, and the [SNP] (G) allele is associated with the ACE-D allele.Another SNP in linkage disequilibrium with the ACE I/D polymorphism is [SNP]., A haplotype of [SNP] , [SNP] , [SNP] increases risk of diabetic nephropathy 4x.'],
#  4120: ['Present in ~0.5% of healthy blood donors, this variant was considered to be a neutral polymorphism for many years even though it was associated with slightly reduced levels of free Protein S in plasma.However, more recently, a 2017 study based on 4,000+ VTE patients has reported that heterozygotes for this variant are at significantly increased risk for venous thromboembolism ( (OR 6.6, CI:4.0–10.6, p=1.73x10e-14).'],
#  250: ['AKT1 polymorphisms and survival of early stage non-small cell lung cancer.'],
#  3170: ['The MECP2 gene is located on the X chromosome, which may be instructive since lupus is a predominantly female disease.An initial survey of 600 Korean patients, followed by 1,000 Caucasian patients, ultimately led to a meta-analysis indicating an odds ratio for the [SNP] (C) risk allele of 1.42 (CI: 1.26&#226;&#8364;&#8220;1.60, p = 1.6&#195;&#8212;10e-08).'],
#  2460: ['Molecular genetic analyses of beta-thalassemia in South India reveals rare mutations in the beta-globin gene.'],
#  4228: ['Polymorphisms in cycloxygenase-2 gene and breast cancer prognosis: association between PTGS2 haplotypes and histopathological features.'],
#  924: ['This gene (and this SNP) were discovered to be strongly associated with 117 patients with eosinophilic esophagitis, a form of esophagitis (or inflammation of the esophagus) that shares many symptoms with gastroesophageal reflux disease (GERD).',
#   'The [SNP] (G;G) homozygous genotype is the most predisposed to developing eosinophilic esophagitis (odds ratio 4.55, CI 1.71&#226;&#8364;&#8220;12.39).'],
#  4599: ['This haplotype is found at ~50% frequency in Native American samples and ~10% in east Asian, but is rare in Europeans and Africans.'],
#  4454: ['There are at least two publications in which the complex allele carrying both variants is reported to be associated with congenital insensitivity to pain (CIP) and/or lower post-operative pain following surgery.However, there is also a report of a patient carrying this complex allele who had a small fiber neuropathy and increased pain.'],
#  3415: ['It was not, however, associated with atrial fibrillation (p=0.14 combined) , pacemaker (p=0.13 combined) , sick sinus syndrome (p=0.18 combined) , or advanced AV block (p=0.33 combined).'],
#  520: ['Sequence variant discovery in DNA repair genes from radiosensitive and radiotolerant prostate brachytherapy patients.'],
#  1484: ['[SNP] (A) ) has been postulated by researchers over the years to have many potential consequences, both positive and negative.On the positive side: this allele may reduce the risk of certain cancers, such as bladder and lung , and it may correlate with somwhat less severe neurodegeneration in Alzheimers.On the other hand, at least two studies PMID 14991823, PMID 15174030 have concluded that the risk of developing Parkinsons disease upon exposure to pesticides is increased from 3 to 8 fold among carriers of CYP2D6 4 alleles.'],
#  3168: ['For individuals with the P53 Arg/Arg genotype, the association was even stronger (p = 5.3e-12) with an odds ratio of 0.16 (95% CI: 0.08&#8211;0.27) , suggesting a possible additive effect of MDM4 and P53 on breast cancer susceptibility.Additionally, smaller scale studies have reported association of [SNP] with esophageal squamous cell carcinoma and ovarian cancer severity and progression.'],
#  1043: ['Association study of genetic variants in eight genes/loci with type 2 diabetes in a Han Chinese population.'],
#  3471: ['Occupational solvent exposure, genetic variation of DNA repair genes, and the risk of non-Hodgkins lymphoma.'],
#  4247: ['In study of 332 Norwegian patients plus a meta-analysis, the [SNP] (A) allele was linked to autoimmune Addisons disease (p=0.003) ==PTPN22 in genetics research==.']}

# %%
# We need the unprocessed CSV file exported from Qualtrics for some of the following information.
# Specifically, let's use this to get the mapping betweeen response IDs (from Qualtrics) and user IDs (from Prolific).
exported_df = pd.read_csv(QUALTRICS_RAW_CSV_EXPORT_PATH)
exported_df.drop(df.index[[0,1]], inplace=True)
prolific_pid_column = "Q564"
response_id_column = "ResponseId"
response_id_to_prolific_pid = dict(zip(exported_df[response_id_column], exported_df[prolific_pid_column]))
response_id_to_prolific_pid
# Out:
# {'R_eOSosrnczqYqE9P': '5f56f670e492b316bbd2a47c',
#  'R_2XjJU6SMJAlU4I2': '5e703f3dd6d4336135b8818d',
#  'R_25R9SJyLb4p6iv7': '5f68eb472f60ad099401f587',
#  'R_1CpRIVeWQ8AGNqi': '5f206e18fb9d281e91500fcd',
#  'R_2wQNxJNyQdjSeq9': '5d3cc9010e510a00013df6f6',
#  'R_qPe5vObZ349P3I5': '5ec5925cb3d6035afea34d20',
#  'R_2Bs2kBIw93NmaCj': '5e7e6df49867d653e250ade8',
#  'R_2wodESRdFsJZ5pq': '5f3e31e2769ffb267b9d1a24',
#  'R_PUpvfu7l6QKh6mJ': '5f4da07b144b1ca7f76c51ed'}

# %%
# Breaking it down by specific users who took the survey.
users_df = df.copy(deep=True)[["response_id","recorded_datetime","status","progress","is_finished","duration"]]
users_df.drop_duplicates(inplace=True)
users_df.reset_index(inplace=True, drop=True)

# Some extra information to know, the duration, and the number of total highlights in each response, and Prolific IDs.
users_df["duration_min"] = users_df["duration"].map(lambda x: math.ceil(x/60))
response_id_to_num_snippets = dict(df.groupby("response_id").size())
users_df["num_snippets"] = users_df["response_id"].map(response_id_to_num_snippets)
users_df["prolific_id"] = users_df["response_id"].map(response_id_to_prolific_pid)
users_df.to_csv(SURVEY_TAKERS_OUTPUT_PATH, index=False)
users_df
# Out:
#          response_id    recorded_datetime      status  progress is_finished  \
# 0  R_eOSosrnczqYqE9P  2020-09-22 10:37:23  IP Address       100        True
# 1  R_2XjJU6SMJAlU4I2  2020-09-22 10:40:27  IP Address       100        True
# 2  R_1CpRIVeWQ8AGNqi  2020-09-22 10:45:55  IP Address       100        True
# 3  R_2wQNxJNyQdjSeq9  2020-09-22 11:20:01  IP Address       100        True
# 4  R_qPe5vObZ349P3I5  2020-09-22 11:32:04  IP Address       100        True
# 5  R_2Bs2kBIw93NmaCj  2020-09-22 12:03:12  IP Address       100        True
# 6  R_2wodESRdFsJZ5pq  2020-09-22 12:13:30  IP Address       100        True
# 7  R_PUpvfu7l6QKh6mJ  2020-09-22 12:35:56  IP Address       100        True
#
#    duration  duration_min  num_snippets               prolific_id
# 0      1252            21            96  5f56f670e492b316bbd2a47c
# 1      1074            18           120  5e703f3dd6d4336135b8818d
# 2      2002            34           171  5f206e18fb9d281e91500fcd
# 3      1438            24           145  5d3cc9010e510a00013df6f6
# 4      3442            58           334  5ec5925cb3d6035afea34d20
# 5      2096            35           235  5e7e6df49867d653e250ade8
# 6      2665            45           248  5f3e31e2769ffb267b9d1a24
# 7      4449            75           223  5f4da07b144b1ca7f76c51ed

# %%
# Create a mapping from unique text IDs to all of the text snippets that were hilighted in these survey results.
unique_text_id_to_snippet_list = {}
for unique_text_id,row_indices in df.groupby("id", axis=0).groups.items():
    hilighted_texts_list = list(df.iloc[row_indices]["snippet"].values)
    unique_text_id_to_snippet_list[unique_text_id] = hilighted_texts_list
print(unique_text_id_to_snippet_list)
# Out:
# {4: ['polymorphism', 'therothrombotic cerebral infarction'], 15: ['congenital Lamellar ichthyosis', 'skin condition'], 21: ["Alzheimer's disease", "late-onset Alzheimer's disease "], 22: ["Alzheimer's disease"], 27: ['depression ', 'depression', 'depressio', 'colonic disease '], 28: ['Polymorphisms in genes that regulate cyclosporine metabolism affect cyclosporine blood levels and clinical outcomes in patients who receive allogeneic hematopoietic stem cell transplantation.', 'esophageal cancer.', ' Pharmacogenetics of antidepressant response. Correlation between genetic polymorphisms', 'rs1045642, also known as C3435T, is a SNP located in the ABCB1 gene. It is often studied in conjunction with rs2032582. C3435T has been mentioned by: A "Silent" Polymorphism in the MDR1 Gene Changes Substrate Specificity (for example, to verapamil) (R)-lansoprazole (Prevacid) concentrations are significantly increased in CYP2C19 extensive metabolizers with ABCB1 C3435T C allele. In a Korean population, plasma concentrations of fexofenadine (Allegra) were 17% lower in 2677AA/3435CC subjects and 47% higher in the 2677TT/3435TT subjects compared to 2677GG/3435CC subjects. In contrast, in this study no association was observed between the C3435T polymorphism and fexofenadine plasma or urine concentrations in a German Caucasian population. A meta-analysis including 9 case-control studies (totaling ~2,500 patients) found no association between rs1045642 and epilepsy riskA study of 98 methadone-maintaining patients concluded that the higher (>150 mg/day) and lower (< or =150 mg/day) methadone dose groups differed significantly in their rs1128503 status (experiment-wise p = 0.0325). Furthermore, individuals with the 3-locus genotype pattern (T;T)-(T;T)-(T;T) for SNPs rs1045642, rs2032582 and rs1128503, respectively, had an approximately 5-fold chance of requiring the \'higher\' methadone dose, while individuals heterozygous for these three SNPs have an approximately 3-fold chance of stabilizing at the \'lower\' methadone dose (point-wise p-value = 0.026). Identifying candidate causal variants responsible for altered activity of the ABCB1 multidrug resistance gene. Genetic predictors of the maximum doses patients receive during clinical use of the anti-epileptic drugs carbamazepine and phenytoin. ABCB1 genotypes and haplotypes in patients with dementia and age-matched non-demented control patients. Association of MDR1 genotypes with susceptibility to colorectal cancer in older non-smokers. Genetic studies of a cluster of acute lymphoblastic leukemia cases in Churchill County, Nevada. MDR1 gene variants, indoor insecticide exposure, and the risk of childhood acute lymphoblastic leukemia. No association between MDR1 (ABCB1) 2677G>T and 3435C>T polymorphism and sporadic colorectal cancer among Bulgarian patients. ABCB1 (MDR1) gene polymorphisms are associated with the clinical response to paroxetine in patients with major depressive disorder. Pharmacogenetics of minimal residual disease response in children with B-precursor acute lymphoblastic leukemia: a report from the Children\'s Oncology Group. Multiplexed genotyping of ABC transporter polymorphisms with the Bioplex suspension array. A PAI-1 (SERPINE1) polymorphism predicts osteonecrosis in children with acute lymphoblastic leukemia: a report from the Children\'s Oncology Group. Association of ABCB1 genetic variants with renal function in Africans and in Caucasians. Genotyping panel for assessing response to cancer chemotherapy. Polymorphisms affecting gene transcription and mRNA processing in pharmacogenetic candidate genes: detection through allelic expression imbalance in human target tissues. Bidirectional translational research: Progress in understanding addictive diseases. The pharmacokinetics and pharmacogenomics of efavirenz and lopinavir/ritonavir in HIV-infected persons requiring hemodialysis. No association of ABCB1 polymorphisms with drug-refractory epilepsy in a north Indian population. Ge ...

# %%
# Use that mapping to create a version of the original dataframe with just the hilighted text snippets.
subset_df = original_df.copy(deep=True)[original_df["id"].isin(unique_text_id_to_snippet_list.keys())]
subset_df["n"] = subset_df["id"].map(lambda x: len(unique_text_id_to_snippet_list[x]))
text_snippets = flatten([unique_text_id_to_snippet_list[i] for i in subset_df["id"].values])

# Extend the dataframe to duplicate each row n times where n is the number of text hilight results from the surveys.
modified_df = subset_df.reindex(np.repeat(subset_df.index.values, subset_df["n"]), method="ffill")

# Make sure that the extension occured as expected based on the number of text snippets, and add them as a new column.
assert len(modified_df) == len(text_snippets)
modified_df["snippet"] = text_snippets
modified_df.head(20)
# Out:
#       gene          snp                                               text  \
# 3    ABCA1    Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...
# 3    ABCA1    Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...
# 14  ABCA12   Rs28940268  This is a recessive SNP for congenital Lamella...
# 14  ABCA12   Rs28940268  This is a recessive SNP for congenital Lamella...
# 15  ABCA12   Rs28940269  This is a recessive SNP for congenital Lamella...
# 15  ABCA12   Rs28940269  This is a recessive SNP for congenital Lamella...
# 16  ABCA12   Rs28940270  This is a recessive SNP for congenital Lamella...
# 16  ABCA12   Rs28940270  This is a recessive SNP for congenital Lamella...
# 17  ABCA12   Rs28940271  This is a recessive SNP for congenital Lamella...
# 17  ABCA12   Rs28940271  This is a recessive SNP for congenital Lamella...
# 18  ABCA12   Rs28940568  This is a recessive SNP for congenital Lamella...
# 18  ABCA12   Rs28940568  This is a recessive SNP for congenital Lamella...
# 24   ABCA7  Rs200538373  rs200538373, also known as c.5570+5G>C, is one...
# 24   ABCA7  Rs200538373  rs200538373, also known as c.5570+5G>C, is one...
# 25   ABCA7    Rs3764650  Alzheimer's disease associated, based on large...
# 47   ABCB4   Rs58238559  aka c.523A>G (p.Thr175Ala)Based on a 2015 stud...
# 52   ABCC2     Rs717620  Association of the multidrug-resistance-associ...
# 52   ABCC2     Rs717620  Association of the multidrug-resistance-associ...
# 82   ABCD1  Rs398123109  aka c.31_46del16 (p.Arg11Serfs)Reported in Cli...
# 82   ABCD1  Rs398123109  aka c.31_46del16 (p.Arg11Serfs)Reported in Cli...
#
#       id  n                              snippet
# 3    4.0  2                         polymorphism
# 3    4.0  2  therothrombotic cerebral infarction
# 14  15.0  2       congenital Lamellar ichthyosis
# 14  15.0  2                       skin condition
# 15  15.0  2       congenital Lamellar ichthyosis
# 15  15.0  2                       skin condition
# 16  15.0  2       congenital Lamellar ichthyosis
# 16  15.0  2                       skin condition
# 17  15.0  2       congenital Lamellar ichthyosis
# 17  15.0  2                       skin condition
# 18  15.0  2       congenital Lamellar ichthyosis
# 18  15.0  2                       skin condition
# 24  21.0  2                  Alzheimer's disease
# 24  21.0  2      late-onset Alzheimer's disease
# 25  22.0  1                  Alzheimer's disease
# 47  44.0  1          atrial fibrillation/flutter
# 52  49.0  2             intrahepatic cholestasis
# 52  49.0  2     nonalcoholic fatty liver disease
# 82  75.0  2                 adrenoleukodystrophy
# 82  75.0  2                 adrenoleukodystrophy

# %%
# Save that dataframe as a new CSV file with just the final cleaned text snippets for each gene and SNP.
modified_df = modified_df[["gene","snp","snippet"]]
modified_df.sort_values(by="gene", inplace=True)
modified_df.to_csv(SNPS_AND_SNIPPETS_OUTPUT_PATH, index=False)
modified_df.to_csv("../genes_snps_snippets.tsv", sep="\t", index=False)
modified_df.head(20)
# Out:
#       gene          snp                              snippet
# 3    ABCA1    Rs1800977                         polymorphism
# 3    ABCA1    Rs1800977  therothrombotic cerebral infarction
# 18  ABCA12   Rs28940568       congenital Lamellar ichthyosis
# 17  ABCA12   Rs28940271                       skin condition
# 17  ABCA12   Rs28940271       congenital Lamellar ichthyosis
# 16  ABCA12   Rs28940270                       skin condition
# 18  ABCA12   Rs28940568                       skin condition
# 15  ABCA12   Rs28940269                       skin condition
# 15  ABCA12   Rs28940269       congenital Lamellar ichthyosis
# 14  ABCA12   Rs28940268                       skin condition
# 14  ABCA12   Rs28940268       congenital Lamellar ichthyosis
# 16  ABCA12   Rs28940270       congenital Lamellar ichthyosis
# 24   ABCA7  Rs200538373                  Alzheimer's disease
# 24   ABCA7  Rs200538373      late-onset Alzheimer's disease
# 25   ABCA7    Rs3764650                  Alzheimer's disease
# 47   ABCB4   Rs58238559          atrial fibrillation/flutter
# 52   ABCC2     Rs717620             intrahepatic cholestasis
# 52   ABCC2     Rs717620     nonalcoholic fatty liver disease
# 82   ABCD1  Rs398123109                 adrenoleukodystrophy
# 82   ABCD1  Rs398123109                 adrenoleukodystrophy

# %%
# How many genes had atleast one snippet associated to it in these results?
len(modified_df["gene"].unique())
# Out:
# 363

# %%
# Create a version of the dataset with mapping genes and SNPs to context sentences.
subset_df = original_df.copy(deep=True)[original_df["id"].isin(id_to_context_sentences.keys())]
subset_df["n"] = subset_df["id"].map(lambda x: len(id_to_context_sentences[x]))
sentences = flatten([id_to_context_sentences[i] for i in subset_df["id"].values])

# Extend the dataframe to duplicate each row n times where n is the number of text hilight results from the surveys.
modified_df = subset_df.reindex(np.repeat(subset_df.index.values, subset_df["n"]), method="ffill")

# Make sure that the extension occured as expected based on the number of text snippets, and add them as a new column.
assert len(modified_df) == len(sentences)
modified_df["context"] = sentences
modified_df.head(20)
# Out:
#        gene          snp                                               text  \
# 3     ABCA1    Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...
# 14   ABCA12   Rs28940268  This is a recessive SNP for congenital Lamella...
# 15   ABCA12   Rs28940269  This is a recessive SNP for congenital Lamella...
# 16   ABCA12   Rs28940270  This is a recessive SNP for congenital Lamella...
# 17   ABCA12   Rs28940271  This is a recessive SNP for congenital Lamella...
# 18   ABCA12   Rs28940568  This is a recessive SNP for congenital Lamella...
# 24    ABCA7  Rs200538373  rs200538373, also known as c.5570+5G>C, is one...
# 25    ABCA7    Rs3764650  Alzheimer's disease associated, based on large...
# 47    ABCB4   Rs58238559  aka c.523A>G (p.Thr175Ala)Based on a 2015 stud...
# 52    ABCC2     Rs717620  Association of the multidrug-resistance-associ...
# 82    ABCD1  Rs398123109  aka c.31_46del16 (p.Arg11Serfs)Reported in Cli...
# 87    ABCG2    Rs1481012  A gene-wide investigation on polymorphisms in ...
# 90    ABCG2    Rs2231142  rs2231142, also known as Q141K and C421A, is a...
# 91    ABCG2    Rs3114018  rs3114018(C), a variant in the ABCG2 gene, was...
# 91    ABCG2    Rs3114018  rs3114018(C), a variant in the ABCG2 gene, was...
# 104     ABO   Rs41302905  may influence ABO blood group see gs129ABO Blo...
# 113     ABO    Rs7853989  This SNP is in the ABO gene, and is therefore ...
# 119     ABO    Rs8176743  This SNP is in the ABO gene, and is therefore ...
# 121     ABO    Rs8176747  This SNP is in the ABO gene, and is therefore ...
# 127    ABP1    Rs2052129  rs2052129, also known as (G4586T), is a varian...
#
#         id  n                                            context
# 3      4.0  1  The -14C->T polymorphism [SNP] of the ABCA1 ge...
# 14    15.0  1  This is a recessive SNP for congenital Lamella...
# 15    15.0  1  This is a recessive SNP for congenital Lamella...
# 16    15.0  1  This is a recessive SNP for congenital Lamella...
# 17    15.0  1  This is a recessive SNP for congenital Lamella...
# 18    15.0  1  This is a recessive SNP for congenital Lamella...
# 24    21.0  1  [SNP] , also known as c.5570+5G>C, is one of s...
# 25    22.0  1  Alzheimers disease associated, based on large ...
# 47    44.0  1  Aka c.523A>G (p.Thr175Ala) Based on a 2015 stu...
# 52    49.0  1  Polymorphisms of MRP2 (ABCC2) are associated w...
# 82    75.0  1  Aka c.31_46del16 (p.Arg11Serfs) Reported in Cl...
# 87    80.0  1  A gene-wide investigation on polymorphisms in ...
# 90    83.0  1  A large study totaling 7,699 participants in t...
# 91    84.0  2  [SNP] (C) , a variant in the ABCG2 gene, was t...
# 91    84.0  2  This study also defined 5 haplotype blocks ass...
# 104   96.0  1  May influence ABO blood group see gs129ABO Blo...
# 113  102.0  1  This SNP is in the ABO gene, and is therefore ...
# 119  102.0  1  This SNP is in the ABO gene, and is therefore ...
# 121  102.0  1  This SNP is in the ABO gene, and is therefore ...
# 127  111.0  1  However, the same study describing the decreas...

# %%
# Save that dataframe as a new CSV file with just the contexts for each gene and SNP.
modified_df = modified_df[["gene","snp","context"]]
modified_df.sort_values(by="gene", inplace=True)
modified_df.to_csv(SNPS_AND_CONTEXTS_OUTPUT_PATH, index=False)
modified_df.to_csv("../genes_snps_contexts.tsv", sep="\t", index=False)
modified_df.head(20)
# Out:
#        gene          snp                                            context
# 3     ABCA1    Rs1800977  The -14C->T polymorphism [SNP] of the ABCA1 ge...
# 14   ABCA12   Rs28940268  This is a recessive SNP for congenital Lamella...
# 15   ABCA12   Rs28940269  This is a recessive SNP for congenital Lamella...
# 16   ABCA12   Rs28940270  This is a recessive SNP for congenital Lamella...
# 17   ABCA12   Rs28940271  This is a recessive SNP for congenital Lamella...
# 18   ABCA12   Rs28940568  This is a recessive SNP for congenital Lamella...
# 24    ABCA7  Rs200538373  [SNP] , also known as c.5570+5G>C, is one of s...
# 25    ABCA7    Rs3764650  Alzheimers disease associated, based on large ...
# 47    ABCB4   Rs58238559  Aka c.523A>G (p.Thr175Ala) Based on a 2015 stu...
# 52    ABCC2     Rs717620  Polymorphisms of MRP2 (ABCC2) are associated w...
# 82    ABCD1  Rs398123109  Aka c.31_46del16 (p.Arg11Serfs) Reported in Cl...
# 87    ABCG2    Rs1481012  A gene-wide investigation on polymorphisms in ...
# 90    ABCG2    Rs2231142  A large study totaling 7,699 participants in t...
# 91    ABCG2    Rs3114018  [SNP] (C) , a variant in the ABCG2 gene, was t...
# 91    ABCG2    Rs3114018  This study also defined 5 haplotype blocks ass...
# 104     ABO   Rs41302905  May influence ABO blood group see gs129ABO Blo...
# 113     ABO    Rs7853989  This SNP is in the ABO gene, and is therefore ...
# 119     ABO    Rs8176743  This SNP is in the ABO gene, and is therefore ...
# 121     ABO    Rs8176747  This SNP is in the ABO gene, and is therefore ...
# 127    ABP1    Rs2052129  However, the same study describing the decreas...
