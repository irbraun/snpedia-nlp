# %%
import pandas as pd
import numpy as np
import json
import random
import datetime
from utils import flatten

# %%
# JSON file from parsing the results of the qualtrics survey designed for extracting phenotypes from text.
QUALTRICS_RESULTS_JSON_PATH = "../qualtrics/results_json_files/test_results.json"

# What the survey was built from, the IDs in this refer to unique text strings so that duplicates weren't part of it.
SURVEY_SOURCE_DATA_PATH = "../data/4_binned_and_blocked_texts.csv"

# This is the original data with duplicate text strings because IDs refer to particular SNPs from particular genes.
ORIGINAL_DATA_PATH = "../data/2_snps_and_cleaned_text.csv"

# Where to send the resulting output dataframes as CSV files.
random_six_digit_number = random.randrange(100000,999999)
datetime_str = datetime.datetime.now().strftime('%m_%d_%Y_h%Hm%Ms%S')
key = "{}_{}".format(random_six_digit_number, datetime_str)

RESPONSES_OUTPUT_PATH = "../data/5_processed_survey_responses_{}.csv".format(key)
SNPS_AND_SNIPPETS_OUTPUT_PATH = "../data/6_snps_and_snippets_{}.csv".format(key)

# %%
# Make sure the mapping between the unique texts used to create the survey and the original SNP data exists.
original_df = pd.read_csv(ORIGINAL_DATA_PATH)
survey_df = pd.read_csv(SURVEY_SOURCE_DATA_PATH)
text_to_unique_text_id = dict(zip(survey_df.text, survey_df.id))
unique_text_id_to_text = dict(zip(survey_df.id, survey_df.text))
original_df["id"] = original_df["text"].map(text_to_unique_text_id)
original_df.head(20)
# Out:
#       gene         snp                                               text  \
# 0    AANAT  Rs28936679  rs28936679, also known as Ala129Thr or A129T (...
# 1    AANAT   Rs3760138  Genetic differences in human circadian clock g...
# 2    AANAT   Rs4238989  Genetic differences in human circadian clock g...
# 3    ABCA1   Rs1800977  The -14C->T polymorphism rs1800977 of the ABCA...
# 4    ABCA1   Rs1883025  Apolipoprotein E levels in cerebrospinal fluid...
# 5    ABCA1   Rs2020927  rs2297404, rs2230808, and rs2020927 haplotype ...
# 6    ABCA1   Rs2066714  Apolipoprotein E levels in cerebrospinal fluid...
# 7    ABCA1   Rs2066715  Apolipoprotein E levels in cerebrospinal fluid...
# 8    ABCA1   Rs2230806  rs2230806, also known as Arg219Lys or R219K, i...
# 9    ABCA1   Rs2230808  rs2297404, rs2230808, and rs2020927 haplotype ...
# 10   ABCA1   Rs2297404  rs2297404, rs2230808, and rs2020927 haplotype ...
# 11   ABCA1    Rs363717  Examining the effect of linkage disequilibrium...
# 12   ABCA1   Rs4149268  G allele is associated with 0.82mg/dl increase...
# 13   ABCA1   Rs4149274  C allele is associated with 1.51mg/dl increase...
# 14  ABCA12  Rs28940268  This is a recessive SNP for congenital Lamella...
# 15  ABCA12  Rs28940269  This is a recessive SNP for congenital Lamella...
# 16  ABCA12  Rs28940270  This is a recessive SNP for congenital Lamella...
# 17  ABCA12  Rs28940271  This is a recessive SNP for congenital Lamella...
# 18  ABCA12  Rs28940568  This is a recessive SNP for congenital Lamella...
# 19  ABCA12    Rs726070  aka c.7093G>A (p.Asp2365Asn)The variant allele...
#
#       id
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    7.0
# 7    8.0
# 8    9.0
# 9   10.0
# 10  11.0
# 11  12.0
# 12  13.0
# 13  14.0
# 14  15.0
# 15  15.0
# 16  15.0
# 17  15.0
# 18  15.0
# 19  16.0

# %%
# Create a dictionary using the JSON data output from a qualtrics survey.
with open(QUALTRICS_RESULTS_JSON_PATH) as f:
    responses = json.load(f)
responses
# Out:
# [{'response_id': 'R_ylqfW7N5mTbCAdr',
#   'recorded_datetime': '2020-09-18 08:51:41',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 57,
#   'hilights': [{'qid': 5379,
#     'selection': 'Von Willebrand disease',
#     'selection_index': 10},
#    {'qid': 1088, 'selection': 'Cystic Fibrosis', 'selection_index': 0},
#    {'qid': 1087, 'selection': 'ystic Fibrosi', 'selection_index': 1},
#    {'qid': 4307,
#     'selection': 'Hirschsprung disease',
#     'selection_index': 156}]},
#  {'response_id': 'R_cNnkm3qGUXV4il3',
#   'recorded_datetime': '2020-09-18 08:52:30',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 40,
#   'hilights': []},
#  {'response_id': 'R_2ZPwp88WejcgblC',
#   'recorded_datetime': '2020-09-18 08:58:38',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 132,
#   'hilights': []},
#  {'response_id': 'R_2EFfqG0VkHP6Eef',
#   'recorded_datetime': '2020-09-18 09:01:08',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 143,
#   'hilights': [{'qid': 1883,
#     'selection': 'Marfan syndrome',
#     'selection_index': 0}]},
#  {'response_id': 'R_2DTe1LE1eho59rQ',
#   'recorded_datetime': '2020-09-18 09:05:58',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 46,
#   'hilights': []},
#  {'response_id': 'R_cHBI2Cg42MmRZSN',
#   'recorded_datetime': '2020-09-18 09:06:27',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 211,
#   'hilights': [{'qid': 2164, 'selection': 'gwas', 'selection_index': 9},
#    {'qid': 2164, 'selection': 'spatial recognition', 'selection_index': 39},
#    {'qid': 916, 'selection': 'leprosy', 'selection_index': 74}]},
#  {'response_id': 'R_pN3Kc5bjVbkY4j7',
#   'recorded_datetime': '2020-09-18 09:13:59',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 388,
#   'hilights': [{'qid': 1100,
#     'selection': 'Cystic Fibrosis',
#     'selection_index': 0},
#    {'qid': 1080, 'selection': 'Cystic Fibrosis', 'selection_index': 0},
#    {'qid': 3706, 'selection': 'nylketonur', 'selection_index': 3},
#    {'qid': 879, 'selection': 'pathogenic', 'selection_index': 5},
#    {'qid': 5193, 'selection': 'Mutations', 'selection_index': 96},
#    {'qid': 5193, 'selection': 'Asthenoteratospermia', 'selection_index': 144},
#    {'qid': 1385, 'selection': 'allele', 'selection_index': 99}]},
#  {'response_id': 'R_Ov7rH78Q4gGMZP3',
#   'recorded_datetime': '2020-09-18 09:14:26',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 27,
#   'hilights': []},
#  {'response_id': 'R_XnOPVmddh1rciGd',
#   'recorded_datetime': '2020-09-18 09:17:19',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 185,
#   'hilights': []},
#  {'response_id': 'R_1GZJCoftfNV96Jn',
#   'recorded_datetime': '2020-09-18 11:27:59',
#   'status': 'Survey Preview',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 155,
#   'hilights': [{'qid': 3936, 'selection': 'PKHD1', 'selection_index': 15},
#    {'qid': 1111, 'selection': 'Cystic Fibrosis', 'selection_index': 0},
#    {'qid': 1106, 'selection': 'Cystic Fibrosis', 'selection_index': 0},
#    {'qid': 1093, 'selection': 'Cystic Fibrosis', 'selection_index': 0},
#    {'qid': 1964,
#     'selection': 'lead to trimethylaminuria',
#     'selection_index': 122},
#    {'qid': 2996, 'selection': 'weight regain', 'selection_index': 162},
#    {'qid': 2996,
#     'selection': 'obesity-related genes and endometrial cancer risk',
#     'selection_index': 202},
#    {'qid': 3069,
#     'selection': 'autosomal dominant Parkinson disorder',
#     'selection_index': 142},
#    {'qid': 22,
#     'selection': 'later age at onset and shorter disease course',
#     'selection_index': 120},
#    {'qid': 22, 'selection': "Alzheimer's disease", 'selection_index': 0},
#    {'qid': 900, 'selection': 'rippling muscle disease', 'selection_index': 72},
#    {'qid': 900,
#     'selection': 'Novel missense mutation in the caveolin-3 gene in a Belgian family with rippling mu',
#     'selection_index': 97},
#    {'qid': 900, 'selection': 'cle disease.', 'selection_index': 181},
#    {'qid': 3065,
#     'selection': "25% chance of Parkinson's disease",
#     'selection_index': 5316},
#    {'qid': 3065, 'selection': ' in their lifetime', 'selection_index': 5349}]},
#  {'response_id': 'R_1meFBGiOv6vrML9',
#   'recorded_datetime': '2020-09-18 11:30:23',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 8152,
#   'hilights': [{'qid': 3937, 'selection': 'PKHD', 'selection_index': 15}]},
#  {'response_id': 'R_2U5EdZFh1JIUPyI',
#   'recorded_datetime': '2020-09-18 11:34:10',
#   'status': 'Survey Preview',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 71,
#   'hilights': [{'qid': 1100, 'selection': 'isrs12190', 'selection_index': 13},
#    {'qid': 385,
#     'selection': 'y be related to longevity. One study found that Ashkenazi who lived to ',
#     'selection_index': 11},
#    {'qid': 248,
#     'selection': ' or W278X)This recessively inherited mutation is considered the most com',
#     'selection_index': 25},
#    {'qid': 4820,
#     'selection': "reased (or decreased) risk for Alzheimer's disease in a study of 1",
#     'selection_index': 85},
#    {'qid': 2168,
#     'selection': 'endence. Polymorphisms in the glutamate decarboxylase 1 gene associated with',
#     'selection_index': 161},
#    {'qid': 1104, 'selection': 'Cystic fibrosis', 'selection_index': 0},
#    {'qid': 1104, 'selection': '(CF)', 'selection_index': 16}]},
#  {'response_id': 'R_Qc4g2cQmkN34J3j',
#   'recorded_datetime': '2020-09-18 11:36:10',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 27,
#   'hilights': []},
#  {'response_id': 'R_3kMpGim0E5HkEaq',
#   'recorded_datetime': '2020-09-18 11:45:08',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 881,
#   'hilights': []},
#  {'response_id': 'R_1Qhc1M7zHVs3uBm',
#   'recorded_datetime': '2020-09-18 11:45:10',
#   'status': 'Survey Preview',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 218,
#   'hilights': [{'qid': 3215,
#     'selection': 'methylation',
#     'selection_index': 30},
#    {'qid': 3215, 'selection': 'colorectal cancer', 'selection_index': 151},
#    {'qid': 2047, 'selection': "Friedreich's ataxia", 'selection_index': 158},
#    {'qid': 2725, 'selection': 'herpes', 'selection_index': 36},
#    {'qid': 2725, 'selection': 'schizophrenia', 'selection_index': 18},
#    {'qid': 2725,
#     'selection': 'herpes simplex virus 1',
#     'selection_index': 119},
#    {'qid': 2725, 'selection': 'schizophrenia', 'selection_index': 58},
#    {'qid': 4247, 'selection': '==Other diseases==', 'selection_index': 7794}]},
#  {'response_id': 'R_3nDf3Fl9mgsPaJu',
#   'recorded_datetime': '2020-09-21 09:18:03',
#   'status': 'IP Address',
#   'progress': 100,
#   'is_finished': 'True',
#   'duration': 1487,
#   'hilights': [{'qid': 276,
#     'selection': 'hereditary fructosuria',
#     'selection_index': 9},
#    {'qid': 1814, 'selection': 'Factor XI Deficiency', 'selection_index': 0},
#    {'qid': 4837,
#     'selection': 'associated with non-obstructive azoospermia',
#     'selection_index': 11},
#    {'qid': 5363, 'selection': 'Von Willebrand disease', 'selection_index': 10},
#    {'qid': 3819,
#     'selection': 'Rhizomelic Chondrodysplasia Punctata Type 1',
#     'selection_index': 0},
#    {'qid': 5079,
#     'selection': 'familial hypertrophic cardiomyopathy',
#     'selection_index': 11},
#    {'qid': 2979,
#     'selection': 'epidermolysis bullosa, junctional,',
#     'selection_index': 0},
#    {'qid': 2979, 'selection': 'Herlitz type', 'selection_index': 35},
#    {'qid': 2310,
#     'selection': 'gene variant associated with deafness',
#     'selection_index': 25},
#    {'qid': 1809, 'selection': 'breast cancer', 'selection_index': 0},
#    {'qid': 948,
#     'selection': "Alzheimer's disease associated",
#     'selection_index': 0},
#    {'qid': 1723,
#     'selection': 'susceptibility to vitiligo in a Korean population',
#     'selection_index': 60},
#    {'qid': 2705,
#     'selection': 'Primary biliary cirrhosis',
#     'selection_index': 0},
#    {'qid': 4321, 'selection': 'multiple sclerosis', 'selection_index': 71},
#    {'qid': 2743,
#     'selection': 'severity of knee osteoarthritis',
#     'selection_index': 13},
#    {'qid': 3873,
#     'selection': 'autosomal dominant polycystic kidney disease',
#     'selection_index': 64},
#    {'qid': 3596,
#     'selection': 'multiple measures of blood pressure',
#     'selection_index': 86},
#    {'qid': 5352,
#     'selection': 'Pontocerebellar hypoplasia type 2E',
#     'selection_index': 61},
#    {'qid': 568, 'selection': ' testicular cance', 'selection_index': 65},
#    {'qid': 3049, 'selection': 'OMIM pathogenic', 'selection_index': 48},
#    {'qid': 986,
#     'selection': 'pathogenic rare mutation for hereditary diffuse gastric cancer',
#     'selection_index': 59},
#    {'qid': 5266,
#     'selection': 'pathogenic for familial hemophagocytic lymphohistiocytosis (HLH)',
#     'selection_index': 38},
#    {'qid': 990,
#     'selection': 'pathogenic rare mutation for hereditary diffuse gastric cancer',
#     'selection_index': 59},
#    {'qid': 4841,
#     'selection': '1.46 times higher odds of primary biliary cirrhosis',
#     'selection_index': 62},
#    {'qid': 4776,
#     'selection': 'eastern Indian attention deficit hyperactivity disorder',
#     'selection_index': 131},
#    {'qid': 741,
#     'selection': 'pathogenic for breast cancer',
#     'selection_index': 109},
#    {'qid': 5284,
#     'selection': 'visual impairment in Usher syndrome 1b and Usher syndrome 2a',
#     'selection_index': 104},
#    {'qid': 772,
#     'selection': 'pathogenic for breast cancer',
#     'selection_index': 111},
#    {'qid': 112,
#     'selection': 'diamine oxidase serum activities',
#     'selection_index': 94},
#    {'qid': 112,
#     'selection': 'lower DAO mRNA expressio',
#     'selection_index': 180},
#    {'qid': 112, 'selection': 'reduced DAO activity', 'selection_index': 134},
#    {'qid': 5320,
#     'selection': 'smaller hippocampal volumes',
#     'selection_index': 106},
#    {'qid': 1131,
#     'selection': 'condition not specified, but based on similar mutations also in the CHAMP1 gene, likely to be a form of autosomal dominant mental retardation',
#     'selection_index': 68},
#    {'qid': 1808,
#     'selection': 'associated with longevity',
#     'selection_index': 175},
#    {'qid': 4011,
#     'selection': 'increase risk for colorectal cancer',
#     'selection_index': 180},
#    {'qid': 2556,
#     'selection': 'associated with slightly (~30%) higher risk for azoospermia (lack of sperm) and thus male infertility in both Chinese and Japanese men',
#     'selection_index': 55},
#    {'qid': 3577,
#     'selection': 'increased circulating natriuretic peptide and thus lower blood pressure',
#     'selection_index': 40},
#    {'qid': 304,
#     'selection': 'pathogenic for the infantile form of hypophosphatasia',
#     'selection_index': 166},
#    {'qid': 4797,
#     'selection': 'thinking cilantro tastes like soap',
#     'selection_index': 76},
#    {'qid': 2267,
#     'selection': 'late-onset noninsulin-dependent diabetes',
#     'selection_index': 97},
#    {'qid': 2627,
#     'selection': 'Schwartz Jampel syndrome type 1 and Lethal Kniest-like syndrome',
#     'selection_index': 65},
#    {'qid': 3116,
#     'selection': 'lower frequency of restless legs syndrome',
#     'selection_index': 77},
#    {'qid': 3116, 'selection': 'ommon sleep disorder', 'selection_index': 123},
#    {'qid': 3239, 'selection': 'lumbar disc disease', 'selection_index': 148},
#    {'qid': 3017,
#     'selection': 'lipoyltransferase 1 deficiency',
#     'selection_index': 199},
#    {'qid': 5311, 'selection': 'prostate cancer', 'selection_index': 126},
#    {'qid': 1145,
#     'selection': 'risk of coronary heart disease',
#     'selection_index': 353},
#    {'qid': 1145, 'selection': 'plasma concentration', 'selection_index': 328},
#    {'qid': 1145,
#     'selection': 'circulating YKL-40 levels',
#     'selection_index': 181},
#    {'qid': 1145,
#     'selection': 'not with angiographic coronary artery disease',
#     'selection_index': 212},
#    {'qid': 4250, 'selection': 'rheumatoid arthritis', 'selection_index': 227},
#    {'qid': 4250, 'selection': 'rheumatoid arthritis', 'selection_index': 274},
#    {'qid': 567,
#     'selection': 'slightly lower (0.8-0.87x) risk for adult ADHD',
#     'selection_index': 334},
#    {'qid': 2919, 'selection': 'sickle cell anemia', 'selection_index': 95},
#    {'qid': 2919, 'selection': 'risk for priapism', 'selection_index': 151},
#    {'qid': 748, 'selection': 'breast cancer', 'selection_index': 147},
#    {'qid': 2872, 'selection': 'cardiac arrhythmias', 'selection_index': 77},
#    {'qid': 4854, 'selection': 'ovarian cancer', 'selection_index': 353},
#    {'qid': 3236, 'selection': 'smoking', 'selection_index': 174},
#    {'qid': 3143, 'selection': 'red hair', 'selection_index': 98},
#    {'qid': 3143, 'selection': 'low tanning', 'selection_index': 122},
#    {'qid': 4484,
#     'selection': 'chronic obstructive pulmonary disease',
#     'selection_index': 339},
#    {'qid': 1232, 'selection': 'cannabis dependence', 'selection_index': 96},
#    {'qid': 1232,
#     'selection': 'longest gaze duration for happy faces',
#     'selection_index': 468},
#    {'qid': 1232,
#     'selection': 'gaze duration for happy faces',
#     'selection_index': 403},
#    {'qid': 713, 'selection': 'breast cancer', 'selection_index': 179},
#    {'qid': 2467,
#     'selection': 'haematological characterization of beta-thalassaemia major',
#     'selection_index': 444},
#    {'qid': 3948,
#     'selection': 'greater risk for gastric cancer',
#     'selection_index': 329},
#    {'qid': 3948, 'selection': 'stomach cancer', 'selection_index': 366},
#    {'qid': 2200, 'selection': 'Duarte galactosemia', 'selection_index': 316},
#    {'qid': 935,
#     'selection': 'recurrent venous thromboembolism',
#     'selection_index': 530},
#    {'qid': 1612,
#     'selection': 'neonatal hyperbilirubinemia',
#     'selection_index': 780},
#    {'qid': 1612,
#     'selection': 'endometrial cancer risk',
#     'selection_index': 435},
#    {'qid': 3245,
#     'selection': 'increased risk for Achilles tendinopathy',
#     'selection_index': 738},
#    {'qid': 2640,
#     'selection': 'modest effect on depression severity',
#     'selection_index': 389},
#    {'qid': 2640,
#     'selection': 'risk for rheumatoid arthritis',
#     'selection_index': 1007},
#    {'qid': 2640,
#     'selection': 'quantitative traits in panic disorder',
#     'selection_index': 1484},
#    {'qid': 3975,
#     'selection': 'alcoholic liver disease',
#     'selection_index': 652},
#    {'qid': 3975, 'selection': 'alcoholic cirrhosis', 'selection_index': 699},
#    {'qid': 3010,
#     'selection': 'coronary artery disease',
#     'selection_index': 401},
#    {'qid': 2750, 'selection': 'ulcerative colitis', 'selection_index': 1506},
#    {'qid': 2750, 'selection': 'ulcerative colitis', 'selection_index': 1660},
#    {'qid': 5035, 'selection': 'asthma', 'selection_index': 1784},
#    {'qid': 450,
#     'selection': 'polypoidal choroidal vasculopathy',
#     'selection_index': 3805}]}]

# %%
# Load the original source CSV that was used in creating the survey. This will used to check against the results.
# We want to make sure there is no discrepency in which IDs are referring to which texts.
source_df = pd.read_csv(SURVEY_SOURCE_DATA_PATH)
#source_df.reset_index(drop=False, inplace=True)

# Question IDs in the actual survey will use the 
#source_df["qid"] = source_df["index"]
#source_df.drop(labels=["index"], axis=1, inplace=True)
#qid_to_source_text = {i:text for i,text in zip(source_df["qid"].values, source_df["text"].values)}
#qid_to_unique_text_id = {qid:i for qid,i in zip(source_df["qid"].values, source_df["id"].values)}
source_df.head(10)
# Out:
#      id                       text  bin_id  bin_size  block_id  block_size  \
# 0  1169                    smoking       1       988         1         247
# 1  3702  Phenylketonuriars62514952       1       988         1         247
# 2  3701   Phenylketonuriars5030860       1       988         1         247
# 3  3700   Phenylketonuriars5030859       1       988         1         247
# 4  3699   Phenylketonuriars5030856       1       988         1         247
# 5  3698   Phenylketonuriars5030851       1       988         1         247
# 6  3697   Phenylketonuriars5030850       1       988         1         247
# 7  3696   Phenylketonuriars5030847       1       988         1         247
# 8  3695   Phenylketonuriars5030846       1       988         1         247
# 9  3694   Phenylketonuriars5030843       1       988         1         247
#
#    block_sample
# 0             5
# 1             5
# 2             5
# 3             5
# 4             5
# 5             5
# 6             5
# 7             5
# 8             5
# 9             5

# %%
# Put the responses into a dataframe.
row_tuples = []
for response in responses:
    
    # Metadata associated with this response.
    response_id = response["response_id"]
    recorded_datetime = response["recorded_datetime"]
    status = response["status"]
    progress = response["progress"]
    is_finished = response["is_finished"]
    duration = response["duration"]


    # The actual highlighted text strings from this response.
    for hilight in response["hilights"]:

        # The information about this one particular highlight.
        qid = hilight["qid"]
        hilighted_text = hilight["selection"]
        index_of_first_selected_char = hilight["selection_index"]
        source_text = unique_text_id_to_text[qid]        

        # First check that the question IDs are correct so we know what the source text was for this question.
        # Then additionally make sure the location of the highlight makes sense as well.
        assert hilighted_text in source_text
        #assert source_text[index_of_first_selected_char:index_of_first_selected_char+len(hilighted_text)] == hilighted_text
        indices_match = (source_text[index_of_first_selected_char:index_of_first_selected_char+len(hilighted_text)] == hilighted_text)
        
        
        # Add this as a row.
        row_tuples.append((response_id, recorded_datetime, status, progress, is_finished, duration, qid, hilighted_text, indices_match))

columns = ["response_id", "recorded_datetime", "status", "progress", "is_finished", "duration", "id", "snippet", "idx_match"]
df = pd.DataFrame(row_tuples, columns=columns)
df.to_csv(RESPONSES_OUTPUT_PATH, index=False)
df.head(20)
# Out:
#           response_id    recorded_datetime          status  progress  \
# 0   R_ylqfW7N5mTbCAdr  2020-09-18 08:51:41      IP Address       100
# 1   R_ylqfW7N5mTbCAdr  2020-09-18 08:51:41      IP Address       100
# 2   R_ylqfW7N5mTbCAdr  2020-09-18 08:51:41      IP Address       100
# 3   R_ylqfW7N5mTbCAdr  2020-09-18 08:51:41      IP Address       100
# 4   R_2EFfqG0VkHP6Eef  2020-09-18 09:01:08      IP Address       100
# 5   R_cHBI2Cg42MmRZSN  2020-09-18 09:06:27      IP Address       100
# 6   R_cHBI2Cg42MmRZSN  2020-09-18 09:06:27      IP Address       100
# 7   R_cHBI2Cg42MmRZSN  2020-09-18 09:06:27      IP Address       100
# 8   R_pN3Kc5bjVbkY4j7  2020-09-18 09:13:59      IP Address       100
# 9   R_pN3Kc5bjVbkY4j7  2020-09-18 09:13:59      IP Address       100
# 10  R_pN3Kc5bjVbkY4j7  2020-09-18 09:13:59      IP Address       100
# 11  R_pN3Kc5bjVbkY4j7  2020-09-18 09:13:59      IP Address       100
# 12  R_pN3Kc5bjVbkY4j7  2020-09-18 09:13:59      IP Address       100
# 13  R_pN3Kc5bjVbkY4j7  2020-09-18 09:13:59      IP Address       100
# 14  R_pN3Kc5bjVbkY4j7  2020-09-18 09:13:59      IP Address       100
# 15  R_1GZJCoftfNV96Jn  2020-09-18 11:27:59  Survey Preview       100
# 16  R_1GZJCoftfNV96Jn  2020-09-18 11:27:59  Survey Preview       100
# 17  R_1GZJCoftfNV96Jn  2020-09-18 11:27:59  Survey Preview       100
# 18  R_1GZJCoftfNV96Jn  2020-09-18 11:27:59  Survey Preview       100
# 19  R_1GZJCoftfNV96Jn  2020-09-18 11:27:59  Survey Preview       100
#
#    is_finished  duration    id                    snippet  idx_match
# 0         True        57  5379     Von Willebrand disease       True
# 1         True        57  1088            Cystic Fibrosis       True
# 2         True        57  1087              ystic Fibrosi       True
# 3         True        57  4307       Hirschsprung disease       True
# 4         True       143  1883            Marfan syndrome       True
# 5         True       211  2164                       gwas       True
# 6         True       211  2164        spatial recognition       True
# 7         True       211   916                    leprosy       True
# 8         True       388  1100            Cystic Fibrosis       True
# 9         True       388  1080            Cystic Fibrosis       True
# 10        True       388  3706                 nylketonur       True
# 11        True       388   879                 pathogenic       True
# 12        True       388  5193                  Mutations       True
# 13        True       388  5193       Asthenoteratospermia       True
# 14        True       388  1385                     allele       True
# 15        True       155  3936                      PKHD1       True
# 16        True       155  1111            Cystic Fibrosis       True
# 17        True       155  1106            Cystic Fibrosis       True
# 18        True       155  1093            Cystic Fibrosis       True
# 19        True       155  1964  lead to trimethylaminuria       True

# %%
# Create a mapping from unique text IDs to all of the text snippets that were hilighted in these survey results.
unique_text_id_to_text_list = {}
for unique_text_id,row_indices in df.groupby("id", axis=0).groups.items():
    hilighted_texts_list = list(df.iloc[row_indices]["snippet"].values)
    unique_text_id_to_text_list[unique_text_id] = hilighted_texts_list
print(unique_text_id_to_text_list)
# Out:
# {22: ['later age at onset and shorter disease course', "Alzheimer's disease"], 112: ['diamine oxidase serum activities', 'lower DAO mRNA expressio', 'reduced DAO activity'], 248: [' or W278X)This recessively inherited mutation is considered the most com'], 276: ['hereditary fructosuria'], 304: ['pathogenic for the infantile form of hypophosphatasia'], 385: ['y be related to longevity. One study found that Ashkenazi who lived to '], 450: ['polypoidal choroidal vasculopathy'], 567: ['slightly lower (0.8-0.87x) risk for adult ADHD'], 568: [' testicular cance'], 713: ['breast cancer'], 741: ['pathogenic for breast cancer'], 748: ['breast cancer'], 772: ['pathogenic for breast cancer'], 879: ['pathogenic'], 900: ['rippling muscle disease', 'Novel missense mutation in the caveolin-3 gene in a Belgian family with rippling mu', 'cle disease.'], 916: ['leprosy'], 935: ['recurrent venous thromboembolism'], 948: ["Alzheimer's disease associated"], 986: ['pathogenic rare mutation for hereditary diffuse gastric cancer'], 990: ['pathogenic rare mutation for hereditary diffuse gastric cancer'], 1080: ['Cystic Fibrosis'], 1087: ['ystic Fibrosi'], 1088: ['Cystic Fibrosis'], 1093: ['Cystic Fibrosis'], 1100: ['Cystic Fibrosis', 'isrs12190'], 1104: ['Cystic fibrosis', '(CF)'], 1106: ['Cystic Fibrosis'], 1111: ['Cystic Fibrosis'], 1131: ['condition not specified, but based on similar mutations also in the CHAMP1 gene, likely to be a form of autosomal dominant mental retardation'], 1145: ['risk of coronary heart disease', 'plasma concentration', 'circulating YKL-40 levels', 'not with angiographic coronary artery disease'], 1232: ['cannabis dependence', 'longest gaze duration for happy faces', 'gaze duration for happy faces'], 1385: ['allele'], 1612: ['neonatal hyperbilirubinemia', 'endometrial cancer risk'], 1723: ['susceptibility to vitiligo in a Korean population'], 1808: ['associated with longevity'], 1809: ['breast cancer'], 1814: ['Factor XI Deficiency'], 1883: ['Marfan syndrome'], 1964: ['lead to trimethylaminuria'], 2047: ["Friedreich's ataxia"], 2164: ['gwas', 'spatial recognition'], 2168: ['endence. Polymorphisms in the glutamate decarboxylase 1 gene associated with'], 2200: ['Duarte galactosemia'], 2267: ['late-onset noninsulin-dependent diabetes'], 2310: ['gene variant associated with deafness'], 2467: ['haematological characterization of beta-thalassaemia major'], 2556: ['associated with slightly (~30%) higher risk for azoospermia (lack of sperm) and thus male infertility in both Chinese and Japanese men'], 2627: ['Schwartz Jampel syndrome type 1 and Lethal Kniest-like syndrome'], 2640: ['modest effect on depression severity', 'risk for rheumatoid arthritis', 'quantitative traits in panic disorder'], 2705: ['Primary biliary cirrhosis'], 2725: ['herpes', 'schizophrenia', 'herpes simplex virus 1', 'schizophrenia'], 2743: ['severity of knee osteoarthritis'], 2750: ['ulcerative colitis', 'ulcerative colitis'], 2872: ['cardiac arrhythmias'], 2919: ['sickle cell anemia', 'risk for priapism'], 2979: ['epidermolysis bullosa, junctional,', 'Herlitz type'], 2996: ['weight regain', 'obesity-related genes and endometrial cancer risk'], 3010: ['coronary artery disease'], 3017: ['lipoyltransferase 1 deficiency'], 3049: ['OMIM pathogenic'], 3065: ["25% chance of Parkinson's disease", ' in their lifetime'], 3069: ['autosomal dominant Parkinson disorder'], 3116: ['lower frequency of restless legs syndrome', 'ommon sleep disorder'], 3143: ['red hair', 'low tanning'], 3215: ['methylation', 'colorectal cancer'], 3236: ['smoking'], 3239: ['lumbar disc disease'], 3245: ['increased risk for Achilles tendinopathy'], 3577: ['increased circulating natriuretic peptide and thus lower blood pressure'], 3596: ['multiple measures of blood pressure'], 3706: ['nylketonur'], 3819: ['Rhizomelic Chondrodysplasia Punctata Type 1'], 3873: ['autosomal dominant polycystic kidney disease'], 3936: ['PKHD1'], 3937: ['PKHD'], 3948: ['greater risk for gastric cancer', 'stomach can ...

# %%
# Use that mapping to create a version of the original dataframe with just the hilighted text snippets.
subset_df = original_df[original_df["id"].isin(unique_text_id_to_text_list.keys())]
subset_df["n"] = subset_df["id"].map(lambda x: len(unique_text_id_to_text_list[x]))
text_snippets = flatten([unique_text_id_to_text_list[i] for i in subset_df["id"].values])

# Extend the dataframe to duplicate each row n times where n is the number of text hilight results from the surveys.
modified_df = subset_df.reindex(np.repeat(subset_df.index.values, subset_df["n"]), method="ffill")

# Make sure that the extension occured as expected based on the number of text snippets, and add them as a new column.
assert len(modified_df) == len(text_snippets)
modified_df["snippet"] = text_snippets
modified_df.head(20)
# Out:
# /anaconda2/envs/oats/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        gene           snp                                               text  \
# 25    ABCA7     Rs3764650  Alzheimer's disease associated, based on large...
# 25    ABCA7     Rs3764650  Alzheimer's disease associated, based on large...
# 130    ABP1     Rs2268999  PMID 21488903 Association of single nucleotide...
# 130    ABP1     Rs2268999  PMID 21488903 Association of single nucleotide...
# 130    ABP1     Rs2268999  PMID 21488903 Association of single nucleotide...
# 273   AIPL1    Rs62637014  aka c.834G>A (p.Trp278Ter or W278X)This recess...
# 304   ALDOB      I5012663                    rs1800546hereditary fructosuria
# 332    ALPL      I5002774  i5002774, also known as c.211C>T or p.R71C, is...
# 393    AOC1     Rs2268999  PMID 21488903 Association of single nucleotide...
# 393    AOC1     Rs2268999  PMID 21488903 Association of single nucleotide...
# 393    AOC1     Rs2268999  PMID 21488903 Association of single nucleotide...
# 422   APOC3     Rs2542052  This SNP may be related to longevity. One stud...
# 492   ARMS2    Rs10490924  rs10490924, also known as c.205G>T, p.Ala69Ser...
# 612  BAIAP2     Rs8079781  Attention-deficit hyperactivity disorder in ad...
# 613    BAK1      Rs210138  / 23andMe blog each rs210138(G) was found to i...
# 772   BRCA1    Rs80357389  rs80357389 represents a rare variant in the BR...
# 800   BRCA1    Rs80357637  rs80357637, also known as 262delT, c.143_143de...
# 807   BRCA1    Rs80357711  rs80357711, also known as 4154delA, 4035delA, ...
# 831   BRCA1    Rs80357880  rs80357880, also known as 2224insT, c.2105_210...
# 949  CARD11  Rs1064795307                                    OMIM pathogenic
#
#         id  n                                            snippet
# 25    22.0  2      later age at onset and shorter disease course
# 25    22.0  2                                Alzheimer's disease
# 130  112.0  3                   diamine oxidase serum activities
# 130  112.0  3                           lower DAO mRNA expressio
# 130  112.0  3                               reduced DAO activity
# 273  248.0  1   or W278X)This recessively inherited mutation ...
# 304  276.0  1                             hereditary fructosuria
# 332  304.0  1  pathogenic for the infantile form of hypophosp...
# 393  112.0  3                   diamine oxidase serum activities
# 393  112.0  3                           lower DAO mRNA expressio
# 393  112.0  3                               reduced DAO activity
# 422  385.0  1  y be related to longevity. One study found tha...
# 492  450.0  1                  polypoidal choroidal vasculopathy
# 612  567.0  1     slightly lower (0.8-0.87x) risk for adult ADHD
# 613  568.0  1                                   testicular cance
# 772  713.0  1                                      breast cancer
# 800  741.0  1                       pathogenic for breast cancer
# 807  748.0  1                                      breast cancer
# 831  772.0  1                       pathogenic for breast cancer
# 949  879.0  1                                         pathogenic

# %%
# Save that dataframe as a new CSV file with just the final cleaned text snippets for each gene and SNP.
modified_df = modified_df[["gene","snp","snippet"]]
modified_df.to_csv(SNPS_AND_SNIPPETS_OUTPUT_PATH, index=False)
modified_df.tail(20)
# Out:
#         gene           snp                                            snippet
# 5588  SNAP25      Rs362988  eastern Indian attention deficit hyperactivity...
# 5609    SNX9    Rs78503206                 thinking cilantro tastes like soap
# 5633   SORL1     Rs1784931  reased (or decreased) risk for Alzheimer's dis...
# 5650    SOX5    Rs10842262        associated with non-obstructive azoospermia
# 5655    SPIB     Rs3745516  1.46 times higher odds of primary biliary cirr...
# 5670  SRD5A2      Rs523349                                     ovarian cancer
# 5680   SSUH2   Rs116840785                            rippling muscle disease
# 5680   SSUH2   Rs116840785  Novel missense mutation in the caveolin-3 gene...
# 5680   SSUH2   Rs116840785                                       cle disease.
# 5984   TNNI3      I5007731               familial hypertrophic cardiomyopathy
# 6196  UGT1A1     Rs8175347                        neonatal hyperbilirubinemia
# 6196  UGT1A1     Rs8175347                            endometrial cancer risk
# 6310  UNC13D   Rs121434354  pathogenic for familial hemophagocytic lymphoh...
# 6332   USH2A   Rs111033273  visual impairment in Usher syndrome 1b and Ush...
# 6360     VDR     Rs2107301                                    prostate cancer
# 6369   VEGFA     Rs2146323                        smaller hippocampal volumes
# 6406   VPS53   Rs587777465                 Pontocerebellar hypoplasia type 2E
# 6417     VWF      I5049117                             Von Willebrand disease
# 6434     VWF      I5049327                             Von Willebrand disease
# 6478    XIAP  Rs1085307106                                         pathogenic
